# %% [markdown]
# # Imports

# %%
import os
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.preprocessing import MinMaxScaler
from skimage import measure
import imageio
import  cv2
# %matplotlib inline

import tensorflow as tf
from tensorflow.keras import backend as K
from tensorflow.keras.models import Model,load_model
from tensorflow.keras.layers import Dense, Flatten, Conv1D, Conv2D, Input, Conv2DTranspose, Concatenate, MaxPool1D, Dropout, Reshape, Lambda, InputLayer, LeakyReLU, BatchNormalization, GaussianNoise
from keras_contrib.layers.normalization.instancenormalization import InstanceNormalization
from tensorflow.keras.optimizers import Adam 
from tensorflow.keras.losses import MeanSquaredError, kullback_leibler_divergence
from tensorflow.keras.metrics import BinaryCrossentropy
from tensorflow.keras.initializers import RandomNormal
from tensorflow.keras.constraints import Constraint
import warnings
import logging
warnings.simplefilter("ignore")
logging.getLogger("tensorflow").setLevel(logging.ERROR)

tf.autograph.set_verbosity(0)
os.environ['AUTOGRAPH_VERBOSITY'] = '0'
os.environ['TF_CPP_MIN_LOG_LEVEL'] = '0'

# %% [markdown]
# ## Test GPU

# %%
physical_devices = tf.config.list_physical_devices('GPU') 
print("GPUs available:",len(physical_devices))
# Out:
# GPUs available: 1

# %% [markdown]
# # Data preparation

# %%
def get_filenames(dimension, simulation, simmetry, score):
    if os.getcwd().split('\\')[2] == 'lucas':
        score_filename = 'E:/Lucas GAN/Dados/4- Mechanical_scores/%s/%sD/%s/%s.csv' %(simulation,dimension,simmetry,score)
        geom_epoch_dirs = 'E:/Lucas GAN/Dados/7- Perfomance_data/%sD/geom_epoch/%s/%s/' %(dimension,simmetry,score)
        gif_filename = 'E:/Lucas GAN/Dados/7- Perfomance_data/%sD/geom_epoch/%s/%s.gif' %(dimension,simmetry,score)
        tmp_models_dir = 'C:/Users/lucas/OneDrive/Documentos/GitHub/INT/Manufatura Aditiva/Simulacao-GAN/Pipeline/3- Machine_learning/GAN/tmp_models/GAN/'
        models_dir = 'D:/Lucas GAN/Dados/5- Models/cGAN/%sD/%s/%s/'%(dimension,simmetry,score)
        arrays_dir = 'E:/Lucas GAN/Dados/1- Arranged_geometries/GAN/%s/%s/' % (simmetry,score)
    else:
        score_filename = 'D:/Lucas GAN/Dados/4- Mechanical_scores/%s/%sD/%s/%s.csv' %(simulation,dimension,simmetry,score)
        geom_epoch_dirs = 'D:/Lucas GAN/Dados/7- Perfomance_data/%sD/geom_epoch/%s/%s/' %(dimension,simmetry,score)
        gif_filename = 'D:/Lucas GAN/Dados/7- Perfomance_data/%sD/geom_epoch/%s/%s.gif' %(dimension,simmetry,score)
        tmp_models_dir = 'C:/Users/lucas.barbosa/Documents/GitHub/INT/Manufatura Aditiva/Simulacao-GAN/Pipeline/3- Machine_learning/GAN/tmp_models/GAN/'
        models_dir = 'D:/Lucas GAN/Dados/5- Models/GAN/%sD/%s/%s/'%(dimension,simmetry,score)
        arrays_dir = 'D:/Lucas GAN/Dados/1- Arranged_geometries/GAN/%s/%s/' % (simmetry,score)


    return score_filename, geom_epoch_dirs, gif_filename, tmp_models_dir, models_dir, arrays_dir

def load_data(score_filename, cutoff, bins, soft=False, balance=False, plot=False):  
    def find_closest(arr, val):
       idx = np.abs(arr - val).argmin()
       return arr[idx]
    data = np.loadtxt(score_filename,delimiter=',')
    X = data[:,1:-1]
    size = int(np.sqrt(X.shape[1]))
    X = X.reshape((X.shape[0],size,size,1))

    y = data[:,-1]
    y = y.reshape((y.shape[0],1))
    y = y[np.argsort(y[:,0])]
    total_size = y.shape[0]

    if plot:
        sns.histplot(y, legend=True, bins=bins, color='b')
    
    cutoff = find_closest(bins,cutoff)
    idxs_good = np.where(y>cutoff)[0]
    y = y[idxs_good]
    X = X[idxs_good]
    min_bin = idxs_good.shape[0]

    if balance:
        bins_good = bins[np.where(bins>=cutoff)]
        for i in range(len(bins_good)-1):
            l,u = bins_good[i:i+2]
            idx_bin = np.where((y>=l) & (y<u))[0]
            y_bin = y[idx_bin]
            min_bin = min(min_bin,y_bin.shape[0])

        X_balanced = np.zeros((min_bin*(bins_good.shape[0]-1),X.shape[1],X.shape[2],X.shape[3]))
        y_balanced = np.zeros((min_bin*(bins_good.shape[0]-1),1))
        y_ = np.ones((min_bin*(bins_good.shape[0]-1),1))

        for i in range(len(bins_good)-1):
            l,u = bins_good[i:i+2]
            idx_bin = np.where((y>=l) & (y<u))[0]
            X_bin = X[idx_bin]
            y_bin = y[idx_bin]

            idx_bin = np.random.choice(y_bin.shape[0],min_bin)
            X_bin = X_bin[idx_bin]
            y_bin = y_bin[idx_bin]

            X_balanced[min_bin*i:min_bin*(i+1)] = X_bin
            y_balanced[min_bin*i:min_bin*(i+1)] = y_bin

        X = X_balanced
        y = y_

        if plot:
            sns.histplot(y_balanced, legend=True, bins=bins, color='r')

    if soft:
        y = np.random.choice(np.linspace(0.7,1.2,6)).round(1)*np.ones(y.shape)
    
    plt.legend(['raw','Balanced'])
    
    print(f"Good = %.2f %%"%(100*len(y)/total_size))
    
    return X, y, size

dimension = 2
simulation = '-m'
simulation = {'-m':'MATLAB','-r':'RTGA'}[simulation]
simmetry = 'p4'
score = 'isotropy'
score_filename,_,_,_,_,_ = get_filenames(dimension, simulation, simmetry, score)

cutoff = 0.6
bins= np.linspace(0,1,41).round(3)
soft = False
plot = True
balance = True

X, y, size = load_data(score_filename, cutoff, bins, soft=soft, balance=balance, plot=plot)
# Out:
# Good = 44.80 %

# %% [markdown]
# # Models definition

# %% [markdown]
# ## Generator

# %%
def setup_G(input_G,output_G,size):
    size = int(size/2)
    in_G = Input(shape=(input_G,),name="G-Latent-Input")

    # foundation for 8x8 image
    n_nodes = input_G * size * size
    out_G = Dense(n_nodes,activation=LeakyReLU(alpha=0.2),name="G-FoundationLayer")(in_G)
    out_G = Reshape((size, size, 128),name="G-ReshapeLayer")(out_G)
    # upsample to 16x16
    out_G = Conv2DTranspose(128, (4,4), strides=(2,2), padding='same',activation=LeakyReLU(alpha=0.2),name="G-HiddenLayer1")(out_G)
    out_G = Conv2D(1, (size,size), activation='sigmoid', padding='same',name="G-Geometry-Output")(out_G)

    # model = Model(name='Generator',inputs=in_G,outputs=[out_G,out_porosity,out_validity])
    model = Model(name='Generator',inputs=in_G,outputs=[out_G])
    return model
G_test = setup_G(128,256,16)
G_test.summary()
tf.keras.utils.plot_model(G_test)
# Out:
# Model: "Generator"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  G-Latent-Input (InputLayer)  [(None, 128)]            0
#
#  G-FoundationLayer (Dense)   (None, 8192)              1056768
#
#  G-ReshapeLayer (Reshape)    (None, 8, 8, 128)         0
#
#  G-HiddenLayer1 (Conv2DTrans  (None, 16, 16, 128)      262272
#  pose)
#
#  G-Geometry-Output (Conv2D)  (None, 16, 16, 1)         8193
#
# =================================================================
# Total params: 1,327,233
# Trainable params: 1,327,233
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# ## Discriminator

# %%
def wasserstein_loss():
    def custom_loss(y_true, y_pred):
	    return K.mean(y_true * y_pred)
    return custom_loss

def porosity_loss():
    def custom_por_loss(y_true,y_pred):
        # size = y_pred.shape[1]*y_pred.shape[2]
        y_pred = K.round(y_pred)
        por_true = K.sum(K.sum(K.sum(y_true,axis=1),axis=1),axis=1)
        por_pred = K.sum(K.sum(K.sum(y_pred,axis=1),axis=1),axis=1)
        mse = tf.cast((por_true-por_pred)**2,tf.float32)
        return mse
    return custom_por_loss

def validity_loss():
    def custom_val_loss(y_true, y_pred):
        # @tf.function
        def connectivity_losss(element):
            size = element.shape[0]
            element = element.numpy().reshape((size,size))
            labels = measure.label(element,connectivity=1)
            return len(np.unique(labels))

        def simmetry_loss(element):
           return 0
            
        y_pred = K.round(y_pred)
        con_loss = tf.map_fn(fn=connectivity_losss, elems=y_pred)
        if simmetry[1:] in ['4m','4g']:
            sim_loss = tf.map_fn(fn=simmetry_loss, elems=y_pred)
            return con_loss + sim_loss
        return con_loss

    return custom_val_loss
    
def setup_D(input_D,loss,lr,alpha_por,alpha_val,normalize=False):
    #define model
    in_D = Input(shape=input_D,name="D-Geometry-Input")

    out_D = GaussianNoise(0.1,name="D-NoiseLayer1")(in_D)
    out_D = Conv2D(64, (3,3), strides=(2, 2), padding='same',name="D-HiddenLayer1")(out_D)
    if normalize:
        out_D = InstanceNormalization(name="D-InstanceNormalization-Layer1")(out_D)
    out_D = LeakyReLU(alpha=0.2,name="D-Activation-Layer1")(out_D)

    out_D = GaussianNoise(0.1,name="D-NoiseLayer2")(out_D)
    out_D = Dropout(0.4,name="D-DropoutLayer1")(out_D)
    out_D = Conv2D(64, (3,3), strides=(2, 2), padding='same',name="D-HiddenLayer2")(out_D)
    if normalize:
        out_D = InstanceNormalization(name="D-InstanceNormalization-Layer2")(out_D)
    out_D = LeakyReLU(alpha=0.2,name="D-Activation-Layer2")(out_D)

    out_D = GaussianNoise(0.1,name="D-NoiseLayer3")(out_D)
    out_D = Dropout(0.4,name="D-DropoutLayer2")(out_D)
    out_D = Flatten(name="D-FlattenLayer")(out_D)
    out_D = Dense(1, activation='sigmoid',name="D-Classification-Output")(out_D)

    # porosity branch
    out_porosity = Lambda(lambda x: x,name='D-Porosity-Output')(in_D)

    # validity branch
    out_validity = Lambda(lambda x: x,name='D-Validity-Output')(in_D)

    opt = Adam(learning_rate=lr, beta_1=0.5)
    
    model = Model(
                name='Discriminator', \
                # inputs=[in_D,in_porosity,in_validity], \
                inputs=[in_D], \
                outputs=[out_D,out_porosity,out_validity])

    loss_func = {'bce':'binary_crossentropy','wl':wasserstein_loss,'kld':kullback_leibler_divergence}[loss]
    model.compile(
                loss=[loss_func,porosity_loss(),validity_loss()], \
                loss_weights=[1.0,0.0,0.0], \
                optimizer='adam', \
                metrics=['accuracy'], \
                run_eagerly=True)
    return model

D_test = setup_D((16,16,1),'bce',1e-4,0.01,0.01,True)
D_test.summary()
tf.keras.utils.plot_model(D_test)
# Out:
# Model: "Discriminator"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  D-Geometry-Input (InputLayer)  [(None, 16, 16, 1)]  0           []
#
#  D-NoiseLayer1 (GaussianNoise)  (None, 16, 16, 1)    0           ['D-Geometry-Input[0][0]']
#
#  D-HiddenLayer1 (Conv2D)        (None, 8, 8, 64)     640         ['D-NoiseLayer1[0][0]']
#
#  D-InstanceNormalization-Layer1  (None, 8, 8, 64)    2           ['D-HiddenLayer1[0][0]']
#   (InstanceNormalization)
#
#  D-Activation-Layer1 (LeakyReLU  (None, 8, 8, 64)    0           ['D-InstanceNormalization-Layer1[
#  )                                                               0][0]']
#
#  D-NoiseLayer2 (GaussianNoise)  (None, 8, 8, 64)     0           ['D-Activation-Layer1[0][0]']
#
#  D-DropoutLayer1 (Dropout)      (None, 8, 8, 64)     0           ['D-NoiseLayer2[0][0]']
#
#  D-HiddenLayer2 (Conv2D)        (None, 4, 4, 64)     36928       ['D-DropoutLayer1[0][0]']
#
#  D-InstanceNormalization-Layer2  (None, 4, 4, 64)    2           ['D-HiddenLayer2[0][0]']
#   (InstanceNormalization)
#
#  D-Activation-Layer2 (LeakyReLU  (None, 4, 4, 64)    0           ['D-InstanceNormalization-Layer2[
#  )                                                               0][0]']
#
#  D-NoiseLayer3 (GaussianNoise)  (None, 4, 4, 64)     0           ['D-Activation-Layer2[0][0]']
#
#  D-DropoutLayer2 (Dropout)      (None, 4, 4, 64)     0           ['D-NoiseLayer3[0][0]']
#
#  D-FlattenLayer (Flatten)       (None, 1024)         0           ['D-DropoutLayer2[0][0]']
#
#  D-Classification-Output (Dense  (None, 1)           1025        ['D-FlattenLayer[0][0]']
#  )
#
#  D-Porosity-Output (Lambda)     (None, 16, 16, 1)    0           ['D-Geometry-Input[0][0]']
#
#  D-Validity-Output (Lambda)     (None, 16, 16, 1)    0           ['D-Geometry-Input[0][0]']
#
# ==================================================================================================
# Total params: 38,597
# Trainable params: 38,597
# Non-trainable params: 0
# __________________________________________________________________________________________________

# %% [markdown]
# ## Setup GAN

# %%
def setup_GAN(G_model,D_model,loss,alpha_por,alpha_val,lr,size):
    D_model.trainable = False
    in_G = G_model.input
    out_GAN = D_model(G_model(in_G))
    
    opt = Adam(learning_rate=lr, beta_1=0.5)
    
    model = Model(name='GAN',inputs=in_G,outputs=out_GAN)
    loss_func = {'bce':'binary_crossentropy','wl':wasserstein_loss,'kld':kullback_leibler_divergence}[loss]
    model.compile(
                loss=[loss_func,porosity_loss(),validity_loss()], \
                loss_weights=[1.0,alpha_por,alpha_val], \
                optimizer='adam', \
                metrics=['accuracy'], \
                run_eagerly=True)
    return model

GAN_test = setup_GAN(setup_G(128,256,16),setup_D((16,16,1),'bce',1e-4,0.01,0.01),'bce',0.01,0.01,1e-4,16)
GAN_test.summary()
tf.keras.utils.plot_model(GAN_test)
# Out:
# Model: "GAN"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  G-Latent-Input (InputLayer)  [(None, 128)]            0
#
#  Generator (Functional)      (None, 16, 16, 1)         1327233
#
#  Discriminator (Functional)  [(None, 1),               38593
#                               (None, 16, 16, 1),
#                               (None, 16, 16, 1)]
#
# =================================================================
# Total params: 1,365,826
# Trainable params: 1,327,233
# Non-trainable params: 38,593
# _________________________________________________________________

# %% [markdown]
# # Aux functions

# %% [markdown]
# ## For geometry manipulation

# %%
def create_unit(element,size,simmetry):
  if simmetry[1:2] == '4':
    unit_size = 2*size
    # fold_size = np.random.choice(4,1)[0]
    unit = np.ones((2*size,2*size))*(-1)
    h,w = element.shape
    for i in range(h):
      for j in range(w):
        el = element[i,j]
        
        j_ = [j,w-1-i,2*h-1-j,i+w]
        i_ = [i+w,j,w-1-i,2*h-1-j]
        # (1,7)->(7,14)->(14,8)->(8,1)
        for (k,l) in list(zip(i_,j_)):
          unit[k,l]  = el
    return unit

def create_arrange(unit,rows,cols):
  size = unit.shape[0]
  arrange = np.zeros((rows*size,cols*size))
  for i in range(unit.shape[0]):
    for j in range(unit.shape[1]):
      for row in range(rows):
        for col in range(cols):
          arrange[j+row*size,i+col*size] = unit[j,i]
  
  return arrange

def get_porosity(geom):
    voids = np.where(geom == 0.0)[0].shape[0]

    return voids/(geom.shape[0]*geom.shape[1])

# %% [markdown]
# ## For GAN

# %%
def generate_fake_samples(G_model, input_G, n_samples, method):
    # generate points in latent space
    X_input = generate_input_G(input_G, n_samples,method)
    # predict outputs
    X = G_model.predict(X_input,verbose = 0)
    # create 'fake' class labels (0)
    y = np.zeros((n_samples, 1))
    return X,y

def generate_input_G(input_G, n_samples, method):

    if method == 'normal':
        # generate points in the latent space
        X_input = np.random.randn(input_G * n_samples)
        # reshape into a batch of inputs for the network
        X_input = X_input.reshape(n_samples, input_G)
    if method == 'uniform':
        X_input = np.random.uniform(n_samples,input_G)
    if method == 'spherical':
        X_input = np.random.randn(input_G * n_samples)
        # reshape into a batch of inputs for the network
        X_input = X_input.reshape(n_samples, input_G)
        X_input /= np.linalg.norm(X_input, axis=0)/3.0
    return X_input

def generate_real_samples(dataset, y, n_samples):
    # choose random instances
    idx = np.random.randint(0, dataset.shape[0], n_samples)
    # retrieve selected images
    X = dataset[idx]
    # generate 'real' class labels (1)
    y = y[idx]
    return X, y

def summarize_performance(epoch,porosity,G_model, D_model, dataset, y, input_G, sampling_method, n_samples=100):
    # prepare real samples
    X_real, y_real = generate_real_samples(dataset, y, n_samples)
    # evaluate discriminator on real examples
    _,_,_,_,acc_real,_,_ = D_model.evaluate(x=[X_real], y=[y_real,porosity*np.ones(X_real.shape),np.zeros(X_real.shape)], verbose=0)
    # prepare fake examples
    X_fake, y_fake = generate_fake_samples(G_model, input_G, n_samples, sampling_method)
    # evaluate discriminator on fake examples
    _,_,_,_,acc_fake,_,_ = D_model.evaluate(x=[X_fake], y=[y_fake,porosity*np.ones(X_fake.shape),np.zeros(X_fake.shape)], verbose=0)
    # summarize discriminator performance
    return  acc_real,acc_fake

# Filter per porosity
def porosity_match(geoms,porosity,tol):
    geoms_ = []
    passed = 0
    for i in range(geoms.shape[0]):
        g =geoms[i,:,:,0]
        size = g.shape[0]
        g = g.reshape((size*size,))
        p = 1 - np.sum(g)/(size*size)
        if p >= porosity-tol and p <= porosity+tol:
            geoms_.append(g.reshape((size,size)))
            passed += 1
    return passed/len(geoms),np.array(geoms_).reshape((passed,size,size,1))

# %% [markdown]
# # Training GAN

# %%
def train_GAN(X, y, G_model, D_model, GAN_model, input_G, porosity, tol_porosity, batch_size, num_epochs, sampling_method, tmp_models_dir, geom_epoch_dirs, seed_geom_gif, tol_fail, alpha_por, alpha_val, vstack=True, save=True, plot=False, verbose_loss=False, verbose_acc=False):
    def train_D(X,y,half_batch):
        if vstack:
            X_real,y_real = generate_real_samples(X,y,half_batch)
            X_fake,y_fake = generate_fake_samples(G_model,input_G,half_batch,sampling_method)            

            X, y = np.vstack((X_real, X_fake)), np.vstack((y_real, y_fake))
            
            if verbose_loss:
                D_loss = D_model.train_on_batch(x=[X], y=[y,porosity*np.ones(X.shape),0*np.ones(X.shape)],return_dict=True)
                D_loss = D_loss['loss']
            else:
                D_loss = D_model.train_on_batch(x=[X], y=[y,porosity*np.ones(X.shape),0*np.ones(X.shape)])
                D_loss = D_loss[0]

        else:
            X_real,y_real = generate_real_samples(X,y,half_batch)
            X_fake,y_fake = generate_fake_samples(G_model,input_G,half_batch,sampling_method)            

            if verbose_loss:
                D_loss_real = D_model.train_on_batch(x=[X_real], y=[y_real,porosity*np.ones(X_real.shape),0*np.ones(X_real.shape)],return_dict=True)
                D_loss_real = D_loss_real['loss']
                D_loss_fake = D_model.train_on_batch(x=[X_fake], y=[y_fake,porosity*np.ones(X_fake.shape),0*np.ones(X_fake.shape)],return_dict=True)
                D_loss_fake = D_loss_fake['loss']
            else:
                D_loss_real = D_model.train_on_batch(x=[X_real], y=[y_real,porosity*np.ones(X_real.shape),0*np.ones(X_real.shape)])
                D_loss_real = D_loss_real[0]
                D_loss_fake = D_model.train_on_batch(x=[X_fake], y=[y_fake,porosity*np.ones(X_fake.shape),0*np.ones(X_fake.shape)])
                D_loss_fake = D_loss_fake[0]

            D_loss = (D_loss_real+D_loss_fake)/2
            

        return D_loss

    def swap_D(tmp_models_dir):
        D_files = os.listdir(tmp_models_dir+'/D/')
        D_file = np.random.choice(D_files,1)[0]
        D_model_swap = load_model(tmp_models_dir+'/D/'+D_file, custom_objects={'custom_por_loss':porosity_loss(),'custom_val_loss':validity_loss(),'InstanceNormalization':InstanceNormalization()})
        return (D_files.index(D_file)+1)*10, D_model_swap.get_weights()
        
    def train_G(X_shape,alpha_por,alpha_val):
        X_GAN = generate_input_G(input_G, batch_size, sampling_method)
        y_GAN = np.ones((batch_size, 1))

        if verbose_loss:
            G_loss_list = GAN_model.train_on_batch(x=X_GAN, y=[y_GAN,porosity*np.ones(X_shape),0*np.ones(X_shape)],return_dict=True)
            idxs = list(G_loss_list.keys())
        else:
            G_loss_list = GAN_model.train_on_batch(x=X_GAN, y=[y_GAN,porosity*np.ones(X_shape),0*np.ones(X_shape)])
            idxs = [0,1,2,3]

        G_total_loss = G_loss_list[idxs[0]]
        G_loss = G_loss_list[idxs[1]]
        G_por_loss = alpha_por*G_loss_list[idxs[2]]
        G_val_loss = alpha_val*G_loss_list[idxs[3]]

        return G_total_loss,G_loss,G_por_loss,G_val_loss

    def clean_tmp_models(tmp_models_dir):
        for file in os.listdir(tmp_models_dir+'G/'):
            os.remove(tmp_models_dir+'G/'+file)

        for file in os.listdir(tmp_models_dir+'D/'):
            os.remove(tmp_models_dir+'D/'+file)

        for geom_file in os.listdir(geom_epoch_dirs):
            os.remove(geom_epoch_dirs+geom_file)

    # remove previous tmp models files
    if save:
        clean_tmp_models(tmp_models_dir)

    batch_per_epoch = int(X.shape[0] /batch_size)
    half_batch = int(batch_size/2)
    
    G_losses = []
    G_por_losses = []
    G_val_losses = []
    D_losses = []

    accs_real = []
    accs_fake = []
    pors_match = []
    stds = []
    
    fig,ax = plt.subplots(1,3);
    fig.set_size_inches((24,8))

    epoch_count = 0
    while epoch_count < num_epochs:
        G_losses_epoch = []
        G_por_losses_epoch = []
        G_val_losses_epoch = []
        D_losses_epoch = []
        batch_count = 0
        while batch_count < batch_per_epoch:
            # train D
            D_loss = train_D(X,y,half_batch)

            # check failure mode
            D_losses_epoch.append(D_loss)

            # train G
            G_total_loss,G_loss,G_por_loss,G_val_loss = train_G((batch_size,X.shape[1],X.shape[2],X.shape[3]),alpha_por,alpha_val)
            G_losses_epoch.append(G_loss)
            G_por_losses_epoch.append(G_por_loss)
            G_val_losses_epoch.append(G_val_loss)

            if verbose_loss: 
                print('>%d, %d/%d, D_loss=%.3f, G_loss=%.3f' % (epoch_count+1, batch_count+1, batch_per_epoch,  D_loss, G_total_loss))

            if (D_loss <= tol_fail or np.std(D_losses[-5:])<=tol_fail) and epoch_count >= 10:
                epoch, weights = swap_D(tmp_models_dir)
                D_model.set_weights(weights)
                print('Failure Mode. Swapping Discriminator model for epoch %d'%epoch)

            batch_count += 1

        epoch_count +=1 
        
        G_losses.append(np.array(G_losses_epoch).mean())
        G_por_losses.append(np.array(G_por_losses_epoch).mean())
        G_val_losses.append(np.array(G_val_losses_epoch).mean())
        D_losses.append(np.array(D_losses_epoch).mean())
        # export model
        if epoch_count % 10 == 0:
            acc_real,acc_fake = summarize_performance(epoch_count,porosity,G_model,D_model,X,y,input_G,sampling_method)
            accs_real.append(acc_real)
            accs_fake.append(acc_fake)

            X_test = generate_input_G(input_G,1000,sampling_method)
            geoms = G_model.predict(X_test, verbose=0)
            geoms = np.array(geoms)
            por_match,_ = porosity_match(geoms, porosity, tol_porosity)
            pors_match.append(por_match)

            score = D_model.predict([geoms],verbose=0)[0]
            std = score.std()
            stds.append(std)

            if save:
                G_model.save(tmp_models_dir+'/G/epoch_%03d_por_%.2f_std_%.2f.h5'%(epoch_count, por_match, std))
                D_model.save(tmp_models_dir+'/D/epoch_%03d_real_%.2f_fake_%.2f.h5'%(epoch_count, acc_real, acc_fake))
                
            if verbose_acc:
                os.system('cls')
                print('>Epoch: %i Porosity match: %.0f%% Std: %.2f real: %.0f%% fake: %.0f%%' % (epoch_count,  por_match*100, std, acc_real*100, acc_fake*100))

        # save geometry
        if epoch_count % 5 == 0:
            geom_gif_filename = geom_epoch_dirs + 'epoch_%03d.png'%(epoch_count)
            elem_gif = G_model.predict(seed_geom_gif, verbose=0)
            size = elem_gif.shape[1]
            elem_gif = elem_gif.reshape((size,size))
            ax[0].imshow(elem_gif,cmap='Greys');
            ax[0].axis('off')

            unit_gif = create_unit(elem_gif,size,'p4') 
            ax[1].imshow(unit_gif,cmap='Greys');
            ax[1].axis('off')

            arrange_gif = create_arrange(unit_gif,3,3)
            ax[2].imshow(arrange_gif,cmap='Greys');
            ax[2].axis('off')
            plt.savefig(geom_gif_filename, bbox_inches='tight')
    
    G_losses = np.array(G_losses)
    G_por_losses = np.array(G_por_losses)
    G_val_losses = np.array(G_val_losses)
    D_losses = np.array(D_losses)

    if plot:
        plt.figure(figsize=((10,8)))
        plt.plot(list(range(1,num_epochs+1)),D_losses,label='D Loss')
        plt.title('Loss')
        plt.ylabel('Loss')
        plt.xlabel('Epoch')
        plt.plot(list(range(1,num_epochs+1)),G_losses,label='G Loss')
        plt.plot(list(range(1,num_epochs+1)),G_por_losses,label='Porosity loss')
        plt.plot(list(range(1,num_epochs+1)),G_val_losses,label='Validity loss')
        plt.legend()
        plt.show()

        fig, ax = plt.subplots(3)
        fig.tight_layout(pad=0.75)
        fig.set_size_inches((10,8))
        ax[0].plot(list(range(1,num_epochs+1,10)),accs_fake,label='Accuracy fake')
        ax[0].set_xlabel('Epoch')
        ax[0].plot(list(range(1,num_epochs+1,10)),accs_real,label='Accuracy real')
        ax[0].legend()

        ax[1].plot(list(range(1,num_epochs+1,10)),pors_match)
        ax[1].set_title('Porosity match')
        ax[1].set_xlabel('Epoch')
        
        ax[2].plot(list(range(1,num_epochs+1,10)),stds)
        ax[2].set_title('Std dev')
        ax[2].set_xlabel('Epoch')
        ax[1].legend()
        plt.show()

# %%
# data origin parameters
dimension = 2
simulation = '-m'
simulation = {'-m':'MATLAB','-r':'RTGA'}[simulation]
simmetry = 'p4'
score = 'isotropy'

# data processing parameters
score_filename, geom_epoch_dirs, gif_filename, tmp_models_dir, models_dir, arrays_dir = get_filenames(dimension, simulation, simmetry, score)
cutoff = 0.8
bins= np.linspace(0,1,41).round(3)
soft = False
plot = True
balance = True
X, y, size = load_data(score_filename, cutoff, bins, soft=soft, balance=balance, plot = plot)

# GAN dimensions
input_G = 128
output_G = input_D = X.shape[1:]
output_D = 1

# training parameters
sampling_method = 'normal'
loss = 'bce' 
num_epochs = 300
batch_size = 64
lr = 1e-4 
alpha_por = 1e-4 #2e-4
alpha_val = 8e-2 #8e-2
vstack=False

# style loss parameters
porosity = 0.55
tol_porosity = 0.02
tol_fail = 5e-2

# setup models
G = setup_G(input_G,output_G,size)
normalize=True
D = setup_D(input_D,loss,lr,alpha_por,alpha_val,normalize)
GAN = setup_GAN(G,D,loss,alpha_por,alpha_val,lr,size)

# metrics paramaters
plot=True
save=True
verbose_loss=True
verbose_acc=True

seed_geom_gif = np.random.randn(input_G).reshape(1, input_G)
train_GAN(X,y,G,D,GAN,input_G,porosity,tol_porosity,batch_size,num_epochs,sampling_method,tmp_models_dir,geom_epoch_dirs,seed_geom_gif,tol_fail,alpha_por, alpha_val, save=save, vstack=vstack,plot=plot,verbose_loss=verbose_loss,verbose_acc=verbose_acc)
# Out:
# Good = 22.40 %
# >1, 1/3, D_loss=1.540, G_loss=1.341
# >1, 2/3, D_loss=0.824, G_loss=6.407
# >1, 3/3, D_loss=0.754, G_loss=5.778
# >2, 1/3, D_loss=0.563, G_loss=4.783
# >2, 2/3, D_loss=0.737, G_loss=4.447
# >2, 3/3, D_loss=0.563, G_loss=3.642
# >3, 1/3, D_loss=0.823, G_loss=3.019
# >3, 2/3, D_loss=0.925, G_loss=2.555
# >3, 3/3, D_loss=1.356, G_loss=2.480
# >4, 1/3, D_loss=1.136, G_loss=2.503
# >4, 2/3, D_loss=1.015, G_loss=2.592
# >4, 3/3, D_loss=0.682, G_loss=3.001
# >5, 1/3, D_loss=0.710, G_loss=3.315
# >5, 2/3, D_loss=0.614, G_loss=3.585
# >5, 3/3, D_loss=0.505, G_loss=3.564
# >6, 1/3, D_loss=0.527, G_loss=3.987
# >6, 2/3, D_loss=0.346, G_loss=3.941
# >6, 3/3, D_loss=0.342, G_loss=4.091
# >7, 1/3, D_loss=0.231, G_loss=4.424
# >7, 2/3, D_loss=0.231, G_loss=4.650
# >7, 3/3, D_loss=0.182, G_loss=4.732
# >8, 1/3, D_loss=0.126, G_loss=4.734
# >8, 2/3, D_loss=0.100, G_loss=5.351
# >8, 3/3, D_loss=0.063, G_loss=5.114
# >9, 1/3, D_loss=0.092, G_loss=5.341
# >9, 2/3, D_loss=0.073, G_loss=5.789
# >9, 3/3, D_loss=0.072, G_loss=6.025
# >10, 1/3, D_loss=0.099, G_loss=6.104
# >10, 2/3, D_loss=0.075, G_loss=6.396
# >10, 3/3, D_loss=0.090, G_loss=6.468
# >Epoch: 10 Porosity match: 0% Std: 0.29 real: 100% fake: 89%
# >11, 1/3, D_loss=0.188, G_loss=6.196
# >11, 2/3, D_loss=0.130, G_loss=6.005
# >11, 3/3, D_loss=0.224, G_loss=6.382
# >12, 1/3, D_loss=0.162, G_loss=6.673
# >12, 2/3, D_loss=0.214, G_loss=5.989
# >12, 3/3, D_loss=0.173, G_loss=5.002
# >13, 1/3, D_loss=0.187, G_loss=5.573
# Failure Mode. Swapping Discriminator model for epoch 10
# >13, 2/3, D_loss=1.238, G_loss=1.907
# Failure Mode. Swapping Discriminator model for epoch 10
# >13, 3/3, D_loss=1.340, G_loss=1.196
# Failure Mode. Swapping Discriminator model for epoch 10
# >14, 1/3, D_loss=1.600, G_loss=1.057
# >14, 2/3, D_loss=0.750, G_loss=1.270
# >14, 3/3, D_loss=0.532, G_loss=2.260
# >15, 1/3, D_loss=0.515, G_loss=3.477
# >15, 2/3, D_loss=0.695, G_loss=3.391
# >15, 3/3, D_loss=0.799, G_loss=2.971
# >16, 1/3, D_loss=0.957, G_loss=2.729
# >16, 2/3, D_loss=1.024, G_loss=2.392
# >16, 3/3, D_loss=0.875, G_loss=2.310
# >17, 1/3, D_loss=0.742, G_loss=2.317
# >17, 2/3, D_loss=0.777, G_loss=2.533
# >17, 3/3, D_loss=0.644, G_loss=2.573
# >18, 1/3, D_loss=0.587, G_loss=2.604
# >18, 2/3, D_loss=0.534, G_loss=2.906
# >18, 3/3, D_loss=0.521, G_loss=3.107
# >19, 1/3, D_loss=0.464, G_loss=3.350
# >19, 2/3, D_loss=0.465, G_loss=3.324
# >19, 3/3, D_loss=0.440, G_loss=3.109
# >20, 1/3, D_loss=0.497, G_loss=3.061
# >20, 2/3, D_loss=0.337, G_loss=3.117
# >20, 3/3, D_loss=0.236, G_loss=3.071
# >Epoch: 20 Porosity match: 0% Std: 0.04 real: 82% fake: 100%
# >21, 1/3, D_loss=0.243, G_loss=3.301
# >21, 2/3, D_loss=0.293, G_loss=3.288
# >21, 3/3, D_loss=0.267, G_loss=3.341
# >22, 1/3, D_loss=0.292, G_loss=3.387
# >22, 2/3, D_loss=0.193, G_loss=3.554
# >22, 3/3, D_loss=0.209, G_loss=3.914
# >23, 1/3, D_loss=0.222, G_loss=3.953
# >23, 2/3, D_loss=0.168, G_loss=4.140
# >23, 3/3, D_loss=0.224, G_loss=4.070
# >24, 1/3, D_loss=0.140, G_loss=4.040
# >24, 2/3, D_loss=0.154, G_loss=4.386
# >24, 3/3, D_loss=0.169, G_loss=4.242
# >25, 1/3, D_loss=0.193, G_loss=4.527
# >25, 2/3, D_loss=0.154, G_loss=4.228
# >25, 3/3, D_loss=0.109, G_loss=4.521
# >26, 1/3, D_loss=0.160, G_loss=4.392
# Failure Mode. Swapping Discriminator model for epoch 10
# >26, 2/3, D_loss=2.479, G_loss=1.427
# Failure Mode. Swapping Discriminator model for epoch 10
# >26, 3/3, D_loss=2.226, G_loss=1.446
# Failure Mode. Swapping Discriminator model for epoch 20
# >27, 1/3, D_loss=0.297, G_loss=3.448
# >27, 2/3, D_loss=0.295, G_loss=3.680
# >27, 3/3, D_loss=0.368, G_loss=4.066
# >28, 1/3, D_loss=0.356, G_loss=3.937
# >28, 2/3, D_loss=0.387, G_loss=4.021
# >28, 3/3, D_loss=0.449, G_loss=3.999
# >29, 1/3, D_loss=0.365, G_loss=3.634
# >29, 2/3, D_loss=0.305, G_loss=3.465
# >29, 3/3, D_loss=0.258, G_loss=3.530
# >30, 1/3, D_loss=0.293, G_loss=3.282
# >30, 2/3, D_loss=0.250, G_loss=3.391
# >30, 3/3, D_loss=0.247, G_loss=3.259
# >Epoch: 30 Porosity match: 0% Std: 0.01 real: 96% fake: 100%
# >31, 1/3, D_loss=0.226, G_loss=3.636
# >31, 2/3, D_loss=0.237, G_loss=3.490
# >31, 3/3, D_loss=0.223, G_loss=3.585
# >32, 1/3, D_loss=0.190, G_loss=3.683
# >32, 2/3, D_loss=0.174, G_loss=3.864
# >32, 3/3, D_loss=0.144, G_loss=4.015
# >33, 1/3, D_loss=0.116, G_loss=4.077
# >33, 2/3, D_loss=0.106, G_loss=4.135
# >33, 3/3, D_loss=0.167, G_loss=4.463
# >34, 1/3, D_loss=0.130, G_loss=4.390
# >34, 2/3, D_loss=0.091, G_loss=4.568
# >34, 3/3, D_loss=0.114, G_loss=4.582
# >35, 1/3, D_loss=0.064, G_loss=4.604
# >35, 2/3, D_loss=0.047, G_loss=4.861
# Failure Mode. Swapping Discriminator model for epoch 20
# >35, 3/3, D_loss=0.370, G_loss=3.126
# >36, 1/3, D_loss=0.275, G_loss=3.147
# Failure Mode. Swapping Discriminator model for epoch 10
# >36, 2/3, D_loss=2.566, G_loss=1.434
# Failure Mode. Swapping Discriminator model for epoch 10
# >36, 3/3, D_loss=2.430, G_loss=1.458
# Failure Mode. Swapping Discriminator model for epoch 10
# >37, 1/3, D_loss=2.080, G_loss=1.494
# >37, 2/3, D_loss=0.922, G_loss=2.055
# >37, 3/3, D_loss=0.468, G_loss=3.291
# >38, 1/3, D_loss=0.472, G_loss=4.296
# >38, 2/3, D_loss=0.790, G_loss=4.869
# >38, 3/3, D_loss=0.970, G_loss=4.767
# >39, 1/3, D_loss=0.704, G_loss=4.421
# >39, 2/3, D_loss=0.792, G_loss=4.086
# >39, 3/3, D_loss=0.668, G_loss=3.536
# >40, 1/3, D_loss=0.455, G_loss=3.239
# >40, 2/3, D_loss=0.477, G_loss=3.020
# >40, 3/3, D_loss=0.459, G_loss=2.759
# >Epoch: 40 Porosity match: 0% Std: 0.00 real: 89% fake: 100%
# >41, 1/3, D_loss=0.507, G_loss=2.566
# >41, 2/3, D_loss=0.494, G_loss=2.594
# >41, 3/3, D_loss=0.372, G_loss=2.729
# >42, 1/3, D_loss=0.324, G_loss=2.777
# >42, 2/3, D_loss=0.410, G_loss=2.880
# >42, 3/3, D_loss=0.268, G_loss=3.134
# >43, 1/3, D_loss=0.288, G_loss=3.198
# >43, 2/3, D_loss=0.294, G_loss=3.224
# >43, 3/3, D_loss=0.228, G_loss=3.281
# >44, 1/3, D_loss=0.277, G_loss=3.455
# >44, 2/3, D_loss=0.360, G_loss=3.511
# >44, 3/3, D_loss=0.286, G_loss=3.514
# >45, 1/3, D_loss=0.387, G_loss=3.529
# >45, 2/3, D_loss=0.188, G_loss=3.534
# >45, 3/3, D_loss=0.216, G_loss=3.433
# >46, 1/3, D_loss=0.261, G_loss=3.456
# >46, 2/3, D_loss=0.185, G_loss=3.576
# >46, 3/3, D_loss=0.149, G_loss=3.566
# >47, 1/3, D_loss=0.170, G_loss=3.727
# Failure Mode. Swapping Discriminator model for epoch 20
# >47, 2/3, D_loss=0.308, G_loss=3.103
# Failure Mode. Swapping Discriminator model for epoch 20
# >47, 3/3, D_loss=0.389, G_loss=3.234
# Failure Mode. Swapping Discriminator model for epoch 10
# >48, 1/3, D_loss=2.381, G_loss=1.428
# Failure Mode. Swapping Discriminator model for epoch 40
# >48, 2/3, D_loss=0.298, G_loss=2.892
# Failure Mode. Swapping Discriminator model for epoch 30
# >48, 3/3, D_loss=0.230, G_loss=3.616
# Failure Mode. Swapping Discriminator model for epoch 30
# >49, 1/3, D_loss=0.229, G_loss=3.469
# >49, 2/3, D_loss=0.166, G_loss=3.778
# >49, 3/3, D_loss=0.156, G_loss=3.998
# >50, 1/3, D_loss=0.204, G_loss=4.321
# >50, 2/3, D_loss=0.186, G_loss=4.293
# >50, 3/3, D_loss=0.233, G_loss=4.315
# >Epoch: 50 Porosity match: 0% Std: 0.00 real: 92% fake: 100%
# >51, 1/3, D_loss=0.189, G_loss=4.180
# >51, 2/3, D_loss=0.158, G_loss=4.136
# >51, 3/3, D_loss=0.122, G_loss=4.136
# >52, 1/3, D_loss=0.109, G_loss=4.098
# >52, 2/3, D_loss=0.111, G_loss=4.108
# >52, 3/3, D_loss=0.111, G_loss=4.196
# >53, 1/3, D_loss=0.133, G_loss=4.443
# >53, 2/3, D_loss=0.120, G_loss=4.437
# >53, 3/3, D_loss=0.106, G_loss=4.451
# >54, 1/3, D_loss=0.069, G_loss=4.617
# Failure Mode. Swapping Discriminator model for epoch 40
# >54, 2/3, D_loss=0.385, G_loss=2.740
# Failure Mode. Swapping Discriminator model for epoch 40
# >54, 3/3, D_loss=0.397, G_loss=2.646
# Failure Mode. Swapping Discriminator model for epoch 40
# >55, 1/3, D_loss=0.409, G_loss=2.636
# >55, 2/3, D_loss=0.408, G_loss=2.924
# >55, 3/3, D_loss=0.389, G_loss=2.954
# >56, 1/3, D_loss=0.334, G_loss=3.291
# >56, 2/3, D_loss=0.353, G_loss=3.283
# >56, 3/3, D_loss=0.316, G_loss=3.381
# >57, 1/3, D_loss=0.306, G_loss=3.267
# >57, 2/3, D_loss=0.371, G_loss=3.593
# >57, 3/3, D_loss=0.330, G_loss=3.727
# >58, 1/3, D_loss=0.223, G_loss=3.579
# >58, 2/3, D_loss=0.324, G_loss=3.626
# >58, 3/3, D_loss=0.230, G_loss=3.536
# >59, 1/3, D_loss=0.243, G_loss=3.473
# Failure Mode. Swapping Discriminator model for epoch 30
# >59, 2/3, D_loss=0.228, G_loss=3.370
# Failure Mode. Swapping Discriminator model for epoch 40
# >59, 3/3, D_loss=0.333, G_loss=2.764
# Failure Mode. Swapping Discriminator model for epoch 40
# >60, 1/3, D_loss=0.396, G_loss=2.866
# >60, 2/3, D_loss=0.359, G_loss=2.900
# >60, 3/3, D_loss=0.415, G_loss=3.231
# >Epoch: 60 Porosity match: 0% Std: 0.00 real: 84% fake: 100%
# >61, 1/3, D_loss=0.313, G_loss=3.184
# Failure Mode. Swapping Discriminator model for epoch 10
# >61, 2/3, D_loss=2.421, G_loss=1.426
# Failure Mode. Swapping Discriminator model for epoch 40
# >61, 3/3, D_loss=0.475, G_loss=3.048
# Failure Mode. Swapping Discriminator model for epoch 30
# >62, 1/3, D_loss=0.190, G_loss=3.507
# >62, 2/3, D_loss=0.193, G_loss=3.707
# >62, 3/3, D_loss=0.256, G_loss=3.957
# >63, 1/3, D_loss=0.237, G_loss=4.232
# >63, 2/3, D_loss=0.163, G_loss=4.003
# >63, 3/3, D_loss=0.234, G_loss=4.148
# >64, 1/3, D_loss=0.193, G_loss=4.085
# >64, 2/3, D_loss=0.220, G_loss=3.896
# >64, 3/3, D_loss=0.163, G_loss=3.843
# >65, 1/3, D_loss=0.178, G_loss=3.887
# >65, 2/3, D_loss=0.126, G_loss=3.882
# >65, 3/3, D_loss=0.121, G_loss=3.966
# >66, 1/3, D_loss=0.077, G_loss=4.290
# >66, 2/3, D_loss=0.079, G_loss=4.644
# >66, 3/3, D_loss=0.085, G_loss=4.646
# >67, 1/3, D_loss=0.076, G_loss=5.002
# >67, 2/3, D_loss=0.081, G_loss=4.810
# >67, 3/3, D_loss=0.077, G_loss=5.379
# >68, 1/3, D_loss=0.105, G_loss=5.301
# >68, 2/3, D_loss=0.062, G_loss=5.016
# >68, 3/3, D_loss=0.050, G_loss=5.049
# >69, 1/3, D_loss=0.032, G_loss=5.044
# Failure Mode. Swapping Discriminator model for epoch 50
# >69, 2/3, D_loss=0.168, G_loss=4.089
# Failure Mode. Swapping Discriminator model for epoch 30
# >69, 3/3, D_loss=0.270, G_loss=3.281
# Failure Mode. Swapping Discriminator model for epoch 40
# >70, 1/3, D_loss=0.384, G_loss=2.816
# Failure Mode. Swapping Discriminator model for epoch 10
# >70, 2/3, D_loss=2.530, G_loss=1.435
# Failure Mode. Swapping Discriminator model for epoch 60
# >70, 3/3, D_loss=0.313, G_loss=3.202
# Failure Mode. Swapping Discriminator model for epoch 10
# >Epoch: 70 Porosity match: 0% Std: 0.00 real: 100% fake: 0%
# >71, 1/3, D_loss=2.287, G_loss=1.459
# >71, 2/3, D_loss=1.578, G_loss=1.663
# >71, 3/3, D_loss=0.676, G_loss=2.689
# >72, 1/3, D_loss=0.444, G_loss=3.861
# >72, 2/3, D_loss=0.490, G_loss=4.878
# >72, 3/3, D_loss=0.772, G_loss=4.728
# >73, 1/3, D_loss=0.813, G_loss=4.421
# >73, 2/3, D_loss=0.765, G_loss=4.205
# >73, 3/3, D_loss=0.574, G_loss=3.548
# >74, 1/3, D_loss=0.426, G_loss=3.455
# >74, 2/3, D_loss=0.385, G_loss=2.896
# >74, 3/3, D_loss=0.345, G_loss=2.838
# >75, 1/3, D_loss=0.413, G_loss=2.695
# >75, 2/3, D_loss=0.351, G_loss=2.874
# >75, 3/3, D_loss=0.384, G_loss=2.797
# >76, 1/3, D_loss=0.336, G_loss=2.913
# >76, 2/3, D_loss=0.297, G_loss=3.063
# >76, 3/3, D_loss=0.346, G_loss=3.207
# >77, 1/3, D_loss=0.218, G_loss=3.303
# >77, 2/3, D_loss=0.288, G_loss=3.349
# >77, 3/3, D_loss=0.263, G_loss=3.559
# >78, 1/3, D_loss=0.217, G_loss=3.869
# >78, 2/3, D_loss=0.183, G_loss=3.818
# >78, 3/3, D_loss=0.158, G_loss=3.734
# >79, 1/3, D_loss=0.191, G_loss=3.932
# >79, 2/3, D_loss=0.197, G_loss=4.026
# >79, 3/3, D_loss=0.144, G_loss=3.957
# >80, 1/3, D_loss=0.193, G_loss=4.063
# >80, 2/3, D_loss=0.152, G_loss=4.194
# >80, 3/3, D_loss=0.126, G_loss=3.917
# >Epoch: 80 Porosity match: 0% Std: 0.00 real: 98% fake: 100%
# >81, 1/3, D_loss=0.152, G_loss=4.155
# >81, 2/3, D_loss=0.140, G_loss=4.317
# >81, 3/3, D_loss=0.114, G_loss=4.158
# >82, 1/3, D_loss=0.115, G_loss=4.386
# Failure Mode. Swapping Discriminator model for epoch 20
# >82, 2/3, D_loss=0.399, G_loss=2.992
# Failure Mode. Swapping Discriminator model for epoch 40
# >82, 3/3, D_loss=0.435, G_loss=2.769
# Failure Mode. Swapping Discriminator model for epoch 80
# >83, 1/3, D_loss=0.128, G_loss=4.206
# >83, 2/3, D_loss=0.152, G_loss=4.394
# >83, 3/3, D_loss=0.115, G_loss=4.711
# >84, 1/3, D_loss=0.138, G_loss=4.574
# >84, 2/3, D_loss=0.082, G_loss=4.761
# >84, 3/3, D_loss=0.093, G_loss=4.674
# >85, 1/3, D_loss=0.106, G_loss=4.615
# >85, 2/3, D_loss=0.091, G_loss=4.844
# >85, 3/3, D_loss=0.090, G_loss=4.936
# >86, 1/3, D_loss=0.076, G_loss=4.919
# >86, 2/3, D_loss=0.081, G_loss=4.831
# >86, 3/3, D_loss=0.044, G_loss=5.174
# Failure Mode. Swapping Discriminator model for epoch 80
# >87, 1/3, D_loss=0.102, G_loss=4.080
# >87, 2/3, D_loss=0.154, G_loss=4.201
# >87, 3/3, D_loss=0.113, G_loss=4.461
# >88, 1/3, D_loss=0.128, G_loss=4.746
# Failure Mode. Swapping Discriminator model for epoch 70
# >88, 2/3, D_loss=2.363, G_loss=1.429
# Failure Mode. Swapping Discriminator model for epoch 80
# >88, 3/3, D_loss=0.149, G_loss=4.382
# Failure Mode. Swapping Discriminator model for epoch 80
# >89, 1/3, D_loss=0.126, G_loss=4.351
# >89, 2/3, D_loss=0.136, G_loss=4.346
# >89, 3/3, D_loss=0.102, G_loss=4.767
# >90, 1/3, D_loss=0.122, G_loss=4.868
# >90, 2/3, D_loss=0.111, G_loss=4.754
# >90, 3/3, D_loss=0.116, G_loss=4.930
# >Epoch: 90 Porosity match: 0% Std: 0.00 real: 92% fake: 100%
# >91, 1/3, D_loss=0.114, G_loss=4.700
# >91, 2/3, D_loss=0.078, G_loss=4.722
# >91, 3/3, D_loss=0.139, G_loss=4.549
# >92, 1/3, D_loss=0.078, G_loss=4.466
# >92, 2/3, D_loss=0.105, G_loss=4.593
# >92, 3/3, D_loss=0.081, G_loss=4.645
# >93, 1/3, D_loss=0.065, G_loss=4.846
# >93, 2/3, D_loss=0.043, G_loss=5.368
# Failure Mode. Swapping Discriminator model for epoch 30
# >93, 3/3, D_loss=0.187, G_loss=3.174
# >94, 1/3, D_loss=0.194, G_loss=3.361
# Failure Mode. Swapping Discriminator model for epoch 50
# >94, 2/3, D_loss=0.140, G_loss=4.340
# Failure Mode. Swapping Discriminator model for epoch 40
# >94, 3/3, D_loss=0.382, G_loss=2.780
# Failure Mode. Swapping Discriminator model for epoch 60
# >95, 1/3, D_loss=0.365, G_loss=3.168
# >95, 2/3, D_loss=0.296, G_loss=3.020
# >95, 3/3, D_loss=0.338, G_loss=3.023
# >96, 1/3, D_loss=0.242, G_loss=3.492
# >96, 2/3, D_loss=0.365, G_loss=3.266
# >96, 3/3, D_loss=0.279, G_loss=3.412
# >97, 1/3, D_loss=0.235, G_loss=3.270
# >97, 2/3, D_loss=0.279, G_loss=3.386
# >97, 3/3, D_loss=0.210, G_loss=3.416
# >98, 1/3, D_loss=0.317, G_loss=3.644
# >98, 2/3, D_loss=0.220, G_loss=3.559
# >98, 3/3, D_loss=0.190, G_loss=3.689
# >99, 1/3, D_loss=0.151, G_loss=3.717
# Failure Mode. Swapping Discriminator model for epoch 50
# >99, 2/3, D_loss=0.174, G_loss=4.370
# Failure Mode. Swapping Discriminator model for epoch 70
# >99, 3/3, D_loss=2.508, G_loss=1.485
# Failure Mode. Swapping Discriminator model for epoch 10
# >100, 1/3, D_loss=2.157, G_loss=1.507
# >100, 2/3, D_loss=1.529, G_loss=1.745
# >100, 3/3, D_loss=0.526, G_loss=2.852
# >Epoch: 100 Porosity match: 0% Std: 0.00 real: 68% fake: 100%
# >101, 1/3, D_loss=0.380, G_loss=4.388
# >101, 2/3, D_loss=0.678, G_loss=4.848
# >101, 3/3, D_loss=0.773, G_loss=4.665
# >102, 1/3, D_loss=0.872, G_loss=4.666
# >102, 2/3, D_loss=0.722, G_loss=3.980
# >102, 3/3, D_loss=0.516, G_loss=3.683
# >103, 1/3, D_loss=0.464, G_loss=3.029
# >103, 2/3, D_loss=0.394, G_loss=2.836
# >103, 3/3, D_loss=0.354, G_loss=2.748
# >104, 1/3, D_loss=0.398, G_loss=2.755
# >104, 2/3, D_loss=0.407, G_loss=2.795
# >104, 3/3, D_loss=0.260, G_loss=2.795
# >105, 1/3, D_loss=0.318, G_loss=2.865
# >105, 2/3, D_loss=0.277, G_loss=3.227
# >105, 3/3, D_loss=0.239, G_loss=3.358
# >106, 1/3, D_loss=0.258, G_loss=3.538
# >106, 2/3, D_loss=0.195, G_loss=3.523
# >106, 3/3, D_loss=0.202, G_loss=3.624
# >107, 1/3, D_loss=0.236, G_loss=3.633
# >107, 2/3, D_loss=0.191, G_loss=3.973
# >107, 3/3, D_loss=0.204, G_loss=4.037
# >108, 1/3, D_loss=0.147, G_loss=3.870
# >108, 2/3, D_loss=0.209, G_loss=4.041
# >108, 3/3, D_loss=0.126, G_loss=3.784
# >109, 1/3, D_loss=0.109, G_loss=3.893
# >109, 2/3, D_loss=0.185, G_loss=3.824
# >109, 3/3, D_loss=0.139, G_loss=4.028
# >110, 1/3, D_loss=0.086, G_loss=3.879
# Failure Mode. Swapping Discriminator model for epoch 20
# >110, 2/3, D_loss=0.413, G_loss=2.970
# Failure Mode. Swapping Discriminator model for epoch 80
# >110, 3/3, D_loss=0.192, G_loss=3.686
# Failure Mode. Swapping Discriminator model for epoch 20
# >Epoch: 110 Porosity match: 0% Std: 0.05 real: 87% fake: 100%
# >111, 1/3, D_loss=0.307, G_loss=3.266
# Failure Mode. Swapping Discriminator model for epoch 40
# >111, 2/3, D_loss=0.572, G_loss=3.225
# Failure Mode. Swapping Discriminator model for epoch 30
# >111, 3/3, D_loss=0.298, G_loss=4.579
# Failure Mode. Swapping Discriminator model for epoch 80
# >112, 1/3, D_loss=0.518, G_loss=5.768
# >112, 2/3, D_loss=0.366, G_loss=8.291
# >112, 3/3, D_loss=0.269, G_loss=9.793
# >113, 1/3, D_loss=0.289, G_loss=9.090
# >113, 2/3, D_loss=0.860, G_loss=5.810
# >113, 3/3, D_loss=1.281, G_loss=2.655
# >114, 1/3, D_loss=0.994, G_loss=2.231
# >114, 2/3, D_loss=1.071, G_loss=2.886
# >114, 3/3, D_loss=0.911, G_loss=3.472
# >115, 1/3, D_loss=0.732, G_loss=3.560
# >115, 2/3, D_loss=0.578, G_loss=3.974
# >115, 3/3, D_loss=0.367, G_loss=3.851
# >116, 1/3, D_loss=0.385, G_loss=3.576
# >116, 2/3, D_loss=0.511, G_loss=3.462
# >116, 3/3, D_loss=0.527, G_loss=3.598
# >117, 1/3, D_loss=0.422, G_loss=3.584
# >117, 2/3, D_loss=0.403, G_loss=3.218
# >117, 3/3, D_loss=0.301, G_loss=3.530
# >118, 1/3, D_loss=0.293, G_loss=3.082
# >118, 2/3, D_loss=0.264, G_loss=3.662
# >118, 3/3, D_loss=0.276, G_loss=4.160
# >119, 1/3, D_loss=0.256, G_loss=3.852
# >119, 2/3, D_loss=0.311, G_loss=3.810
# >119, 3/3, D_loss=0.338, G_loss=3.581
# >120, 1/3, D_loss=0.311, G_loss=3.635
# >120, 2/3, D_loss=0.318, G_loss=3.455
# >120, 3/3, D_loss=0.315, G_loss=3.399
# >Epoch: 120 Porosity match: 4% Std: 0.29 real: 90% fake: 83%
# >121, 1/3, D_loss=0.452, G_loss=2.856
# >121, 2/3, D_loss=0.425, G_loss=3.040
# >121, 3/3, D_loss=0.382, G_loss=3.137
# >122, 1/3, D_loss=0.404, G_loss=2.410
# >122, 2/3, D_loss=0.414, G_loss=2.609
# >122, 3/3, D_loss=0.585, G_loss=2.545
# >123, 1/3, D_loss=0.427, G_loss=2.829
# >123, 2/3, D_loss=0.591, G_loss=2.468
# >123, 3/3, D_loss=0.523, G_loss=2.601
# >124, 1/3, D_loss=0.564, G_loss=2.093
# >124, 2/3, D_loss=0.607, G_loss=2.075
# >124, 3/3, D_loss=0.612, G_loss=2.101
# >125, 1/3, D_loss=0.444, G_loss=2.242
# >125, 2/3, D_loss=0.503, G_loss=2.045
# >125, 3/3, D_loss=0.556, G_loss=2.173
# >126, 1/3, D_loss=0.629, G_loss=2.160
# >126, 2/3, D_loss=0.588, G_loss=1.914
# >126, 3/3, D_loss=0.560, G_loss=1.847
# >127, 1/3, D_loss=0.517, G_loss=1.710
# >127, 2/3, D_loss=0.636, G_loss=1.526
# >127, 3/3, D_loss=0.621, G_loss=1.828
# >128, 1/3, D_loss=0.566, G_loss=1.817
# Failure Mode. Swapping Discriminator model for epoch 80
# >128, 2/3, D_loss=1.278, G_loss=1.311
# Failure Mode. Swapping Discriminator model for epoch 80
# >128, 3/3, D_loss=1.165, G_loss=1.273
# Failure Mode. Swapping Discriminator model for epoch 110
# >129, 1/3, D_loss=0.710, G_loss=1.569
# >129, 2/3, D_loss=0.768, G_loss=1.868
# >129, 3/3, D_loss=0.593, G_loss=2.283
# >130, 1/3, D_loss=0.686, G_loss=2.294
# >130, 2/3, D_loss=0.651, G_loss=2.553
# >130, 3/3, D_loss=0.633, G_loss=2.292
# >Epoch: 130 Porosity match: 3% Std: 0.14 real: 26% fake: 95%
# >131, 1/3, D_loss=0.763, G_loss=2.202
# >131, 2/3, D_loss=0.625, G_loss=1.984
# >131, 3/3, D_loss=0.608, G_loss=1.840
# >132, 1/3, D_loss=0.523, G_loss=1.624
# >132, 2/3, D_loss=0.556, G_loss=1.396
# >132, 3/3, D_loss=0.644, G_loss=1.287
# >133, 1/3, D_loss=0.579, G_loss=1.417
# >133, 2/3, D_loss=0.525, G_loss=1.570
# >133, 3/3, D_loss=0.566, G_loss=1.557
# >134, 1/3, D_loss=0.667, G_loss=1.570
# >134, 2/3, D_loss=0.547, G_loss=1.559
# >134, 3/3, D_loss=0.544, G_loss=1.601
# >135, 1/3, D_loss=0.615, G_loss=1.649
# Failure Mode. Swapping Discriminator model for epoch 120
# >135, 2/3, D_loss=1.825, G_loss=0.550
# Failure Mode. Swapping Discriminator model for epoch 50
# >135, 3/3, D_loss=0.941, G_loss=0.960
# Failure Mode. Swapping Discriminator model for epoch 60
# >136, 1/3, D_loss=0.944, G_loss=0.943
# >136, 2/3, D_loss=0.740, G_loss=1.159
# >136, 3/3, D_loss=0.868, G_loss=1.231
# >137, 1/3, D_loss=0.876, G_loss=1.482
# >137, 2/3, D_loss=0.741, G_loss=1.778
# >137, 3/3, D_loss=0.718, G_loss=1.457
# >138, 1/3, D_loss=0.745, G_loss=1.729
# >138, 2/3, D_loss=0.758, G_loss=1.480
# >138, 3/3, D_loss=0.774, G_loss=1.680
# >139, 1/3, D_loss=0.564, G_loss=1.376
# >139, 2/3, D_loss=0.676, G_loss=1.153
# >139, 3/3, D_loss=0.737, G_loss=1.186
# >140, 1/3, D_loss=0.680, G_loss=1.310
# >140, 2/3, D_loss=0.630, G_loss=1.076
# >140, 3/3, D_loss=0.774, G_loss=1.131
# >Epoch: 140 Porosity match: 10% Std: 0.20 real: 71% fake: 55%
# >141, 1/3, D_loss=0.719, G_loss=1.105
# >141, 2/3, D_loss=0.741, G_loss=1.114
# >141, 3/3, D_loss=0.695, G_loss=1.328
# >142, 1/3, D_loss=0.575, G_loss=1.210
# Failure Mode. Swapping Discriminator model for epoch 130
# >142, 2/3, D_loss=0.976, G_loss=1.435
# Failure Mode. Swapping Discriminator model for epoch 20
# >142, 3/3, D_loss=1.158, G_loss=0.705
# Failure Mode. Swapping Discriminator model for epoch 80
# >143, 1/3, D_loss=1.711, G_loss=0.686
# >143, 2/3, D_loss=1.168, G_loss=0.774
# >143, 3/3, D_loss=1.005, G_loss=0.931
# >144, 1/3, D_loss=0.871, G_loss=1.060
# >144, 2/3, D_loss=0.780, G_loss=1.600
# >144, 3/3, D_loss=0.846, G_loss=1.836
# >145, 1/3, D_loss=0.729, G_loss=1.841
# >145, 2/3, D_loss=0.821, G_loss=1.498
# >145, 3/3, D_loss=0.792, G_loss=1.864
# >146, 1/3, D_loss=0.999, G_loss=1.572
# >146, 2/3, D_loss=0.835, G_loss=1.569
# >146, 3/3, D_loss=0.704, G_loss=1.342
# >147, 1/3, D_loss=0.646, G_loss=1.265
# >147, 2/3, D_loss=0.677, G_loss=1.313
# >147, 3/3, D_loss=0.689, G_loss=1.214
# >148, 1/3, D_loss=0.829, G_loss=1.176
# >148, 2/3, D_loss=0.721, G_loss=1.167
# >148, 3/3, D_loss=0.646, G_loss=1.098
# >149, 1/3, D_loss=0.690, G_loss=1.085
# >149, 2/3, D_loss=0.723, G_loss=1.260
# >149, 3/3, D_loss=0.587, G_loss=1.214
# >150, 1/3, D_loss=0.499, G_loss=1.324
# >150, 2/3, D_loss=0.577, G_loss=1.346
# >150, 3/3, D_loss=0.563, G_loss=1.255
# >Epoch: 150 Porosity match: 17% Std: 0.14 real: 62% fake: 86%
# >151, 1/3, D_loss=0.711, G_loss=1.499
# >151, 2/3, D_loss=0.577, G_loss=1.491
# >151, 3/3, D_loss=0.601, G_loss=1.454
# >152, 1/3, D_loss=0.575, G_loss=1.246
# >152, 2/3, D_loss=0.596, G_loss=1.494
# >152, 3/3, D_loss=0.600, G_loss=1.641
# >153, 1/3, D_loss=0.701, G_loss=1.501
# >153, 2/3, D_loss=0.709, G_loss=1.494
# >153, 3/3, D_loss=0.659, G_loss=1.425
# >154, 1/3, D_loss=0.569, G_loss=1.365
# >154, 2/3, D_loss=0.650, G_loss=1.407
# >154, 3/3, D_loss=0.610, G_loss=1.418
# >155, 1/3, D_loss=0.529, G_loss=1.462
# Failure Mode. Swapping Discriminator model for epoch 130
# >155, 2/3, D_loss=1.066, G_loss=1.667
# Failure Mode. Swapping Discriminator model for epoch 130
# >155, 3/3, D_loss=0.856, G_loss=1.466
# Failure Mode. Swapping Discriminator model for epoch 70
# >156, 1/3, D_loss=2.070, G_loss=0.539
# >156, 2/3, D_loss=1.784, G_loss=0.666
# >156, 3/3, D_loss=1.346, G_loss=0.831
# >157, 1/3, D_loss=0.797, G_loss=1.402
# >157, 2/3, D_loss=0.663, G_loss=2.112
# >157, 3/3, D_loss=1.041, G_loss=2.437
# >158, 1/3, D_loss=0.971, G_loss=2.379
# >158, 2/3, D_loss=1.042, G_loss=1.919
# >158, 3/3, D_loss=0.947, G_loss=1.558
# >159, 1/3, D_loss=0.810, G_loss=1.291
# >159, 2/3, D_loss=0.681, G_loss=1.122
# >159, 3/3, D_loss=0.728, G_loss=1.073
# >160, 1/3, D_loss=0.739, G_loss=0.911
# >160, 2/3, D_loss=0.736, G_loss=1.035
# >160, 3/3, D_loss=0.712, G_loss=1.039
# >Epoch: 160 Porosity match: 12% Std: 0.11 real: 96% fake: 22%
# >161, 1/3, D_loss=0.624, G_loss=1.168
# >161, 2/3, D_loss=0.610, G_loss=1.329
# >161, 3/3, D_loss=0.672, G_loss=1.406
# >162, 1/3, D_loss=0.624, G_loss=1.411
# >162, 2/3, D_loss=0.654, G_loss=1.298
# >162, 3/3, D_loss=0.695, G_loss=1.359
# >163, 1/3, D_loss=0.621, G_loss=1.439
# >163, 2/3, D_loss=0.764, G_loss=1.307
# >163, 3/3, D_loss=0.639, G_loss=1.338
# >164, 1/3, D_loss=0.674, G_loss=1.365
# Failure Mode. Swapping Discriminator model for epoch 90
# >164, 2/3, D_loss=1.815, G_loss=0.520
# Failure Mode. Swapping Discriminator model for epoch 110
# >164, 3/3, D_loss=1.189, G_loss=0.844
# Failure Mode. Swapping Discriminator model for epoch 70
# >165, 1/3, D_loss=2.321, G_loss=0.420
# >165, 2/3, D_loss=1.812, G_loss=0.567
# >165, 3/3, D_loss=1.270, G_loss=0.933
# >166, 1/3, D_loss=0.719, G_loss=1.667
# >166, 2/3, D_loss=0.748, G_loss=2.295
# >166, 3/3, D_loss=1.115, G_loss=2.526
# >167, 1/3, D_loss=1.224, G_loss=2.290
# >167, 2/3, D_loss=1.165, G_loss=1.812
# >167, 3/3, D_loss=0.910, G_loss=1.456
# >168, 1/3, D_loss=0.820, G_loss=1.228
# >168, 2/3, D_loss=0.805, G_loss=0.955
# >168, 3/3, D_loss=0.932, G_loss=0.778
# >169, 1/3, D_loss=0.788, G_loss=0.829
# >169, 2/3, D_loss=0.854, G_loss=0.877
# >169, 3/3, D_loss=0.748, G_loss=0.907
# >170, 1/3, D_loss=0.700, G_loss=0.873
# >170, 2/3, D_loss=0.756, G_loss=1.055
# >170, 3/3, D_loss=0.716, G_loss=1.158
# >Epoch: 170 Porosity match: 16% Std: 0.08 real: 77% fake: 47%
# >171, 1/3, D_loss=0.638, G_loss=1.302
# >171, 2/3, D_loss=0.707, G_loss=1.247
# >171, 3/3, D_loss=0.659, G_loss=1.247
# >172, 1/3, D_loss=0.695, G_loss=1.195
# >172, 2/3, D_loss=0.714, G_loss=1.271
# >172, 3/3, D_loss=0.756, G_loss=1.198
# >173, 1/3, D_loss=0.670, G_loss=1.370
# >173, 2/3, D_loss=0.721, G_loss=1.242
# >173, 3/3, D_loss=0.705, G_loss=1.261
# >174, 1/3, D_loss=0.680, G_loss=1.213
# Failure Mode. Swapping Discriminator model for epoch 30
# >174, 2/3, D_loss=1.708, G_loss=0.570
# Failure Mode. Swapping Discriminator model for epoch 80
# >174, 3/3, D_loss=1.760, G_loss=0.524
# Failure Mode. Swapping Discriminator model for epoch 90
# >175, 1/3, D_loss=1.941, G_loss=0.511
# >175, 2/3, D_loss=1.157, G_loss=0.750
# >175, 3/3, D_loss=0.937, G_loss=1.142
# >176, 1/3, D_loss=0.820, G_loss=1.355
# >176, 2/3, D_loss=0.732, G_loss=2.103
# >176, 3/3, D_loss=0.872, G_loss=1.966
# >177, 1/3, D_loss=0.982, G_loss=1.818
# >177, 2/3, D_loss=1.101, G_loss=1.954
# >177, 3/3, D_loss=0.947, G_loss=1.856
# >178, 1/3, D_loss=0.782, G_loss=1.725
# >178, 2/3, D_loss=0.893, G_loss=1.529
# >178, 3/3, D_loss=0.656, G_loss=1.360
# >179, 1/3, D_loss=0.764, G_loss=1.153
# >179, 2/3, D_loss=0.647, G_loss=1.122
# >179, 3/3, D_loss=0.731, G_loss=1.051
# >180, 1/3, D_loss=0.760, G_loss=0.992
# >180, 2/3, D_loss=0.723, G_loss=0.907
# >180, 3/3, D_loss=0.909, G_loss=1.025
# >Epoch: 180 Porosity match: 17% Std: 0.16 real: 84% fake: 38%
# >181, 1/3, D_loss=0.680, G_loss=0.993
# >181, 2/3, D_loss=0.764, G_loss=1.165
# >181, 3/3, D_loss=0.704, G_loss=1.187
# >182, 1/3, D_loss=0.751, G_loss=1.240
# >182, 2/3, D_loss=0.715, G_loss=1.114
# >182, 3/3, D_loss=0.699, G_loss=1.298
# >183, 1/3, D_loss=0.654, G_loss=1.410
# Failure Mode. Swapping Discriminator model for epoch 50
# >183, 2/3, D_loss=1.741, G_loss=0.726
# Failure Mode. Swapping Discriminator model for epoch 30
# >183, 3/3, D_loss=1.044, G_loss=0.722
# Failure Mode. Swapping Discriminator model for epoch 10
# >184, 1/3, D_loss=2.302, G_loss=0.445
# >184, 2/3, D_loss=1.929, G_loss=0.553
# >184, 3/3, D_loss=1.129, G_loss=0.900
# >185, 1/3, D_loss=0.728, G_loss=1.754
# >185, 2/3, D_loss=0.911, G_loss=2.182
# >185, 3/3, D_loss=1.217, G_loss=2.360
# >186, 1/3, D_loss=1.180, G_loss=2.309
# >186, 2/3, D_loss=0.963, G_loss=1.753
# >186, 3/3, D_loss=1.046, G_loss=1.401
# >187, 1/3, D_loss=0.745, G_loss=1.171
# >187, 2/3, D_loss=0.771, G_loss=1.186
# >187, 3/3, D_loss=0.785, G_loss=0.854
# >188, 1/3, D_loss=0.771, G_loss=0.951
# >188, 2/3, D_loss=0.785, G_loss=0.930
# >188, 3/3, D_loss=0.641, G_loss=1.080
# >189, 1/3, D_loss=0.632, G_loss=1.052
# >189, 2/3, D_loss=0.669, G_loss=1.139
# >189, 3/3, D_loss=0.675, G_loss=1.411
# >190, 1/3, D_loss=0.685, G_loss=1.384
# >190, 2/3, D_loss=0.616, G_loss=1.650
# >190, 3/3, D_loss=0.687, G_loss=1.570
# >Epoch: 190 Porosity match: 20% Std: 0.12 real: 36% fake: 85%
# >191, 1/3, D_loss=0.839, G_loss=1.515
# >191, 2/3, D_loss=0.714, G_loss=1.513
# >191, 3/3, D_loss=0.698, G_loss=1.343
# >192, 1/3, D_loss=0.678, G_loss=1.495
# Failure Mode. Swapping Discriminator model for epoch 170
# >192, 2/3, D_loss=0.746, G_loss=1.217
# Failure Mode. Swapping Discriminator model for epoch 160
# >192, 3/3, D_loss=0.695, G_loss=0.874
# Failure Mode. Swapping Discriminator model for epoch 110
# >193, 1/3, D_loss=1.337, G_loss=0.644
# Failure Mode. Swapping Discriminator model for epoch 70
# >193, 2/3, D_loss=2.622, G_loss=0.414
# Failure Mode. Swapping Discriminator model for epoch 70
# >193, 3/3, D_loss=2.334, G_loss=0.355
# Failure Mode. Swapping Discriminator model for epoch 40
# >194, 1/3, D_loss=1.147, G_loss=0.734
# >194, 2/3, D_loss=1.256, G_loss=0.854
# >194, 3/3, D_loss=0.998, G_loss=1.052
# >195, 1/3, D_loss=0.996, G_loss=1.233
# >195, 2/3, D_loss=0.810, G_loss=1.385
# >195, 3/3, D_loss=0.737, G_loss=1.461
# >196, 1/3, D_loss=0.869, G_loss=1.702
# >196, 2/3, D_loss=0.864, G_loss=1.333
# >196, 3/3, D_loss=0.942, G_loss=1.383
# >197, 1/3, D_loss=0.854, G_loss=1.331
# >197, 2/3, D_loss=0.849, G_loss=1.213
# >197, 3/3, D_loss=0.814, G_loss=1.075
# >198, 1/3, D_loss=0.845, G_loss=1.021
# >198, 2/3, D_loss=0.796, G_loss=1.013
# >198, 3/3, D_loss=0.682, G_loss=0.921
# >199, 1/3, D_loss=0.843, G_loss=0.918
# >199, 2/3, D_loss=0.741, G_loss=0.942
# >199, 3/3, D_loss=0.692, G_loss=0.996
# >200, 1/3, D_loss=0.703, G_loss=1.069
# Failure Mode. Swapping Discriminator model for epoch 190
# >200, 2/3, D_loss=0.676, G_loss=1.344
# Failure Mode. Swapping Discriminator model for epoch 130
# >200, 3/3, D_loss=0.868, G_loss=1.147
# Failure Mode. Swapping Discriminator model for epoch 150
# >Epoch: 200 Porosity match: 21% Std: 0.15 real: 69% fake: 64%
# >201, 1/3, D_loss=0.499, G_loss=1.293
# >201, 2/3, D_loss=0.716, G_loss=1.176
# >201, 3/3, D_loss=0.668, G_loss=1.252
# >202, 1/3, D_loss=0.686, G_loss=1.359
# >202, 2/3, D_loss=0.612, G_loss=1.260
# >202, 3/3, D_loss=0.670, G_loss=1.400
# >203, 1/3, D_loss=0.628, G_loss=1.475
# >203, 2/3, D_loss=0.690, G_loss=1.257
# >203, 3/3, D_loss=0.628, G_loss=1.415
# >204, 1/3, D_loss=0.700, G_loss=1.358
# >204, 2/3, D_loss=0.557, G_loss=1.380
# >204, 3/3, D_loss=0.576, G_loss=1.353
# >205, 1/3, D_loss=0.710, G_loss=1.386
# Failure Mode. Swapping Discriminator model for epoch 190
# >205, 2/3, D_loss=0.663, G_loss=1.358
# Failure Mode. Swapping Discriminator model for epoch 200
# >205, 3/3, D_loss=0.716, G_loss=1.034
# Failure Mode. Swapping Discriminator model for epoch 110
# >206, 1/3, D_loss=1.339, G_loss=0.691
# Failure Mode. Swapping Discriminator model for epoch 40
# >206, 2/3, D_loss=1.358, G_loss=0.689
# Failure Mode. Swapping Discriminator model for epoch 110
# >206, 3/3, D_loss=1.448, G_loss=0.870
# Failure Mode. Swapping Discriminator model for epoch 160
# >207, 1/3, D_loss=0.702, G_loss=1.069
# >207, 2/3, D_loss=0.658, G_loss=1.259
# >207, 3/3, D_loss=0.707, G_loss=1.441
# >208, 1/3, D_loss=0.744, G_loss=1.585
# >208, 2/3, D_loss=0.853, G_loss=1.581
# >208, 3/3, D_loss=0.731, G_loss=1.536
# >209, 1/3, D_loss=0.770, G_loss=1.576
# >209, 2/3, D_loss=0.764, G_loss=1.466
# >209, 3/3, D_loss=0.773, G_loss=1.326
# >210, 1/3, D_loss=0.729, G_loss=1.285
# >210, 2/3, D_loss=0.632, G_loss=1.200
# >210, 3/3, D_loss=0.658, G_loss=1.228
# >Epoch: 210 Porosity match: 21% Std: 0.10 real: 90% fake: 42%
# >211, 1/3, D_loss=0.663, G_loss=1.020
# >211, 2/3, D_loss=0.675, G_loss=1.112
# >211, 3/3, D_loss=0.700, G_loss=1.125
# >212, 1/3, D_loss=0.665, G_loss=1.111
# Failure Mode. Swapping Discriminator model for epoch 30
# >212, 2/3, D_loss=1.662, G_loss=0.565
# Failure Mode. Swapping Discriminator model for epoch 130
# >212, 3/3, D_loss=1.067, G_loss=1.276
# Failure Mode. Swapping Discriminator model for epoch 160
# >213, 1/3, D_loss=0.810, G_loss=0.895
# >213, 2/3, D_loss=0.902, G_loss=0.916
# >213, 3/3, D_loss=0.766, G_loss=1.063
# >214, 1/3, D_loss=0.695, G_loss=1.213
# >214, 2/3, D_loss=0.675, G_loss=1.196
# >214, 3/3, D_loss=0.661, G_loss=1.239
# >215, 1/3, D_loss=0.743, G_loss=1.395
# >215, 2/3, D_loss=0.778, G_loss=1.384
# >215, 3/3, D_loss=0.699, G_loss=1.307
# >216, 1/3, D_loss=0.707, G_loss=1.331
# >216, 2/3, D_loss=0.797, G_loss=1.223
# >216, 3/3, D_loss=0.634, G_loss=1.099
# >217, 1/3, D_loss=0.710, G_loss=1.142
# >217, 2/3, D_loss=0.691, G_loss=1.173
# >217, 3/3, D_loss=0.769, G_loss=1.108
# >218, 1/3, D_loss=0.730, G_loss=1.153
# Failure Mode. Swapping Discriminator model for epoch 180
# >218, 2/3, D_loss=0.721, G_loss=1.078
# Failure Mode. Swapping Discriminator model for epoch 60
# >218, 3/3, D_loss=1.092, G_loss=0.723
# Failure Mode. Swapping Discriminator model for epoch 130
# >219, 1/3, D_loss=1.009, G_loss=1.457
# >219, 2/3, D_loss=0.815, G_loss=1.339
# >219, 3/3, D_loss=1.074, G_loss=1.308
# >220, 1/3, D_loss=0.867, G_loss=1.326
# >220, 2/3, D_loss=1.020, G_loss=1.202
# >220, 3/3, D_loss=0.953, G_loss=1.137
# >Epoch: 220 Porosity match: 16% Std: 0.20 real: 38% fake: 50%
# >221, 1/3, D_loss=0.741, G_loss=1.140
# >221, 2/3, D_loss=0.830, G_loss=1.084
# >221, 3/3, D_loss=0.841, G_loss=1.203
# >222, 1/3, D_loss=0.896, G_loss=1.184
# >222, 2/3, D_loss=0.717, G_loss=1.179
# >222, 3/3, D_loss=0.858, G_loss=1.226
# >223, 1/3, D_loss=0.771, G_loss=1.232
# >223, 2/3, D_loss=0.711, G_loss=1.248
# >223, 3/3, D_loss=0.731, G_loss=1.253
# >224, 1/3, D_loss=0.811, G_loss=1.352
# >224, 2/3, D_loss=0.836, G_loss=1.341
# >224, 3/3, D_loss=0.766, G_loss=1.304
# >225, 1/3, D_loss=0.639, G_loss=1.275
# >225, 2/3, D_loss=0.663, G_loss=1.385
# >225, 3/3, D_loss=0.614, G_loss=1.255
# >226, 1/3, D_loss=0.734, G_loss=1.330
# >226, 2/3, D_loss=0.651, G_loss=1.365
# >226, 3/3, D_loss=0.720, G_loss=1.410
# >227, 1/3, D_loss=0.624, G_loss=1.359
# >227, 2/3, D_loss=0.724, G_loss=1.366
# >227, 3/3, D_loss=0.708, G_loss=1.288
# >228, 1/3, D_loss=0.683, G_loss=1.387
# >228, 2/3, D_loss=0.663, G_loss=1.473
# >228, 3/3, D_loss=0.681, G_loss=1.401
# >229, 1/3, D_loss=0.658, G_loss=1.525
# >229, 2/3, D_loss=0.622, G_loss=1.652
# >229, 3/3, D_loss=0.731, G_loss=1.513
# >230, 1/3, D_loss=0.704, G_loss=1.530
# Failure Mode. Swapping Discriminator model for epoch 150
# >230, 2/3, D_loss=0.959, G_loss=1.241
# Failure Mode. Swapping Discriminator model for epoch 150
# >230, 3/3, D_loss=0.784, G_loss=1.156
# Failure Mode. Swapping Discriminator model for epoch 90
# >Epoch: 230 Porosity match: 16% Std: 0.11 real: 96% fake: 2%
# >231, 1/3, D_loss=1.627, G_loss=0.663
# >231, 2/3, D_loss=1.892, G_loss=0.743
# >231, 3/3, D_loss=1.522, G_loss=0.816
# >232, 1/3, D_loss=1.059, G_loss=1.012
# >232, 2/3, D_loss=0.912, G_loss=1.281
# >232, 3/3, D_loss=1.117, G_loss=1.484
# >233, 1/3, D_loss=1.046, G_loss=1.928
# >233, 2/3, D_loss=0.980, G_loss=1.790
# >233, 3/3, D_loss=0.946, G_loss=1.868
# >234, 1/3, D_loss=1.034, G_loss=1.690
# >234, 2/3, D_loss=1.271, G_loss=1.585
# >234, 3/3, D_loss=1.126, G_loss=1.624
# >235, 1/3, D_loss=0.808, G_loss=1.421
# >235, 2/3, D_loss=0.978, G_loss=1.392
# >235, 3/3, D_loss=0.807, G_loss=1.305
# >236, 1/3, D_loss=0.936, G_loss=1.427
# >236, 2/3, D_loss=0.710, G_loss=1.266
# >236, 3/3, D_loss=0.879, G_loss=1.161
# >237, 1/3, D_loss=0.891, G_loss=1.177
# >237, 2/3, D_loss=0.883, G_loss=1.255
# >237, 3/3, D_loss=0.744, G_loss=1.224
# >238, 1/3, D_loss=0.830, G_loss=1.238
# >238, 2/3, D_loss=0.784, G_loss=1.196
# >238, 3/3, D_loss=0.777, G_loss=1.191
# >239, 1/3, D_loss=0.746, G_loss=1.165
# >239, 2/3, D_loss=0.779, G_loss=1.366
# >239, 3/3, D_loss=0.748, G_loss=1.313
# >240, 1/3, D_loss=0.819, G_loss=1.463
# Failure Mode. Swapping Discriminator model for epoch 200
# >240, 2/3, D_loss=0.922, G_loss=1.225
# Failure Mode. Swapping Discriminator model for epoch 200
# >240, 3/3, D_loss=0.830, G_loss=1.218
# Failure Mode. Swapping Discriminator model for epoch 190
# >Epoch: 240 Porosity match: 12% Std: 0.10 real: 41% fake: 96%
# >241, 1/3, D_loss=0.713, G_loss=1.793
# Failure Mode. Swapping Discriminator model for epoch 210
# >241, 2/3, D_loss=0.573, G_loss=1.511
# Failure Mode. Swapping Discriminator model for epoch 10
# >241, 3/3, D_loss=2.521, G_loss=0.580
# Failure Mode. Swapping Discriminator model for epoch 30
# >242, 1/3, D_loss=1.468, G_loss=0.715
# >242, 2/3, D_loss=1.379, G_loss=0.844
# >242, 3/3, D_loss=1.204, G_loss=0.961
# >243, 1/3, D_loss=0.957, G_loss=1.272
# >243, 2/3, D_loss=0.865, G_loss=1.242
# >243, 3/3, D_loss=0.869, G_loss=1.634
# >244, 1/3, D_loss=0.831, G_loss=2.009
# >244, 2/3, D_loss=0.870, G_loss=1.795
# >244, 3/3, D_loss=0.893, G_loss=1.830
# >245, 1/3, D_loss=0.900, G_loss=1.692
# >245, 2/3, D_loss=0.820, G_loss=1.680
# >245, 3/3, D_loss=0.761, G_loss=1.635
# >246, 1/3, D_loss=0.748, G_loss=1.428
# >246, 2/3, D_loss=0.702, G_loss=1.389
# >246, 3/3, D_loss=0.593, G_loss=1.313
# >247, 1/3, D_loss=0.735, G_loss=1.326
# >247, 2/3, D_loss=0.608, G_loss=1.184
# >247, 3/3, D_loss=0.597, G_loss=1.218
# >248, 1/3, D_loss=0.679, G_loss=1.275
# >248, 2/3, D_loss=0.676, G_loss=1.337
# >248, 3/3, D_loss=0.577, G_loss=1.212
# >249, 1/3, D_loss=0.638, G_loss=1.315
# >249, 2/3, D_loss=0.680, G_loss=1.344
# >249, 3/3, D_loss=0.571, G_loss=1.417
# >250, 1/3, D_loss=0.702, G_loss=1.530
# >250, 2/3, D_loss=0.552, G_loss=1.420
# >250, 3/3, D_loss=0.639, G_loss=1.594
# >Epoch: 250 Porosity match: 18% Std: 0.14 real: 47% fake: 73%
# >251, 1/3, D_loss=0.604, G_loss=1.489
# Failure Mode. Swapping Discriminator model for epoch 180
# >251, 2/3, D_loss=0.905, G_loss=0.909
# Failure Mode. Swapping Discriminator model for epoch 30
# >251, 3/3, D_loss=1.896, G_loss=0.464
# Failure Mode. Swapping Discriminator model for epoch 120
# >252, 1/3, D_loss=1.121, G_loss=0.780
# >252, 2/3, D_loss=0.898, G_loss=1.196
# >252, 3/3, D_loss=0.786, G_loss=1.758
# >253, 1/3, D_loss=1.098, G_loss=1.804
# >253, 2/3, D_loss=1.129, G_loss=1.516
# >253, 3/3, D_loss=0.881, G_loss=1.359
# >254, 1/3, D_loss=1.024, G_loss=1.153
# >254, 2/3, D_loss=0.822, G_loss=1.083
# >254, 3/3, D_loss=0.778, G_loss=0.996
# >255, 1/3, D_loss=0.766, G_loss=1.174
# >255, 2/3, D_loss=0.695, G_loss=1.254
# >255, 3/3, D_loss=0.779, G_loss=1.336
# >256, 1/3, D_loss=0.741, G_loss=1.212
# >256, 2/3, D_loss=0.743, G_loss=1.276
# >256, 3/3, D_loss=0.654, G_loss=1.447
# >257, 1/3, D_loss=0.743, G_loss=1.248
# >257, 2/3, D_loss=0.792, G_loss=1.248
# >257, 3/3, D_loss=0.798, G_loss=1.218
# >258, 1/3, D_loss=0.807, G_loss=1.087
# >258, 2/3, D_loss=0.742, G_loss=1.101
# >258, 3/3, D_loss=0.819, G_loss=0.910
# >259, 1/3, D_loss=0.715, G_loss=1.133
# >259, 2/3, D_loss=0.677, G_loss=1.257
# >259, 3/3, D_loss=0.847, G_loss=1.282
# >260, 1/3, D_loss=0.615, G_loss=1.418
# Failure Mode. Swapping Discriminator model for epoch 80
# >260, 2/3, D_loss=1.391, G_loss=0.621
# Failure Mode. Swapping Discriminator model for epoch 150
# >260, 3/3, D_loss=0.714, G_loss=1.215
# Failure Mode. Swapping Discriminator model for epoch 30
# >Epoch: 260 Porosity match: 11% Std: 0.18 real: 96% fake: 6%
# >261, 1/3, D_loss=1.345, G_loss=0.596
# >261, 2/3, D_loss=1.178, G_loss=0.866
# >261, 3/3, D_loss=0.796, G_loss=1.103
# >262, 1/3, D_loss=0.743, G_loss=1.472
# >262, 2/3, D_loss=0.633, G_loss=1.963
# >262, 3/3, D_loss=0.771, G_loss=2.010
# >263, 1/3, D_loss=0.750, G_loss=2.025
# >263, 2/3, D_loss=0.657, G_loss=2.260
# >263, 3/3, D_loss=0.816, G_loss=1.953
# >264, 1/3, D_loss=0.771, G_loss=1.889
# >264, 2/3, D_loss=0.706, G_loss=1.650
# >264, 3/3, D_loss=0.687, G_loss=1.446
# >265, 1/3, D_loss=0.772, G_loss=1.454
# >265, 2/3, D_loss=0.798, G_loss=1.258
# >265, 3/3, D_loss=0.766, G_loss=1.143
# >266, 1/3, D_loss=0.764, G_loss=1.291
# >266, 2/3, D_loss=0.727, G_loss=1.043
# >266, 3/3, D_loss=0.758, G_loss=1.017
# >267, 1/3, D_loss=0.711, G_loss=1.201
# Failure Mode. Swapping Discriminator model for epoch 130
# >267, 2/3, D_loss=1.039, G_loss=1.204
# Failure Mode. Swapping Discriminator model for epoch 100
# >267, 3/3, D_loss=0.944, G_loss=0.946
# Failure Mode. Swapping Discriminator model for epoch 170
# >268, 1/3, D_loss=0.664, G_loss=1.132
# >268, 2/3, D_loss=0.663, G_loss=1.163
# >268, 3/3, D_loss=0.655, G_loss=1.271
# >269, 1/3, D_loss=0.722, G_loss=1.374
# >269, 2/3, D_loss=0.685, G_loss=1.288
# >269, 3/3, D_loss=0.710, G_loss=1.396
# >270, 1/3, D_loss=0.658, G_loss=1.363
# >270, 2/3, D_loss=0.700, G_loss=1.427
# >270, 3/3, D_loss=0.726, G_loss=1.456
# >Epoch: 270 Porosity match: 25% Std: 0.09 real: 58% fake: 91%
# >271, 1/3, D_loss=0.690, G_loss=1.383
# >271, 2/3, D_loss=0.670, G_loss=1.270
# >271, 3/3, D_loss=0.671, G_loss=1.236
# >272, 1/3, D_loss=0.692, G_loss=1.387
# >272, 2/3, D_loss=0.644, G_loss=1.268
# >272, 3/3, D_loss=0.683, G_loss=1.277
# >273, 1/3, D_loss=0.668, G_loss=1.289
# Failure Mode. Swapping Discriminator model for epoch 70
# >273, 2/3, D_loss=2.487, G_loss=0.390
# Failure Mode. Swapping Discriminator model for epoch 160
# >273, 3/3, D_loss=0.925, G_loss=0.967
# Failure Mode. Swapping Discriminator model for epoch 10
# >274, 1/3, D_loss=2.255, G_loss=0.417
# >274, 2/3, D_loss=1.643, G_loss=0.595
# >274, 3/3, D_loss=0.996, G_loss=1.011
# >275, 1/3, D_loss=0.711, G_loss=1.707
# >275, 2/3, D_loss=0.786, G_loss=2.526
# >275, 3/3, D_loss=1.124, G_loss=2.665
# >276, 1/3, D_loss=1.052, G_loss=2.303
# >276, 2/3, D_loss=1.096, G_loss=1.991
# >276, 3/3, D_loss=1.042, G_loss=1.394
# >277, 1/3, D_loss=0.817, G_loss=1.150
# >277, 2/3, D_loss=0.787, G_loss=1.021
# >277, 3/3, D_loss=0.909, G_loss=0.874
# >278, 1/3, D_loss=0.780, G_loss=0.876
# >278, 2/3, D_loss=0.761, G_loss=0.886
# >278, 3/3, D_loss=0.812, G_loss=0.912
# >279, 1/3, D_loss=0.758, G_loss=1.023
# >279, 2/3, D_loss=0.735, G_loss=0.967
# >279, 3/3, D_loss=0.743, G_loss=1.055
# >280, 1/3, D_loss=0.734, G_loss=1.156
# >280, 2/3, D_loss=0.704, G_loss=1.230
# >280, 3/3, D_loss=0.729, G_loss=1.198
# >Epoch: 280 Porosity match: 20% Std: 0.09 real: 51% fake: 84%
# >281, 1/3, D_loss=0.697, G_loss=1.404
# >281, 2/3, D_loss=0.653, G_loss=1.302
# >281, 3/3, D_loss=0.675, G_loss=1.277
# >282, 1/3, D_loss=0.727, G_loss=1.357
# >282, 2/3, D_loss=0.688, G_loss=1.192
# >282, 3/3, D_loss=0.653, G_loss=1.422
# >283, 1/3, D_loss=0.665, G_loss=1.369
# Failure Mode. Swapping Discriminator model for epoch 270
# >283, 2/3, D_loss=0.779, G_loss=1.163
# Failure Mode. Swapping Discriminator model for epoch 160
# >283, 3/3, D_loss=0.858, G_loss=0.726
# Failure Mode. Swapping Discriminator model for epoch 10
# >284, 1/3, D_loss=2.459, G_loss=0.276
# Failure Mode. Swapping Discriminator model for epoch 180
# >284, 2/3, D_loss=0.782, G_loss=0.950
# Failure Mode. Swapping Discriminator model for epoch 170
# >284, 3/3, D_loss=0.776, G_loss=1.162
# Failure Mode. Swapping Discriminator model for epoch 160
# >285, 1/3, D_loss=0.796, G_loss=0.788
# >285, 2/3, D_loss=0.878, G_loss=0.977
# >285, 3/3, D_loss=0.712, G_loss=1.077
# >286, 1/3, D_loss=0.705, G_loss=1.257
# >286, 2/3, D_loss=0.766, G_loss=1.234
# >286, 3/3, D_loss=0.773, G_loss=1.311
# >287, 1/3, D_loss=0.696, G_loss=1.289
# >287, 2/3, D_loss=0.810, G_loss=1.244
# >287, 3/3, D_loss=0.734, G_loss=1.202
# >288, 1/3, D_loss=0.725, G_loss=1.128
# >288, 2/3, D_loss=0.735, G_loss=1.148
# >288, 3/3, D_loss=0.691, G_loss=1.120
# >289, 1/3, D_loss=0.651, G_loss=1.021
# >289, 2/3, D_loss=0.733, G_loss=1.021
# >289, 3/3, D_loss=0.798, G_loss=1.057
# >290, 1/3, D_loss=0.722, G_loss=1.045
# Failure Mode. Swapping Discriminator model for epoch 50
# >290, 2/3, D_loss=1.654, G_loss=0.480
# Failure Mode. Swapping Discriminator model for epoch 230
# >290, 3/3, D_loss=1.975, G_loss=0.430
# Failure Mode. Swapping Discriminator model for epoch 250
# >Epoch: 290 Porosity match: 12% Std: 0.14 real: 62% fake: 55%
# >291, 1/3, D_loss=0.685, G_loss=1.255
# >291, 2/3, D_loss=0.757, G_loss=1.363
# >291, 3/3, D_loss=0.675, G_loss=1.356
# >292, 1/3, D_loss=0.699, G_loss=1.553
# >292, 2/3, D_loss=0.799, G_loss=1.387
# >292, 3/3, D_loss=0.811, G_loss=1.386
# >293, 1/3, D_loss=0.699, G_loss=1.361
# >293, 2/3, D_loss=0.653, G_loss=1.338
# >293, 3/3, D_loss=0.673, G_loss=1.252
# >294, 1/3, D_loss=0.645, G_loss=1.149
# >294, 2/3, D_loss=0.704, G_loss=1.166
# >294, 3/3, D_loss=0.639, G_loss=1.067
# >295, 1/3, D_loss=0.651, G_loss=1.131
# >295, 2/3, D_loss=0.771, G_loss=0.998
# >295, 3/3, D_loss=0.662, G_loss=0.982
# >296, 1/3, D_loss=0.670, G_loss=1.085
# Failure Mode. Swapping Discriminator model for epoch 190
# >296, 2/3, D_loss=0.717, G_loss=1.015
# Failure Mode. Swapping Discriminator model for epoch 120
# >296, 3/3, D_loss=1.770, G_loss=0.369
# Failure Mode. Swapping Discriminator model for epoch 30
# >297, 1/3, D_loss=1.370, G_loss=0.554
# >297, 2/3, D_loss=1.306, G_loss=0.592
# >297, 3/3, D_loss=1.016, G_loss=0.858
# >298, 1/3, D_loss=0.714, G_loss=0.999
# >298, 2/3, D_loss=0.827, G_loss=1.267
# >298, 3/3, D_loss=0.828, G_loss=1.508
# >299, 1/3, D_loss=0.861, G_loss=1.607
# >299, 2/3, D_loss=0.854, G_loss=1.585
# >299, 3/3, D_loss=0.851, G_loss=1.467
# >300, 1/3, D_loss=0.879, G_loss=1.516
# >300, 2/3, D_loss=0.855, G_loss=1.507
# >300, 3/3, D_loss=0.886, G_loss=1.288
# >Epoch: 300 Porosity match: 15% Std: 0.15 real: 30% fake: 77%
# No handles with labels found to put in legend.

# %% [markdown]
# # Evaluate `Generator`

# %% [markdown]
# ## Compile gif

# %%
score_filename, geom_epoch_dirs, gif_filename, tmp_models_dir, models_dir, arrays_dir = get_filenames(dimension, simulation, simmetry, score)

with imageio.get_writer(gif_filename, mode='I') as writer:
    geom_filenames = os.listdir(geom_epoch_dirs)
    for geom_filename in geom_filenames:
        image = imageio.imread(geom_epoch_dirs+geom_filename)
        foo = cv2.putText(
                    image,
                    str((geom_filenames.index(geom_filename)+1)*5),
                    (5, 25),
                    cv2.FONT_HERSHEY_SIMPLEX,
                    1,
                    (255, 0, 0),
                    2)
        for i in range(3):
            # image = imageio.imread(geom_epoch_dirs+geom_filename)
            writer.append_data(image)

# %% [markdown]
# ## Visualize geometries

# %%
def check_unit(unit, desired_porosity, tol):
  labels = measure.label(unit,connectivity=1)
  main_label = 0
  main_label_count = 0
  passed = True

  element = unit[int(unit.shape[0]/2):,:int(unit.shape[0]/2)]

  for label in range(1,len(np.unique(labels))):
      label_count = np.where(labels==label)[0].shape[0]
      if label_count > main_label_count:
        main_label = label
        main_label_count = label_count

  void_count = 0

  for label in range(1,len(np.unique(labels))):
    if label not in [0,main_label]:
      void_count += np.where(labels==label)[0].shape[0]
      unit[np.where(labels==label)] = 0.

  porosity = get_porosity(unit)

  if porosity > desired_porosity - tol and porosity < desired_porosity + tol:
    for label in range(1,len(np.unique(labels))):
      if label not in [0,main_label]:
        unit[np.where(labels==label)] = 0.

    if unit[0,:].sum() > 0 and unit[:,0].sum() > 0:
      # check if there is connectivity right-left
      connections_rl = 0
      for i in range(unit.shape[0]):
        if (unit[i,0] == 1 and unit[i,-1] == 1):
          connections_rl += 1

      # check if there is connectivity top-bottom
      connections_tb = 0
      for j in range(unit.shape[1]):
        if (unit[0,j] == 1 and unit[-1,j] == 1):
          connections_tb += 1

      if connections_rl == 0 or connections_tb == 0:
        passed = False
      
    else:
      passed = False
      
  else:
    passed = False

  if passed:
    passed = False
    for i in range(element.shape[0]):
      if [element[i,0],element[element.shape[0]-1,element.shape[1]-i-1]]==[1,1]:
        passed = True

  return passed, element

def check_singularity(element, simmetry):
  passeds = [True for i in range(4)]

  # check singularities inside element
  for i in range(element.shape[0]-1):
    for j in range(element.shape[1]-1):
      # print(element[i:i+2,j:j+2])
      diag1 = list(element[i:i+2,j:j+2].diagonal())
      diag2 = list(np.fliplr(element[i:i+2,j:j+2]).diagonal())
      if (diag1 == [1,1] and diag2 == [0,0]) or (diag1 == [0,0] and diag2 == [1,1]):
        passeds[0] = False    

  # check singularities in element boundary and singularities in unit boundary
  if simmetry[1:] == '4':
    for j in range(element.shape[1]-1):
      arr = np.array([[element[element.shape[0]-j-1,element.shape[1]-1],element[element.shape[0]-j-2,element.shape[1]-1]],[element[0,j],element[0,j+1]]])
      diag1 = list(arr.diagonal())
      diag2 = list(np.fliplr(arr).diagonal())
      if (diag1 == [1,1] and diag2 == [0,0]) or (diag1 == [0,0] and diag2 == [1,1]):
        passeds[1] = False
      
      arr = np.array([[element[element.shape[0]-1,j],element[element.shape[0]-1,j+1]],[element[j,0],element[j+1,0]]])
      diag1 = list(arr.diagonal())
      diag2 = list(np.fliplr(arr).diagonal())
      if (diag1 == [1,1] and diag2 == [0,0]) or (diag1 == [0,0] and diag2 == [1,1]):
        passeds[2] = False
      if [element[0,0],element[element.shape[0]-1,element.shape[1]-1]] == [1, 0] or [element[0,0],element[element.shape[0]-1,element.shape[1]-1]] == [0, 1]:
        passeds[3] = False

  return passeds

epoch_G = 220
epoch_D = 110
tol = 0.02
score = 'isotropy'
input_G = 128
simmetry = 'p4'
sampling_method = 'normal'
top = 5
rounds = 20
test_size = 10000
desired_porosity=0.55
save = False
plot = not save

score_filename, geom_epoch_dirs, gif_filename, tmp_models_dir, models_dir, arrays_dir = get_filenames(dimension, simulation, simmetry, score)

def save_models(epoch_G,epoch_D,save,tmp_models_dir,models_dir):
  # select model
  G_files = os.listdir(tmp_models_dir+'/G/')
  for i in range(len(G_files)):
    G_file = G_files[i]
    if int(G_file.split('_')[1]) == epoch_G:
      G = load_model(tmp_models_dir+'/G/'+G_file)
      break

  D_files = os.listdir(tmp_models_dir+'/D/')
  for i in range(len(D_files)):
    D_file = D_files[i]
    if int(D_file.split('_')[1]) == epoch_D:
      D = load_model(tmp_models_dir+'/D/'+D_file, custom_objects={'custom_por_loss':porosity_loss(),'custom_val_loss':validity_loss(),'InstanceNormalization':InstanceNormalization()})
      break

  if save: 
      models_filename = os.listdir(models_dir)
      models_filename = ['_'.join(x.split('_')[1:]) for x in models_filename]
      if G_file not in models_filename:
        idx_model = len(models_filename)+1
        G.save(models_dir+'%04d_'%(idx_model)+G_file)
      else:
        # find idx of existing model
        idx_model = models_filename.index(G_file)+1
  else:
    idx_model = None
  return G, D, idx_model

G,D,idx_model = save_models(epoch_G,epoch_D,save,tmp_models_dir,models_dir)

def generate_geometries(test_size, rounds, idx_model, top, tol, desired_porosity, save, plot):
  idx = len(os.listdir(arrays_dir))+1
  for r in range(rounds):
    X_test = generate_input_G(input_G,test_size,sampling_method)
    geometries = G.predict(X_test,verbose = 0)
    size = geometries.shape[1]

    prepor_size = geometries.shape[0]
    
    if plot:
      fig,ax = plt.subplots(1,2);
      fig.set_size_inches((10,5));
      
      ax[0].set_title('Porosity Histogram')
      ax[0].set_ylabel('Frequency')
      porosities = 1-np.sum(geometries.round().reshape((test_size,int(size*size))),axis=-1)/int(size*size)
      sns.histplot(porosities,ax=ax[0],bins=32,stat="density");
    
    _, geometries = porosity_match(geometries, desired_porosity, tol)
    elements = []
    preval_size = geometries.shape[0]

    for i in range(len(geometries)):
      geom = geometries[i].reshape((size,size)).round()
      unit = create_unit(geom,size,simmetry)
      passed_connectivity,element = check_unit(unit, desired_porosity, tol)
      passed_singularity = check_singularity(element, simmetry)
      if passed_connectivity and all(passed_singularity):
        elements.append(element)

    geometries = np.array(elements)
    postval_size = geometries.shape[0]

    # Get scores
    scores = D.predict([geometries],verbose = 0)[0].ravel()

    if plot:
      ax[1].set_title('Score Histogram')
      ax[1].set_ylabel('Frequency')
      sns.histplot(scores,ax=ax[1],bins=32,stat="density");
      print('Avg porosity: %.2f. Avg score: %.2f Validity match: %.2f'%(porosities.mean(),scores.mean(),postval_size/preval_size))
      plt.show()

    top_idxs = np.argsort(-scores)[:top]

    for top_idx in top_idxs:
      elem = geometries[top_idx]
      unit = create_unit(elem.reshape((size,size)),size,simmetry)
      arrange = create_arrange(unit,3,3)
      
      if plot:
        print("Score: %.2f Porosity: %.2f"%(scores[top_idx],get_porosity(elem)))
        fig,ax = plt.subplots(1,3);
        fig.set_size_inches((15,5))
        
        ax[0].imshow(elem,cmap='Greys');
        ax[0].axis('off')
        
        ax[1].imshow(unit,cmap="Greys")
        ax[1].axis('off')

        ax[2].imshow(arrange,cmap="Greys")
        ax[2].axis('off')
        plt.show()

      if save:
        filename = arrays_dir+"%05d_model_%04d_porosity_%.4f.txt" % (idx, idx_model, 1.0-elem.ravel().sum()/(size*size))
        elem = elem.ravel()
        elem_ = np.zeros(elem.shape[0]+1)
        elem_[0] = int(np.sqrt(elem.shape[0]))
        elem_[1:] = elem[:]
        elem = elem_
        np.savetxt(filename, elem, delimiter='/n', fmt='%s')
        idx += 1

generate_geometries(test_size, rounds, idx_model, top, tol, desired_porosity, save, plot)
# Out:
# Avg porosity: 0.49. Avg score: 0.94 Validity match: 0.25
# Score: 1.00 Porosity: 0.55
# Score: 1.00 Porosity: 0.56
# Score: 1.00 Porosity: 0.54
# Score: 1.00 Porosity: 0.57
# Score: 1.00 Porosity: 0.53
# Avg porosity: 0.49. Avg score: 0.94 Validity match: 0.24
# Score: 1.00 Porosity: 0.55
# Score: 1.00 Porosity: 0.54
# Score: 1.00 Porosity: 0.55
# Score: 1.00 Porosity: 0.56
# Score: 1.00 Porosity: 0.54
# Avg porosity: 0.49. Avg score: 0.94 Validity match: 0.24
# Score: 1.00 Porosity: 0.53
# Score: 1.00 Porosity: 0.54
# Score: 1.00 Porosity: 0.56
# Score: 1.00 Porosity: 0.57
# Score: 1.00 Porosity: 0.56
# Avg porosity: 0.49. Avg score: 0.94 Validity match: 0.23
# Score: 1.00 Porosity: 0.54
# Score: 1.00 Porosity: 0.53
# Score: 1.00 Porosity: 0.56
# Score: 1.00 Porosity: 0.56
# Score: 1.00 Porosity: 0.55
# Avg porosity: 0.49. Avg score: 0.93 Validity match: 0.23
# Score: 1.00 Porosity: 0.56
# Score: 1.00 Porosity: 0.53
# Score: 1.00 Porosity: 0.55
# Score: 1.00 Porosity: 0.57
# Score: 1.00 Porosity: 0.55
# Avg porosity: 0.49. Avg score: 0.94 Validity match: 0.25
# Score: 1.00 Porosity: 0.56
# Score: 1.00 Porosity: 0.54
# Score: 1.00 Porosity: 0.54
# Score: 1.00 Porosity: 0.54
# Score: 1.00 Porosity: 0.54
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-21-8084d5475e7d> in <module>
#     210         idx += 1
#     211
# --> 212 generate_geometries(test_size, rounds, idx_model, top, tol, desired_porosity, save, plot)
#
# <ipython-input-21-8084d5475e7d> in generate_geometries(test_size, rounds, idx_model, top, tol, desired_porosity, save, plot)
#     159     for i in range(len(geometries)):
#     160       geom = geometries[i].reshape((size,size)).round()
# --> 161       unit = create_unit(geom,size,simmetry)
#     162       passed_connectivity,element = check_unit(unit, desired_porosity, tol)
#     163       passed_singularity = check_singularity(element, simmetry)
#
# <ipython-input-7-8f3e49184112> in create_unit(element, size, simmetry)
#       3     unit_size = 2*size
#       4     # fold_size = np.random.choice(4,1)[0]
# ----> 5     unit = np.ones((2*size,2*size))*(-1)
#       6     h,w = element.shape
#       7     for i in range(h):
#
# c:\Users\lucas\Anaconda3\envs\deeplearn37\lib\site-packages\numpy\core\numeric.py in ones(shape, dtype, order, like)
#     203
#     204     a = empty(shape, dtype, order)
# --> 205     multiarray.copyto(a, 1, casting='unsafe')
#     206     return a
#     207
#
# <__array_function__ internals> in copyto(*args, **kwargs)
#
# KeyboardInterrupt:

# %%
geoms = np.random.randint(0,2,(100,256,1))
ref = geoms[0]
rmses = []
for i in range(1,len(geoms)):
    rmses.append(np.mean((ref-geoms[i])**2))

return np.round(np.mean(rmses),3)

sns.histplot(rmses,bins=32)
# Out:
# 0.499
# <AxesSubplot:ylabel='Count'>
