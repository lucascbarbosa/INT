# %% [markdown]
# # Imports

# %%
import os
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.preprocessing import MinMaxScaler
from skimage import measure
import imageio
import  cv2
# %matplotlib inline

import tensorflow as tf
from tensorflow.keras import backend as K
from tensorflow.keras.models import Model,load_model
from tensorflow.keras.layers import Dense, Flatten, Conv1D, Conv2D, Input, Conv2DTranspose, Concatenate, MaxPool1D, Dropout, Reshape, Lambda, InputLayer, LeakyReLU, BatchNormalization, GaussianNoise
from keras_contrib.layers.normalization.instancenormalization import InstanceNormalization
from tensorflow.keras.optimizers import Adam 
from tensorflow.keras.losses import MeanSquaredError, kullback_leibler_divergence
from tensorflow.keras.metrics import BinaryCrossentropy
from tensorflow.keras.initializers import RandomNormal
from tensorflow.keras.constraints import Constraint
import warnings
import logging
warnings.simplefilter("ignore")
logging.getLogger("tensorflow").setLevel(logging.ERROR)

tf.autograph.set_verbosity(0)
os.environ['AUTOGRAPH_VERBOSITY'] = '0'
os.environ['TF_CPP_MIN_LOG_LEVEL'] = '0'

# %% [markdown]
# ## Test GPU

# %%
physical_devices = tf.config.list_physical_devices('GPU') 
print("GPUs available:",len(physical_devices))
# Out:
# GPUs available: 1

# %% [markdown]
# # Data preparation

# %%
def get_filenames(dimension, simulation, simmetry, score):
    if os.getcwd().split('\\')[2] == 'lucas':
        score_filename = 'E:/Lucas GAN/Dados/4- Mechanical_scores/%s/%sD/%s/%s.csv' %(simulation,dimension,simmetry,score)
        geom_epoch_dirs = 'E:/Lucas GAN/Dados/7- Perfomance_data/%sD/geom_epoch/%s/%s/' %(dimension,simmetry,score)
        gif_filename = 'E:/Lucas GAN/Dados/7- Perfomance_data/%sD/geom_epoch/%s/%s.gif' %(dimension,simmetry,score)
        tmp_models_dir = 'C:/Users/lucas/OneDrive/Documentos/GitHub/INT/Manufatura Aditiva/Simulacao-GAN/Pipeline/3- Machine_learning/GAN/tmp_models/'
        models_dir = 'E:/Lucas GAN/Dados/5- GAN_models/%sD/%s/%s/'%(dimension,simmetry,score)
        arrays_dir = 'E:/Lucas GAN/Dados/1- Arranged_geometries/GAN/%s/%s/' % (simmetry,score)
    else:
        score_filename = 'D:/Lucas GAN/Dados/4- Mechanical_scores/%s/%sD/%s/%s.csv' %(simulation,dimension,simmetry,score)
        geom_epoch_dirs = 'D:/Lucas GAN/Dados/7- Perfomance_data/%sD/geom_epoch/%s/%s/' %(dimension,simmetry,score)
        gif_filename = 'D:/Lucas GAN/Dados/7- Perfomance_data/%sD/geom_epoch/%s/%s.gif' %(dimension,simmetry,score)
        tmp_models_dir = 'C:/Users/lucas/OneDrive/Documentos/GitHub/INT/Manufatura Aditiva/Simulacao-GAN/Pipeline/3- Machine_learning/GAN/tmp_models/'
        models_dir = 'D:/Lucas GAN/Dados/5- GAN_models/%sD/%s/%s/'%(dimension,simmetry,score)
        arrays_dir = 'D:/Lucas GAN/Dados/1- Arranged_geometries/GAN/%s/%s/' % (simmetry,score)

    return score_filename, geom_epoch_dirs, gif_filename, tmp_models_dir, models_dir, arrays_dir

def load_data(score_filename, cutoff, bins, soft=False, balance=False, plot=False):  
    def find_closest(arr, val):
       idx = np.abs(arr - val).argmin()
       return arr[idx]
    data = np.loadtxt(score_filename,delimiter=',')
    X = data[:,1:-1]
    size = int(np.sqrt(X.shape[1]))
    X = X.reshape((X.shape[0],size,size,1))

    y = data[:,-1]
    y = y.reshape((y.shape[0],1))
    y = y[np.argsort(y[:,0])]
    total_size = y.shape[0]

    if plot:
        sns.histplot(y, legend=True, bins=bins, color='b')
    
    cutoff = find_closest(bins,cutoff)
    idxs_good = np.where(y>cutoff)[0]
    y = y[idxs_good]
    X = X[idxs_good]
    min_bin = idxs_good.shape[0]

    if balance:
        bins_good = bins[np.where(bins>=cutoff)]
        for i in range(len(bins_good)-1):
            l,u = bins_good[i:i+2]
            idx_bin = np.where((y>=l) & (y<u))[0]
            y_bin = y[idx_bin]
            min_bin = min(min_bin,y_bin.shape[0])

        X_balanced = np.zeros((min_bin*(bins_good.shape[0]-1),X.shape[1],X.shape[2],X.shape[3]))
        y_balanced = np.zeros((min_bin*(bins_good.shape[0]-1),1))

        for i in range(len(bins_good)-1):
            l,u = bins_good[i:i+2]
            idx_bin = np.where((y>=l) & (y<u))[0]
            y_bin = y[idx_bin]
            X_bin = X[idx_bin]

            idx_bin = np.random.choice(y_bin.shape[0],min_bin)
            y_bin = y_bin[idx_bin]
            X_bin = X_bin[idx_bin]

            X_balanced[min_bin*i:min_bin*(i+1)] = X_bin
            y_balanced[min_bin*i:min_bin*(i+1)] = y_bin

        y = y_balanced
        X = X_balanced

        if plot:
            sns.histplot(y, legend=True, bins=bins, color='r')

    if soft:
        y = np.random.choice(np.linspace(0.7,1.2,6)).round(1)*np.ones(y.shape)
    
    plt.legend(['raw','Balanced'])
    
    print(f"Good = %.2f %%"%(100*len(y)/total_size))
    
    return X, y, size

dimension = 2
simulation = '-m'
simulation = {'-m':'MATLAB','-r':'RTGA'}[simulation]
simmetry = 'p4'
score = 'isotropy'
score_filename,_,_,_,_,_ = get_filenames(dimension, simulation, simmetry, score)

cutoff = 0.7
bins= np.linspace(0,1,41).round(3)
soft = True
plot = True
balance = True

X, y, size = load_data(score_filename, cutoff, bins, soft=soft, balance=balance, plot=plot)
# Out:
# Good = 33.60 %

# %% [markdown]
# # Models definition

# %% [markdown]
# ## Generator

# %%
def setup_G(input_G,output_G,size):
    size = int(size/2)
    in_G = Input(shape=(input_G,))

    # foundation for 8x8 image
    n_nodes = 128 * size * size
    out_G = Dense(n_nodes,activation=LeakyReLU(alpha=0.2))(in_G)
    # out_G = BatchNormalization()(out_G)
    out_G = LeakyReLU(alpha=0.2)(out_G)
    out_G = Reshape((size, size, 128))(out_G)
    # upsample to 16x16
    out_G = Conv2DTranspose(128, (4,4), strides=(2,2), padding='same',activation=LeakyReLU(alpha=0.2))(out_G)
    # out_G = BatchNormalization()(out_G)
    out_G = LeakyReLU(alpha=0.2)(out_G)
    out_G = Conv2D(1, (size,size), activation='sigmoid', padding='same')(out_G)
    out_porosity = Lambda(lambda x:x)(out_G)
    out_validity = Lambda(lambda x:x)(out_G)

    model = Model(name='Generator',inputs=in_G,outputs=[out_G,out_porosity,out_validity])
    return model
setup_G(128,256,16).summary()
# Out:
# Model: "Generator"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_1 (InputLayer)           [(None, 128)]        0           []
#
#  dense (Dense)                  (None, 8192)         1056768     ['input_1[0][0]']
#
#  leaky_re_lu_1 (LeakyReLU)      (None, 8192)         0           ['dense[0][0]']
#
#  reshape (Reshape)              (None, 8, 8, 128)    0           ['leaky_re_lu_1[0][0]']
#
#  conv2d_transpose (Conv2DTransp  (None, 16, 16, 128)  262272     ['reshape[0][0]']
#  ose)
#
#  leaky_re_lu_3 (LeakyReLU)      (None, 16, 16, 128)  0           ['conv2d_transpose[0][0]']
#
#  conv2d (Conv2D)                (None, 16, 16, 1)    8193        ['leaky_re_lu_3[0][0]']
#
#  lambda (Lambda)                (None, 16, 16, 1)    0           ['conv2d[0][0]']
#
#  lambda_1 (Lambda)              (None, 16, 16, 1)    0           ['conv2d[0][0]']
#
# ==================================================================================================
# Total params: 1,327,233
# Trainable params: 1,327,233
# Non-trainable params: 0
# __________________________________________________________________________________________________

# %% [markdown]
# ## Discriminator

# %%
def wasserstein_loss():
    def custom_loss(y_true, y_pred):
	    return K.mean(y_true * y_pred)
    return custom_loss

def porosity_loss():
    def custom_loss(y_true,y_pred):
        # size = y_pred.shape[1]*y_pred.shape[2]
        y_pred = K.round(y_pred)
        por_true = K.sum(K.sum(K.sum(y_true,axis=1),axis=1),axis=1)
        por_pred = K.sum(K.sum(K.sum(y_pred,axis=1),axis=1),axis=1)
        mse = tf.cast((por_true-por_pred)**2,tf.float32)
        return mse
    return custom_loss

def validity_loss():
    def custom_loss(y_true, y_pred):
        # @tf.function
        def connectivity_losss(element):
            size = element.shape[0]
            element = element.numpy().reshape((size,size))
            labels = measure.label(element,connectivity=1)
            return len(np.unique(labels))*2/(size*size)

        def simmetry_loss(element):
           return 0
            
        y_pred = K.round(y_pred)
        con_loss = tf.map_fn(fn=connectivity_losss, elems=y_pred)
        if simmetry[1:] in ['4m','4g']:
            sim_loss = tf.map_fn(fn=simmetry_loss, elems=y_pred)
            return con_loss + sim_loss
        return con_loss

    return custom_loss
    
def setup_D(input_D,loss,lr,alpha_por,alpha_val):
    #define model
    in_D = Input(shape=input_D)
    out_D = GaussianNoise(0.1)(in_D)
    out_D = Conv2D(64, (3,3), strides=(2, 2), padding='same', activation=LeakyReLU(alpha=0.2))(out_D)
    # out_D = InstanceNormalization()(out_D)
    # out_D = LeakyReLU(alpha=0.2)(out_D)
    out_D = GaussianNoise(0.1)(out_D)
    out_D = Dropout(0.4)(out_D)
    out_D = Conv2D(64, (3,3), strides=(2, 2), padding='same', activation=LeakyReLU(alpha=0.2))(out_D)
    # out_D = InstanceNormalization()(out_D)
    # out_D = LeakyReLU(alpha=0.2)(out_D)
    out_D = GaussianNoise(0.1)(out_D)
    out_D = Dropout(0.4)(out_D)
    out_D = Flatten()(out_D)
    out_D = Dense(1, activation='sigmoid')(out_D)

    # porosity branch
    in_porosity = Input(shape=input_D)
    out_porosity = Lambda(lambda x: x)(in_D)

    # validity branch
    in_validity = Input(shape=input_D)
    out_validity = Lambda(lambda x: x)(in_D)

    opt = Adam(learning_rate=lr, beta_1=0.5)
    
    model = Model(
                name='Discriminator', \
                inputs=[in_D,in_porosity,in_validity], \
                outputs=[out_D,out_porosity,out_validity])

    loss_func = {'bce':'binary_crossentropy','wl':wasserstein_loss,'kld':kullback_leibler_divergence}[loss]
    model.compile(
                loss=[loss_func,porosity_loss(),validity_loss()], \
                loss_weights=[1.0,0.0,0.0], \
                optimizer='adam', \
                metrics=['accuracy'], \
                run_eagerly=True)
    return model

D_test = setup_D((16,16,1),'bce',1e-4,0.01,0.01)
D_test.summary()
# tf.keras.utils.plot_model(D_test)
# Out:
# Model: "Discriminator"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_2 (InputLayer)           [(None, 16, 16, 1)]  0           []
#
#  gaussian_noise (GaussianNoise)  (None, 16, 16, 1)   0           ['input_2[0][0]']
#
#  conv2d_1 (Conv2D)              (None, 8, 8, 64)     640         ['gaussian_noise[0][0]']
#
#  gaussian_noise_1 (GaussianNois  (None, 8, 8, 64)    0           ['conv2d_1[0][0]']
#  e)
#
#  dropout (Dropout)              (None, 8, 8, 64)     0           ['gaussian_noise_1[0][0]']
#
#  conv2d_2 (Conv2D)              (None, 4, 4, 64)     36928       ['dropout[0][0]']
#
#  gaussian_noise_2 (GaussianNois  (None, 4, 4, 64)    0           ['conv2d_2[0][0]']
#  e)
#
#  dropout_1 (Dropout)            (None, 4, 4, 64)     0           ['gaussian_noise_2[0][0]']
#
#  flatten (Flatten)              (None, 1024)         0           ['dropout_1[0][0]']
#
#  input_3 (InputLayer)           [(None, 16, 16, 1)]  0           []
#
#  input_4 (InputLayer)           [(None, 16, 16, 1)]  0           []
#
#  dense_1 (Dense)                (None, 1)            1025        ['flatten[0][0]']
#
#  lambda_2 (Lambda)              (None, 16, 16, 1)    0           ['input_2[0][0]']
#
#  lambda_3 (Lambda)              (None, 16, 16, 1)    0           ['input_2[0][0]']
#
# ==================================================================================================
# Total params: 38,593
# Trainable params: 38,593
# Non-trainable params: 0
# __________________________________________________________________________________________________

# %% [markdown]
# ## Setup GAN

# %%
def setup_GAN(G_model,D_model,loss,alpha_por,alpha_val,lr,size):
    D_model.trainable = False
    in_G = G_model.input
    out_GAN = D_model(G_model(in_G))
    
    opt = Adam(learning_rate=lr, beta_1=0.5)
    
    model = Model(name='GAN',inputs=in_G,outputs=out_GAN)
    loss_func = {'bce':'binary_crossentropy','wl':wasserstein_loss,'kld':kullback_leibler_divergence}[loss]
    model.compile(
                loss=[loss_func,porosity_loss(),validity_loss()], \
                loss_weights=[1.0,alpha_por,alpha_val], \
                optimizer='adam', \
                metrics=['accuracy'], \
                run_eagerly=True)
    return model

setup_GAN(setup_G(128,256,16),setup_D((16,16,1),'bce',1e-4,0.01,0.01),'bce',0.01,0.01,1e-4,16).summary()
# Out:
# Model: "GAN"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_5 (InputLayer)           [(None, 128)]        0           []
#
#  Generator (Functional)         [(None, 16, 16, 1),  1327233     ['input_5[0][0]']
#                                  (None, 16, 16, 1),
#                                  (None, 16, 16, 1)]
#
#  Discriminator (Functional)     [(None, 1),          38593       ['Generator[0][0]',
#                                  (None, 16, 16, 1),               'Generator[0][1]',
#                                  (None, 16, 16, 1)]               'Generator[0][2]']
#
# ==================================================================================================
# Total params: 1,365,826
# Trainable params: 1,327,233
# Non-trainable params: 38,593
# __________________________________________________________________________________________________

# %% [markdown]
# # Aux functions

# %% [markdown]
# ## For geometry manipulation

# %%
def create_unit(element,size,simmetry):
  if simmetry[1:] == '4':
    unit_size = 2*size
    # fold_size = np.random.choice(4,1)[0]
    unit = np.ones((2*size,2*size))*(-1)
    h,w = element.shape
    for i in range(h):
      for j in range(w):
        el = element[i,j]
        
        j_ = [j,w-1-i,2*h-1-j,i+w]
        i_ = [i+w,j,w-1-i,2*h-1-j]
        # (1,7)->(7,14)->(14,8)->(8,1)
        for (k,l) in list(zip(i_,j_)):
          unit[k,l]  = el
    return unit

  if simmetry[1:] in ['4m','4g']:
    unit_element_size = 2*size
    # fold_element_size = np.random.choice(4,1)[0]
    unit = np.ones((2*size,2*size))*(-1)
    h,w = element.shape
    for i in range(h):
      for j in range(w):
        el = element[i,j]
        j_ = [j,unit_size-1-j,unit_size-1-j,j]
        i_ = [i+size,i+size,size-1-i,size-1-i]
        # (1,2)-> (1,13) -> (14,13) -> (14,2)
        for (k,l) in list(zip(i_,j_)):
          unit[k,l]  = el
    return unit

def create_arrange(unit,rows,cols):
  size = unit.shape[0]
  arrange = np.zeros((rows*size,cols*size))
  for i in range(unit.shape[0]):
    for j in range(unit.shape[1]):
      for row in range(rows):
        for col in range(cols):
          arrange[j+row*size,i+col*size] = unit[j,i]
  
  return arrange

def get_porosity(geom):
    voids = np.where(geom == 0.0)[0].shape[0]

    return voids/(geom.shape[0]*geom.shape[1])

# %% [markdown]
# ## For GAN

# %%
def generate_fake_samples(G_model, input_G, n_samples, method):
    # generate points in latent space
    X_input = generate_input_G(input_G, n_samples,method)
    # predict outputs
    X,_,_ = G_model.predict(X_input,verbose = 0)
    # create 'fake' class labels (0)
    y = np.zeros((n_samples, 1))
    return X,y

def generate_input_G(input_G, n_samples, method):

    if method == 'normal':
        # generate points in the latent space
        X_input = np.random.randn(input_G * n_samples)
        # reshape into a batch of inputs for the network
        X_input = X_input.reshape(n_samples, input_G)
    if method == 'uniform':
        X_input = np.random.uniform(n_samples,input_G)
    if method == 'spherical':
        X_input = np.random.randn(input_G * n_samples)
        # reshape into a batch of inputs for the network
        X_input = X_input.reshape(n_samples, input_G)
        X_input /= np.linalg.norm(X_input, axis=0)/3.0
    return X_input

def generate_real_samples(dataset, y, n_samples):
    # choose random instances
    idx = np.random.randint(0, dataset.shape[0], n_samples)
    # retrieve selected images
    X = dataset[idx]
    # generate 'real' class labels (1)
    y = y[idx]
    return X, y

def summarize_performance(epoch,porosity,G_model, D_model, dataset, y, input_G, sampling_method, n_samples=100):
    # prepare real samples
    X_real, y_real = generate_real_samples(dataset, y, n_samples)
    # evaluate discriminator on real examples
    _,_,_,_,acc_real,_,_ = D_model.evaluate(x=[X_real,X_real,X_real], y=[y_real,porosity*np.ones(X_real.shape),np.zeros(X_real.shape)], verbose=0)
    # prepare fake examples
    X_fake, y_fake = generate_fake_samples(G_model, input_G, n_samples, sampling_method)
    # evaluate discriminator on fake examples
    _,_,_,_,acc_fake,_,_ = D_model.evaluate(x=[X_fake,X_fake,X_fake], y=[y_fake,porosity*np.ones(X_fake.shape),np.zeros(X_fake.shape)], verbose=0)
    # summarize discriminator performance
    return  acc_real,acc_fake

# Filter per porosity
def porosity_match(geoms,porosity,tol):
    geoms_ = []
    passed = 0
    for i in range(geoms.shape[0]):
        g =geoms[i,:,:,0]
        size = g.shape[0]
        g = g.reshape((size*size,))
        p = 1 - np.sum(g)/(size*size)
        if p >= porosity-tol and p <= porosity+tol:
            geoms_.append(g.reshape((size,size)))
            passed += 1
    return passed/len(geoms),np.array(geoms_).reshape((passed,size,size,1))

# %% [markdown]
# # Training GAN

# %%
def train_GAN(X, y, G_model, D_model, GAN_model, input_G, porosity, tol_porosity, batch_size, num_epochs, sampling_method, tmp_models_dir, geom_epoch_dirs, seed_geom_gif, tol_fail, alpha_por, alpha_val, vstack=True, plot=False, verbose_loss=False, verbose_acc=False):
    def train_D(X,y,half_batch):
        if vstack:
            X_real,y_real = generate_real_samples(X,y,half_batch)
            X_fake,y_fake = generate_fake_samples(G_model,input_G,half_batch,sampling_method)            

            X, y = np.vstack((X_real, X_fake)), np.vstack((y_real, y_fake))
            
            if verbose_loss:
                D_loss = D_model.train_on_batch(x=[X,X,X], y=[y,porosity*np.ones(X.shape),0*np.ones(X.shape)],return_dict=True)
                D_loss = D_loss['loss']
            else:
                D_loss = D_model.train_on_batch(x=[X,X,X], y=[y,porosity*np.ones(X.shape),0*np.ones(X.shape)])
                D_loss = D_loss[0]

        else:
            X_real,y_real = generate_real_samples(X,y,half_batch)
            X_fake,y_fake = generate_fake_samples(G_model,input_G,half_batch,sampling_method)            

            if verbose_loss:
                D_loss_real = D_model.train_on_batch(x=[X_real,X_real,X_real], y=[y_real,porosity*np.ones(X_real.shape),0*np.ones(X_real.shape)],return_dict=True)
                D_loss_real = D_loss_real['loss']
                D_loss_fake = D_model.train_on_batch(x=[X_fake,X_fake,X_fake], y=[y_fake,porosity*np.ones(X_fake.shape),0*np.ones(X_fake.shape)],return_dict=True)
                D_loss_fake = D_loss_fake['loss']
            else:
                D_loss_real = D_model.train_on_batch(x=[X_real,X_real,X_real], y=[y_real,porosity*np.ones(X_real.shape),0*np.ones(X_real.shape)])
                D_loss_real = D_loss_real[0]
                D_loss_fake = D_model.train_on_batch(x=[X_fake,X_fake,X_fake], y=[y_fake,porosity*np.ones(X_fake.shape),0*np.ones(X_fake.shape)])
                D_loss_fake = D_loss_fake[0]

            D_loss = (D_loss_real+D_loss_fake)/2
            

        return D_loss
    
    def train_G(X_shape,alpha_por,alpha_val):
        X_GAN = generate_input_G(input_G, batch_size, sampling_method)
        y_GAN = np.ones((batch_size, 1))

        if verbose_loss:
            G_loss_list = GAN_model.train_on_batch(x=X_GAN, y=[y_GAN,porosity*np.ones(X_shape),0*np.ones(X_shape)],return_dict=True)
            idxs = list(G_loss_list.keys())
        else:
            G_loss_list = GAN_model.train_on_batch(x=X_GAN, y=[y_GAN,porosity*np.ones(X_shape),0*np.ones(X_shape)])
            idxs = [0,1,2,3]

        G_total_loss = G_loss_list[idxs[0]]
        G_loss = G_loss_list[idxs[1]]
        G_por_loss = alpha_por*G_loss_list[idxs[2]]
        G_val_loss = alpha_val*G_loss_list[idxs[3]]

        return G_total_loss,G_loss,G_por_loss,G_val_loss

    def clean_tmp_models(tmp_models_dir):
        for file in os.listdir(tmp_models_dir+'/G/'):
            os.remove(tmp_models_dir+'/G/'+file)

        for file in os.listdir(tmp_models_dir+'/D/'):
            os.remove(tmp_models_dir+'/D/'+file)

        for geom_file in os.listdir(geom_epoch_dirs):
            os.remove(geom_epoch_dirs+geom_file)

    # remove previous tmp models files
    clean_tmp_models(tmp_models_dir)

    batch_per_epoch = int(X.shape[0] /batch_size)
    half_batch = int(batch_size/2)
    
    G_losses = []
    G_por_losses = []
    G_val_losses = []
    D_losses = []

    accs_real = []
    accs_fake = []
    pors_match = []
    stds = []
    
    fig,ax = plt.subplots(1,3);
    fig.set_size_inches((24,8))

    for i in range(num_epochs):
        G_losses_epoch = []
        G_por_losses_epoch = []
        G_val_losses_epoch = []
        D_losses_epoch = []
        for j in range(batch_per_epoch):
            # train D
            D_loss = train_D(X,y,half_batch)
            # check failure mode
            if D_loss <= tol_fail:
                print('Failure Mode. Stopping training...')

            D_losses_epoch.append(D_loss)

            # train G
            G_total_loss,G_loss,G_por_loss,G_val_loss = train_G((batch_size,X.shape[1],X.shape[2],X.shape[3]),alpha_por,alpha_val)
            G_losses_epoch.append(G_total_loss)
            G_por_losses_epoch.append(G_por_loss)
            G_val_losses_epoch.append(G_val_loss)
            if verbose_loss: 
                print('>%d, %d/%d, D_loss=%.3f, G_loss=%.3f' % (i+1, j+1, batch_per_epoch,  D_loss, G_total_loss))

        G_losses.append(np.array(G_losses_epoch).mean())
        G_por_losses.append(np.array(G_por_losses_epoch).mean())
        G_val_losses.append(np.array(G_val_losses_epoch).mean())
        D_losses.append(np.array(D_losses_epoch).mean())
        
        # export model
        if (i+1) % 10 == 0:
            acc_real,acc_fake = summarize_performance(i+1,porosity,G_model,D_model,X,y,input_G,sampling_method)
            accs_real.append(acc_real)
            accs_fake.append(acc_fake)

            X_test = generate_input_G(input_G,1000,sampling_method)
            geoms,_,_ = G_model.predict(X_test, verbose=0)
            geoms = np.array(geoms)
            por_match,_ = porosity_match(geoms, porosity, tol_porosity)
            pors_match.append(por_match)

            score = D_model.predict([geoms,geoms,geoms],verbose=0)[0]
            std = score.std()
            stds.append(std)

            G_model.save(tmp_models_dir+'/G/epoch_%03d_por_%.2f_std_%.2f_real_%.2f_fake_%.2f.h5'%(i+1, por_match, std, acc_real, acc_fake))
            D_model.save(tmp_models_dir+'/D/epoch_%03d.h5'%(i+1))
            
            if verbose_acc:
                os.system('cls')
                print('>Epoch: %i Porosity match: %.0f%% Std: %.0f real: %.0f%% fake: %.0f%%' % (i+1, std, por_match*100, acc_real*100, acc_fake*100))

        # save geometry
        if (i+1) % 5 == 0:
            geom_gif_filename = geom_epoch_dirs + 'epoch_%03d.png'%(i+1)
            elem_gif,_,_ = G_model.predict(seed_geom_gif, verbose=0)
            size = elem_gif.shape[1]
            elem_gif = elem_gif.reshape((size,size))
            ax[0].imshow(elem_gif,cmap='Greys');
            ax[0].axis('off')

            unit_gif = create_unit(elem_gif,size,'p4') 
            ax[1].imshow(unit_gif,cmap='Greys');
            ax[1].axis('off')

            arrange_gif = create_arrange(unit_gif,3,3)
            ax[2].imshow(arrange_gif,cmap='Greys');
            ax[2].axis('off')
            plt.savefig(geom_gif_filename, bbox_inches='tight')
    
    G_losses = np.array(G_losses)
    G_por_losses = np.array(G_por_losses)
    G_val_losses = np.array(G_val_losses)
    D_losses = np.array(D_losses)

    if plot:
        plt.figure(figsize=((10,8)))
        plt.plot(list(range(1,num_epochs+1)),D_losses,label='D Loss')
        plt.title('Loss')
        plt.ylabel('Loss')
        plt.xlabel('Epoch')
        plt.plot(list(range(1,num_epochs+1)),G_losses,label='G Loss')
        plt.plot(list(range(1,num_epochs+1)),G_por_losses,label='Porosity loss')
        plt.plot(list(range(1,num_epochs+1)),G_val_losses,label='Validity loss')
        plt.legend()
        plt.show()

        fig, ax = plt.subplots(3)
        fig.tight_layout(pad=0.75)
        fig.set_size_inches((10,8))
        ax[0].plot(list(range(1,num_epochs+1,10)),accs_fake,label='Accuracy fake')
        ax[0].set_xlabel('Epoch')
        ax[0].plot(list(range(1,num_epochs+1,10)),accs_real,label='Accuracy real')
        ax[0].legend()

        ax[1].plot(list(range(1,num_epochs+1,10)),pors_match)
        ax[1].set_title('Porosity match')
        ax[1].set_xlabel('Epoch')
        
        ax[2].plot(list(range(1,num_epochs+1,10)),stds)
        ax[2].set_title('Std dev')
        ax[2].set_xlabel('Epoch')
        ax[1].legend()
        plt.show()

# %%
# data origin parameters
dimension = 2
simulation = '-m'
simulation = {'-m':'MATLAB','-r':'RTGA'}[simulation]
simmetry = 'p4'
score = 'isotropy'

# data processing parameters
# cutoff = 0.56 # p4m
score_filename, geom_epoch_dirs, gif_filename, tmp_models_dir, models_dir, arrays_dir = get_filenames(dimension, simulation, simmetry, score)
cutoff = 0.7 # p4
bins= np.linspace(0,1,41).round(3)
soft = True
plot = True
balance = True
X, y, size = load_data(score_filename, cutoff, bins, soft=soft, balance=balance, plot = plot)

# GAN dimensions
input_G = 128
output_G = input_D = X.shape[1:]
output_D = 1

# training parameters
sampling_method = 'normal'
loss = 'bce' 
num_epochs = 300
batch_size = 64
lr = 1e-4
alpha_por = 2e-4 #2e-4
alpha_val = 2e-1 #2e-1
vstack=False

# style loss parameters
porosity = 0.55
tol_porosity = 0.02
tol_fail = 5e-3

# setup models
G = setup_G(input_G,output_G,size)
D = setup_D(input_D,loss,lr,alpha_por,alpha_val)
GAN = setup_GAN(G,D,loss,alpha_por,alpha_val,lr,size)

# metrics paramaters
plot=True
verbose_loss=True
verbose_acc=True

seed_geom_gif = np.random.randn(input_G).reshape(1, input_G)

train_GAN(X,y,G,D,GAN,input_G,porosity,tol_porosity,batch_size,num_epochs,sampling_method,tmp_models_dir,geom_epoch_dirs,seed_geom_gif,tol_fail,alpha_por, alpha_val, vstack=vstack,plot=plot,verbose_loss=verbose_loss,verbose_acc=verbose_acc)
# Out:
# Good = 33.60 %
# >1, 1/5, D_loss=0.731, G_loss=0.705
# >1, 2/5, D_loss=0.698, G_loss=3.257
# >1, 3/5, D_loss=0.731, G_loss=3.292
# >1, 4/5, D_loss=0.687, G_loss=3.335
# >1, 5/5, D_loss=0.695, G_loss=3.385
# >2, 1/5, D_loss=0.661, G_loss=3.387
# >2, 2/5, D_loss=0.645, G_loss=2.980
# >2, 3/5, D_loss=0.629, G_loss=1.221
# >2, 4/5, D_loss=0.638, G_loss=0.822
# >2, 5/5, D_loss=0.657, G_loss=1.025
# >3, 1/5, D_loss=0.698, G_loss=1.733
# >3, 2/5, D_loss=0.654, G_loss=3.326
# >3, 3/5, D_loss=0.649, G_loss=4.044
# >3, 4/5, D_loss=0.732, G_loss=4.430
# >3, 5/5, D_loss=0.725, G_loss=4.667
# >4, 1/5, D_loss=0.706, G_loss=4.618
# >4, 2/5, D_loss=0.718, G_loss=4.598
# >4, 3/5, D_loss=0.700, G_loss=4.580
# >4, 4/5, D_loss=0.699, G_loss=4.569
# >4, 5/5, D_loss=0.715, G_loss=4.575
# >5, 1/5, D_loss=0.675, G_loss=4.597
# >5, 2/5, D_loss=0.662, G_loss=4.598
# >5, 3/5, D_loss=0.620, G_loss=4.599
# >5, 4/5, D_loss=0.561, G_loss=4.588
# >5, 5/5, D_loss=0.539, G_loss=4.605
# >6, 1/5, D_loss=0.545, G_loss=4.589
# >6, 2/5, D_loss=0.527, G_loss=4.599
# >6, 3/5, D_loss=0.499, G_loss=4.619
# >6, 4/5, D_loss=0.462, G_loss=4.658
# >6, 5/5, D_loss=0.446, G_loss=4.624
# >7, 1/5, D_loss=0.436, G_loss=4.650
# >7, 2/5, D_loss=0.415, G_loss=4.652
# >7, 3/5, D_loss=0.398, G_loss=4.664
# >7, 4/5, D_loss=0.394, G_loss=4.659
# >7, 5/5, D_loss=0.362, G_loss=4.720
# >8, 1/5, D_loss=0.351, G_loss=4.721
# >8, 2/5, D_loss=0.336, G_loss=4.754
# >8, 3/5, D_loss=0.335, G_loss=4.811
# >8, 4/5, D_loss=0.305, G_loss=4.829
# >8, 5/5, D_loss=0.292, G_loss=4.856
# >9, 1/5, D_loss=0.274, G_loss=4.908
# >9, 2/5, D_loss=0.311, G_loss=4.890
# >9, 3/5, D_loss=0.275, G_loss=4.860
# >9, 4/5, D_loss=0.287, G_loss=4.892
# >9, 5/5, D_loss=0.350, G_loss=4.634
# >10, 1/5, D_loss=0.450, G_loss=3.774
# >10, 2/5, D_loss=0.627, G_loss=2.092
# >10, 3/5, D_loss=0.957, G_loss=1.185
# >10, 4/5, D_loss=1.067, G_loss=0.462
# >10, 5/5, D_loss=0.960, G_loss=1.572
# >Epoch: 10 Porosity match: 0% Std: 0 real: 98% fake: 0%
# >11, 1/5, D_loss=0.735, G_loss=3.398
# >11, 2/5, D_loss=0.707, G_loss=4.595
# >11, 3/5, D_loss=0.833, G_loss=5.160
# >11, 4/5, D_loss=0.900, G_loss=5.116
# >11, 5/5, D_loss=0.944, G_loss=4.790
# >12, 1/5, D_loss=0.807, G_loss=4.506
# >12, 2/5, D_loss=0.719, G_loss=3.966
# >12, 3/5, D_loss=0.605, G_loss=3.825
# >12, 4/5, D_loss=0.652, G_loss=3.760
# >12, 5/5, D_loss=0.593, G_loss=3.533
# >13, 1/5, D_loss=0.574, G_loss=3.886
# >13, 2/5, D_loss=0.527, G_loss=4.057
# >13, 3/5, D_loss=0.494, G_loss=4.283
# >13, 4/5, D_loss=0.411, G_loss=4.408
# >13, 5/5, D_loss=0.464, G_loss=4.685
# >14, 1/5, D_loss=0.405, G_loss=4.917
# >14, 2/5, D_loss=0.443, G_loss=4.991
# >14, 3/5, D_loss=0.392, G_loss=4.646
# >14, 4/5, D_loss=0.438, G_loss=4.750
# >14, 5/5, D_loss=0.384, G_loss=4.418
# >15, 1/5, D_loss=0.438, G_loss=4.469
# >15, 2/5, D_loss=0.430, G_loss=4.845
# >15, 3/5, D_loss=0.485, G_loss=4.214
# >15, 4/5, D_loss=0.429, G_loss=4.382
# >15, 5/5, D_loss=0.539, G_loss=3.958
# >16, 1/5, D_loss=0.430, G_loss=4.092
# >16, 2/5, D_loss=0.504, G_loss=3.745
# >16, 3/5, D_loss=0.554, G_loss=3.736
# >16, 4/5, D_loss=0.642, G_loss=3.370
# >16, 5/5, D_loss=0.627, G_loss=1.766
# >17, 1/5, D_loss=0.915, G_loss=1.086
# >17, 2/5, D_loss=0.895, G_loss=2.283
# >17, 3/5, D_loss=0.886, G_loss=3.480
# >17, 4/5, D_loss=0.807, G_loss=3.889
# >17, 5/5, D_loss=0.787, G_loss=4.203
# >18, 1/5, D_loss=0.640, G_loss=4.367
# >18, 2/5, D_loss=0.639, G_loss=4.452
# >18, 3/5, D_loss=0.668, G_loss=4.450
# >18, 4/5, D_loss=0.586, G_loss=4.493
# >18, 5/5, D_loss=0.531, G_loss=4.523
# >19, 1/5, D_loss=0.534, G_loss=4.501
# >19, 2/5, D_loss=0.478, G_loss=4.562
# >19, 3/5, D_loss=0.482, G_loss=4.512
# >19, 4/5, D_loss=0.462, G_loss=4.490
# >19, 5/5, D_loss=0.448, G_loss=4.496
# >20, 1/5, D_loss=0.464, G_loss=4.399
# >20, 2/5, D_loss=0.434, G_loss=4.288
# >20, 3/5, D_loss=0.412, G_loss=4.148
# >20, 4/5, D_loss=0.431, G_loss=4.032
# >20, 5/5, D_loss=0.436, G_loss=3.831
# >Epoch: 20 Porosity match: 0% Std: 0 real: 100% fake: 36%
# >21, 1/5, D_loss=0.493, G_loss=3.522
# >21, 2/5, D_loss=0.519, G_loss=2.990
# >21, 3/5, D_loss=0.591, G_loss=2.526
# >21, 4/5, D_loss=0.600, G_loss=2.458
# >21, 5/5, D_loss=0.657, G_loss=1.798
# >22, 1/5, D_loss=0.665, G_loss=1.582
# >22, 2/5, D_loss=0.645, G_loss=1.292
# >22, 3/5, D_loss=0.659, G_loss=0.944
# >22, 4/5, D_loss=0.736, G_loss=0.861
# >22, 5/5, D_loss=0.743, G_loss=0.847
# >23, 1/5, D_loss=0.812, G_loss=1.080
# >23, 2/5, D_loss=0.809, G_loss=1.510
# >23, 3/5, D_loss=0.852, G_loss=1.769
# >23, 4/5, D_loss=0.922, G_loss=2.173
# >23, 5/5, D_loss=0.911, G_loss=2.671
# >24, 1/5, D_loss=0.910, G_loss=2.755
# >24, 2/5, D_loss=0.892, G_loss=3.009
# >24, 3/5, D_loss=0.896, G_loss=3.070
# >24, 4/5, D_loss=0.824, G_loss=3.205
# >24, 5/5, D_loss=0.813, G_loss=3.300
# >25, 1/5, D_loss=0.760, G_loss=3.432
# >25, 2/5, D_loss=0.756, G_loss=3.626
# >25, 3/5, D_loss=0.723, G_loss=3.665
# >25, 4/5, D_loss=0.717, G_loss=3.691
# >25, 5/5, D_loss=0.733, G_loss=3.714
# >26, 1/5, D_loss=0.661, G_loss=3.753
# >26, 2/5, D_loss=0.672, G_loss=3.843
# >26, 3/5, D_loss=0.637, G_loss=3.801
# >26, 4/5, D_loss=0.664, G_loss=3.890
# >26, 5/5, D_loss=0.610, G_loss=3.884
# >27, 1/5, D_loss=0.606, G_loss=3.943
# >27, 2/5, D_loss=0.578, G_loss=3.926
# >27, 3/5, D_loss=0.581, G_loss=3.947
# >27, 4/5, D_loss=0.579, G_loss=3.997
# >27, 5/5, D_loss=0.610, G_loss=3.999
# >28, 1/5, D_loss=0.551, G_loss=3.922
# >28, 2/5, D_loss=0.607, G_loss=3.968
# >28, 3/5, D_loss=0.560, G_loss=3.919
# >28, 4/5, D_loss=0.551, G_loss=3.894
# >28, 5/5, D_loss=0.566, G_loss=3.824
# >29, 1/5, D_loss=0.563, G_loss=3.747
# >29, 2/5, D_loss=0.503, G_loss=3.800
# >29, 3/5, D_loss=0.535, G_loss=3.674
# >29, 4/5, D_loss=0.502, G_loss=3.724
# >29, 5/5, D_loss=0.485, G_loss=3.581
# >30, 1/5, D_loss=0.491, G_loss=3.791
# >30, 2/5, D_loss=0.527, G_loss=3.481
# >30, 3/5, D_loss=0.466, G_loss=3.676
# >30, 4/5, D_loss=0.485, G_loss=3.528
# >30, 5/5, D_loss=0.496, G_loss=3.450
# >Epoch: 30 Porosity match: 0% Std: 0 real: 66% fake: 94%
# >31, 1/5, D_loss=0.493, G_loss=3.048
# >31, 2/5, D_loss=0.481, G_loss=3.176
# >31, 3/5, D_loss=0.507, G_loss=3.074
# >31, 4/5, D_loss=0.445, G_loss=3.444
# >31, 5/5, D_loss=0.475, G_loss=3.168
# >32, 1/5, D_loss=0.520, G_loss=3.452
# >32, 2/5, D_loss=0.556, G_loss=3.191
# >32, 3/5, D_loss=0.464, G_loss=2.639
# >32, 4/5, D_loss=0.484, G_loss=3.431
# >32, 5/5, D_loss=0.541, G_loss=2.848
# >33, 1/5, D_loss=0.459, G_loss=3.315
# >33, 2/5, D_loss=0.533, G_loss=2.390
# >33, 3/5, D_loss=0.483, G_loss=2.775
# >33, 4/5, D_loss=0.429, G_loss=2.986
# >33, 5/5, D_loss=0.541, G_loss=3.119
# >34, 1/5, D_loss=0.498, G_loss=2.996
# >34, 2/5, D_loss=0.484, G_loss=2.944
# >34, 3/5, D_loss=0.457, G_loss=2.875
# >34, 4/5, D_loss=0.374, G_loss=2.558
# >34, 5/5, D_loss=0.505, G_loss=2.918
# >35, 1/5, D_loss=0.537, G_loss=2.621
# >35, 2/5, D_loss=0.508, G_loss=2.596
# >35, 3/5, D_loss=0.472, G_loss=2.880
# >35, 4/5, D_loss=0.604, G_loss=2.706
# >35, 5/5, D_loss=0.469, G_loss=3.352
# >36, 1/5, D_loss=0.596, G_loss=2.888
# >36, 2/5, D_loss=0.524, G_loss=2.127
# >36, 3/5, D_loss=0.591, G_loss=1.847
# >36, 4/5, D_loss=0.625, G_loss=2.504
# >36, 5/5, D_loss=0.504, G_loss=2.051
# >37, 1/5, D_loss=0.576, G_loss=2.491
# >37, 2/5, D_loss=0.571, G_loss=2.250
# >37, 3/5, D_loss=0.606, G_loss=1.953
# >37, 4/5, D_loss=0.544, G_loss=1.940
# >37, 5/5, D_loss=0.560, G_loss=1.591
# >38, 1/5, D_loss=0.643, G_loss=1.632
# >38, 2/5, D_loss=0.652, G_loss=1.427
# >38, 3/5, D_loss=0.679, G_loss=1.315
# >38, 4/5, D_loss=0.719, G_loss=1.160
# >38, 5/5, D_loss=0.802, G_loss=1.285
# >39, 1/5, D_loss=0.721, G_loss=1.276
# >39, 2/5, D_loss=0.791, G_loss=1.317
# >39, 3/5, D_loss=0.842, G_loss=1.325
# >39, 4/5, D_loss=0.866, G_loss=1.567
# >39, 5/5, D_loss=0.756, G_loss=1.671
# >40, 1/5, D_loss=0.828, G_loss=1.827
# >40, 2/5, D_loss=0.809, G_loss=1.953
# >40, 3/5, D_loss=0.806, G_loss=2.253
# >40, 4/5, D_loss=0.739, G_loss=2.223
# >40, 5/5, D_loss=0.779, G_loss=2.483
# >Epoch: 40 Porosity match: 0% Std: 0 real: 95% fake: 0%
# >41, 1/5, D_loss=0.730, G_loss=2.728
# >41, 2/5, D_loss=0.706, G_loss=2.823
# >41, 3/5, D_loss=0.679, G_loss=2.909
# >41, 4/5, D_loss=0.642, G_loss=2.974
# >41, 5/5, D_loss=0.610, G_loss=3.197
# >42, 1/5, D_loss=0.565, G_loss=3.228
# >42, 2/5, D_loss=0.563, G_loss=3.280
# >42, 3/5, D_loss=0.534, G_loss=3.407
# >42, 4/5, D_loss=0.560, G_loss=3.374
# >42, 5/5, D_loss=0.509, G_loss=3.358
# >43, 1/5, D_loss=0.458, G_loss=3.340
# >43, 2/5, D_loss=0.487, G_loss=3.318
# >43, 3/5, D_loss=0.476, G_loss=3.381
# >43, 4/5, D_loss=0.479, G_loss=3.400
# >43, 5/5, D_loss=0.437, G_loss=3.297
# >44, 1/5, D_loss=0.423, G_loss=3.217
# >44, 2/5, D_loss=0.444, G_loss=3.214
# >44, 3/5, D_loss=0.410, G_loss=3.132
# >44, 4/5, D_loss=0.396, G_loss=3.107
# >44, 5/5, D_loss=0.399, G_loss=3.014
# >45, 1/5, D_loss=0.431, G_loss=2.866
# >45, 2/5, D_loss=0.371, G_loss=2.706
# >45, 3/5, D_loss=0.381, G_loss=2.538
# >45, 4/5, D_loss=0.400, G_loss=2.495
# >45, 5/5, D_loss=0.367, G_loss=2.308
# >46, 1/5, D_loss=0.377, G_loss=2.382
# >46, 2/5, D_loss=0.386, G_loss=2.218
# >46, 3/5, D_loss=0.361, G_loss=2.158
# >46, 4/5, D_loss=0.406, G_loss=2.098
# >46, 5/5, D_loss=0.356, G_loss=2.048
# >47, 1/5, D_loss=0.388, G_loss=1.928
# >47, 2/5, D_loss=0.381, G_loss=1.835
# >47, 3/5, D_loss=0.424, G_loss=1.850
# >47, 4/5, D_loss=0.398, G_loss=1.719
# >47, 5/5, D_loss=0.421, G_loss=1.624
# >48, 1/5, D_loss=0.450, G_loss=1.668
# >48, 2/5, D_loss=0.462, G_loss=1.737
# >48, 3/5, D_loss=0.484, G_loss=1.844
# >48, 4/5, D_loss=0.489, G_loss=1.602
# >48, 5/5, D_loss=0.693, G_loss=1.570
# >49, 1/5, D_loss=0.661, G_loss=1.636
# >49, 2/5, D_loss=0.619, G_loss=1.537
# >49, 3/5, D_loss=0.646, G_loss=1.763
# >49, 4/5, D_loss=0.670, G_loss=1.703
# >49, 5/5, D_loss=0.892, G_loss=1.562
# >50, 1/5, D_loss=0.978, G_loss=1.495
# >50, 2/5, D_loss=0.955, G_loss=1.558
# >50, 3/5, D_loss=0.920, G_loss=1.571
# >50, 4/5, D_loss=0.957, G_loss=1.869
# >50, 5/5, D_loss=0.963, G_loss=2.016
# >Epoch: 50 Porosity match: 0% Std: 5 real: 5% fake: 75%
# >51, 1/5, D_loss=0.997, G_loss=1.915
# >51, 2/5, D_loss=0.944, G_loss=1.966
# >51, 3/5, D_loss=0.938, G_loss=1.907
# >51, 4/5, D_loss=0.931, G_loss=1.645
# >51, 5/5, D_loss=0.883, G_loss=1.622
# >52, 1/5, D_loss=1.021, G_loss=1.658
# >52, 2/5, D_loss=1.005, G_loss=1.561
# >52, 3/5, D_loss=0.945, G_loss=1.796
# >52, 4/5, D_loss=0.860, G_loss=1.849
# >52, 5/5, D_loss=1.009, G_loss=1.818
# >53, 1/5, D_loss=0.911, G_loss=1.920
# >53, 2/5, D_loss=0.876, G_loss=2.196
# >53, 3/5, D_loss=0.817, G_loss=1.837
# >53, 4/5, D_loss=0.865, G_loss=2.002
# >53, 5/5, D_loss=0.836, G_loss=2.019
# >54, 1/5, D_loss=0.831, G_loss=1.913
# >54, 2/5, D_loss=0.823, G_loss=1.856
# >54, 3/5, D_loss=0.827, G_loss=1.610
# >54, 4/5, D_loss=0.838, G_loss=1.625
# >54, 5/5, D_loss=0.767, G_loss=1.543
# >55, 1/5, D_loss=0.766, G_loss=1.487
# >55, 2/5, D_loss=0.849, G_loss=1.375
# >55, 3/5, D_loss=0.770, G_loss=1.383
# >55, 4/5, D_loss=0.769, G_loss=1.348
# >55, 5/5, D_loss=0.821, G_loss=1.329
# >56, 1/5, D_loss=0.740, G_loss=1.280
# >56, 2/5, D_loss=0.793, G_loss=1.347
# >56, 3/5, D_loss=0.744, G_loss=1.174
# >56, 4/5, D_loss=0.731, G_loss=1.224
# >56, 5/5, D_loss=0.673, G_loss=1.215
# >57, 1/5, D_loss=0.751, G_loss=1.180
# >57, 2/5, D_loss=0.605, G_loss=1.301
# >57, 3/5, D_loss=0.640, G_loss=1.337
# >57, 4/5, D_loss=0.626, G_loss=1.353
# >57, 5/5, D_loss=0.590, G_loss=1.633
# >58, 1/5, D_loss=0.539, G_loss=1.646
# >58, 2/5, D_loss=0.503, G_loss=1.615
# >58, 3/5, D_loss=0.453, G_loss=1.825
# >58, 4/5, D_loss=0.446, G_loss=2.069
# >58, 5/5, D_loss=0.359, G_loss=2.248
# >59, 1/5, D_loss=0.346, G_loss=2.162
# >59, 2/5, D_loss=0.365, G_loss=2.516
# >59, 3/5, D_loss=0.294, G_loss=2.420
# >59, 4/5, D_loss=0.252, G_loss=2.679
# >59, 5/5, D_loss=0.239, G_loss=2.648
# >60, 1/5, D_loss=0.226, G_loss=2.931
# >60, 2/5, D_loss=0.179, G_loss=2.730
# >60, 3/5, D_loss=0.182, G_loss=3.048
# >60, 4/5, D_loss=0.154, G_loss=3.004
# >60, 5/5, D_loss=0.111, G_loss=3.253
# >Epoch: 60 Porosity match: 0% Std: 5 real: 100% fake: 98%
# >61, 1/5, D_loss=0.123, G_loss=3.419
# >61, 2/5, D_loss=0.096, G_loss=3.262
# >61, 3/5, D_loss=0.101, G_loss=3.377
# >61, 4/5, D_loss=0.089, G_loss=3.652
# >61, 5/5, D_loss=0.096, G_loss=4.057
# >62, 1/5, D_loss=0.080, G_loss=3.859
# >62, 2/5, D_loss=0.079, G_loss=4.159
# >62, 3/5, D_loss=0.087, G_loss=4.111
# >62, 4/5, D_loss=0.073, G_loss=4.043
# >62, 5/5, D_loss=0.104, G_loss=4.486
# >63, 1/5, D_loss=0.098, G_loss=3.600
# >63, 2/5, D_loss=0.120, G_loss=4.271
# >63, 3/5, D_loss=0.089, G_loss=4.008
# >63, 4/5, D_loss=0.117, G_loss=3.743
# >63, 5/5, D_loss=0.141, G_loss=3.925
# >64, 1/5, D_loss=0.138, G_loss=3.533
# >64, 2/5, D_loss=0.142, G_loss=3.434
# >64, 3/5, D_loss=0.178, G_loss=3.398
# >64, 4/5, D_loss=0.181, G_loss=3.298
# >64, 5/5, D_loss=0.169, G_loss=3.518
# >65, 1/5, D_loss=0.144, G_loss=3.407
# >65, 2/5, D_loss=0.136, G_loss=3.421
# >65, 3/5, D_loss=0.164, G_loss=3.686
# >65, 4/5, D_loss=0.218, G_loss=3.555
# >65, 5/5, D_loss=0.238, G_loss=3.675
# >66, 1/5, D_loss=0.211, G_loss=3.336
# >66, 2/5, D_loss=0.216, G_loss=3.326
# >66, 3/5, D_loss=0.220, G_loss=3.768
# >66, 4/5, D_loss=0.237, G_loss=3.482
# >66, 5/5, D_loss=0.219, G_loss=3.434
# >67, 1/5, D_loss=0.268, G_loss=3.505
# >67, 2/5, D_loss=0.246, G_loss=3.416
# >67, 3/5, D_loss=0.243, G_loss=3.480
# >67, 4/5, D_loss=0.346, G_loss=3.567
# >67, 5/5, D_loss=0.304, G_loss=3.649
# >68, 1/5, D_loss=0.298, G_loss=3.908
# >68, 2/5, D_loss=0.281, G_loss=4.027
# >68, 3/5, D_loss=0.290, G_loss=4.165
# >68, 4/5, D_loss=0.272, G_loss=4.300
# >68, 5/5, D_loss=0.233, G_loss=4.428
# >69, 1/5, D_loss=0.212, G_loss=4.482
# >69, 2/5, D_loss=0.223, G_loss=4.764
# >69, 3/5, D_loss=0.209, G_loss=4.879
# >69, 4/5, D_loss=0.204, G_loss=5.099
# >69, 5/5, D_loss=0.214, G_loss=5.157
# >70, 1/5, D_loss=0.174, G_loss=5.058
# >70, 2/5, D_loss=0.140, G_loss=5.223
# >70, 3/5, D_loss=0.145, G_loss=5.224
# >70, 4/5, D_loss=0.149, G_loss=5.409
# >70, 5/5, D_loss=0.173, G_loss=5.367
# >Epoch: 70 Porosity match: 0% Std: 0 real: 100% fake: 92%
# >71, 1/5, D_loss=0.178, G_loss=5.265
# >71, 2/5, D_loss=0.156, G_loss=5.273
# >71, 3/5, D_loss=0.182, G_loss=5.193
# >71, 4/5, D_loss=0.233, G_loss=4.944
# >71, 5/5, D_loss=0.190, G_loss=4.685
# >72, 1/5, D_loss=0.334, G_loss=4.966
# >72, 2/5, D_loss=0.292, G_loss=4.729
# >72, 3/5, D_loss=0.417, G_loss=5.105
# >72, 4/5, D_loss=0.510, G_loss=5.085
# >72, 5/5, D_loss=0.432, G_loss=5.208
# >73, 1/5, D_loss=0.345, G_loss=5.039
# >73, 2/5, D_loss=0.504, G_loss=4.642
# >73, 3/5, D_loss=0.448, G_loss=4.288
# >73, 4/5, D_loss=0.480, G_loss=4.463
# >73, 5/5, D_loss=0.226, G_loss=4.504
# >74, 1/5, D_loss=0.268, G_loss=5.435
# >74, 2/5, D_loss=0.245, G_loss=5.987
# >74, 3/5, D_loss=0.185, G_loss=5.746
# >74, 4/5, D_loss=0.129, G_loss=5.914
# >74, 5/5, D_loss=0.219, G_loss=5.961
# >75, 1/5, D_loss=0.173, G_loss=5.826
# >75, 2/5, D_loss=0.132, G_loss=6.137
# >75, 3/5, D_loss=0.119, G_loss=5.529
# >75, 4/5, D_loss=0.276, G_loss=6.755
# >75, 5/5, D_loss=0.087, G_loss=7.505
# >76, 1/5, D_loss=0.096, G_loss=7.605
# >76, 2/5, D_loss=0.148, G_loss=7.090
# >76, 3/5, D_loss=0.099, G_loss=8.654
# >76, 4/5, D_loss=0.346, G_loss=7.973
# >76, 5/5, D_loss=0.186, G_loss=7.957
# >77, 1/5, D_loss=0.293, G_loss=6.782
# >77, 2/5, D_loss=0.279, G_loss=7.294
# >77, 3/5, D_loss=0.698, G_loss=6.304
# >77, 4/5, D_loss=0.413, G_loss=5.642
# >77, 5/5, D_loss=0.479, G_loss=7.255
# >78, 1/5, D_loss=0.691, G_loss=5.006
# >78, 2/5, D_loss=0.740, G_loss=4.465
# >78, 3/5, D_loss=0.738, G_loss=4.206
# >78, 4/5, D_loss=1.008, G_loss=4.340
# >78, 5/5, D_loss=0.964, G_loss=4.679
# >79, 1/5, D_loss=0.789, G_loss=4.287
# >79, 2/5, D_loss=1.295, G_loss=3.763
# >79, 3/5, D_loss=1.349, G_loss=3.766
# >79, 4/5, D_loss=1.281, G_loss=4.146
# >79, 5/5, D_loss=1.153, G_loss=4.792
# >80, 1/5, D_loss=1.055, G_loss=4.648
# >80, 2/5, D_loss=0.833, G_loss=4.859
# >80, 3/5, D_loss=0.833, G_loss=5.034
# >80, 4/5, D_loss=0.653, G_loss=5.787
# >80, 5/5, D_loss=0.485, G_loss=5.924
# >Epoch: 80 Porosity match: 0% Std: 0 real: 53% fake: 100%
# >81, 1/5, D_loss=0.342, G_loss=6.181
# >81, 2/5, D_loss=0.516, G_loss=5.551
# >81, 3/5, D_loss=0.415, G_loss=5.614
# >81, 4/5, D_loss=0.459, G_loss=5.760
# >81, 5/5, D_loss=0.503, G_loss=5.560
# >82, 1/5, D_loss=0.500, G_loss=6.150
# >82, 2/5, D_loss=0.631, G_loss=6.300
# >82, 3/5, D_loss=0.350, G_loss=5.641
# >82, 4/5, D_loss=0.401, G_loss=5.494
# >82, 5/5, D_loss=0.565, G_loss=5.595
# >83, 1/5, D_loss=0.350, G_loss=5.021
# >83, 2/5, D_loss=0.582, G_loss=5.264
# >83, 3/5, D_loss=0.385, G_loss=5.626
# >83, 4/5, D_loss=0.432, G_loss=5.858
# >83, 5/5, D_loss=0.407, G_loss=6.254
# >84, 1/5, D_loss=0.233, G_loss=6.644
# >84, 2/5, D_loss=0.230, G_loss=6.241
# >84, 3/5, D_loss=0.342, G_loss=5.830
# >84, 4/5, D_loss=0.303, G_loss=5.264
# >84, 5/5, D_loss=0.338, G_loss=5.068
# >85, 1/5, D_loss=0.486, G_loss=4.620
# >85, 2/5, D_loss=0.574, G_loss=4.431
# >85, 3/5, D_loss=0.305, G_loss=5.280
# >85, 4/5, D_loss=0.230, G_loss=6.103
# >85, 5/5, D_loss=0.270, G_loss=6.272
# >86, 1/5, D_loss=0.314, G_loss=6.181
# >86, 2/5, D_loss=0.433, G_loss=6.100
# >86, 3/5, D_loss=0.192, G_loss=5.399
# >86, 4/5, D_loss=0.272, G_loss=4.849
# >86, 5/5, D_loss=0.236, G_loss=4.327
# >87, 1/5, D_loss=0.391, G_loss=4.660
# >87, 2/5, D_loss=0.368, G_loss=3.952
# >87, 3/5, D_loss=0.425, G_loss=3.791
# >87, 4/5, D_loss=0.458, G_loss=3.935
# >87, 5/5, D_loss=0.439, G_loss=3.772
# >88, 1/5, D_loss=0.558, G_loss=4.584
# >88, 2/5, D_loss=0.412, G_loss=4.079
# >88, 3/5, D_loss=0.295, G_loss=5.254
# >88, 4/5, D_loss=0.269, G_loss=4.563
# >88, 5/5, D_loss=0.509, G_loss=4.177
# >89, 1/5, D_loss=0.451, G_loss=3.774
# >89, 2/5, D_loss=0.312, G_loss=4.030
# >89, 3/5, D_loss=0.426, G_loss=2.658
# >89, 4/5, D_loss=0.457, G_loss=3.013
# >89, 5/5, D_loss=0.421, G_loss=2.737
# >90, 1/5, D_loss=0.400, G_loss=2.461
# >90, 2/5, D_loss=0.405, G_loss=3.180
# >90, 3/5, D_loss=0.446, G_loss=3.126
# >90, 4/5, D_loss=0.504, G_loss=2.615
# >90, 5/5, D_loss=0.326, G_loss=2.697
# >Epoch: 90 Porosity match: 0% Std: 5 real: 76% fake: 80%
# >91, 1/5, D_loss=0.448, G_loss=2.621
# >91, 2/5, D_loss=0.469, G_loss=3.020
# >91, 3/5, D_loss=0.509, G_loss=2.597
# >91, 4/5, D_loss=0.528, G_loss=2.359
# >91, 5/5, D_loss=0.405, G_loss=2.404
# >92, 1/5, D_loss=0.566, G_loss=2.184
# >92, 2/5, D_loss=0.556, G_loss=2.059
# >92, 3/5, D_loss=0.472, G_loss=2.197
# >92, 4/5, D_loss=0.600, G_loss=1.970
# >92, 5/5, D_loss=0.458, G_loss=2.015
# >93, 1/5, D_loss=0.496, G_loss=2.031
# >93, 2/5, D_loss=0.554, G_loss=2.005
# >93, 3/5, D_loss=0.506, G_loss=2.328
# >93, 4/5, D_loss=0.569, G_loss=1.992
# >93, 5/5, D_loss=0.603, G_loss=2.140
# >94, 1/5, D_loss=0.542, G_loss=1.700
# >94, 2/5, D_loss=0.643, G_loss=1.540
# >94, 3/5, D_loss=0.605, G_loss=1.716
# >94, 4/5, D_loss=0.636, G_loss=1.781
# >94, 5/5, D_loss=0.536, G_loss=1.615
# >95, 1/5, D_loss=0.567, G_loss=1.616
# >95, 2/5, D_loss=0.469, G_loss=1.491
# >95, 3/5, D_loss=0.744, G_loss=1.579
# >95, 4/5, D_loss=0.600, G_loss=1.418
# >95, 5/5, D_loss=0.702, G_loss=1.195
# >96, 1/5, D_loss=0.660, G_loss=1.333
# >96, 2/5, D_loss=0.899, G_loss=1.269
# >96, 3/5, D_loss=0.761, G_loss=1.197
# >96, 4/5, D_loss=0.787, G_loss=1.200
# >96, 5/5, D_loss=0.814, G_loss=1.097
# >97, 1/5, D_loss=0.704, G_loss=1.245
# >97, 2/5, D_loss=0.862, G_loss=1.254
# >97, 3/5, D_loss=0.803, G_loss=1.333
# >97, 4/5, D_loss=0.769, G_loss=1.318
# >97, 5/5, D_loss=1.056, G_loss=1.417
# >98, 1/5, D_loss=0.969, G_loss=1.226
# >98, 2/5, D_loss=1.010, G_loss=1.284
# >98, 3/5, D_loss=0.929, G_loss=1.292
# >98, 4/5, D_loss=1.020, G_loss=1.365
# >98, 5/5, D_loss=0.913, G_loss=1.511
# >99, 1/5, D_loss=0.946, G_loss=1.477
# >99, 2/5, D_loss=0.919, G_loss=1.511
# >99, 3/5, D_loss=0.923, G_loss=1.560
# >99, 4/5, D_loss=1.022, G_loss=1.696
# >99, 5/5, D_loss=0.847, G_loss=1.631
# >100, 1/5, D_loss=0.859, G_loss=1.775
# >100, 2/5, D_loss=0.817, G_loss=1.769
# >100, 3/5, D_loss=0.777, G_loss=1.988
# >100, 4/5, D_loss=0.819, G_loss=2.081
# >100, 5/5, D_loss=0.711, G_loss=1.979
# >Epoch: 100 Porosity match: 0% Std: 0 real: 80% fake: 33%
# >101, 1/5, D_loss=0.688, G_loss=1.828
# >101, 2/5, D_loss=0.632, G_loss=2.017
# >101, 3/5, D_loss=0.676, G_loss=2.173
# >101, 4/5, D_loss=0.729, G_loss=2.223
# >101, 5/5, D_loss=0.607, G_loss=2.300
# >102, 1/5, D_loss=0.704, G_loss=2.422
# >102, 2/5, D_loss=0.709, G_loss=2.600
# >102, 3/5, D_loss=0.667, G_loss=2.617
# >102, 4/5, D_loss=0.591, G_loss=2.563
# >102, 5/5, D_loss=0.531, G_loss=2.379
# >103, 1/5, D_loss=0.604, G_loss=2.645
# >103, 2/5, D_loss=0.546, G_loss=2.630
# >103, 3/5, D_loss=0.426, G_loss=2.571
# >103, 4/5, D_loss=0.430, G_loss=2.669
# >103, 5/5, D_loss=0.439, G_loss=2.605
# >104, 1/5, D_loss=0.444, G_loss=2.803
# >104, 2/5, D_loss=0.436, G_loss=2.614
# >104, 3/5, D_loss=0.381, G_loss=2.511
# >104, 4/5, D_loss=0.402, G_loss=2.519
# >104, 5/5, D_loss=0.363, G_loss=2.583
# >105, 1/5, D_loss=0.402, G_loss=2.368
# >105, 2/5, D_loss=0.394, G_loss=2.351
# >105, 3/5, D_loss=0.440, G_loss=2.360
# >105, 4/5, D_loss=0.395, G_loss=2.418
# >105, 5/5, D_loss=0.382, G_loss=2.247
# >106, 1/5, D_loss=0.328, G_loss=2.181
# >106, 2/5, D_loss=0.432, G_loss=1.999
# >106, 3/5, D_loss=0.415, G_loss=2.045
# >106, 4/5, D_loss=0.386, G_loss=2.005
# >106, 5/5, D_loss=0.343, G_loss=2.029
# >107, 1/5, D_loss=0.441, G_loss=1.919
# >107, 2/5, D_loss=0.441, G_loss=2.009
# >107, 3/5, D_loss=0.480, G_loss=1.985
# >107, 4/5, D_loss=0.417, G_loss=1.935
# >107, 5/5, D_loss=0.432, G_loss=1.921
# >108, 1/5, D_loss=0.550, G_loss=1.907
# >108, 2/5, D_loss=0.487, G_loss=1.826
# >108, 3/5, D_loss=0.527, G_loss=1.604
# >108, 4/5, D_loss=0.419, G_loss=1.637
# >108, 5/5, D_loss=0.496, G_loss=1.685
# >109, 1/5, D_loss=0.626, G_loss=1.621
# >109, 2/5, D_loss=0.616, G_loss=1.271
# >109, 3/5, D_loss=0.603, G_loss=1.334
# >109, 4/5, D_loss=0.633, G_loss=1.311
# >109, 5/5, D_loss=0.565, G_loss=1.160
# >110, 1/5, D_loss=0.593, G_loss=1.245
# >110, 2/5, D_loss=0.813, G_loss=1.219
# >110, 3/5, D_loss=0.662, G_loss=1.049
# >110, 4/5, D_loss=0.804, G_loss=1.106
# >110, 5/5, D_loss=0.675, G_loss=1.088
# >Epoch: 110 Porosity match: 0% Std: 13 real: 62% fake: 52%
# >111, 1/5, D_loss=0.645, G_loss=1.227
# >111, 2/5, D_loss=0.742, G_loss=1.196
# >111, 3/5, D_loss=0.786, G_loss=1.223
# >111, 4/5, D_loss=0.717, G_loss=1.179
# >111, 5/5, D_loss=0.617, G_loss=1.289
# >112, 1/5, D_loss=0.754, G_loss=1.323
# >112, 2/5, D_loss=0.742, G_loss=1.215
# >112, 3/5, D_loss=0.898, G_loss=1.275
# >112, 4/5, D_loss=0.703, G_loss=1.189
# >112, 5/5, D_loss=0.855, G_loss=1.122
# >113, 1/5, D_loss=0.681, G_loss=1.093
# >113, 2/5, D_loss=0.670, G_loss=1.112
# >113, 3/5, D_loss=0.909, G_loss=1.181
# >113, 4/5, D_loss=0.796, G_loss=1.061
# >113, 5/5, D_loss=0.723, G_loss=1.267
# >114, 1/5, D_loss=0.755, G_loss=1.017
# >114, 2/5, D_loss=0.728, G_loss=1.138
# >114, 3/5, D_loss=0.696, G_loss=1.007
# >114, 4/5, D_loss=0.693, G_loss=1.061
# >114, 5/5, D_loss=0.762, G_loss=1.077
# >115, 1/5, D_loss=0.705, G_loss=1.113
# >115, 2/5, D_loss=0.856, G_loss=1.008
# >115, 3/5, D_loss=0.655, G_loss=1.187
# >115, 4/5, D_loss=0.691, G_loss=1.254
# >115, 5/5, D_loss=0.658, G_loss=1.250
# >116, 1/5, D_loss=0.760, G_loss=1.256
# >116, 2/5, D_loss=0.675, G_loss=1.267
# >116, 3/5, D_loss=0.711, G_loss=1.231
# >116, 4/5, D_loss=0.660, G_loss=1.116
# >116, 5/5, D_loss=0.654, G_loss=1.230
# >117, 1/5, D_loss=0.787, G_loss=1.263
# >117, 2/5, D_loss=0.554, G_loss=1.280
# >117, 3/5, D_loss=0.737, G_loss=1.258
# >117, 4/5, D_loss=0.685, G_loss=1.299
# >117, 5/5, D_loss=0.694, G_loss=1.338
# >118, 1/5, D_loss=0.552, G_loss=1.584
# >118, 2/5, D_loss=0.682, G_loss=1.517
# >118, 3/5, D_loss=0.643, G_loss=1.492
# >118, 4/5, D_loss=0.561, G_loss=1.386
# >118, 5/5, D_loss=0.655, G_loss=1.187
# >119, 1/5, D_loss=0.668, G_loss=1.255
# >119, 2/5, D_loss=0.616, G_loss=1.331
# >119, 3/5, D_loss=0.580, G_loss=1.213
# >119, 4/5, D_loss=0.594, G_loss=1.174
# >119, 5/5, D_loss=0.617, G_loss=1.150
# >120, 1/5, D_loss=0.620, G_loss=1.270
# >120, 2/5, D_loss=0.630, G_loss=1.305
# >120, 3/5, D_loss=0.614, G_loss=1.374
# >120, 4/5, D_loss=0.543, G_loss=1.434
# >120, 5/5, D_loss=0.578, G_loss=1.491
# >Epoch: 120 Porosity match: 0% Std: 7 real: 76% fake: 77%
# >121, 1/5, D_loss=0.667, G_loss=1.283
# >121, 2/5, D_loss=0.637, G_loss=1.275
# >121, 3/5, D_loss=0.565, G_loss=1.440
# >121, 4/5, D_loss=0.614, G_loss=1.330
# >121, 5/5, D_loss=0.640, G_loss=1.482
# >122, 1/5, D_loss=0.691, G_loss=1.439
# >122, 2/5, D_loss=0.594, G_loss=1.135
# >122, 3/5, D_loss=0.625, G_loss=1.341
# >122, 4/5, D_loss=0.592, G_loss=1.236
# >122, 5/5, D_loss=0.676, G_loss=1.190
# >123, 1/5, D_loss=0.704, G_loss=1.348
# >123, 2/5, D_loss=0.666, G_loss=1.279
# >123, 3/5, D_loss=0.610, G_loss=1.275
# >123, 4/5, D_loss=0.517, G_loss=1.336
# >123, 5/5, D_loss=0.581, G_loss=1.146
# >124, 1/5, D_loss=0.549, G_loss=1.308
# >124, 2/5, D_loss=0.614, G_loss=1.198
# >124, 3/5, D_loss=0.598, G_loss=1.258
# >124, 4/5, D_loss=0.663, G_loss=1.147
# >124, 5/5, D_loss=0.570, G_loss=1.237
# >125, 1/5, D_loss=0.606, G_loss=1.075
# >125, 2/5, D_loss=0.668, G_loss=1.313
# >125, 3/5, D_loss=0.591, G_loss=1.329
# >125, 4/5, D_loss=0.588, G_loss=1.297
# >125, 5/5, D_loss=0.602, G_loss=1.384
# >126, 1/5, D_loss=0.582, G_loss=1.456
# >126, 2/5, D_loss=0.638, G_loss=1.279
# >126, 3/5, D_loss=0.569, G_loss=1.224
# >126, 4/5, D_loss=0.632, G_loss=1.255
# >126, 5/5, D_loss=0.525, G_loss=1.064
# >127, 1/5, D_loss=0.607, G_loss=1.201
# >127, 2/5, D_loss=0.589, G_loss=1.224
# >127, 3/5, D_loss=0.579, G_loss=1.235
# >127, 4/5, D_loss=0.563, G_loss=0.935
# >127, 5/5, D_loss=0.625, G_loss=1.283
# >128, 1/5, D_loss=0.695, G_loss=1.232
# >128, 2/5, D_loss=0.577, G_loss=1.210
# >128, 3/5, D_loss=0.567, G_loss=1.126
# >128, 4/5, D_loss=0.699, G_loss=1.300
# >128, 5/5, D_loss=0.615, G_loss=1.127
# >129, 1/5, D_loss=0.572, G_loss=1.216
# >129, 2/5, D_loss=0.559, G_loss=1.256
# >129, 3/5, D_loss=0.575, G_loss=1.262
# >129, 4/5, D_loss=0.597, G_loss=1.283
# >129, 5/5, D_loss=0.549, G_loss=1.261
# >130, 1/5, D_loss=0.559, G_loss=1.168
# >130, 2/5, D_loss=0.562, G_loss=1.162
# >130, 3/5, D_loss=0.618, G_loss=1.305
# >130, 4/5, D_loss=0.616, G_loss=1.196
# >130, 5/5, D_loss=0.661, G_loss=1.451
# >Epoch: 130 Porosity match: 0% Std: 21 real: 86% fake: 61%
# >131, 1/5, D_loss=0.640, G_loss=1.482
# >131, 2/5, D_loss=0.642, G_loss=1.291
# >131, 3/5, D_loss=0.660, G_loss=1.430
# >131, 4/5, D_loss=0.605, G_loss=1.380
# >131, 5/5, D_loss=0.652, G_loss=1.392
# >132, 1/5, D_loss=0.594, G_loss=1.409
# >132, 2/5, D_loss=0.627, G_loss=1.372
# >132, 3/5, D_loss=0.634, G_loss=1.337
# >132, 4/5, D_loss=0.685, G_loss=1.270
# >132, 5/5, D_loss=0.618, G_loss=1.447
# >133, 1/5, D_loss=0.583, G_loss=1.273
# >133, 2/5, D_loss=0.638, G_loss=1.349
# >133, 3/5, D_loss=0.697, G_loss=1.280
# >133, 4/5, D_loss=0.627, G_loss=1.368
# >133, 5/5, D_loss=0.740, G_loss=1.238
# >134, 1/5, D_loss=0.594, G_loss=1.246
# >134, 2/5, D_loss=0.687, G_loss=1.328
# >134, 3/5, D_loss=0.586, G_loss=1.431
# >134, 4/5, D_loss=0.691, G_loss=1.308
# >134, 5/5, D_loss=0.562, G_loss=1.162
# >135, 1/5, D_loss=0.717, G_loss=1.295
# >135, 2/5, D_loss=0.645, G_loss=1.220
# >135, 3/5, D_loss=0.623, G_loss=1.347
# >135, 4/5, D_loss=0.627, G_loss=1.129
# >135, 5/5, D_loss=0.672, G_loss=1.195
# >136, 1/5, D_loss=0.678, G_loss=1.321
# >136, 2/5, D_loss=0.639, G_loss=1.267
# >136, 3/5, D_loss=0.663, G_loss=1.280
# >136, 4/5, D_loss=0.624, G_loss=1.377
# >136, 5/5, D_loss=0.594, G_loss=1.397
# >137, 1/5, D_loss=0.701, G_loss=1.383
# >137, 2/5, D_loss=0.523, G_loss=1.365
# >137, 3/5, D_loss=0.557, G_loss=1.412
# >137, 4/5, D_loss=0.541, G_loss=1.366
# >137, 5/5, D_loss=0.548, G_loss=1.428
# >138, 1/5, D_loss=0.532, G_loss=1.484
# >138, 2/5, D_loss=0.523, G_loss=1.473
# >138, 3/5, D_loss=0.617, G_loss=1.533
# >138, 4/5, D_loss=0.575, G_loss=1.498
# >138, 5/5, D_loss=0.453, G_loss=1.524
# >139, 1/5, D_loss=0.499, G_loss=1.519
# >139, 2/5, D_loss=0.479, G_loss=1.641
# >139, 3/5, D_loss=0.432, G_loss=1.638
# >139, 4/5, D_loss=0.537, G_loss=1.587
# >139, 5/5, D_loss=0.508, G_loss=1.650
# >140, 1/5, D_loss=0.472, G_loss=1.615
# >140, 2/5, D_loss=0.474, G_loss=1.674
# >140, 3/5, D_loss=0.501, G_loss=1.854
# >140, 4/5, D_loss=0.471, G_loss=1.701
# >140, 5/5, D_loss=0.452, G_loss=1.769
# >Epoch: 140 Porosity match: 0% Std: 21 real: 97% fake: 86%
# >141, 1/5, D_loss=0.401, G_loss=1.645
# >141, 2/5, D_loss=0.451, G_loss=1.673
# >141, 3/5, D_loss=0.354, G_loss=1.798
# >141, 4/5, D_loss=0.466, G_loss=1.719
# >141, 5/5, D_loss=0.420, G_loss=1.554
# >142, 1/5, D_loss=0.439, G_loss=1.635
# >142, 2/5, D_loss=0.506, G_loss=1.577
# >142, 3/5, D_loss=0.451, G_loss=1.750
# >142, 4/5, D_loss=0.382, G_loss=1.599
# >142, 5/5, D_loss=0.468, G_loss=1.461
# >143, 1/5, D_loss=0.474, G_loss=1.478
# >143, 2/5, D_loss=0.415, G_loss=1.589
# >143, 3/5, D_loss=0.425, G_loss=1.579
# >143, 4/5, D_loss=0.494, G_loss=1.434
# >143, 5/5, D_loss=0.478, G_loss=1.444
# >144, 1/5, D_loss=0.566, G_loss=1.418
# >144, 2/5, D_loss=0.569, G_loss=1.360
# >144, 3/5, D_loss=0.505, G_loss=1.393
# >144, 4/5, D_loss=0.670, G_loss=1.412
# >144, 5/5, D_loss=0.630, G_loss=1.256
# >145, 1/5, D_loss=0.610, G_loss=1.542
# >145, 2/5, D_loss=0.628, G_loss=1.277
# >145, 3/5, D_loss=0.605, G_loss=1.435
# >145, 4/5, D_loss=0.573, G_loss=1.142
# >145, 5/5, D_loss=0.667, G_loss=1.283
# >146, 1/5, D_loss=0.695, G_loss=1.085
# >146, 2/5, D_loss=0.655, G_loss=1.372
# >146, 3/5, D_loss=0.868, G_loss=1.124
# >146, 4/5, D_loss=0.588, G_loss=1.191
# >146, 5/5, D_loss=0.642, G_loss=1.215
# >147, 1/5, D_loss=0.665, G_loss=1.346
# >147, 2/5, D_loss=0.685, G_loss=1.353
# >147, 3/5, D_loss=0.659, G_loss=1.323
# >147, 4/5, D_loss=0.777, G_loss=1.226
# >147, 5/5, D_loss=0.696, G_loss=1.241
# >148, 1/5, D_loss=0.678, G_loss=1.117
# >148, 2/5, D_loss=0.817, G_loss=1.149
# >148, 3/5, D_loss=0.646, G_loss=1.155
# >148, 4/5, D_loss=0.604, G_loss=1.153
# >148, 5/5, D_loss=0.749, G_loss=1.158
# >149, 1/5, D_loss=0.780, G_loss=1.100
# >149, 2/5, D_loss=0.822, G_loss=1.061
# >149, 3/5, D_loss=0.627, G_loss=1.169
# >149, 4/5, D_loss=0.715, G_loss=1.338
# >149, 5/5, D_loss=0.724, G_loss=1.116
# >150, 1/5, D_loss=0.745, G_loss=1.103
# >150, 2/5, D_loss=0.701, G_loss=1.067
# >150, 3/5, D_loss=0.804, G_loss=1.181
# >150, 4/5, D_loss=0.700, G_loss=1.000
# >150, 5/5, D_loss=0.858, G_loss=1.099
# >Epoch: 150 Porosity match: 0% Std: 9 real: 73% fake: 53%
# >151, 1/5, D_loss=0.705, G_loss=1.056
# >151, 2/5, D_loss=0.606, G_loss=1.079
# >151, 3/5, D_loss=0.684, G_loss=1.158
# >151, 4/5, D_loss=0.698, G_loss=1.088
# >151, 5/5, D_loss=0.676, G_loss=1.145
# >152, 1/5, D_loss=0.623, G_loss=1.234
# >152, 2/5, D_loss=0.666, G_loss=1.102
# >152, 3/5, D_loss=0.708, G_loss=1.141
# >152, 4/5, D_loss=0.644, G_loss=1.118
# >152, 5/5, D_loss=0.643, G_loss=1.145
# >153, 1/5, D_loss=0.629, G_loss=1.171
# >153, 2/5, D_loss=0.685, G_loss=1.153
# >153, 3/5, D_loss=0.631, G_loss=1.285
# >153, 4/5, D_loss=0.635, G_loss=1.360
# >153, 5/5, D_loss=0.623, G_loss=1.298
# >154, 1/5, D_loss=0.701, G_loss=1.164
# >154, 2/5, D_loss=0.682, G_loss=1.113
# >154, 3/5, D_loss=0.680, G_loss=1.223
# >154, 4/5, D_loss=0.637, G_loss=1.171
# >154, 5/5, D_loss=0.668, G_loss=1.157
# >155, 1/5, D_loss=0.590, G_loss=1.167
# >155, 2/5, D_loss=0.631, G_loss=1.086
# >155, 3/5, D_loss=0.670, G_loss=1.214
# >155, 4/5, D_loss=0.605, G_loss=1.122
# >155, 5/5, D_loss=0.667, G_loss=1.150
# >156, 1/5, D_loss=0.601, G_loss=1.174
# >156, 2/5, D_loss=0.652, G_loss=1.400
# >156, 3/5, D_loss=0.648, G_loss=1.184
# >156, 4/5, D_loss=0.687, G_loss=1.109
# >156, 5/5, D_loss=0.618, G_loss=1.175
# >157, 1/5, D_loss=0.563, G_loss=1.200
# >157, 2/5, D_loss=0.609, G_loss=1.158
# >157, 3/5, D_loss=0.627, G_loss=1.183
# >157, 4/5, D_loss=0.643, G_loss=1.242
# >157, 5/5, D_loss=0.674, G_loss=1.216
# >158, 1/5, D_loss=0.564, G_loss=1.053
# >158, 2/5, D_loss=0.567, G_loss=1.118
# >158, 3/5, D_loss=0.586, G_loss=1.199
# >158, 4/5, D_loss=0.697, G_loss=1.170
# >158, 5/5, D_loss=0.633, G_loss=1.196
# >159, 1/5, D_loss=0.653, G_loss=1.190
# >159, 2/5, D_loss=0.634, G_loss=1.131
# >159, 3/5, D_loss=0.696, G_loss=1.171
# >159, 4/5, D_loss=0.578, G_loss=1.278
# >159, 5/5, D_loss=0.613, G_loss=1.266
# >160, 1/5, D_loss=0.647, G_loss=1.355
# >160, 2/5, D_loss=0.648, G_loss=1.345
# >160, 3/5, D_loss=0.674, G_loss=1.388
# >160, 4/5, D_loss=0.746, G_loss=1.407
# >160, 5/5, D_loss=0.532, G_loss=1.401
# >Epoch: 160 Porosity match: 0% Std: 21 real: 77% fake: 64%
# >161, 1/5, D_loss=0.592, G_loss=1.345
# >161, 2/5, D_loss=0.550, G_loss=1.441
# >161, 3/5, D_loss=0.603, G_loss=1.492
# >161, 4/5, D_loss=0.667, G_loss=1.542
# >161, 5/5, D_loss=0.682, G_loss=1.323
# >162, 1/5, D_loss=0.647, G_loss=1.453
# >162, 2/5, D_loss=0.655, G_loss=1.475
# >162, 3/5, D_loss=0.811, G_loss=1.414
# >162, 4/5, D_loss=0.599, G_loss=1.520
# >162, 5/5, D_loss=0.589, G_loss=1.447
# >163, 1/5, D_loss=0.538, G_loss=1.466
# >163, 2/5, D_loss=0.628, G_loss=1.485
# >163, 3/5, D_loss=0.627, G_loss=1.546
# >163, 4/5, D_loss=0.618, G_loss=1.509
# >163, 5/5, D_loss=0.598, G_loss=1.565
# >164, 1/5, D_loss=0.579, G_loss=1.659
# >164, 2/5, D_loss=0.599, G_loss=1.693
# >164, 3/5, D_loss=0.554, G_loss=1.722
# >164, 4/5, D_loss=0.616, G_loss=1.737
# >164, 5/5, D_loss=0.617, G_loss=1.810
# >165, 1/5, D_loss=0.545, G_loss=1.828
# >165, 2/5, D_loss=0.559, G_loss=1.854
# >165, 3/5, D_loss=0.612, G_loss=1.868
# >165, 4/5, D_loss=0.602, G_loss=1.850
# >165, 5/5, D_loss=0.497, G_loss=1.702
# >166, 1/5, D_loss=0.576, G_loss=1.943
# >166, 2/5, D_loss=0.646, G_loss=1.863
# >166, 3/5, D_loss=0.599, G_loss=1.916
# >166, 4/5, D_loss=0.524, G_loss=2.035
# >166, 5/5, D_loss=0.565, G_loss=1.950
# >167, 1/5, D_loss=0.629, G_loss=1.980
# >167, 2/5, D_loss=0.536, G_loss=1.969
# >167, 3/5, D_loss=0.488, G_loss=2.089
# >167, 4/5, D_loss=0.496, G_loss=2.016
# >167, 5/5, D_loss=0.531, G_loss=2.179
# >168, 1/5, D_loss=0.502, G_loss=2.145
# >168, 2/5, D_loss=0.439, G_loss=2.263
# >168, 3/5, D_loss=0.429, G_loss=2.182
# >168, 4/5, D_loss=0.497, G_loss=2.141
# >168, 5/5, D_loss=0.442, G_loss=2.105
# >169, 1/5, D_loss=0.436, G_loss=2.127
# >169, 2/5, D_loss=0.478, G_loss=2.189
# >169, 3/5, D_loss=0.463, G_loss=2.109
# >169, 4/5, D_loss=0.476, G_loss=2.149
# >169, 5/5, D_loss=0.484, G_loss=2.162
# >170, 1/5, D_loss=0.447, G_loss=2.035
# >170, 2/5, D_loss=0.414, G_loss=2.118
# >170, 3/5, D_loss=0.458, G_loss=2.217
# >170, 4/5, D_loss=0.381, G_loss=2.008
# >170, 5/5, D_loss=0.375, G_loss=1.981
# >Epoch: 170 Porosity match: 0% Std: 0 real: 98% fake: 64%
# >171, 1/5, D_loss=0.420, G_loss=2.041
# >171, 2/5, D_loss=0.464, G_loss=2.026
# >171, 3/5, D_loss=0.484, G_loss=2.001
# >171, 4/5, D_loss=0.437, G_loss=1.893
# >171, 5/5, D_loss=0.451, G_loss=1.879
# >172, 1/5, D_loss=0.465, G_loss=1.965
# >172, 2/5, D_loss=0.485, G_loss=1.742
# >172, 3/5, D_loss=0.550, G_loss=1.618
# >172, 4/5, D_loss=0.478, G_loss=1.587
# >172, 5/5, D_loss=0.565, G_loss=1.603
# >173, 1/5, D_loss=0.467, G_loss=1.539
# >173, 2/5, D_loss=0.632, G_loss=1.632
# >173, 3/5, D_loss=0.553, G_loss=1.495
# >173, 4/5, D_loss=0.591, G_loss=1.703
# >173, 5/5, D_loss=0.621, G_loss=1.461
# >174, 1/5, D_loss=0.533, G_loss=1.668
# >174, 2/5, D_loss=0.568, G_loss=1.570
# >174, 3/5, D_loss=0.657, G_loss=1.402
# >174, 4/5, D_loss=0.623, G_loss=1.322
# >174, 5/5, D_loss=0.658, G_loss=1.257
# >175, 1/5, D_loss=0.734, G_loss=1.296
# >175, 2/5, D_loss=0.667, G_loss=1.157
# >175, 3/5, D_loss=0.725, G_loss=1.317
# >175, 4/5, D_loss=0.695, G_loss=1.143
# >175, 5/5, D_loss=0.728, G_loss=1.056
# >176, 1/5, D_loss=0.653, G_loss=1.086
# >176, 2/5, D_loss=0.659, G_loss=1.084
# >176, 3/5, D_loss=0.822, G_loss=1.076
# >176, 4/5, D_loss=0.735, G_loss=1.175
# >176, 5/5, D_loss=0.827, G_loss=1.119
# >177, 1/5, D_loss=0.656, G_loss=1.193
# >177, 2/5, D_loss=0.706, G_loss=1.083
# >177, 3/5, D_loss=0.881, G_loss=0.992
# >177, 4/5, D_loss=0.798, G_loss=0.921
# >177, 5/5, D_loss=0.825, G_loss=1.046
# >178, 1/5, D_loss=0.798, G_loss=1.015
# >178, 2/5, D_loss=0.823, G_loss=1.134
# >178, 3/5, D_loss=0.719, G_loss=1.090
# >178, 4/5, D_loss=0.803, G_loss=1.000
# >178, 5/5, D_loss=0.703, G_loss=0.910
# >179, 1/5, D_loss=0.701, G_loss=0.948
# >179, 2/5, D_loss=0.705, G_loss=0.915
# >179, 3/5, D_loss=0.793, G_loss=0.946
# >179, 4/5, D_loss=0.745, G_loss=0.931
# >179, 5/5, D_loss=0.792, G_loss=0.915
# >180, 1/5, D_loss=0.852, G_loss=0.958
# >180, 2/5, D_loss=0.811, G_loss=1.045
# >180, 3/5, D_loss=0.864, G_loss=1.101
# >180, 4/5, D_loss=0.715, G_loss=1.060
# >180, 5/5, D_loss=0.699, G_loss=1.084
# >Epoch: 180 Porosity match: 0% Std: 7 real: 56% fake: 65%
# >181, 1/5, D_loss=0.829, G_loss=1.018
# >181, 2/5, D_loss=0.761, G_loss=1.106
# >181, 3/5, D_loss=0.736, G_loss=0.974
# >181, 4/5, D_loss=0.737, G_loss=0.971
# >181, 5/5, D_loss=0.694, G_loss=1.059
# >182, 1/5, D_loss=0.749, G_loss=0.960
# >182, 2/5, D_loss=0.716, G_loss=1.136
# >182, 3/5, D_loss=0.799, G_loss=1.149
# >182, 4/5, D_loss=0.697, G_loss=1.099
# >182, 5/5, D_loss=0.761, G_loss=1.058
# >183, 1/5, D_loss=0.621, G_loss=1.070
# >183, 2/5, D_loss=0.813, G_loss=1.133
# >183, 3/5, D_loss=0.677, G_loss=1.148
# >183, 4/5, D_loss=0.730, G_loss=1.009
# >183, 5/5, D_loss=0.620, G_loss=1.105
# >184, 1/5, D_loss=0.739, G_loss=0.986
# >184, 2/5, D_loss=0.709, G_loss=1.079
# >184, 3/5, D_loss=0.641, G_loss=0.982
# >184, 4/5, D_loss=0.616, G_loss=0.972
# >184, 5/5, D_loss=0.661, G_loss=1.060
# >185, 1/5, D_loss=0.650, G_loss=1.095
# >185, 2/5, D_loss=0.717, G_loss=1.104
# >185, 3/5, D_loss=0.639, G_loss=1.065
# >185, 4/5, D_loss=0.650, G_loss=1.046
# >185, 5/5, D_loss=0.723, G_loss=1.154
# >186, 1/5, D_loss=0.680, G_loss=1.172
# >186, 2/5, D_loss=0.715, G_loss=1.107
# >186, 3/5, D_loss=0.656, G_loss=1.141
# >186, 4/5, D_loss=0.633, G_loss=1.164
# >186, 5/5, D_loss=0.704, G_loss=1.189
# >187, 1/5, D_loss=0.655, G_loss=1.155
# >187, 2/5, D_loss=0.629, G_loss=1.056
# >187, 3/5, D_loss=0.762, G_loss=1.133
# >187, 4/5, D_loss=0.703, G_loss=1.231
# >187, 5/5, D_loss=0.588, G_loss=1.116
# >188, 1/5, D_loss=0.629, G_loss=1.192
# >188, 2/5, D_loss=0.611, G_loss=1.189
# >188, 3/5, D_loss=0.578, G_loss=1.132
# >188, 4/5, D_loss=0.626, G_loss=1.167
# >188, 5/5, D_loss=0.641, G_loss=1.194
# >189, 1/5, D_loss=0.648, G_loss=1.056
# >189, 2/5, D_loss=0.690, G_loss=0.950
# >189, 3/5, D_loss=0.602, G_loss=1.074
# >189, 4/5, D_loss=0.621, G_loss=1.006
# >189, 5/5, D_loss=0.616, G_loss=1.094
# >190, 1/5, D_loss=0.582, G_loss=1.159
# >190, 2/5, D_loss=0.626, G_loss=1.168
# >190, 3/5, D_loss=0.629, G_loss=1.065
# >190, 4/5, D_loss=0.689, G_loss=1.101
# >190, 5/5, D_loss=0.598, G_loss=1.154
# >Epoch: 190 Porosity match: 0% Std: 4 real: 81% fake: 74%
# >191, 1/5, D_loss=0.601, G_loss=1.070
# >191, 2/5, D_loss=0.617, G_loss=1.243
# >191, 3/5, D_loss=0.578, G_loss=1.195
# >191, 4/5, D_loss=0.605, G_loss=1.227
# >191, 5/5, D_loss=0.572, G_loss=1.106
# >192, 1/5, D_loss=0.530, G_loss=1.238
# >192, 2/5, D_loss=0.571, G_loss=1.045
# >192, 3/5, D_loss=0.600, G_loss=1.222
# >192, 4/5, D_loss=0.564, G_loss=1.156
# >192, 5/5, D_loss=0.481, G_loss=1.262
# >193, 1/5, D_loss=0.529, G_loss=1.249
# >193, 2/5, D_loss=0.575, G_loss=1.382
# >193, 3/5, D_loss=0.555, G_loss=1.368
# >193, 4/5, D_loss=0.476, G_loss=1.406
# >193, 5/5, D_loss=0.519, G_loss=1.336
# >194, 1/5, D_loss=0.493, G_loss=1.454
# >194, 2/5, D_loss=0.620, G_loss=1.394
# >194, 3/5, D_loss=0.499, G_loss=1.317
# >194, 4/5, D_loss=0.494, G_loss=1.360
# >194, 5/5, D_loss=0.547, G_loss=1.395
# >195, 1/5, D_loss=0.501, G_loss=1.448
# >195, 2/5, D_loss=0.551, G_loss=1.197
# >195, 3/5, D_loss=0.519, G_loss=1.280
# >195, 4/5, D_loss=0.508, G_loss=1.362
# >195, 5/5, D_loss=0.431, G_loss=1.283
# >196, 1/5, D_loss=0.535, G_loss=1.326
# >196, 2/5, D_loss=0.473, G_loss=1.300
# >196, 3/5, D_loss=0.443, G_loss=1.221
# >196, 4/5, D_loss=0.536, G_loss=1.316
# >196, 5/5, D_loss=0.529, G_loss=1.300
# >197, 1/5, D_loss=0.496, G_loss=1.379
# >197, 2/5, D_loss=0.500, G_loss=1.486
# >197, 3/5, D_loss=0.519, G_loss=1.426
# >197, 4/5, D_loss=0.432, G_loss=1.447
# >197, 5/5, D_loss=0.502, G_loss=1.508
# >198, 1/5, D_loss=0.523, G_loss=1.516
# >198, 2/5, D_loss=0.548, G_loss=1.188
# >198, 3/5, D_loss=0.525, G_loss=1.306
# >198, 4/5, D_loss=0.486, G_loss=1.424
# >198, 5/5, D_loss=0.553, G_loss=1.295
# >199, 1/5, D_loss=0.547, G_loss=1.308
# >199, 2/5, D_loss=0.593, G_loss=1.284
# >199, 3/5, D_loss=0.504, G_loss=1.277
# >199, 4/5, D_loss=0.548, G_loss=1.213
# >199, 5/5, D_loss=0.560, G_loss=1.364
# >200, 1/5, D_loss=0.540, G_loss=1.289
# >200, 2/5, D_loss=0.611, G_loss=1.315
# >200, 3/5, D_loss=0.559, G_loss=1.222
# >200, 4/5, D_loss=0.578, G_loss=1.168
# >200, 5/5, D_loss=0.629, G_loss=1.111
# >Epoch: 200 Porosity match: 0% Std: 20 real: 85% fake: 63%
# >201, 1/5, D_loss=0.605, G_loss=1.267
# >201, 2/5, D_loss=0.653, G_loss=1.288
# >201, 3/5, D_loss=0.662, G_loss=1.144
# >201, 4/5, D_loss=0.677, G_loss=0.978
# >201, 5/5, D_loss=0.710, G_loss=1.061
# >202, 1/5, D_loss=0.668, G_loss=1.019
# >202, 2/5, D_loss=0.703, G_loss=1.196
# >202, 3/5, D_loss=0.804, G_loss=0.902
# >202, 4/5, D_loss=0.719, G_loss=0.954
# >202, 5/5, D_loss=0.711, G_loss=1.018
# >203, 1/5, D_loss=0.741, G_loss=1.013
# >203, 2/5, D_loss=0.785, G_loss=1.061
# >203, 3/5, D_loss=0.759, G_loss=1.163
# >203, 4/5, D_loss=0.772, G_loss=0.984
# >203, 5/5, D_loss=0.746, G_loss=0.978
# >204, 1/5, D_loss=0.745, G_loss=0.944
# >204, 2/5, D_loss=0.760, G_loss=0.955
# >204, 3/5, D_loss=0.792, G_loss=0.894
# >204, 4/5, D_loss=0.769, G_loss=1.066
# >204, 5/5, D_loss=0.853, G_loss=1.053
# >205, 1/5, D_loss=0.749, G_loss=0.948
# >205, 2/5, D_loss=0.748, G_loss=1.050
# >205, 3/5, D_loss=0.805, G_loss=0.966
# >205, 4/5, D_loss=0.735, G_loss=0.962
# >205, 5/5, D_loss=0.683, G_loss=1.002
# >206, 1/5, D_loss=0.848, G_loss=1.047
# >206, 2/5, D_loss=0.873, G_loss=1.019
# >206, 3/5, D_loss=0.767, G_loss=1.067
# >206, 4/5, D_loss=0.725, G_loss=1.059
# >206, 5/5, D_loss=0.751, G_loss=1.184
# >207, 1/5, D_loss=0.763, G_loss=1.116
# >207, 2/5, D_loss=0.772, G_loss=1.119
# >207, 3/5, D_loss=0.819, G_loss=1.159
# >207, 4/5, D_loss=0.766, G_loss=1.098
# >207, 5/5, D_loss=0.805, G_loss=1.092
# >208, 1/5, D_loss=0.703, G_loss=1.161
# >208, 2/5, D_loss=0.800, G_loss=1.138
# >208, 3/5, D_loss=0.651, G_loss=1.161
# >208, 4/5, D_loss=0.668, G_loss=1.226
# >208, 5/5, D_loss=0.757, G_loss=1.301
# >209, 1/5, D_loss=0.692, G_loss=1.312
# >209, 2/5, D_loss=0.770, G_loss=1.401
# >209, 3/5, D_loss=0.692, G_loss=1.247
# >209, 4/5, D_loss=0.690, G_loss=1.307
# >209, 5/5, D_loss=0.711, G_loss=1.340
# >210, 1/5, D_loss=0.668, G_loss=1.392
# >210, 2/5, D_loss=0.719, G_loss=1.376
# >210, 3/5, D_loss=0.749, G_loss=1.357
# >210, 4/5, D_loss=0.681, G_loss=1.461
# >210, 5/5, D_loss=0.704, G_loss=1.443
# >Epoch: 210 Porosity match: 0% Std: 3 real: 88% fake: 46%
# >211, 1/5, D_loss=0.646, G_loss=1.345
# >211, 2/5, D_loss=0.779, G_loss=1.412
# >211, 3/5, D_loss=0.639, G_loss=1.488
# >211, 4/5, D_loss=0.615, G_loss=1.449
# >211, 5/5, D_loss=0.678, G_loss=1.428
# >212, 1/5, D_loss=0.652, G_loss=1.461
# >212, 2/5, D_loss=0.610, G_loss=1.442
# >212, 3/5, D_loss=0.565, G_loss=1.435
# >212, 4/5, D_loss=0.595, G_loss=1.471
# >212, 5/5, D_loss=0.566, G_loss=1.497
# >213, 1/5, D_loss=0.624, G_loss=1.472
# >213, 2/5, D_loss=0.635, G_loss=1.516
# >213, 3/5, D_loss=0.589, G_loss=1.462
# >213, 4/5, D_loss=0.582, G_loss=1.452
# >213, 5/5, D_loss=0.531, G_loss=1.383
# >214, 1/5, D_loss=0.647, G_loss=1.490
# >214, 2/5, D_loss=0.574, G_loss=1.490
# >214, 3/5, D_loss=0.635, G_loss=1.503
# >214, 4/5, D_loss=0.512, G_loss=1.599
# >214, 5/5, D_loss=0.566, G_loss=1.534
# >215, 1/5, D_loss=0.582, G_loss=1.337
# >215, 2/5, D_loss=0.573, G_loss=1.442
# >215, 3/5, D_loss=0.620, G_loss=1.436
# >215, 4/5, D_loss=0.526, G_loss=1.445
# >215, 5/5, D_loss=0.568, G_loss=1.549
# >216, 1/5, D_loss=0.523, G_loss=1.347
# >216, 2/5, D_loss=0.604, G_loss=1.430
# >216, 3/5, D_loss=0.626, G_loss=1.492
# >216, 4/5, D_loss=0.496, G_loss=1.305
# >216, 5/5, D_loss=0.515, G_loss=1.458
# >217, 1/5, D_loss=0.590, G_loss=1.490
# >217, 2/5, D_loss=0.609, G_loss=1.486
# >217, 3/5, D_loss=0.576, G_loss=1.561
# >217, 4/5, D_loss=0.539, G_loss=1.531
# >217, 5/5, D_loss=0.624, G_loss=1.350
# >218, 1/5, D_loss=0.573, G_loss=1.449
# >218, 2/5, D_loss=0.601, G_loss=1.445
# >218, 3/5, D_loss=0.533, G_loss=1.401
# >218, 4/5, D_loss=0.524, G_loss=1.392
# >218, 5/5, D_loss=0.588, G_loss=1.453
# >219, 1/5, D_loss=0.583, G_loss=1.350
# >219, 2/5, D_loss=0.627, G_loss=1.382
# >219, 3/5, D_loss=0.507, G_loss=1.405
# >219, 4/5, D_loss=0.530, G_loss=1.393
# >219, 5/5, D_loss=0.632, G_loss=1.385
# >220, 1/5, D_loss=0.580, G_loss=1.426
# >220, 2/5, D_loss=0.552, G_loss=1.362
# >220, 3/5, D_loss=0.613, G_loss=1.358
# >220, 4/5, D_loss=0.587, G_loss=1.328
# >220, 5/5, D_loss=0.547, G_loss=1.282
# >Epoch: 220 Porosity match: 0% Std: 20 real: 84% fake: 63%
# >221, 1/5, D_loss=0.670, G_loss=1.336
# >221, 2/5, D_loss=0.620, G_loss=1.382
# >221, 3/5, D_loss=0.546, G_loss=1.205
# >221, 4/5, D_loss=0.638, G_loss=1.247
# >221, 5/5, D_loss=0.557, G_loss=1.214
# >222, 1/5, D_loss=0.581, G_loss=1.176
# >222, 2/5, D_loss=0.667, G_loss=1.300
# >222, 3/5, D_loss=0.643, G_loss=1.185
# >222, 4/5, D_loss=0.583, G_loss=1.192
# >222, 5/5, D_loss=0.584, G_loss=1.197
# >223, 1/5, D_loss=0.564, G_loss=1.125
# >223, 2/5, D_loss=0.651, G_loss=1.232
# >223, 3/5, D_loss=0.639, G_loss=1.154
# >223, 4/5, D_loss=0.604, G_loss=1.147
# >223, 5/5, D_loss=0.621, G_loss=1.222
# >224, 1/5, D_loss=0.614, G_loss=1.229
# >224, 2/5, D_loss=0.595, G_loss=1.221
# >224, 3/5, D_loss=0.616, G_loss=1.126
# >224, 4/5, D_loss=0.755, G_loss=1.201
# >224, 5/5, D_loss=0.590, G_loss=1.031
# >225, 1/5, D_loss=0.565, G_loss=1.237
# >225, 2/5, D_loss=0.628, G_loss=1.055
# >225, 3/5, D_loss=0.669, G_loss=1.102
# >225, 4/5, D_loss=0.611, G_loss=1.196
# >225, 5/5, D_loss=0.638, G_loss=1.310
# >226, 1/5, D_loss=0.629, G_loss=1.067
# >226, 2/5, D_loss=0.580, G_loss=1.158
# >226, 3/5, D_loss=0.666, G_loss=1.123
# >226, 4/5, D_loss=0.480, G_loss=0.973
# >226, 5/5, D_loss=0.625, G_loss=1.125
# >227, 1/5, D_loss=0.638, G_loss=1.181
# >227, 2/5, D_loss=0.580, G_loss=1.272
# >227, 3/5, D_loss=0.602, G_loss=1.264
# >227, 4/5, D_loss=0.602, G_loss=1.461
# >227, 5/5, D_loss=0.585, G_loss=1.369
# >228, 1/5, D_loss=0.626, G_loss=1.358
# >228, 2/5, D_loss=0.538, G_loss=1.300
# >228, 3/5, D_loss=0.583, G_loss=1.289
# >228, 4/5, D_loss=0.514, G_loss=1.262
# >228, 5/5, D_loss=0.533, G_loss=1.209
# >229, 1/5, D_loss=0.567, G_loss=1.175
# >229, 2/5, D_loss=0.571, G_loss=1.273
# >229, 3/5, D_loss=0.601, G_loss=1.334
# >229, 4/5, D_loss=0.704, G_loss=1.271
# >229, 5/5, D_loss=0.604, G_loss=1.211
# >230, 1/5, D_loss=0.583, G_loss=1.205
# >230, 2/5, D_loss=0.501, G_loss=1.223
# >230, 3/5, D_loss=0.625, G_loss=1.150
# >230, 4/5, D_loss=0.523, G_loss=1.175
# >230, 5/5, D_loss=0.593, G_loss=1.271
# >Epoch: 230 Porosity match: 0% Std: 19 real: 86% fake: 75%
# >231, 1/5, D_loss=0.640, G_loss=1.097
# >231, 2/5, D_loss=0.471, G_loss=1.278
# >231, 3/5, D_loss=0.540, G_loss=1.313
# >231, 4/5, D_loss=0.650, G_loss=1.219
# >231, 5/5, D_loss=0.563, G_loss=1.182
# >232, 1/5, D_loss=0.556, G_loss=1.289
# >232, 2/5, D_loss=0.602, G_loss=1.333
# >232, 3/5, D_loss=0.705, G_loss=1.122
# >232, 4/5, D_loss=0.615, G_loss=1.131
# >232, 5/5, D_loss=0.673, G_loss=1.109
# >233, 1/5, D_loss=0.621, G_loss=1.202
# >233, 2/5, D_loss=0.664, G_loss=1.256
# >233, 3/5, D_loss=0.627, G_loss=1.219
# >233, 4/5, D_loss=0.557, G_loss=1.125
# >233, 5/5, D_loss=0.628, G_loss=1.328
# >234, 1/5, D_loss=0.569, G_loss=1.290
# >234, 2/5, D_loss=0.599, G_loss=1.072
# >234, 3/5, D_loss=0.577, G_loss=1.230
# >234, 4/5, D_loss=0.738, G_loss=1.201
# >234, 5/5, D_loss=0.644, G_loss=1.171
# >235, 1/5, D_loss=0.669, G_loss=1.181
# >235, 2/5, D_loss=0.665, G_loss=1.114
# >235, 3/5, D_loss=0.651, G_loss=1.311
# >235, 4/5, D_loss=0.697, G_loss=1.076
# >235, 5/5, D_loss=0.616, G_loss=1.301
# >236, 1/5, D_loss=0.708, G_loss=1.067
# >236, 2/5, D_loss=0.624, G_loss=1.073
# >236, 3/5, D_loss=0.700, G_loss=1.131
# >236, 4/5, D_loss=0.619, G_loss=0.963
# >236, 5/5, D_loss=0.735, G_loss=0.935
# >237, 1/5, D_loss=0.726, G_loss=0.961
# >237, 2/5, D_loss=0.704, G_loss=1.052
# >237, 3/5, D_loss=0.629, G_loss=1.046
# >237, 4/5, D_loss=0.781, G_loss=1.082
# >237, 5/5, D_loss=0.769, G_loss=1.054
# >238, 1/5, D_loss=0.687, G_loss=1.177
# >238, 2/5, D_loss=0.736, G_loss=1.048
# >238, 3/5, D_loss=0.672, G_loss=1.068
# >238, 4/5, D_loss=0.757, G_loss=1.124
# >238, 5/5, D_loss=0.735, G_loss=1.093
# >239, 1/5, D_loss=0.717, G_loss=1.025
# >239, 2/5, D_loss=0.712, G_loss=1.006
# >239, 3/5, D_loss=0.735, G_loss=0.960
# >239, 4/5, D_loss=0.690, G_loss=0.958
# >239, 5/5, D_loss=0.692, G_loss=1.046
# >240, 1/5, D_loss=0.728, G_loss=1.057
# >240, 2/5, D_loss=0.769, G_loss=1.040
# >240, 3/5, D_loss=0.801, G_loss=1.023
# >240, 4/5, D_loss=0.796, G_loss=0.970
# >240, 5/5, D_loss=0.738, G_loss=0.875
# >Epoch: 240 Porosity match: 0% Std: 24 real: 80% fake: 36%
# >241, 1/5, D_loss=0.746, G_loss=0.927
# >241, 2/5, D_loss=0.704, G_loss=1.009
# >241, 3/5, D_loss=0.663, G_loss=0.961
# >241, 4/5, D_loss=0.627, G_loss=0.940
# >241, 5/5, D_loss=0.770, G_loss=0.968
# >242, 1/5, D_loss=0.831, G_loss=0.998
# >242, 2/5, D_loss=0.705, G_loss=0.903
# >242, 3/5, D_loss=0.712, G_loss=0.898
# >242, 4/5, D_loss=0.737, G_loss=0.934
# >242, 5/5, D_loss=0.630, G_loss=0.869
# >243, 1/5, D_loss=0.741, G_loss=0.995
# >243, 2/5, D_loss=0.702, G_loss=0.958
# >243, 3/5, D_loss=0.710, G_loss=1.055
# >243, 4/5, D_loss=0.688, G_loss=1.073
# >243, 5/5, D_loss=0.693, G_loss=0.929
# >244, 1/5, D_loss=0.675, G_loss=1.027
# >244, 2/5, D_loss=0.714, G_loss=1.008
# >244, 3/5, D_loss=0.709, G_loss=1.056
# >244, 4/5, D_loss=0.702, G_loss=1.042
# >244, 5/5, D_loss=0.649, G_loss=0.998
# >245, 1/5, D_loss=0.642, G_loss=1.046
# >245, 2/5, D_loss=0.740, G_loss=1.049
# >245, 3/5, D_loss=0.699, G_loss=1.104
# >245, 4/5, D_loss=0.740, G_loss=1.103
# >245, 5/5, D_loss=0.606, G_loss=1.008
# >246, 1/5, D_loss=0.570, G_loss=1.148
# >246, 2/5, D_loss=0.593, G_loss=1.142
# >246, 3/5, D_loss=0.653, G_loss=1.208
# >246, 4/5, D_loss=0.616, G_loss=1.281
# >246, 5/5, D_loss=0.589, G_loss=1.110
# >247, 1/5, D_loss=0.565, G_loss=1.325
# >247, 2/5, D_loss=0.620, G_loss=1.208
# >247, 3/5, D_loss=0.627, G_loss=1.282
# >247, 4/5, D_loss=0.598, G_loss=1.322
# >247, 5/5, D_loss=0.594, G_loss=1.304
# >248, 1/5, D_loss=0.575, G_loss=1.263
# >248, 2/5, D_loss=0.531, G_loss=1.252
# >248, 3/5, D_loss=0.561, G_loss=1.389
# >248, 4/5, D_loss=0.569, G_loss=1.353
# >248, 5/5, D_loss=0.597, G_loss=1.463
# >249, 1/5, D_loss=0.545, G_loss=1.403
# >249, 2/5, D_loss=0.543, G_loss=1.369
# >249, 3/5, D_loss=0.564, G_loss=1.301
# >249, 4/5, D_loss=0.561, G_loss=1.361
# >249, 5/5, D_loss=0.609, G_loss=1.318
# >250, 1/5, D_loss=0.544, G_loss=1.392
# >250, 2/5, D_loss=0.526, G_loss=1.396
# >250, 3/5, D_loss=0.567, G_loss=1.383
# >250, 4/5, D_loss=0.614, G_loss=1.422
# >250, 5/5, D_loss=0.470, G_loss=1.221
# >Epoch: 250 Porosity match: 0% Std: 24 real: 97% fake: 80%
# >251, 1/5, D_loss=0.564, G_loss=1.381
# >251, 2/5, D_loss=0.466, G_loss=1.414
# >251, 3/5, D_loss=0.573, G_loss=1.484
# >251, 4/5, D_loss=0.540, G_loss=1.372
# >251, 5/5, D_loss=0.565, G_loss=1.316
# >252, 1/5, D_loss=0.580, G_loss=1.427
# >252, 2/5, D_loss=0.463, G_loss=1.522
# >252, 3/5, D_loss=0.482, G_loss=1.446
# >252, 4/5, D_loss=0.483, G_loss=1.446
# >252, 5/5, D_loss=0.463, G_loss=1.418
# >253, 1/5, D_loss=0.553, G_loss=1.484
# >253, 2/5, D_loss=0.521, G_loss=1.331
# >253, 3/5, D_loss=0.541, G_loss=1.370
# >253, 4/5, D_loss=0.562, G_loss=1.457
# >253, 5/5, D_loss=0.572, G_loss=1.319
# >254, 1/5, D_loss=0.509, G_loss=1.344
# >254, 2/5, D_loss=0.483, G_loss=1.377
# >254, 3/5, D_loss=0.541, G_loss=1.322
# >254, 4/5, D_loss=0.650, G_loss=1.350
# >254, 5/5, D_loss=0.508, G_loss=1.231
# >255, 1/5, D_loss=0.468, G_loss=1.302
# >255, 2/5, D_loss=0.540, G_loss=1.231
# >255, 3/5, D_loss=0.527, G_loss=1.247
# >255, 4/5, D_loss=0.607, G_loss=1.347
# >255, 5/5, D_loss=0.571, G_loss=1.269
# >256, 1/5, D_loss=0.597, G_loss=1.349
# >256, 2/5, D_loss=0.612, G_loss=1.230
# >256, 3/5, D_loss=0.666, G_loss=1.290
# >256, 4/5, D_loss=0.589, G_loss=1.306
# >256, 5/5, D_loss=0.535, G_loss=1.247
# >257, 1/5, D_loss=0.564, G_loss=1.204
# >257, 2/5, D_loss=0.585, G_loss=1.139
# >257, 3/5, D_loss=0.596, G_loss=1.112
# >257, 4/5, D_loss=0.620, G_loss=1.134
# >257, 5/5, D_loss=0.578, G_loss=1.101
# >258, 1/5, D_loss=0.586, G_loss=1.118
# >258, 2/5, D_loss=0.714, G_loss=1.112
# >258, 3/5, D_loss=0.568, G_loss=1.146
# >258, 4/5, D_loss=0.645, G_loss=1.206
# >258, 5/5, D_loss=0.586, G_loss=1.140
# >259, 1/5, D_loss=0.603, G_loss=1.347
# >259, 2/5, D_loss=0.607, G_loss=1.242
# >259, 3/5, D_loss=0.631, G_loss=1.217
# >259, 4/5, D_loss=0.620, G_loss=1.221
# >259, 5/5, D_loss=0.559, G_loss=1.055
# >260, 1/5, D_loss=0.694, G_loss=1.172
# >260, 2/5, D_loss=0.629, G_loss=0.949
# >260, 3/5, D_loss=0.611, G_loss=1.176
# >260, 4/5, D_loss=0.620, G_loss=0.968
# >260, 5/5, D_loss=0.645, G_loss=1.050
# >Epoch: 260 Porosity match: 0% Std: 18 real: 89% fake: 41%
# >261, 1/5, D_loss=0.695, G_loss=1.005
# >261, 2/5, D_loss=0.641, G_loss=0.856
# >261, 3/5, D_loss=0.664, G_loss=1.030
# >261, 4/5, D_loss=0.672, G_loss=1.109
# >261, 5/5, D_loss=0.529, G_loss=1.137
# >262, 1/5, D_loss=0.675, G_loss=1.166
# >262, 2/5, D_loss=0.676, G_loss=1.073
# >262, 3/5, D_loss=0.639, G_loss=1.173
# >262, 4/5, D_loss=0.640, G_loss=1.117
# >262, 5/5, D_loss=0.721, G_loss=1.011
# >263, 1/5, D_loss=0.677, G_loss=1.060
# >263, 2/5, D_loss=0.659, G_loss=1.058
# >263, 3/5, D_loss=0.677, G_loss=0.913
# >263, 4/5, D_loss=0.659, G_loss=0.868
# >263, 5/5, D_loss=0.599, G_loss=0.925
# >264, 1/5, D_loss=0.774, G_loss=0.858
# >264, 2/5, D_loss=0.790, G_loss=0.969
# >264, 3/5, D_loss=0.615, G_loss=0.969
# >264, 4/5, D_loss=0.605, G_loss=0.951
# >264, 5/5, D_loss=0.688, G_loss=1.033
# >265, 1/5, D_loss=0.637, G_loss=1.101
# >265, 2/5, D_loss=0.730, G_loss=1.093
# >265, 3/5, D_loss=0.561, G_loss=1.127
# >265, 4/5, D_loss=0.706, G_loss=1.158
# >265, 5/5, D_loss=0.641, G_loss=1.077
# >266, 1/5, D_loss=0.735, G_loss=0.945
# >266, 2/5, D_loss=0.732, G_loss=1.094
# >266, 3/5, D_loss=0.780, G_loss=1.102
# >266, 4/5, D_loss=0.654, G_loss=1.131
# >266, 5/5, D_loss=0.626, G_loss=1.114
# >267, 1/5, D_loss=0.694, G_loss=0.939
# >267, 2/5, D_loss=0.684, G_loss=1.043
# >267, 3/5, D_loss=0.576, G_loss=1.070
# >267, 4/5, D_loss=0.637, G_loss=1.167
# >267, 5/5, D_loss=0.700, G_loss=1.002
# >268, 1/5, D_loss=0.521, G_loss=1.073
# >268, 2/5, D_loss=0.702, G_loss=1.138
# >268, 3/5, D_loss=0.556, G_loss=1.125
# >268, 4/5, D_loss=0.662, G_loss=1.191
# >268, 5/5, D_loss=0.713, G_loss=1.072
# >269, 1/5, D_loss=0.639, G_loss=1.168
# >269, 2/5, D_loss=0.611, G_loss=1.117
# >269, 3/5, D_loss=0.709, G_loss=1.058
# >269, 4/5, D_loss=0.647, G_loss=1.135
# >269, 5/5, D_loss=0.662, G_loss=1.090
# >270, 1/5, D_loss=0.609, G_loss=1.129
# >270, 2/5, D_loss=0.607, G_loss=1.161
# >270, 3/5, D_loss=0.553, G_loss=1.199
# >270, 4/5, D_loss=0.676, G_loss=1.164
# >270, 5/5, D_loss=0.667, G_loss=1.109
# >Epoch: 270 Porosity match: 0% Std: 16 real: 87% fake: 60%
# >271, 1/5, D_loss=0.663, G_loss=1.196
# >271, 2/5, D_loss=0.639, G_loss=1.086
# >271, 3/5, D_loss=0.589, G_loss=1.117
# >271, 4/5, D_loss=0.630, G_loss=1.029
# >271, 5/5, D_loss=0.608, G_loss=1.260
# >272, 1/5, D_loss=0.605, G_loss=1.193
# >272, 2/5, D_loss=0.570, G_loss=1.132
# >272, 3/5, D_loss=0.629, G_loss=1.154
# >272, 4/5, D_loss=0.627, G_loss=1.390
# >272, 5/5, D_loss=0.612, G_loss=1.214
# >273, 1/5, D_loss=0.593, G_loss=1.201
# >273, 2/5, D_loss=0.618, G_loss=1.135
# >273, 3/5, D_loss=0.641, G_loss=1.224
# >273, 4/5, D_loss=0.575, G_loss=1.195
# >273, 5/5, D_loss=0.673, G_loss=1.180
# >274, 1/5, D_loss=0.576, G_loss=1.244
# >274, 2/5, D_loss=0.669, G_loss=1.317
# >274, 3/5, D_loss=0.788, G_loss=1.016
# >274, 4/5, D_loss=0.537, G_loss=1.230
# >274, 5/5, D_loss=0.636, G_loss=1.161
# >275, 1/5, D_loss=0.585, G_loss=1.234
# >275, 2/5, D_loss=0.570, G_loss=1.130
# >275, 3/5, D_loss=0.578, G_loss=1.126
# >275, 4/5, D_loss=0.543, G_loss=1.154
# >275, 5/5, D_loss=0.667, G_loss=1.223
# >276, 1/5, D_loss=0.635, G_loss=1.244
# >276, 2/5, D_loss=0.640, G_loss=1.138
# >276, 3/5, D_loss=0.622, G_loss=1.118
# >276, 4/5, D_loss=0.585, G_loss=1.175
# >276, 5/5, D_loss=0.636, G_loss=1.172
# >277, 1/5, D_loss=0.593, G_loss=1.251
# >277, 2/5, D_loss=0.584, G_loss=1.232
# >277, 3/5, D_loss=0.608, G_loss=1.241
# >277, 4/5, D_loss=0.588, G_loss=1.221
# >277, 5/5, D_loss=0.571, G_loss=1.197
# >278, 1/5, D_loss=0.662, G_loss=1.243
# >278, 2/5, D_loss=0.619, G_loss=1.234
# >278, 3/5, D_loss=0.609, G_loss=1.280
# >278, 4/5, D_loss=0.639, G_loss=1.178
# >278, 5/5, D_loss=0.691, G_loss=1.176
# >279, 1/5, D_loss=0.662, G_loss=1.328
# >279, 2/5, D_loss=0.562, G_loss=1.235
# >279, 3/5, D_loss=0.635, G_loss=1.196
# >279, 4/5, D_loss=0.595, G_loss=1.391
# >279, 5/5, D_loss=0.664, G_loss=1.354
# >280, 1/5, D_loss=0.631, G_loss=1.378
# >280, 2/5, D_loss=0.577, G_loss=1.495
# >280, 3/5, D_loss=0.604, G_loss=1.516
# >280, 4/5, D_loss=0.658, G_loss=1.320
# >280, 5/5, D_loss=0.647, G_loss=1.431
# >Epoch: 280 Porosity match: 0% Std: 11 real: 94% fake: 54%
# >281, 1/5, D_loss=0.585, G_loss=1.494
# >281, 2/5, D_loss=0.648, G_loss=1.438
# >281, 3/5, D_loss=0.602, G_loss=1.569
# >281, 4/5, D_loss=0.574, G_loss=1.540
# >281, 5/5, D_loss=0.559, G_loss=1.553
# >282, 1/5, D_loss=0.549, G_loss=1.517
# >282, 2/5, D_loss=0.551, G_loss=1.460
# >282, 3/5, D_loss=0.635, G_loss=1.609
# >282, 4/5, D_loss=0.690, G_loss=1.634
# >282, 5/5, D_loss=0.521, G_loss=1.480
# >283, 1/5, D_loss=0.562, G_loss=1.692
# >283, 2/5, D_loss=0.561, G_loss=1.745
# >283, 3/5, D_loss=0.614, G_loss=1.619
# >283, 4/5, D_loss=0.539, G_loss=1.663
# >283, 5/5, D_loss=0.540, G_loss=1.678
# >284, 1/5, D_loss=0.485, G_loss=1.673
# >284, 2/5, D_loss=0.531, G_loss=1.647
# >284, 3/5, D_loss=0.547, G_loss=1.829
# >284, 4/5, D_loss=0.482, G_loss=1.755
# >284, 5/5, D_loss=0.411, G_loss=1.631
# >285, 1/5, D_loss=0.515, G_loss=1.579
# >285, 2/5, D_loss=0.509, G_loss=1.721
# >285, 3/5, D_loss=0.542, G_loss=1.656
# >285, 4/5, D_loss=0.558, G_loss=1.737
# >285, 5/5, D_loss=0.412, G_loss=1.809
# >286, 1/5, D_loss=0.464, G_loss=1.730
# >286, 2/5, D_loss=0.472, G_loss=1.995
# >286, 3/5, D_loss=0.603, G_loss=1.673
# >286, 4/5, D_loss=0.442, G_loss=1.768
# >286, 5/5, D_loss=0.491, G_loss=1.803
# >287, 1/5, D_loss=0.499, G_loss=1.715
# >287, 2/5, D_loss=0.526, G_loss=1.933
# >287, 3/5, D_loss=0.468, G_loss=1.834
# >287, 4/5, D_loss=0.420, G_loss=1.645
# >287, 5/5, D_loss=0.437, G_loss=1.860
# >288, 1/5, D_loss=0.524, G_loss=1.893
# >288, 2/5, D_loss=0.526, G_loss=1.751
# >288, 3/5, D_loss=0.506, G_loss=1.726
# >288, 4/5, D_loss=0.503, G_loss=1.761
# >288, 5/5, D_loss=0.455, G_loss=1.711
# >289, 1/5, D_loss=0.465, G_loss=1.587
# >289, 2/5, D_loss=0.545, G_loss=1.653
# >289, 3/5, D_loss=0.487, G_loss=1.398
# >289, 4/5, D_loss=0.567, G_loss=1.612
# >289, 5/5, D_loss=0.440, G_loss=1.360
# >290, 1/5, D_loss=0.473, G_loss=1.569
# >290, 2/5, D_loss=0.562, G_loss=1.525
# >290, 3/5, D_loss=0.515, G_loss=1.726
# >290, 4/5, D_loss=0.666, G_loss=1.633
# >290, 5/5, D_loss=0.577, G_loss=1.489
# >Epoch: 290 Porosity match: 0% Std: 15 real: 92% fake: 58%
# >291, 1/5, D_loss=0.606, G_loss=1.430
# >291, 2/5, D_loss=0.592, G_loss=1.524
# >291, 3/5, D_loss=0.489, G_loss=1.461
# >291, 4/5, D_loss=0.627, G_loss=1.368
# >291, 5/5, D_loss=0.586, G_loss=1.392
# >292, 1/5, D_loss=0.501, G_loss=1.302
# >292, 2/5, D_loss=0.656, G_loss=1.386
# >292, 3/5, D_loss=0.664, G_loss=1.259
# >292, 4/5, D_loss=0.680, G_loss=1.468
# >292, 5/5, D_loss=0.692, G_loss=1.466
# >293, 1/5, D_loss=0.655, G_loss=1.288
# >293, 2/5, D_loss=0.577, G_loss=1.265
# >293, 3/5, D_loss=0.740, G_loss=1.283
# >293, 4/5, D_loss=0.810, G_loss=1.117
# >293, 5/5, D_loss=0.803, G_loss=1.032
# >294, 1/5, D_loss=0.674, G_loss=1.177
# >294, 2/5, D_loss=0.787, G_loss=0.955
# >294, 3/5, D_loss=0.726, G_loss=1.173
# >294, 4/5, D_loss=0.755, G_loss=1.131
# >294, 5/5, D_loss=0.728, G_loss=1.139
# >295, 1/5, D_loss=0.671, G_loss=1.126
# >295, 2/5, D_loss=0.699, G_loss=0.992
# >295, 3/5, D_loss=0.808, G_loss=1.223
# >295, 4/5, D_loss=0.702, G_loss=1.110
# >295, 5/5, D_loss=0.756, G_loss=1.184
# >296, 1/5, D_loss=0.713, G_loss=0.947
# >296, 2/5, D_loss=0.823, G_loss=1.124
# >296, 3/5, D_loss=0.759, G_loss=1.105
# >296, 4/5, D_loss=0.793, G_loss=0.893
# >296, 5/5, D_loss=0.921, G_loss=1.020
# >297, 1/5, D_loss=0.819, G_loss=0.982
# >297, 2/5, D_loss=0.742, G_loss=0.959
# >297, 3/5, D_loss=0.697, G_loss=0.964
# >297, 4/5, D_loss=0.751, G_loss=0.877
# >297, 5/5, D_loss=0.719, G_loss=0.923
# >298, 1/5, D_loss=0.690, G_loss=1.106
# >298, 2/5, D_loss=0.732, G_loss=0.985
# >298, 3/5, D_loss=0.692, G_loss=1.034
# >298, 4/5, D_loss=0.647, G_loss=0.943
# >298, 5/5, D_loss=0.719, G_loss=1.003
# >299, 1/5, D_loss=0.808, G_loss=1.046
# >299, 2/5, D_loss=0.680, G_loss=1.017
# >299, 3/5, D_loss=0.723, G_loss=0.928
# >299, 4/5, D_loss=0.770, G_loss=1.045
# >299, 5/5, D_loss=0.705, G_loss=1.019
# >300, 1/5, D_loss=0.650, G_loss=1.091
# >300, 2/5, D_loss=0.655, G_loss=1.121
# >300, 3/5, D_loss=0.729, G_loss=1.088
# >300, 4/5, D_loss=0.688, G_loss=1.120
# >300, 5/5, D_loss=0.673, G_loss=1.062
# >Epoch: 300 Porosity match: 0% Std: 9 real: 66% fake: 58%
# No handles with labels found to put in legend.

# %% [markdown]
# # Evaluate `Generator`

# %% [markdown]
# ## Compile gif

# %%
score_filename, geom_epoch_dirs, gif_filename, tmp_models_dir, models_dir, arrays_dir = get_filenames(dimension, simulation, simmetry, score)

with imageio.get_writer(gif_filename, mode='I') as writer:
    geom_filenames = os.listdir(geom_epoch_dirs)
    for geom_filename in geom_filenames:
        image = imageio.imread(geom_epoch_dirs+geom_filename)
        foo = cv2.putText(
                    image,
                    str((geom_filenames.index(geom_filename)+1)*5),
                    (5, 25),
                    cv2.FONT_HERSHEY_SIMPLEX,
                    1,
                    (255, 0, 0),
                    2)
        for i in range(3):
            # image = imageio.imread(geom_epoch_dirs+geom_filename)
            writer.append_data(image)

# %% [markdown]
# ## Visualize geometries

# %%
def check_unit(unit, desired_porosity, tol):
  labels = measure.label(unit,connectivity=1)
  main_label = 0
  main_label_count = 0
  passed = True

  element = unit[int(unit.shape[0]/2):,:int(unit.shape[0]/2)]

  for label in range(1,len(np.unique(labels))):
      label_count = np.where(labels==label)[0].shape[0]
      if label_count > main_label_count:
        main_label = label
        main_label_count = label_count

  void_count = 0

  for label in range(1,len(np.unique(labels))):
    if label not in [0,main_label]:
      void_count += np.where(labels==label)[0].shape[0]
      unit[np.where(labels==label)] = 0.

  porosity = get_porosity(unit)

  if porosity > desired_porosity - tol and porosity < desired_porosity + tol:
    for label in range(1,len(np.unique(labels))):
      if label not in [0,main_label]:
        unit[np.where(labels==label)] = 0.

    if unit[0,:].sum() > 0 and unit[:,0].sum() > 0:
      # check if there is connectivity right-left
      connections_rl = 0
      for i in range(unit.shape[0]):
        if (unit[i,0] == 1 and unit[i,-1] == 1):
          connections_rl += 1

      # check if there is connectivity top-bottom
      connections_tb = 0
      for j in range(unit.shape[1]):
        if (unit[0,j] == 1 and unit[-1,j] == 1):
          connections_tb += 1

      if connections_rl == 0 or connections_tb == 0:
        passed = False
      
    else:
      passed = False
      
  else:
    passed = False

  if passed:
    passed = False
    for i in range(element.shape[0]):
      if [element[i,0],element[element.shape[0]-1,element.shape[1]-i-1]]==[1,1]:
        passed = True

  return passed, element

def check_singularity(element, simmetry):
  passeds = [True for i in range(4)]

  # check singularities inside element
  for i in range(element.shape[0]-1):
    for j in range(element.shape[1]-1):
      # print(element[i:i+2,j:j+2])
      diag1 = list(element[i:i+2,j:j+2].diagonal())
      diag2 = list(np.fliplr(element[i:i+2,j:j+2]).diagonal())
      if (diag1 == [1,1] and diag2 == [0,0]) or (diag1 == [0,0] and diag2 == [1,1]):
        passeds[0] = False    

  # check singularities in element boundary and singularities in unit boundary
  if simmetry[1:] == '4':
    for j in range(element.shape[1]-1):
      arr = np.array([[element[element.shape[0]-j-1,element.shape[1]-1],element[element.shape[0]-j-2,element.shape[1]-1]],[element[0,j],element[0,j+1]]])
      diag1 = list(arr.diagonal())
      diag2 = list(np.fliplr(arr).diagonal())
      if (diag1 == [1,1] and diag2 == [0,0]) or (diag1 == [0,0] and diag2 == [1,1]):
        passeds[1] = False
      
      arr = np.array([[element[element.shape[0]-1,j],element[element.shape[0]-1,j+1]],[element[j,0],element[j+1,0]]])
      diag1 = list(arr.diagonal())
      diag2 = list(np.fliplr(arr).diagonal())
      if (diag1 == [1,1] and diag2 == [0,0]) or (diag1 == [0,0] and diag2 == [1,1]):
        passeds[2] = False
      if [element[0,0],element[element.shape[0]-1,element.shape[1]-1]] == [1, 0] or [element[0,0],element[element.shape[0]-1,element.shape[1]-1]] == [0, 1]:
        passeds[3] = False

  return passeds

epoch = 200
tol = 0.02
score = 'isotropy'
input_G = 128
simmetry = 'p4'
sampling_method = 'normal'
top = 5
rounds = 20
test_size = 10000
desired_porosity=0.55
save = False
plot = not save

score_filename, geom_epoch_dirs, gif_filename, tmp_models_dir, models_dir, arrays_dir = get_filenames(dimension, simulation, simmetry, score)

def save_models(epoch,save,tmp_models_dir,models_dir):
  # select model
  G_files = os.listdir(tmp_models_dir+'/G/')
  D_files = os.listdir(tmp_models_dir+'/D/')
  for i in range(len(G_files)):
      G_file = G_files[i]
      D_file = D_files[i]
      if int(G_file.split('_')[1]) == epoch:
          G = load_model(tmp_models_dir+'/G/'+G_file)
          D = load_model(tmp_models_dir+'/D/'+D_file, custom_objects={'custom_loss':validity_loss()})
          break

  if save: 
      models_filename = os.listdir(models_dir)
      models_filename = ['_'.join(x.split('_')[1:]) for x in models_filename]
      if G_file not in models_filename:
        idx_model = len(models_filename)+1
        G.save(models_dir+'%04d_'%(idx_model)+G_file)
      else:
        # find idx of existing model
        idx_model = models_filename.index(G_file)+1
  else:
    idx_model = None
  return G, D, idx_model

G,D,idx_model = save_models(epoch,save,tmp_models_dir,models_dir)

def generate_geometries(test_size, rounds, idx_model, top, tol, desired_porosity, save, plot):
  idx = len(os.listdir(arrays_dir))+1
  for r in range(rounds):
    X_test = generate_input_G(input_G,test_size,sampling_method)
    geometries,_,_ = G.predict(X_test,verbose = 0)
    size = geometries.shape[1]

    if plot:
      sns.histplot(1-np.sum(geometries.round().reshape((test_size,int(size*size))),axis=-1)/int(size*size),bins=32);
    _, geometries = porosity_match(geometries, desired_porosity, tol)
    elements = []

    for i in range(len(geometries)):
      geom = geometries[i].reshape((size,size)).round()
      unit = create_unit(geom,size,simmetry)
      passed_connectivity,element = check_unit(unit, desired_porosity, tol)
      passed_singularity = check_singularity(element, simmetry)
      if passed_connectivity and all(passed_singularity):
        elements.append(element)

    geometries = np.array(elements)

    # Get scores
    scores = D.predict([geometries,geometries,geometries],verbose = 0)[0].ravel()
    top_idxs = np.argsort(-scores)[:top]

    for top_idx in top_idxs:
      elem = geometries[top_idx]
      unit = create_unit(elem.reshape((size,size)),size,simmetry)
      arrange = create_arrange(unit,3,3)
      
      if plot:
        print("Score: %.2f Porosity: %.2f"%(scores[top_idx],get_porosity(elem)))
        fig,ax = plt.subplots(1,3);
        fig.set_size_inches((15,5))
        
        ax[0].imshow(elem,cmap='Greys');
        ax[0].axis('off')
        
        ax[1].imshow(unit,cmap="Greys")
        ax[1].axis('off')

        ax[2].imshow(arrange,cmap="Greys")
        ax[2].axis('off')
        plt.show()

      if save:
        filename = arrays_dir+"%05d_model_%04d_porosity_%.4f.txt" % (idx, idx_model, 1.0-elem.ravel().sum()/(size*size))
        elem = elem.ravel()
        elem_ = np.zeros(elem.shape[0]+1)
        elem_[0] = int(np.sqrt(elem.shape[0]))
        elem_[1:] = elem[:]
        elem = elem_
        np.savetxt(filename, elem, delimiter='/n', fmt='%s')
        idx += 1

generate_geometries(test_size, rounds, idx_model, top, tol, desired_porosity, save, plot)
# Out:
# Score: 0.84 Porosity: 0.56
# Score: 0.82 Porosity: 0.54
# Score: 0.81 Porosity: 0.57
# Score: 0.80 Porosity: 0.54
# Score: 0.80 Porosity: 0.55
# Score: 0.79 Porosity: 0.54
# Score: 0.79 Porosity: 0.55
# Score: 0.77 Porosity: 0.54
# Score: 0.77 Porosity: 0.56
# Score: 0.76 Porosity: 0.56
# Score: 0.89 Porosity: 0.55
# Score: 0.83 Porosity: 0.54
# Score: 0.77 Porosity: 0.57
# Score: 0.76 Porosity: 0.55
# Score: 0.75 Porosity: 0.55
# Score: 0.81 Porosity: 0.53
# Score: 0.79 Porosity: 0.56
# Score: 0.79 Porosity: 0.54
# Score: 0.76 Porosity: 0.55
# Score: 0.75 Porosity: 0.55
# Score: 0.80 Porosity: 0.54
# Score: 0.79 Porosity: 0.56
# Score: 0.77 Porosity: 0.56
# Score: 0.75 Porosity: 0.55
# Score: 0.74 Porosity: 0.55
# Score: 0.83 Porosity: 0.54
# Score: 0.82 Porosity: 0.54
# Score: 0.81 Porosity: 0.55
# Score: 0.79 Porosity: 0.54
# Score: 0.79 Porosity: 0.55
# Score: 0.79 Porosity: 0.54
# Score: 0.79 Porosity: 0.54
# Score: 0.78 Porosity: 0.54
# Score: 0.78 Porosity: 0.55
# Score: 0.77 Porosity: 0.54
# Score: 0.77 Porosity: 0.56
# Score: 0.77 Porosity: 0.55
# Score: 0.76 Porosity: 0.55
# Score: 0.75 Porosity: 0.55
# Score: 0.74 Porosity: 0.55
# Score: 0.80 Porosity: 0.55
# Score: 0.80 Porosity: 0.53
# Score: 0.76 Porosity: 0.55
# Score: 0.75 Porosity: 0.55
# Score: 0.74 Porosity: 0.53
# Score: 0.84 Porosity: 0.55
# Score: 0.77 Porosity: 0.54
# Score: 0.76 Porosity: 0.55
# Score: 0.75 Porosity: 0.53
# Score: 0.75 Porosity: 0.57
# Score: 0.85 Porosity: 0.57
# Score: 0.83 Porosity: 0.54
# Score: 0.79 Porosity: 0.55
# Score: 0.77 Porosity: 0.57
# Score: 0.77 Porosity: 0.54
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-26-f6d0b49d1d85> in <module>
#     186         idx += 1
#     187
# --> 188 generate_geometries(test_size, rounds, idx_model, top, tol, desired_porosity, save, plot)
#
# <ipython-input-26-f6d0b49d1d85> in generate_geometries(test_size, rounds, idx_model, top, tol, desired_porosity, save, plot)
#     145       geom = geometries[i].reshape((size,size)).round()
#     146       unit = create_unit(geom,size,simmetry)
# --> 147       passed_connectivity,element = check_unit(unit, desired_porosity, tol)
#     148       passed_singularity = check_singularity(element, simmetry)
#     149       if passed_connectivity and all(passed_singularity):
#
# <ipython-input-26-f6d0b49d1d85> in check_unit(unit, desired_porosity, tol)
#      18     if label not in [0,main_label]:
#      19       void_count += np.where(labels==label)[0].shape[0]
# ---> 20       unit[np.where(labels==label)] = 0.
#      21
#      22   porosity = get_porosity(unit)
#
# KeyboardInterrupt:
