# %% [markdown]
# # Imports

# %%
import os
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.preprocessing import MinMaxScaler
from skimage import measure
import imageio
import  cv2
# %matplotlib inline

import tensorflow as tf
from tensorflow.keras import backend as K
from tensorflow.keras.models import Model,load_model
from tensorflow.keras.layers import Dense, Flatten, Conv1D, Conv2D, Input, Conv2DTranspose, Concatenate, MaxPool1D, Dropout, Reshape, Lambda, InputLayer, LeakyReLU, BatchNormalization, GaussianNoise
from keras_contrib.layers.normalization.instancenormalization import InstanceNormalization
from tensorflow.keras.optimizers import Adam 
from tensorflow.keras.losses import MeanSquaredError, kullback_leibler_divergence
from tensorflow.keras.metrics import BinaryCrossentropy
from tensorflow.keras.initializers import RandomNormal
from tensorflow.keras.constraints import Constraint
import warnings
import logging
warnings.simplefilter("ignore")
logging.getLogger("tensorflow").setLevel(logging.ERROR)

tf.autograph.set_verbosity(0)
os.environ['AUTOGRAPH_VERBOSITY'] = '0'
os.environ['TF_CPP_MIN_LOG_LEVEL'] = '0'

# %% [markdown]
# ## Test GPU

# %%
physical_devices = tf.config.list_physical_devices('GPU') 
print("GPUs available:",len(physical_devices))
# Out:
# GPUs available: 1

# %% [markdown]
# # Data preparation

# %%
def get_filenames(dimension, simulation, simmetry, score):
    if os.getcwd().split('\\')[2] == 'lucas':
        score_filename = 'E:/Lucas GAN/Dados/4- Mechanical_scores/%s/%sD/%s/%s.csv' %(simulation,dimension,simmetry,score)
        geom_epoch_dirs = 'E:/Lucas GAN/Dados/7- Perfomance_data/%sD/geom_epoch/%s/%s/' %(dimension,simmetry,score)
        gif_filename = 'E:/Lucas GAN/Dados/7- Perfomance_data/%sD/geom_epoch/%s/%s.gif' %(dimension,simmetry,score)
        tmp_models_dir = 'C:/Users/lucas/OneDrive/Documentos/GitHub/INT/Manufatura Aditiva/Simulacao-GAN/Pipeline/3- Machine_learning/GAN/tmp_models/GAN/'
        models_dir = 'D:/Lucas GAN/Dados/5- Models/cGAN/%sD/%s/%s/'%(dimension,simmetry,score)
        arrays_dir = 'E:/Lucas GAN/Dados/1- Arranged_geometries/GAN/%s/%s/' % (simmetry,score)
    else:
        score_filename = 'D:/Lucas GAN/Dados/4- Mechanical_scores/%s/%sD/%s/%s.csv' %(simulation,dimension,simmetry,score)
        geom_epoch_dirs = 'D:/Lucas GAN/Dados/7- Perfomance_data/%sD/geom_epoch/%s/%s/' %(dimension,simmetry,score)
        gif_filename = 'D:/Lucas GAN/Dados/7- Perfomance_data/%sD/geom_epoch/%s/%s.gif' %(dimension,simmetry,score)
        tmp_models_dir = 'C:/Users/lucas.barbosa/Documents/GitHub/INT/Manufatura Aditiva/Simulacao-GAN/Pipeline/3- Machine_learning/GAN/tmp_models/GAN/'
        models_dir = 'D:/Lucas GAN/Dados/5- Models/GAN/%sD/%s/%s/'%(dimension,simmetry,score)
        arrays_dir = 'D:/Lucas GAN/Dados/1- Arranged_geometries/GAN/%s/%s/' % (simmetry,score)


    return score_filename, geom_epoch_dirs, gif_filename, tmp_models_dir, models_dir, arrays_dir

def load_data(score_filename, cutoff, bins, soft=False, balance=False, plot=False):  
    def find_closest(arr, val):
       idx = np.abs(arr - val).argmin()
       return arr[idx]
    data = np.loadtxt(score_filename,delimiter=',')
    X = data[:,1:-1]
    size = int(np.sqrt(X.shape[1]))
    X = X.reshape((X.shape[0],size,size,1))

    y = data[:,-1]
    y = y.reshape((y.shape[0],1))
    y = y[np.argsort(y[:,0])]
    total_size = y.shape[0]

    if plot:
        sns.histplot(y, legend=True, bins=bins, color='b')
    
    cutoff = find_closest(bins,cutoff)
    idxs_good = np.where(y>cutoff)[0]
    y = y[idxs_good]
    X = X[idxs_good]
    min_bin = idxs_good.shape[0]

    if balance:
        bins_good = bins[np.where(bins>=cutoff)]
        for i in range(len(bins_good)-1):
            l,u = bins_good[i:i+2]
            idx_bin = np.where((y>=l) & (y<u))[0]
            y_bin = y[idx_bin]
            min_bin = min(min_bin,y_bin.shape[0])

        X_balanced = np.zeros((min_bin*(bins_good.shape[0]-1),X.shape[1],X.shape[2],X.shape[3]))
        y_balanced = np.zeros((min_bin*(bins_good.shape[0]-1),1))
        y_ = np.ones((min_bin*(bins_good.shape[0]-1),1))

        for i in range(len(bins_good)-1):
            l,u = bins_good[i:i+2]
            idx_bin = np.where((y>=l) & (y<u))[0]
            X_bin = X[idx_bin]
            y_bin = y[idx_bin]

            idx_bin = np.random.choice(y_bin.shape[0],min_bin)
            X_bin = X_bin[idx_bin]
            y_bin = y_bin[idx_bin]

            X_balanced[min_bin*i:min_bin*(i+1)] = X_bin
            y_balanced[min_bin*i:min_bin*(i+1)] = y_bin

        X = X_balanced
        y = y_

        if plot:
            sns.histplot(y_balanced, legend=True, bins=bins, color='r')

    if soft:
        y = np.random.choice(np.linspace(0.7,1.2,6)).round(1)*np.ones(y.shape)
    
    plt.legend(['raw','Balanced'])
    
    print(f"Good = %.2f %%"%(100*len(y)/total_size))
    
    return X, y, size

dimension = 2
simulation = '-r'
simulation = {'-m':'MATLAB','-r':'RTGA'}[simulation]
simmetry = 'p4m'
score = 'isotropy'
score_filename,_,_,_,_,_ = get_filenames(dimension, simulation, simmetry, score)

cutoff = 0.6
bins= np.linspace(0,1,41).round(3)
soft = False
plot = True
balance = True

X, y, size = load_data(score_filename, cutoff, bins, soft=soft, balance=balance, plot=plot)
# Out:
# Good = 17.70 %

# %% [markdown]
# # Models definition

# %% [markdown]
# ## Generator

# %%
def setup_G(input_G,output_G,size):
    size = int(size/2)
    in_G = Input(shape=(input_G,),name="G-Latent-Input")

    # foundation for 8x8 image
    n_nodes = input_G * size * size
    out_G = Dense(n_nodes,activation=LeakyReLU(alpha=0.2),name="G-FoundationLayer")(in_G)
    out_G = Reshape((size, size, 128),name="G-ReshapeLayer")(out_G)
    # upsample to 16x16
    out_G = Conv2DTranspose(128, (4,4), strides=(2,2), padding='same',activation=LeakyReLU(alpha=0.2),name="G-HiddenLayer1")(out_G)
    out_G = Conv2D(1, (size,size), activation='sigmoid', padding='same',name="G-Geometry-Output")(out_G)

    # model = Model(name='Generator',inputs=in_G,outputs=[out_G,out_porosity,out_validity])
    model = Model(name='Generator',inputs=in_G,outputs=[out_G])
    return model
G_test = setup_G(128,256,16)
G_test.summary()
tf.keras.utils.plot_model(G_test)
# Out:
# Model: "Generator"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  G-Latent-Input (InputLayer)  [(None, 128)]            0
#
#  G-FoundationLayer (Dense)   (None, 8192)              1056768
#
#  G-ReshapeLayer (Reshape)    (None, 8, 8, 128)         0
#
#  G-HiddenLayer1 (Conv2DTrans  (None, 16, 16, 128)      262272
#  pose)
#
#  G-Geometry-Output (Conv2D)  (None, 16, 16, 1)         8193
#
# =================================================================
# Total params: 1,327,233
# Trainable params: 1,327,233
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# ## Discriminator

# %%
def wasserstein_loss():
    def custom_loss(y_true, y_pred):
	    return K.mean(y_true * y_pred)
    return custom_loss

def porosity_loss():
    def custom_por_loss(y_true,y_pred):
        # size = y_pred.shape[1]*y_pred.shape[2]
        y_pred = K.round(y_pred)
        por_true = K.sum(K.sum(K.sum(y_true,axis=1),axis=1),axis=1)
        por_pred = K.sum(K.sum(K.sum(y_pred,axis=1),axis=1),axis=1)
        mse = tf.cast((por_true-por_pred)**2,tf.float32)
        return mse
    return custom_por_loss

def validity_loss():
    def custom_val_loss(y_true, y_pred):
        # @tf.function
        def connectivity_losss(element):
            size = element.shape[0]
            element = element.numpy().reshape((size,size))
            labels = measure.label(element,connectivity=1)
            return len(np.unique(labels))

        def simmetry_loss(element):
           return 0
            
        y_pred = K.round(y_pred)
        con_loss = tf.map_fn(fn=connectivity_losss, elems=y_pred)
        if simmetry[1:] in ['4m','4g']:
            sim_loss = tf.map_fn(fn=simmetry_loss, elems=y_pred)
            return con_loss + sim_loss
        return con_loss

    return custom_val_loss
    
def setup_D(input_D,loss,lr,alpha_por,alpha_val,normalize=False):
    #define model
    in_D = Input(shape=input_D,name="D-Geometry-Input")

    out_D = GaussianNoise(0.1,name="D-NoiseLayer1")(in_D)
    out_D = Conv2D(64, (3,3), strides=(2, 2), padding='same',name="D-HiddenLayer1")(out_D)
    if normalize:
        out_D = InstanceNormalization(name="D-InstanceNormalization-Layer1")(out_D)
    out_D = LeakyReLU(alpha=0.2,name="D-Activation-Layer1")(out_D)

    out_D = GaussianNoise(0.1,name="D-NoiseLayer2")(out_D)
    out_D = Dropout(0.4,name="D-DropoutLayer1")(out_D)
    out_D = Conv2D(64, (3,3), strides=(2, 2), padding='same',name="D-HiddenLayer2")(out_D)
    if normalize:
        out_D = InstanceNormalization(name="D-InstanceNormalization-Layer2")(out_D)
    out_D = LeakyReLU(alpha=0.2,name="D-Activation-Layer2")(out_D)

    out_D = GaussianNoise(0.1,name="D-NoiseLayer3")(out_D)
    out_D = Dropout(0.4,name="D-DropoutLayer2")(out_D)
    out_D = Flatten(name="D-FlattenLayer")(out_D)
    out_D = Dense(1, activation='sigmoid',name="D-Classification-Output")(out_D)

    # porosity branch
    out_porosity = Lambda(lambda x: x,name='D-Porosity-Output')(in_D)

    # validity branch
    out_validity = Lambda(lambda x: x,name='D-Validity-Output')(in_D)

    opt = Adam(learning_rate=lr, beta_1=0.5)
    
    model = Model(
                name='Discriminator', \
                # inputs=[in_D,in_porosity,in_validity], \
                inputs=[in_D], \
                outputs=[out_D,out_porosity,out_validity])

    loss_func = {'bce':'binary_crossentropy','wl':wasserstein_loss,'kld':kullback_leibler_divergence}[loss]
    model.compile(
                loss=[loss_func,porosity_loss(),validity_loss()], \
                loss_weights=[1.0,0.0,0.0], \
                optimizer='adam', \
                metrics=['accuracy'], \
                run_eagerly=True)
    return model

D_test = setup_D((16,16,1),'bce',1e-4,0.01,0.01,True)
D_test.summary()
tf.keras.utils.plot_model(D_test)
# Out:
# Model: "Discriminator"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  D-Geometry-Input (InputLayer)  [(None, 16, 16, 1)]  0           []
#
#  D-NoiseLayer1 (GaussianNoise)  (None, 16, 16, 1)    0           ['D-Geometry-Input[0][0]']
#
#  D-HiddenLayer1 (Conv2D)        (None, 8, 8, 64)     640         ['D-NoiseLayer1[0][0]']
#
#  D-InstanceNormalization-Layer1  (None, 8, 8, 64)    2           ['D-HiddenLayer1[0][0]']
#   (InstanceNormalization)
#
#  D-Activation-Layer1 (LeakyReLU  (None, 8, 8, 64)    0           ['D-InstanceNormalization-Layer1[
#  )                                                               0][0]']
#
#  D-NoiseLayer2 (GaussianNoise)  (None, 8, 8, 64)     0           ['D-Activation-Layer1[0][0]']
#
#  D-DropoutLayer1 (Dropout)      (None, 8, 8, 64)     0           ['D-NoiseLayer2[0][0]']
#
#  D-HiddenLayer2 (Conv2D)        (None, 4, 4, 64)     36928       ['D-DropoutLayer1[0][0]']
#
#  D-InstanceNormalization-Layer2  (None, 4, 4, 64)    2           ['D-HiddenLayer2[0][0]']
#   (InstanceNormalization)
#
#  D-Activation-Layer2 (LeakyReLU  (None, 4, 4, 64)    0           ['D-InstanceNormalization-Layer2[
#  )                                                               0][0]']
#
#  D-NoiseLayer3 (GaussianNoise)  (None, 4, 4, 64)     0           ['D-Activation-Layer2[0][0]']
#
#  D-DropoutLayer2 (Dropout)      (None, 4, 4, 64)     0           ['D-NoiseLayer3[0][0]']
#
#  D-FlattenLayer (Flatten)       (None, 1024)         0           ['D-DropoutLayer2[0][0]']
#
#  D-Classification-Output (Dense  (None, 1)           1025        ['D-FlattenLayer[0][0]']
#  )
#
#  D-Porosity-Output (Lambda)     (None, 16, 16, 1)    0           ['D-Geometry-Input[0][0]']
#
#  D-Validity-Output (Lambda)     (None, 16, 16, 1)    0           ['D-Geometry-Input[0][0]']
#
# ==================================================================================================
# Total params: 38,597
# Trainable params: 38,597
# Non-trainable params: 0
# __________________________________________________________________________________________________

# %% [markdown]
# ## Setup GAN

# %%
def setup_GAN(G_model,D_model,loss,alpha_por,alpha_val,lr,size):
    D_model.trainable = False
    in_G = G_model.input
    out_GAN = D_model(G_model(in_G))
    
    opt = Adam(learning_rate=lr, beta_1=0.5)
    
    model = Model(name='GAN',inputs=in_G,outputs=out_GAN)
    loss_func = {'bce':'binary_crossentropy','wl':wasserstein_loss,'kld':kullback_leibler_divergence}[loss]
    model.compile(
                loss=[loss_func,porosity_loss(),validity_loss()], \
                loss_weights=[1.0,alpha_por,alpha_val], \
                optimizer='adam', \
                metrics=['accuracy'], \
                run_eagerly=True)
    return model

setup_GAN(setup_G(128,256,16),setup_D((16,16,1),'bce',1e-4,0.01,0.01),'bce',0.01,0.01,1e-4,16).summary()
# Out:
# Model: "GAN"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  G-Latent-Input (InputLayer)  [(None, 128)]            0
#
#  Generator (Functional)      (None, 16, 16, 1)         1327233
#
#  Discriminator (Functional)  [(None, 1),               38593
#                               (None, 16, 16, 1),
#                               (None, 16, 16, 1)]
#
# =================================================================
# Total params: 1,365,826
# Trainable params: 1,327,233
# Non-trainable params: 38,593
# _________________________________________________________________

# %% [markdown]
# # Aux functions

# %% [markdown]
# ## For geometry manipulation

# %%
def create_unit(element,size,simmetry):
  if simmetry[1:2] == '4':
    unit_size = 2*size
    # fold_size = np.random.choice(4,1)[0]
    unit = np.ones((2*size,2*size))*(-1)
    h,w = element.shape
    for i in range(h):
      for j in range(w):
        el = element[i,j]
        
        j_ = [j,w-1-i,2*h-1-j,i+w]
        i_ = [i+w,j,w-1-i,2*h-1-j]
        # (1,7)->(7,14)->(14,8)->(8,1)
        for (k,l) in list(zip(i_,j_)):
          unit[k,l]  = el
    return unit

def create_arrange(unit,rows,cols):
  size = unit.shape[0]
  arrange = np.zeros((rows*size,cols*size))
  for i in range(unit.shape[0]):
    for j in range(unit.shape[1]):
      for row in range(rows):
        for col in range(cols):
          arrange[j+row*size,i+col*size] = unit[j,i]
  
  return arrange

def get_porosity(geom):
    voids = np.where(geom == 0.0)[0].shape[0]

    return voids/(geom.shape[0]*geom.shape[1])

# %% [markdown]
# ## For GAN

# %%
def generate_fake_samples(G_model, input_G, n_samples, method):
    # generate points in latent space
    X_input = generate_input_G(input_G, n_samples,method)
    # predict outputs
    X = G_model.predict(X_input,verbose = 0)
    # create 'fake' class labels (0)
    y = np.zeros((n_samples, 1))
    return X,y

def generate_input_G(input_G, n_samples, method):

    if method == 'normal':
        # generate points in the latent space
        X_input = np.random.randn(input_G * n_samples)
        # reshape into a batch of inputs for the network
        X_input = X_input.reshape(n_samples, input_G)
    if method == 'uniform':
        X_input = np.random.uniform(n_samples,input_G)
    if method == 'spherical':
        X_input = np.random.randn(input_G * n_samples)
        # reshape into a batch of inputs for the network
        X_input = X_input.reshape(n_samples, input_G)
        X_input /= np.linalg.norm(X_input, axis=0)/3.0
    return X_input

def generate_real_samples(dataset, y, n_samples):
    # choose random instances
    idx = np.random.randint(0, dataset.shape[0], n_samples)
    # retrieve selected images
    X = dataset[idx]
    # generate 'real' class labels (1)
    y = y[idx]
    return X, y

def summarize_performance(epoch,porosity,G_model, D_model, dataset, y, input_G, sampling_method, n_samples=100):
    # prepare real samples
    X_real, y_real = generate_real_samples(dataset, y, n_samples)
    # evaluate discriminator on real examples
    _,_,_,_,acc_real,_,_ = D_model.evaluate(x=[X_real], y=[y_real,porosity*np.ones(X_real.shape),np.zeros(X_real.shape)], verbose=0)
    # prepare fake examples
    X_fake, y_fake = generate_fake_samples(G_model, input_G, n_samples, sampling_method)
    # evaluate discriminator on fake examples
    _,_,_,_,acc_fake,_,_ = D_model.evaluate(x=[X_fake], y=[y_fake,porosity*np.ones(X_fake.shape),np.zeros(X_fake.shape)], verbose=0)
    # summarize discriminator performance
    return  acc_real,acc_fake

# Filter per porosity
def porosity_match(geoms,porosity,tol):
    geoms_ = []
    passed = 0
    for i in range(geoms.shape[0]):
        g =geoms[i,:,:,0]
        size = g.shape[0]
        g = g.reshape((size*size,))
        p = 1 - np.sum(g)/(size*size)
        if p >= porosity-tol and p <= porosity+tol:
            geoms_.append(g.reshape((size,size)))
            passed += 1
    return passed/len(geoms),np.array(geoms_).reshape((passed,size,size,1))

# %% [markdown]
# # Training GAN

# %%
def train_GAN(X, y, G_model, D_model, GAN_model, input_G, porosity, tol_porosity, batch_size, num_epochs, sampling_method, tmp_models_dir, geom_epoch_dirs, seed_geom_gif, tol_fail, alpha_por, alpha_val, vstack=True, save=True, plot=False, verbose_loss=False, verbose_acc=False):
    def train_D(X,y,half_batch):
        if vstack:
            X_real,y_real = generate_real_samples(X,y,half_batch)
            X_fake,y_fake = generate_fake_samples(G_model,input_G,half_batch,sampling_method)            

            X, y = np.vstack((X_real, X_fake)), np.vstack((y_real, y_fake))
            
            if verbose_loss:
                D_loss = D_model.train_on_batch(x=[X], y=[y,porosity*np.ones(X.shape),0*np.ones(X.shape)],return_dict=True)
                D_loss = D_loss['loss']
            else:
                D_loss = D_model.train_on_batch(x=[X], y=[y,porosity*np.ones(X.shape),0*np.ones(X.shape)])
                D_loss = D_loss[0]

        else:
            X_real,y_real = generate_real_samples(X,y,half_batch)
            X_fake,y_fake = generate_fake_samples(G_model,input_G,half_batch,sampling_method)            

            if verbose_loss:
                D_loss_real = D_model.train_on_batch(x=[X_real], y=[y_real,porosity*np.ones(X_real.shape),0*np.ones(X_real.shape)],return_dict=True)
                D_loss_real = D_loss_real['loss']
                D_loss_fake = D_model.train_on_batch(x=[X_fake], y=[y_fake,porosity*np.ones(X_fake.shape),0*np.ones(X_fake.shape)],return_dict=True)
                D_loss_fake = D_loss_fake['loss']
            else:
                D_loss_real = D_model.train_on_batch(x=[X_real], y=[y_real,porosity*np.ones(X_real.shape),0*np.ones(X_real.shape)])
                D_loss_real = D_loss_real[0]
                D_loss_fake = D_model.train_on_batch(x=[X_fake], y=[y_fake,porosity*np.ones(X_fake.shape),0*np.ones(X_fake.shape)])
                D_loss_fake = D_loss_fake[0]

            D_loss = (D_loss_real+D_loss_fake)/2
            

        return D_loss

    def swap_weights(tmp_models_dir):
        D_files = os.listdir(tmp_models_dir+'/D/')
        D_file = np.random.choice(D_files,1)[0]
        D_model_swap = load_model(tmp_models_dir+'/D/'+D_file, custom_objects={'custom_por_loss':porosity_loss(),'custom_val_loss':validity_loss(),'InstanceNormalization':InstanceNormalization()})
        return (D_files.index(D_file)+1)*5, D_model_swap.get_weights()
    
    def reset_weights(weights_shape):
        return [np.random.random(x) for x in weights_shape] 

    def train_G(X_shape,alpha_por,alpha_val):
        X_GAN = generate_input_G(input_G, batch_size, sampling_method)
        y_GAN = np.ones((batch_size, 1))

        if verbose_loss:
            G_loss_list = GAN_model.train_on_batch(x=X_GAN, y=[y_GAN,porosity*np.ones(X_shape),0*np.ones(X_shape)],return_dict=True)
            idxs = list(G_loss_list.keys())
        else:
            G_loss_list = GAN_model.train_on_batch(x=X_GAN, y=[y_GAN,porosity*np.ones(X_shape),0*np.ones(X_shape)])
            idxs = [0,1,2,3]

        G_total_loss = G_loss_list[idxs[0]]
        G_loss = G_loss_list[idxs[1]]
        G_por_loss = alpha_por*G_loss_list[idxs[2]]
        G_val_loss = alpha_val*G_loss_list[idxs[3]]

        return G_total_loss,G_loss,G_por_loss,G_val_loss

    def clean_tmp_models(tmp_models_dir):
        for file in os.listdir(tmp_models_dir+'G/'):
            os.remove(tmp_models_dir+'G/'+file)

        for file in os.listdir(tmp_models_dir+'D/'):
            os.remove(tmp_models_dir+'D/'+file)

        for geom_file in os.listdir(geom_epoch_dirs):
            os.remove(geom_epoch_dirs+geom_file)

    # remove previous tmp models files
    if save:
        clean_tmp_models(tmp_models_dir)
    
    weights_shape = [x.shape for x in D_model.get_weights()]
    batch_per_epoch = int(X.shape[0] /batch_size)
    half_batch = int(batch_size/2)
    
    G_losses = []
    G_por_losses = []
    G_val_losses = []
    D_losses = []

    accs_real = []
    accs_fake = []
    pors_match = []
    stds = []
    
    fig,ax = plt.subplots(1,3);
    fig.set_size_inches((24,8))

    epoch_count = 0
    while epoch_count < num_epochs:
        G_losses_epoch = []
        G_por_losses_epoch = []
        G_val_losses_epoch = []
        D_losses_epoch = []
        batch_count = 0
        while batch_count < batch_per_epoch:
            # train D
            D_loss = train_D(X,y,half_batch)

            # check failure mode
            D_losses_epoch.append(D_loss)

            # train G
            G_total_loss,G_loss,G_por_loss,G_val_loss = train_G((batch_size,X.shape[1],X.shape[2],X.shape[3]),alpha_por,alpha_val)
            G_losses_epoch.append(G_loss)
            G_por_losses_epoch.append(G_por_loss)
            G_val_losses_epoch.append(G_val_loss)

            if verbose_loss: 
                print('>%d, %d/%d, D_loss=%.3f, G_loss=%.3f' % (epoch_count+1, batch_count+1, batch_per_epoch,  D_loss, G_total_loss))
            
            batch_count += 1
        
        epoch_count +=1 
            
        G_losses.append(np.array(G_losses_epoch).mean())
        G_por_losses.append(np.array(G_por_losses_epoch).mean())
        G_val_losses.append(np.array(G_val_losses_epoch).mean())
        D_losses.append(np.array(D_losses_epoch).mean())

        # check failure modes
        if D_losses[-1] <= tol_fail:
            weights = reset_weights(weights_shape)
            D_model.set_weights(weights)
            print('Failure Mode 1: reseting D model')

        elif np.std(D_losses[-5:])<=tol_fail and epoch_count >= 10:
            epoch, weights = swap_weights(tmp_models_dir)
            D_model.set_weights(weights)
            print('Failure Mode 2: swapping to D model of epoch %d'%epoch)
            
        # export model
        if epoch_count % 5 == 0:
            acc_real,acc_fake = summarize_performance(epoch_count,porosity,G_model,D_model,X,y,input_G,sampling_method)
            accs_real.append(acc_real)
            accs_fake.append(acc_fake)

            X_test = generate_input_G(input_G,1000,sampling_method)
            geoms = G_model.predict(X_test, verbose=0)
            geoms = np.array(geoms)
            por_match,_ = porosity_match(geoms, porosity, tol_porosity)
            pors_match.append(por_match)

            score = D_model.predict([geoms],verbose=0)[0]
            std = score.std()
            stds.append(std)

            if save:
                G_model.save(tmp_models_dir+'/G/epoch_%03d_por_%.2f_std_%.2f.h5'%(epoch_count, por_match, std))
                D_model.save(tmp_models_dir+'/D/epoch_%03d_real_%.2f_fake_%.2f.h5'%(epoch_count, acc_real, acc_fake))
                
            if verbose_acc:
                os.system('cls')
                print('>Epoch: %i Porosity match: %.0f%% Std: %.2f real: %.0f%% fake: %.0f%%' % (epoch_count,  por_match*100, std, acc_real*100, acc_fake*100))

        # save geometry
        if epoch_count % 5 == 0:
            geom_gif_filename = geom_epoch_dirs + 'epoch_%03d.png'%(epoch_count)
            elem_gif = G_model.predict(seed_geom_gif, verbose=0)
            size = elem_gif.shape[1]
            elem_gif = elem_gif.reshape((size,size))
            ax[0].imshow(elem_gif,cmap='Greys');
            ax[0].axis('off')

            unit_gif = create_unit(elem_gif,size,'p4') 
            ax[1].imshow(unit_gif,cmap='Greys');
            ax[1].axis('off')

            arrange_gif = create_arrange(unit_gif,3,3)
            ax[2].imshow(arrange_gif,cmap='Greys');
            ax[2].axis('off')
            plt.savefig(geom_gif_filename, bbox_inches='tight')
    
    G_losses = np.array(G_losses)
    G_por_losses = np.array(G_por_losses)
    G_val_losses = np.array(G_val_losses)
    D_losses = np.array(D_losses)

    if plot:
        plt.figure(figsize=((10,8)))
        plt.plot(list(range(1,num_epochs+1)),D_losses,label='D Loss')
        plt.title('Loss')
        plt.ylabel('Loss')
        plt.xlabel('Epoch')
        plt.plot(list(range(1,num_epochs+1)),G_losses,label='G Loss')
        plt.plot(list(range(1,num_epochs+1)),G_por_losses,label='Porosity loss')
        plt.plot(list(range(1,num_epochs+1)),G_val_losses,label='Validity loss')
        plt.legend()
        plt.show()

        fig, ax = plt.subplots(3)
        fig.tight_layout(pad=0.75)
        fig.set_size_inches((10,8))
        ax[0].plot(list(range(1,num_epochs+1,5)),accs_fake,label='Accuracy fake')
        ax[0].set_xlabel('Epoch')
        ax[0].plot(list(range(1,num_epochs+1,5)),accs_real,label='Accuracy real')
        ax[0].legend()

        ax[1].plot(list(range(1,num_epochs+1,5)),pors_match)
        ax[1].set_title('Porosity match')
        ax[1].set_xlabel('Epoch')
        
        ax[2].plot(list(range(1,num_epochs+1,5)),stds)
        ax[2].set_title('Std dev')
        ax[2].set_xlabel('Epoch')
        ax[1].legend()
        plt.show()

# %%
# data origin parameters
dimension = 2
simulation = '-r'
simulation = {'-m':'MATLAB','-r':'RTGA'}[simulation]
simmetry = 'p4m'
score = 'isotropy'

# data processing parameters
score_filename, geom_epoch_dirs, gif_filename, tmp_models_dir, models_dir, arrays_dir = get_filenames(dimension, simulation, simmetry, score)
cutoff = 0.8
bins= np.linspace(0,1,41).round(3)
soft = False
plot = True
balance = True
X, y, size = load_data(score_filename, cutoff, bins, soft=soft, balance=balance, plot = plot)

# GAN dimensions
input_G = 128
output_G = input_D = X.shape[1:]
output_D = 1

# training parameters
num_epochs = 100
batch_size = 64
sampling_method = 'normal'
loss = 'bce' 
lr = 1e-4 
alpha_por = 1e-3 #2e-4
alpha_val = 1e-1 #8e-2
vstack=False

# style loss parameters
porosity = 0.55
tol_porosity = 0.02
tol_fail = 5e-2

# setup models
G = setup_G(input_G,output_G,size)
normalize=True
D = setup_D(input_D,loss,lr,alpha_por,alpha_val,normalize)
GAN = setup_GAN(G,D,loss,alpha_por,alpha_val,lr,size)

# metrics paramaters
plot=True
save=True
verbose_loss=True
verbose_acc=True

seed_geom_gif = np.random.randn(input_G).reshape(1, input_G)
train_GAN(X,y,G,D,GAN,input_G,porosity,tol_porosity,batch_size,num_epochs,sampling_method,tmp_models_dir,geom_epoch_dirs,seed_geom_gif,tol_fail,alpha_por, alpha_val, save=save, vstack=vstack,plot=plot,verbose_loss=verbose_loss,verbose_acc=verbose_acc)
# Out:
# Good = 8.85 %
# >1, 1/13, D_loss=1.337, G_loss=2.582
# >1, 2/13, D_loss=0.870, G_loss=2.346
# >1, 3/13, D_loss=0.678, G_loss=2.879
# >1, 4/13, D_loss=0.726, G_loss=2.595
# >1, 5/13, D_loss=0.634, G_loss=2.682
# >1, 6/13, D_loss=0.557, G_loss=2.930
# >1, 7/13, D_loss=0.542, G_loss=3.365
# >1, 8/13, D_loss=0.414, G_loss=3.837
# >1, 9/13, D_loss=0.233, G_loss=4.330
# >1, 10/13, D_loss=0.178, G_loss=4.676
# >1, 11/13, D_loss=0.113, G_loss=5.972
# >1, 12/13, D_loss=0.083, G_loss=7.616
# >1, 13/13, D_loss=0.074, G_loss=11.888
# >2, 1/13, D_loss=0.082, G_loss=15.382
# >2, 2/13, D_loss=0.222, G_loss=18.361
# >2, 3/13, D_loss=0.935, G_loss=18.883
# >2, 4/13, D_loss=1.387, G_loss=19.615
# >2, 5/13, D_loss=1.532, G_loss=20.355
# >2, 6/13, D_loss=1.166, G_loss=20.925
# >2, 7/13, D_loss=0.514, G_loss=22.176
# >2, 8/13, D_loss=0.367, G_loss=23.200
# >2, 9/13, D_loss=0.283, G_loss=24.502
# >2, 10/13, D_loss=0.428, G_loss=25.619
# >2, 11/13, D_loss=0.242, G_loss=25.643
# >2, 12/13, D_loss=0.232, G_loss=26.007
# >2, 13/13, D_loss=0.106, G_loss=25.411
# >3, 1/13, D_loss=0.086, G_loss=25.727
# >3, 2/13, D_loss=0.077, G_loss=25.103
# >3, 3/13, D_loss=0.074, G_loss=25.011
# >3, 4/13, D_loss=0.134, G_loss=24.433
# >3, 5/13, D_loss=0.203, G_loss=23.642
# >3, 6/13, D_loss=0.280, G_loss=23.935
# >3, 7/13, D_loss=0.240, G_loss=22.144
# >3, 8/13, D_loss=0.378, G_loss=20.587
# >3, 9/13, D_loss=0.279, G_loss=17.981
# >3, 10/13, D_loss=0.656, G_loss=12.977
# >3, 11/13, D_loss=1.765, G_loss=11.277
# >3, 12/13, D_loss=2.015, G_loss=7.675
# >3, 13/13, D_loss=1.979, G_loss=6.518
# >4, 1/13, D_loss=1.472, G_loss=5.452
# >4, 2/13, D_loss=1.278, G_loss=4.858
# >4, 3/13, D_loss=0.834, G_loss=4.560
# >4, 4/13, D_loss=0.906, G_loss=4.110
# >4, 5/13, D_loss=0.818, G_loss=2.819
# >4, 6/13, D_loss=0.784, G_loss=2.602
# >4, 7/13, D_loss=0.711, G_loss=2.285
# >4, 8/13, D_loss=0.571, G_loss=2.320
# >4, 9/13, D_loss=0.466, G_loss=2.173
# >4, 10/13, D_loss=0.441, G_loss=2.237
# >4, 11/13, D_loss=0.502, G_loss=2.163
# >4, 12/13, D_loss=0.460, G_loss=2.029
# >4, 13/13, D_loss=0.370, G_loss=2.078
# >5, 1/13, D_loss=0.324, G_loss=1.958
# >5, 2/13, D_loss=0.391, G_loss=2.540
# >5, 3/13, D_loss=0.461, G_loss=3.488
# >5, 4/13, D_loss=0.403, G_loss=4.259
# >5, 5/13, D_loss=0.409, G_loss=4.504
# >5, 6/13, D_loss=0.502, G_loss=4.742
# >5, 7/13, D_loss=0.321, G_loss=5.075
# >5, 8/13, D_loss=0.360, G_loss=5.442
# >5, 9/13, D_loss=0.317, G_loss=5.892
# >5, 10/13, D_loss=0.223, G_loss=5.906
# >5, 11/13, D_loss=0.327, G_loss=6.055
# >5, 12/13, D_loss=0.485, G_loss=6.230
# >5, 13/13, D_loss=0.353, G_loss=6.234
# >Epoch: 5 Porosity match: 0% Std: 0.18 real: 89% fake: 95%
# >6, 1/13, D_loss=0.336, G_loss=6.291
# >6, 2/13, D_loss=0.357, G_loss=6.266
# >6, 3/13, D_loss=0.349, G_loss=6.588
# >6, 4/13, D_loss=0.494, G_loss=7.489
# >6, 5/13, D_loss=0.422, G_loss=10.413
# >6, 6/13, D_loss=0.589, G_loss=13.188
# >6, 7/13, D_loss=0.652, G_loss=13.984
# >6, 8/13, D_loss=0.431, G_loss=14.957
# >6, 9/13, D_loss=0.571, G_loss=15.041
# >6, 10/13, D_loss=0.517, G_loss=14.742
# >6, 11/13, D_loss=0.631, G_loss=14.334
# >6, 12/13, D_loss=0.740, G_loss=14.246
# >6, 13/13, D_loss=0.476, G_loss=13.229
# >7, 1/13, D_loss=0.627, G_loss=13.345
# >7, 2/13, D_loss=0.663, G_loss=13.027
# >7, 3/13, D_loss=0.536, G_loss=13.020
# >7, 4/13, D_loss=0.415, G_loss=13.483
# >7, 5/13, D_loss=0.451, G_loss=13.084
# >7, 6/13, D_loss=0.375, G_loss=13.779
# >7, 7/13, D_loss=0.356, G_loss=13.309
# >7, 8/13, D_loss=0.377, G_loss=14.282
# >7, 9/13, D_loss=0.456, G_loss=13.938
# >7, 10/13, D_loss=0.347, G_loss=13.391
# >7, 11/13, D_loss=0.325, G_loss=13.485
# >7, 12/13, D_loss=0.321, G_loss=13.163
# >7, 13/13, D_loss=0.379, G_loss=13.129
# >8, 1/13, D_loss=0.453, G_loss=13.888
# >8, 2/13, D_loss=0.374, G_loss=13.148
# >8, 3/13, D_loss=0.421, G_loss=12.644
# >8, 4/13, D_loss=0.363, G_loss=12.347
# >8, 5/13, D_loss=0.652, G_loss=11.804
# >8, 6/13, D_loss=0.568, G_loss=12.763
# >8, 7/13, D_loss=0.548, G_loss=12.606
# >8, 8/13, D_loss=0.398, G_loss=11.603
# >8, 9/13, D_loss=0.419, G_loss=10.871
# >8, 10/13, D_loss=0.403, G_loss=11.089
# >8, 11/13, D_loss=0.421, G_loss=10.816
# >8, 12/13, D_loss=0.619, G_loss=11.204
# >8, 13/13, D_loss=0.453, G_loss=11.224
# >9, 1/13, D_loss=0.409, G_loss=11.511
# >9, 2/13, D_loss=0.376, G_loss=10.791
# >9, 3/13, D_loss=0.184, G_loss=11.357
# >9, 4/13, D_loss=0.375, G_loss=10.733
# >9, 5/13, D_loss=0.432, G_loss=9.422
# >9, 6/13, D_loss=0.340, G_loss=10.597
# >9, 7/13, D_loss=0.407, G_loss=10.389
# >9, 8/13, D_loss=0.350, G_loss=10.702
# >9, 9/13, D_loss=0.416, G_loss=9.862
# >9, 10/13, D_loss=0.627, G_loss=10.359
# >9, 11/13, D_loss=0.242, G_loss=9.802
# >9, 12/13, D_loss=0.256, G_loss=9.699
# >9, 13/13, D_loss=0.304, G_loss=9.950
# >10, 1/13, D_loss=0.298, G_loss=9.443
# >10, 2/13, D_loss=0.367, G_loss=10.539
# >10, 3/13, D_loss=0.338, G_loss=12.145
# >10, 4/13, D_loss=0.446, G_loss=9.695
# >10, 5/13, D_loss=0.286, G_loss=9.520
# >10, 6/13, D_loss=0.292, G_loss=10.923
# >10, 7/13, D_loss=0.262, G_loss=10.203
# >10, 8/13, D_loss=0.239, G_loss=9.586
# >10, 9/13, D_loss=0.311, G_loss=10.257
# >10, 10/13, D_loss=0.280, G_loss=9.934
# >10, 11/13, D_loss=0.323, G_loss=9.747
# >10, 12/13, D_loss=0.303, G_loss=9.888
# >10, 13/13, D_loss=0.286, G_loss=9.461
# >Epoch: 10 Porosity match: 3% Std: 0.17 real: 88% fake: 92%
# >11, 1/13, D_loss=0.389, G_loss=10.241
# >11, 2/13, D_loss=0.346, G_loss=11.374
# >11, 3/13, D_loss=0.422, G_loss=10.127
# >11, 4/13, D_loss=0.210, G_loss=9.377
# >11, 5/13, D_loss=0.265, G_loss=9.535
# >11, 6/13, D_loss=0.211, G_loss=10.629
# >11, 7/13, D_loss=0.211, G_loss=10.683
# >11, 8/13, D_loss=0.244, G_loss=9.631
# >11, 9/13, D_loss=0.360, G_loss=8.999
# >11, 10/13, D_loss=0.234, G_loss=9.468
# >11, 11/13, D_loss=0.396, G_loss=9.669
# >11, 12/13, D_loss=0.198, G_loss=9.101
# >11, 13/13, D_loss=0.218, G_loss=10.079
# >12, 1/13, D_loss=0.192, G_loss=9.000
# >12, 2/13, D_loss=0.160, G_loss=10.752
# >12, 3/13, D_loss=0.274, G_loss=8.970
# >12, 4/13, D_loss=0.129, G_loss=9.179
# >12, 5/13, D_loss=0.189, G_loss=9.551
# >12, 6/13, D_loss=0.182, G_loss=8.854
# >12, 7/13, D_loss=0.304, G_loss=8.634
# >12, 8/13, D_loss=0.302, G_loss=9.627
# >12, 9/13, D_loss=0.181, G_loss=9.770
# >12, 10/13, D_loss=0.269, G_loss=10.080
# >12, 11/13, D_loss=0.167, G_loss=9.032
# >12, 12/13, D_loss=0.240, G_loss=9.534
# >12, 13/13, D_loss=0.172, G_loss=8.364
# >13, 1/13, D_loss=0.163, G_loss=7.249
# >13, 2/13, D_loss=0.215, G_loss=7.676
# >13, 3/13, D_loss=0.219, G_loss=7.181
# >13, 4/13, D_loss=0.204, G_loss=9.421
# >13, 5/13, D_loss=0.121, G_loss=8.401
# >13, 6/13, D_loss=0.163, G_loss=8.686
# >13, 7/13, D_loss=0.144, G_loss=7.683
# >13, 8/13, D_loss=0.122, G_loss=7.658
# >13, 9/13, D_loss=0.123, G_loss=7.944
# >13, 10/13, D_loss=0.115, G_loss=7.761
# >13, 11/13, D_loss=0.134, G_loss=8.256
# >13, 12/13, D_loss=0.121, G_loss=8.190
# >13, 13/13, D_loss=0.120, G_loss=8.822
# >14, 1/13, D_loss=0.105, G_loss=8.654
# >14, 2/13, D_loss=0.170, G_loss=9.015
# >14, 3/13, D_loss=0.158, G_loss=8.029
# >14, 4/13, D_loss=0.150, G_loss=9.507
# >14, 5/13, D_loss=0.088, G_loss=8.896
# >14, 6/13, D_loss=0.183, G_loss=8.549
# >14, 7/13, D_loss=0.236, G_loss=7.898
# >14, 8/13, D_loss=0.194, G_loss=7.237
# >14, 9/13, D_loss=0.099, G_loss=7.554
# >14, 10/13, D_loss=0.204, G_loss=7.137
# >14, 11/13, D_loss=0.445, G_loss=7.153
# >14, 12/13, D_loss=0.552, G_loss=6.618
# >14, 13/13, D_loss=0.424, G_loss=6.138
# >15, 1/13, D_loss=0.366, G_loss=7.252
# >15, 2/13, D_loss=0.547, G_loss=6.611
# >15, 3/13, D_loss=0.537, G_loss=6.774
# >15, 4/13, D_loss=0.476, G_loss=6.593
# >15, 5/13, D_loss=0.636, G_loss=5.561
# >15, 6/13, D_loss=0.510, G_loss=4.621
# >15, 7/13, D_loss=0.698, G_loss=4.464
# >15, 8/13, D_loss=0.472, G_loss=5.323
# >15, 9/13, D_loss=0.437, G_loss=5.512
# >15, 10/13, D_loss=0.460, G_loss=5.218
# >15, 11/13, D_loss=0.402, G_loss=5.169
# >15, 12/13, D_loss=0.303, G_loss=4.949
# >15, 13/13, D_loss=0.385, G_loss=4.626
# >Epoch: 15 Porosity match: 19% Std: 0.19 real: 96% fake: 93%
# >16, 1/13, D_loss=0.292, G_loss=4.663
# >16, 2/13, D_loss=0.253, G_loss=4.754
# >16, 3/13, D_loss=0.183, G_loss=4.832
# >16, 4/13, D_loss=0.203, G_loss=5.064
# >16, 5/13, D_loss=0.245, G_loss=5.103
# >16, 6/13, D_loss=0.159, G_loss=5.034
# >16, 7/13, D_loss=0.210, G_loss=4.783
# >16, 8/13, D_loss=0.122, G_loss=4.819
# >16, 9/13, D_loss=0.198, G_loss=4.830
# >16, 10/13, D_loss=0.173, G_loss=4.542
# >16, 11/13, D_loss=0.180, G_loss=4.794
# >16, 12/13, D_loss=0.220, G_loss=4.247
# >16, 13/13, D_loss=0.118, G_loss=4.776
# >17, 1/13, D_loss=0.101, G_loss=5.101
# >17, 2/13, D_loss=0.189, G_loss=4.896
# >17, 3/13, D_loss=0.098, G_loss=4.469
# >17, 4/13, D_loss=0.194, G_loss=4.510
# >17, 5/13, D_loss=0.176, G_loss=4.056
# >17, 6/13, D_loss=0.260, G_loss=4.628
# >17, 7/13, D_loss=0.160, G_loss=4.162
# >17, 8/13, D_loss=0.213, G_loss=4.132
# >17, 9/13, D_loss=0.298, G_loss=4.035
# >17, 10/13, D_loss=0.219, G_loss=3.533
# >17, 11/13, D_loss=0.238, G_loss=3.788
# >17, 12/13, D_loss=0.141, G_loss=3.966
# ERROR:tensorflow:==================================
# Object was never used (type <class 'tensorflow.python.ops.tensor_array_ops.TensorArray'>):
# <tensorflow.python.ops.tensor_array_ops.TensorArray object at 0x0000011D4813BE88>
# If you want to mark it as used call its "mark_used()" method.
# It was originally created here:
#   File "c:\Users\lucas.barbosa\.conda\envs\deeplearn37\lib\site-packages\tensorflow\python\ops\control_flow_ops.py", line 2797, in while_loop
#     return result  File "c:\Users\lucas.barbosa\.conda\envs\deeplearn37\lib\site-packages\tensorflow\python\ops\control_flow_ops.py", line 2753, in <lambda>
#     body = lambda i, lv: (i + 1, orig_body(*lv))  File "c:\Users\lucas.barbosa\.conda\envs\deeplearn37\lib\site-packages\tensorflow\python\ops\map_fn.py", line 496, in compute
#     return (i + 1, tas)  File "c:\Users\lucas.barbosa\.conda\envs\deeplearn37\lib\site-packages\tensorflow\python\ops\map_fn.py", line 494, in <listcomp>
#     ta.write(i, value) for (ta, value) in zip(tas, result_value_batchable)  File "c:\Users\lucas.barbosa\.conda\envs\deeplearn37\lib\site-packages\tensorflow\python\util\tf_should_use.py", line 245, in wrapped
#     error_in_function=error_in_function)
# ==================================
# >17, 13/13, D_loss=0.157, G_loss=3.975
# >18, 1/13, D_loss=0.193, G_loss=4.269
# >18, 2/13, D_loss=0.334, G_loss=3.805
# >18, 3/13, D_loss=0.266, G_loss=4.293
# >18, 4/13, D_loss=0.099, G_loss=4.810
# >18, 5/13, D_loss=0.204, G_loss=4.690
# >18, 6/13, D_loss=0.216, G_loss=4.251
# >18, 7/13, D_loss=0.171, G_loss=4.300
# >18, 8/13, D_loss=0.164, G_loss=4.684
# >18, 9/13, D_loss=0.202, G_loss=5.095
# >18, 10/13, D_loss=0.212, G_loss=4.515
# >18, 11/13, D_loss=0.131, G_loss=3.998
# >18, 12/13, D_loss=0.135, G_loss=4.933
# >18, 13/13, D_loss=0.180, G_loss=4.448
# >19, 1/13, D_loss=0.164, G_loss=5.135
# >19, 2/13, D_loss=0.133, G_loss=5.110
# >19, 3/13, D_loss=0.081, G_loss=4.431
# >19, 4/13, D_loss=0.113, G_loss=4.807
# >19, 5/13, D_loss=0.101, G_loss=4.439
# >19, 6/13, D_loss=0.166, G_loss=4.816
# >19, 7/13, D_loss=0.137, G_loss=4.963
# >19, 8/13, D_loss=0.109, G_loss=5.609
# >19, 9/13, D_loss=0.225, G_loss=5.215
# >19, 10/13, D_loss=0.085, G_loss=4.527
# >19, 11/13, D_loss=0.111, G_loss=4.649
# >19, 12/13, D_loss=0.196, G_loss=5.109
# >19, 13/13, D_loss=0.205, G_loss=4.965
# >20, 1/13, D_loss=0.122, G_loss=4.545
# >20, 2/13, D_loss=0.139, G_loss=5.255
# >20, 3/13, D_loss=0.128, G_loss=4.885
# >20, 4/13, D_loss=0.290, G_loss=4.920
# >20, 5/13, D_loss=0.266, G_loss=4.856
# >20, 6/13, D_loss=0.219, G_loss=4.800
# >20, 7/13, D_loss=0.389, G_loss=4.506
# >20, 8/13, D_loss=0.187, G_loss=4.147
# >20, 9/13, D_loss=0.243, G_loss=4.564
# >20, 10/13, D_loss=0.257, G_loss=4.391
# >20, 11/13, D_loss=0.149, G_loss=5.110
# >20, 12/13, D_loss=0.318, G_loss=5.102
# >20, 13/13, D_loss=0.410, G_loss=4.812
# Failure Mode 2: swapping to D model of epoch 10
# >Epoch: 20 Porosity match: 24% Std: 0.19 real: 94% fake: 11%
# >21, 1/13, D_loss=1.265, G_loss=2.558
# >21, 2/13, D_loss=0.876, G_loss=2.954
# >21, 3/13, D_loss=0.756, G_loss=3.691
# >21, 4/13, D_loss=0.859, G_loss=3.770
# >21, 5/13, D_loss=0.722, G_loss=4.422
# >21, 6/13, D_loss=0.905, G_loss=4.590
# >21, 7/13, D_loss=0.756, G_loss=4.214
# >21, 8/13, D_loss=0.929, G_loss=3.942
# >21, 9/13, D_loss=0.754, G_loss=4.559
# >21, 10/13, D_loss=0.617, G_loss=4.243
# >21, 11/13, D_loss=0.710, G_loss=4.368
# >21, 12/13, D_loss=0.640, G_loss=4.650
# >21, 13/13, D_loss=0.450, G_loss=4.901
# >22, 1/13, D_loss=0.511, G_loss=4.831
# >22, 2/13, D_loss=0.408, G_loss=5.149
# >22, 3/13, D_loss=0.463, G_loss=5.301
# >22, 4/13, D_loss=0.472, G_loss=5.727
# >22, 5/13, D_loss=0.492, G_loss=5.898
# >22, 6/13, D_loss=0.413, G_loss=5.830
# >22, 7/13, D_loss=0.466, G_loss=5.434
# >22, 8/13, D_loss=0.443, G_loss=5.280
# >22, 9/13, D_loss=0.381, G_loss=5.987
# >22, 10/13, D_loss=0.430, G_loss=5.611
# >22, 11/13, D_loss=0.387, G_loss=5.897
# >22, 12/13, D_loss=0.417, G_loss=6.265
# >22, 13/13, D_loss=0.362, G_loss=5.687
# >23, 1/13, D_loss=0.300, G_loss=5.587
# >23, 2/13, D_loss=0.349, G_loss=6.446
# >23, 3/13, D_loss=0.389, G_loss=6.100
# >23, 4/13, D_loss=0.362, G_loss=5.493
# >23, 5/13, D_loss=0.292, G_loss=5.611
# >23, 6/13, D_loss=0.274, G_loss=5.616
# >23, 7/13, D_loss=0.375, G_loss=5.602
# >23, 8/13, D_loss=0.300, G_loss=5.556
# >23, 9/13, D_loss=0.241, G_loss=5.267
# >23, 10/13, D_loss=0.307, G_loss=5.177
# >23, 11/13, D_loss=0.327, G_loss=5.398
# >23, 12/13, D_loss=0.321, G_loss=4.824
# >23, 13/13, D_loss=0.296, G_loss=5.134
# >24, 1/13, D_loss=0.354, G_loss=4.835
# >24, 2/13, D_loss=0.395, G_loss=4.385
# >24, 3/13, D_loss=0.454, G_loss=4.590
# >24, 4/13, D_loss=0.330, G_loss=5.120
# >24, 5/13, D_loss=0.346, G_loss=4.000
# >24, 6/13, D_loss=0.444, G_loss=3.892
# >24, 7/13, D_loss=0.277, G_loss=3.905
# >24, 8/13, D_loss=0.362, G_loss=3.871
# >24, 9/13, D_loss=0.432, G_loss=3.969
# >24, 10/13, D_loss=0.559, G_loss=4.252
# >24, 11/13, D_loss=0.397, G_loss=3.916
# >24, 12/13, D_loss=0.420, G_loss=3.902
# >24, 13/13, D_loss=0.427, G_loss=3.551
# >25, 1/13, D_loss=0.601, G_loss=3.629
# >25, 2/13, D_loss=0.525, G_loss=3.632
# >25, 3/13, D_loss=0.472, G_loss=3.439
# >25, 4/13, D_loss=0.395, G_loss=4.215
# >25, 5/13, D_loss=0.418, G_loss=3.773
# >25, 6/13, D_loss=0.546, G_loss=3.394
# >25, 7/13, D_loss=0.534, G_loss=3.452
# >25, 8/13, D_loss=0.379, G_loss=3.390
# >25, 9/13, D_loss=0.481, G_loss=3.110
# >25, 10/13, D_loss=0.396, G_loss=3.014
# >25, 11/13, D_loss=0.427, G_loss=3.595
# >25, 12/13, D_loss=0.480, G_loss=3.620
# >25, 13/13, D_loss=0.413, G_loss=3.448
# >Epoch: 25 Porosity match: 24% Std: 0.17 real: 89% fake: 96%
# >26, 1/13, D_loss=0.418, G_loss=3.484
# >26, 2/13, D_loss=0.436, G_loss=3.435
# >26, 3/13, D_loss=0.463, G_loss=3.323
# >26, 4/13, D_loss=0.502, G_loss=3.263
# >26, 5/13, D_loss=0.349, G_loss=3.043
# >26, 6/13, D_loss=0.433, G_loss=3.512
# >26, 7/13, D_loss=0.451, G_loss=2.752
# >26, 8/13, D_loss=0.364, G_loss=3.406
# >26, 9/13, D_loss=0.363, G_loss=3.408
# >26, 10/13, D_loss=0.370, G_loss=3.489
# >26, 11/13, D_loss=0.468, G_loss=3.428
# >26, 12/13, D_loss=0.376, G_loss=2.813
# >26, 13/13, D_loss=0.318, G_loss=2.877
# Failure Mode 2: swapping to D model of epoch 10
# >27, 1/13, D_loss=0.836, G_loss=2.348
# >27, 2/13, D_loss=0.848, G_loss=2.489
# >27, 3/13, D_loss=0.696, G_loss=3.097
# >27, 4/13, D_loss=0.546, G_loss=3.445
# >27, 5/13, D_loss=0.621, G_loss=3.106
# >27, 6/13, D_loss=0.826, G_loss=3.030
# >27, 7/13, D_loss=0.760, G_loss=2.664
# >27, 8/13, D_loss=0.559, G_loss=2.560
# >27, 9/13, D_loss=0.676, G_loss=2.879
# >27, 10/13, D_loss=0.586, G_loss=2.709
# >27, 11/13, D_loss=0.569, G_loss=3.213
# >27, 12/13, D_loss=0.536, G_loss=3.009
# >27, 13/13, D_loss=0.494, G_loss=3.529
# >28, 1/13, D_loss=0.483, G_loss=3.262
# >28, 2/13, D_loss=0.499, G_loss=3.120
# >28, 3/13, D_loss=0.469, G_loss=2.963
# >28, 4/13, D_loss=0.521, G_loss=2.988
# >28, 5/13, D_loss=0.385, G_loss=3.273
# >28, 6/13, D_loss=0.475, G_loss=3.093
# >28, 7/13, D_loss=0.521, G_loss=3.032
# >28, 8/13, D_loss=0.440, G_loss=3.194
# >28, 9/13, D_loss=0.530, G_loss=3.652
# >28, 10/13, D_loss=0.352, G_loss=3.567
# >28, 11/13, D_loss=0.412, G_loss=3.333
# >28, 12/13, D_loss=0.413, G_loss=3.399
# >28, 13/13, D_loss=0.394, G_loss=3.299
# >29, 1/13, D_loss=0.476, G_loss=3.439
# >29, 2/13, D_loss=0.470, G_loss=3.070
# >29, 3/13, D_loss=0.510, G_loss=3.612
# >29, 4/13, D_loss=0.415, G_loss=3.721
# >29, 5/13, D_loss=0.378, G_loss=3.618
# >29, 6/13, D_loss=0.356, G_loss=3.540
# >29, 7/13, D_loss=0.429, G_loss=3.228
# >29, 8/13, D_loss=0.315, G_loss=3.583
# >29, 9/13, D_loss=0.402, G_loss=3.398
# >29, 10/13, D_loss=0.450, G_loss=3.629
# >29, 11/13, D_loss=0.452, G_loss=3.826
# >29, 12/13, D_loss=0.403, G_loss=3.835
# >29, 13/13, D_loss=0.455, G_loss=3.679
# >30, 1/13, D_loss=0.458, G_loss=3.333
# >30, 2/13, D_loss=0.335, G_loss=3.492
# >30, 3/13, D_loss=0.438, G_loss=3.397
# >30, 4/13, D_loss=0.374, G_loss=3.182
# >30, 5/13, D_loss=0.352, G_loss=3.788
# >30, 6/13, D_loss=0.409, G_loss=3.646
# >30, 7/13, D_loss=0.634, G_loss=3.777
# >30, 8/13, D_loss=0.454, G_loss=3.620
# >30, 9/13, D_loss=0.476, G_loss=3.769
# >30, 10/13, D_loss=0.481, G_loss=4.026
# >30, 11/13, D_loss=0.521, G_loss=4.359
# >30, 12/13, D_loss=0.464, G_loss=3.547
# >30, 13/13, D_loss=0.475, G_loss=3.272
# >Epoch: 30 Porosity match: 19% Std: 0.19 real: 90% fake: 89%
# >31, 1/13, D_loss=0.391, G_loss=3.735
# >31, 2/13, D_loss=0.509, G_loss=3.651
# >31, 3/13, D_loss=0.436, G_loss=4.293
# >31, 4/13, D_loss=0.460, G_loss=4.111
# >31, 5/13, D_loss=0.509, G_loss=3.706
# >31, 6/13, D_loss=0.461, G_loss=3.480
# >31, 7/13, D_loss=0.439, G_loss=3.946
# >31, 8/13, D_loss=0.419, G_loss=3.952
# >31, 9/13, D_loss=0.336, G_loss=4.188
# >31, 10/13, D_loss=0.310, G_loss=4.041
# >31, 11/13, D_loss=0.456, G_loss=3.650
# >31, 12/13, D_loss=0.407, G_loss=3.908
# >31, 13/13, D_loss=0.423, G_loss=4.094
# >32, 1/13, D_loss=0.412, G_loss=4.376
# >32, 2/13, D_loss=0.323, G_loss=4.617
# >32, 3/13, D_loss=0.324, G_loss=4.103
# >32, 4/13, D_loss=0.357, G_loss=4.157
# >32, 5/13, D_loss=0.295, G_loss=4.224
# >32, 6/13, D_loss=0.325, G_loss=4.713
# >32, 7/13, D_loss=0.369, G_loss=4.559
# >32, 8/13, D_loss=0.345, G_loss=4.010
# >32, 9/13, D_loss=0.334, G_loss=4.467
# >32, 10/13, D_loss=0.294, G_loss=4.454
# >32, 11/13, D_loss=0.414, G_loss=4.612
# >32, 12/13, D_loss=0.224, G_loss=4.956
# >32, 13/13, D_loss=0.283, G_loss=5.189
# Failure Mode 2: swapping to D model of epoch 10
# >33, 1/13, D_loss=1.561, G_loss=3.005
# >33, 2/13, D_loss=1.125, G_loss=3.470
# >33, 3/13, D_loss=1.068, G_loss=3.354
# >33, 4/13, D_loss=1.128, G_loss=3.887
# >33, 5/13, D_loss=1.065, G_loss=4.186
# >33, 6/13, D_loss=0.986, G_loss=4.473
# >33, 7/13, D_loss=1.036, G_loss=4.328
# >33, 8/13, D_loss=1.018, G_loss=4.176
# >33, 9/13, D_loss=0.836, G_loss=4.011
# >33, 10/13, D_loss=0.891, G_loss=4.289
# >33, 11/13, D_loss=0.844, G_loss=3.795
# >33, 12/13, D_loss=0.853, G_loss=3.822
# >33, 13/13, D_loss=0.763, G_loss=3.594
# >34, 1/13, D_loss=0.834, G_loss=4.416
# >34, 2/13, D_loss=0.714, G_loss=4.351
# >34, 3/13, D_loss=0.568, G_loss=4.226
# >34, 4/13, D_loss=0.700, G_loss=4.302
# >34, 5/13, D_loss=0.574, G_loss=4.280
# >34, 6/13, D_loss=0.602, G_loss=4.688
# >34, 7/13, D_loss=0.692, G_loss=4.425
# >34, 8/13, D_loss=0.544, G_loss=4.736
# >34, 9/13, D_loss=0.610, G_loss=4.396
# >34, 10/13, D_loss=0.547, G_loss=4.579
# >34, 11/13, D_loss=0.566, G_loss=4.590
# >34, 12/13, D_loss=0.620, G_loss=4.770
# >34, 13/13, D_loss=0.553, G_loss=4.708
# >35, 1/13, D_loss=0.445, G_loss=4.380
# >35, 2/13, D_loss=0.507, G_loss=4.788
# >35, 3/13, D_loss=0.564, G_loss=4.578
# >35, 4/13, D_loss=0.466, G_loss=4.772
# >35, 5/13, D_loss=0.493, G_loss=4.539
# >35, 6/13, D_loss=0.418, G_loss=4.935
# >35, 7/13, D_loss=0.393, G_loss=4.447
# >35, 8/13, D_loss=0.433, G_loss=4.683
# >35, 9/13, D_loss=0.398, G_loss=4.515
# >35, 10/13, D_loss=0.392, G_loss=4.694
# >35, 11/13, D_loss=0.406, G_loss=4.339
# >35, 12/13, D_loss=0.389, G_loss=4.322
# >35, 13/13, D_loss=0.423, G_loss=4.504
# >Epoch: 35 Porosity match: 9% Std: 0.13 real: 99% fake: 100%
# >36, 1/13, D_loss=0.352, G_loss=4.918
# >36, 2/13, D_loss=0.303, G_loss=4.657
# >36, 3/13, D_loss=0.352, G_loss=4.486
# >36, 4/13, D_loss=0.394, G_loss=4.810
# >36, 5/13, D_loss=0.407, G_loss=4.695
# >36, 6/13, D_loss=0.364, G_loss=4.216
# >36, 7/13, D_loss=0.431, G_loss=4.040
# >36, 8/13, D_loss=0.370, G_loss=4.371
# >36, 9/13, D_loss=0.373, G_loss=4.022
# >36, 10/13, D_loss=0.318, G_loss=4.256
# >36, 11/13, D_loss=0.381, G_loss=3.919
# >36, 12/13, D_loss=0.414, G_loss=3.638
# >36, 13/13, D_loss=0.334, G_loss=3.806
# >37, 1/13, D_loss=0.377, G_loss=4.745
# >37, 2/13, D_loss=0.358, G_loss=3.851
# >37, 3/13, D_loss=0.295, G_loss=4.039
# >37, 4/13, D_loss=0.356, G_loss=3.678
# >37, 5/13, D_loss=0.348, G_loss=3.878
# >37, 6/13, D_loss=0.368, G_loss=4.279
# >37, 7/13, D_loss=0.385, G_loss=3.240
# >37, 8/13, D_loss=0.394, G_loss=3.356
# >37, 9/13, D_loss=0.325, G_loss=3.482
# >37, 10/13, D_loss=0.384, G_loss=3.720
# >37, 11/13, D_loss=0.380, G_loss=3.680
# >37, 12/13, D_loss=0.433, G_loss=3.680
# >37, 13/13, D_loss=0.417, G_loss=3.421
# >38, 1/13, D_loss=0.366, G_loss=3.493
# >38, 2/13, D_loss=0.460, G_loss=3.031
# >38, 3/13, D_loss=0.495, G_loss=3.191
# >38, 4/13, D_loss=0.429, G_loss=2.847
# >38, 5/13, D_loss=0.351, G_loss=2.869
# >38, 6/13, D_loss=0.378, G_loss=3.158
# >38, 7/13, D_loss=0.468, G_loss=3.455
# >38, 8/13, D_loss=0.373, G_loss=3.413
# >38, 9/13, D_loss=0.469, G_loss=3.159
# >38, 10/13, D_loss=0.472, G_loss=2.985
# >38, 11/13, D_loss=0.500, G_loss=3.139
# >38, 12/13, D_loss=0.353, G_loss=2.919
# >38, 13/13, D_loss=0.459, G_loss=2.902
# >39, 1/13, D_loss=0.376, G_loss=3.062
# >39, 2/13, D_loss=0.371, G_loss=2.820
# >39, 3/13, D_loss=0.348, G_loss=2.856
# >39, 4/13, D_loss=0.396, G_loss=2.740
# >39, 5/13, D_loss=0.356, G_loss=2.712
# >39, 6/13, D_loss=0.423, G_loss=2.843
# >39, 7/13, D_loss=0.562, G_loss=2.736
# >39, 8/13, D_loss=0.356, G_loss=2.755
# >39, 9/13, D_loss=0.427, G_loss=2.601
# >39, 10/13, D_loss=0.280, G_loss=2.434
# >39, 11/13, D_loss=0.267, G_loss=2.814
# >39, 12/13, D_loss=0.382, G_loss=2.625
# >39, 13/13, D_loss=0.382, G_loss=3.179
# Failure Mode 2: swapping to D model of epoch 25
# >40, 1/13, D_loss=0.468, G_loss=2.544
# >40, 2/13, D_loss=0.450, G_loss=2.559
# >40, 3/13, D_loss=0.401, G_loss=2.463
# >40, 4/13, D_loss=0.459, G_loss=2.667
# >40, 5/13, D_loss=0.432, G_loss=2.355
# >40, 6/13, D_loss=0.421, G_loss=2.438
# >40, 7/13, D_loss=0.551, G_loss=2.295
# >40, 8/13, D_loss=0.473, G_loss=2.298
# >40, 9/13, D_loss=0.542, G_loss=2.207
# >40, 10/13, D_loss=0.499, G_loss=2.726
# >40, 11/13, D_loss=0.517, G_loss=2.745
# >40, 12/13, D_loss=0.385, G_loss=2.606
# >40, 13/13, D_loss=0.392, G_loss=2.864
# Failure Mode 2: swapping to D model of epoch 30
# >Epoch: 40 Porosity match: 23% Std: 0.13 real: 91% fake: 99%
# >41, 1/13, D_loss=0.334, G_loss=2.850
# >41, 2/13, D_loss=0.278, G_loss=2.869
# >41, 3/13, D_loss=0.275, G_loss=2.741
# >41, 4/13, D_loss=0.252, G_loss=3.126
# >41, 5/13, D_loss=0.286, G_loss=2.985
# >41, 6/13, D_loss=0.403, G_loss=2.967
# >41, 7/13, D_loss=0.282, G_loss=3.221
# >41, 8/13, D_loss=0.310, G_loss=3.158
# >41, 9/13, D_loss=0.308, G_loss=3.164
# >41, 10/13, D_loss=0.284, G_loss=3.094
# >41, 11/13, D_loss=0.198, G_loss=3.116
# >41, 12/13, D_loss=0.355, G_loss=2.830
# >41, 13/13, D_loss=0.256, G_loss=3.060
# >42, 1/13, D_loss=0.336, G_loss=2.980
# >42, 2/13, D_loss=0.266, G_loss=3.324
# >42, 3/13, D_loss=0.184, G_loss=3.615
# >42, 4/13, D_loss=0.311, G_loss=3.693
# >42, 5/13, D_loss=0.405, G_loss=2.885
# >42, 6/13, D_loss=0.346, G_loss=3.200
# >42, 7/13, D_loss=0.476, G_loss=2.548
# >42, 8/13, D_loss=0.267, G_loss=2.879
# >42, 9/13, D_loss=0.294, G_loss=3.255
# >42, 10/13, D_loss=0.229, G_loss=3.147
# >42, 11/13, D_loss=0.321, G_loss=3.383
# >42, 12/13, D_loss=0.376, G_loss=3.104
# >42, 13/13, D_loss=0.322, G_loss=3.570
# >43, 1/13, D_loss=0.288, G_loss=3.468
# >43, 2/13, D_loss=0.292, G_loss=3.917
# >43, 3/13, D_loss=0.316, G_loss=3.746
# >43, 4/13, D_loss=0.346, G_loss=3.845
# >43, 5/13, D_loss=0.365, G_loss=3.398
# >43, 6/13, D_loss=0.342, G_loss=3.488
# >43, 7/13, D_loss=0.346, G_loss=3.503
# >43, 8/13, D_loss=0.353, G_loss=3.482
# >43, 9/13, D_loss=0.370, G_loss=3.592
# >43, 10/13, D_loss=0.419, G_loss=3.708
# >43, 11/13, D_loss=0.321, G_loss=3.710
# >43, 12/13, D_loss=0.408, G_loss=3.527
# >43, 13/13, D_loss=0.547, G_loss=3.181
# >44, 1/13, D_loss=0.487, G_loss=3.271
# >44, 2/13, D_loss=0.408, G_loss=3.192
# >44, 3/13, D_loss=0.452, G_loss=3.361
# >44, 4/13, D_loss=0.575, G_loss=3.562
# >44, 5/13, D_loss=0.440, G_loss=3.812
# >44, 6/13, D_loss=0.472, G_loss=4.066
# >44, 7/13, D_loss=0.557, G_loss=3.710
# >44, 8/13, D_loss=0.412, G_loss=3.345
# >44, 9/13, D_loss=0.569, G_loss=3.316
# >44, 10/13, D_loss=0.475, G_loss=3.589
# >44, 11/13, D_loss=0.507, G_loss=3.909
# >44, 12/13, D_loss=0.467, G_loss=3.772
# >44, 13/13, D_loss=0.439, G_loss=4.125
# >45, 1/13, D_loss=0.559, G_loss=4.114
# >45, 2/13, D_loss=0.432, G_loss=4.127
# >45, 3/13, D_loss=0.580, G_loss=3.401
# >45, 4/13, D_loss=0.563, G_loss=3.393
# >45, 5/13, D_loss=0.627, G_loss=3.277
# >45, 6/13, D_loss=0.463, G_loss=3.694
# >45, 7/13, D_loss=0.406, G_loss=3.852
# >45, 8/13, D_loss=0.345, G_loss=4.466
# >45, 9/13, D_loss=0.582, G_loss=3.935
# >45, 10/13, D_loss=0.517, G_loss=4.370
# >45, 11/13, D_loss=0.595, G_loss=3.585
# >45, 12/13, D_loss=0.464, G_loss=3.741
# >45, 13/13, D_loss=0.468, G_loss=4.272
# >Epoch: 45 Porosity match: 12% Std: 0.17 real: 90% fake: 91%
# >46, 1/13, D_loss=0.481, G_loss=4.262
# >46, 2/13, D_loss=0.521, G_loss=4.282
# >46, 3/13, D_loss=0.414, G_loss=4.467
# >46, 4/13, D_loss=0.413, G_loss=4.375
# >46, 5/13, D_loss=0.345, G_loss=4.397
# >46, 6/13, D_loss=0.387, G_loss=4.589
# >46, 7/13, D_loss=0.292, G_loss=4.873
# >46, 8/13, D_loss=0.282, G_loss=4.817
# >46, 9/13, D_loss=0.297, G_loss=4.882
# >46, 10/13, D_loss=0.283, G_loss=5.113
# >46, 11/13, D_loss=0.308, G_loss=4.973
# >46, 12/13, D_loss=0.225, G_loss=5.546
# >46, 13/13, D_loss=0.302, G_loss=5.339
# >47, 1/13, D_loss=0.200, G_loss=5.719
# >47, 2/13, D_loss=0.192, G_loss=5.190
# >47, 3/13, D_loss=0.200, G_loss=5.737
# >47, 4/13, D_loss=0.168, G_loss=5.360
# >47, 5/13, D_loss=0.180, G_loss=5.465
# >47, 6/13, D_loss=0.133, G_loss=4.979
# >47, 7/13, D_loss=0.220, G_loss=5.784
# >47, 8/13, D_loss=0.143, G_loss=5.797
# >47, 9/13, D_loss=0.156, G_loss=5.396
# >47, 10/13, D_loss=0.185, G_loss=5.498
# >47, 11/13, D_loss=0.140, G_loss=5.651
# >47, 12/13, D_loss=0.252, G_loss=5.567
# >47, 13/13, D_loss=0.103, G_loss=5.643
# >48, 1/13, D_loss=0.129, G_loss=5.413
# >48, 2/13, D_loss=0.201, G_loss=5.402
# >48, 3/13, D_loss=0.253, G_loss=5.191
# >48, 4/13, D_loss=0.167, G_loss=5.283
# >48, 5/13, D_loss=0.099, G_loss=4.931
# >48, 6/13, D_loss=0.157, G_loss=4.895
# >48, 7/13, D_loss=0.246, G_loss=4.531
# >48, 8/13, D_loss=0.121, G_loss=4.732
# >48, 9/13, D_loss=0.117, G_loss=4.485
# >48, 10/13, D_loss=0.187, G_loss=5.643
# >48, 11/13, D_loss=0.218, G_loss=5.160
# >48, 12/13, D_loss=0.241, G_loss=4.991
# >48, 13/13, D_loss=0.208, G_loss=4.257
# >49, 1/13, D_loss=0.142, G_loss=4.671
# >49, 2/13, D_loss=0.153, G_loss=4.464
# >49, 3/13, D_loss=0.230, G_loss=4.024
# >49, 4/13, D_loss=0.134, G_loss=4.923
# >49, 5/13, D_loss=0.176, G_loss=4.626
# >49, 6/13, D_loss=0.148, G_loss=4.526
# >49, 7/13, D_loss=0.156, G_loss=4.487
# >49, 8/13, D_loss=0.251, G_loss=4.223
# >49, 9/13, D_loss=0.206, G_loss=4.161
# >49, 10/13, D_loss=0.277, G_loss=3.519
# >49, 11/13, D_loss=0.197, G_loss=3.961
# >49, 12/13, D_loss=0.258, G_loss=4.269
# >49, 13/13, D_loss=0.251, G_loss=3.976
# >50, 1/13, D_loss=0.187, G_loss=3.826
# >50, 2/13, D_loss=0.225, G_loss=3.687
# >50, 3/13, D_loss=0.292, G_loss=3.760
# >50, 4/13, D_loss=0.222, G_loss=3.827
# >50, 5/13, D_loss=0.199, G_loss=3.576
# >50, 6/13, D_loss=0.284, G_loss=3.580
# >50, 7/13, D_loss=0.269, G_loss=3.661
# >50, 8/13, D_loss=0.368, G_loss=3.584
# >50, 9/13, D_loss=0.246, G_loss=3.871
# >50, 10/13, D_loss=0.337, G_loss=4.078
# >50, 11/13, D_loss=0.247, G_loss=3.534
# >50, 12/13, D_loss=0.538, G_loss=3.515
# >50, 13/13, D_loss=0.494, G_loss=3.520
# >Epoch: 50 Porosity match: 20% Std: 0.18 real: 94% fake: 92%
# >51, 1/13, D_loss=0.336, G_loss=3.703
# >51, 2/13, D_loss=0.346, G_loss=3.513
# >51, 3/13, D_loss=0.304, G_loss=2.940
# >51, 4/13, D_loss=0.361, G_loss=3.385
# >51, 5/13, D_loss=0.237, G_loss=3.792
# >51, 6/13, D_loss=0.370, G_loss=3.414
# >51, 7/13, D_loss=0.310, G_loss=3.907
# >51, 8/13, D_loss=0.411, G_loss=3.784
# >51, 9/13, D_loss=0.271, G_loss=3.299
# >51, 10/13, D_loss=0.367, G_loss=2.835
# >51, 11/13, D_loss=0.379, G_loss=3.204
# >51, 12/13, D_loss=0.305, G_loss=3.277
# >51, 13/13, D_loss=0.333, G_loss=3.375
# >52, 1/13, D_loss=0.357, G_loss=3.492
# >52, 2/13, D_loss=0.329, G_loss=3.631
# >52, 3/13, D_loss=0.349, G_loss=4.002
# >52, 4/13, D_loss=0.454, G_loss=3.904
# >52, 5/13, D_loss=0.379, G_loss=3.359
# >52, 6/13, D_loss=0.428, G_loss=2.887
# >52, 7/13, D_loss=0.461, G_loss=3.469
# >52, 8/13, D_loss=0.384, G_loss=3.093
# >52, 9/13, D_loss=0.302, G_loss=3.670
# >52, 10/13, D_loss=0.329, G_loss=3.537
# >52, 11/13, D_loss=0.360, G_loss=4.468
# >52, 12/13, D_loss=0.353, G_loss=3.915
# >52, 13/13, D_loss=0.286, G_loss=3.425
# >53, 1/13, D_loss=0.311, G_loss=3.303
# >53, 2/13, D_loss=0.350, G_loss=3.297
# >53, 3/13, D_loss=0.349, G_loss=3.450
# >53, 4/13, D_loss=0.349, G_loss=3.978
# >53, 5/13, D_loss=0.285, G_loss=4.001
# >53, 6/13, D_loss=0.284, G_loss=3.935
# >53, 7/13, D_loss=0.351, G_loss=3.783
# >53, 8/13, D_loss=0.277, G_loss=3.646
# >53, 9/13, D_loss=0.312, G_loss=3.993
# >53, 10/13, D_loss=0.329, G_loss=3.881
# >53, 11/13, D_loss=0.210, G_loss=4.044
# >53, 12/13, D_loss=0.302, G_loss=3.984
# >53, 13/13, D_loss=0.271, G_loss=3.815
# >54, 1/13, D_loss=0.341, G_loss=3.704
# >54, 2/13, D_loss=0.212, G_loss=3.572
# >54, 3/13, D_loss=0.299, G_loss=3.874
# >54, 4/13, D_loss=0.207, G_loss=4.114
# >54, 5/13, D_loss=0.220, G_loss=3.948
# >54, 6/13, D_loss=0.164, G_loss=4.438
# >54, 7/13, D_loss=0.251, G_loss=4.630
# >54, 8/13, D_loss=0.259, G_loss=4.286
# >54, 9/13, D_loss=0.254, G_loss=4.036
# >54, 10/13, D_loss=0.323, G_loss=4.415
# >54, 11/13, D_loss=0.156, G_loss=3.696
# >54, 12/13, D_loss=0.245, G_loss=3.935
# >54, 13/13, D_loss=0.158, G_loss=4.492
# Failure Mode 2: swapping to D model of epoch 15
# >55, 1/13, D_loss=1.255, G_loss=2.025
# >55, 2/13, D_loss=0.931, G_loss=2.349
# >55, 3/13, D_loss=0.714, G_loss=2.926
# >55, 4/13, D_loss=0.907, G_loss=2.922
# >55, 5/13, D_loss=1.025, G_loss=2.806
# >55, 6/13, D_loss=0.600, G_loss=2.476
# >55, 7/13, D_loss=0.904, G_loss=2.126
# >55, 8/13, D_loss=0.806, G_loss=2.126
# >55, 9/13, D_loss=0.758, G_loss=2.146
# >55, 10/13, D_loss=0.814, G_loss=2.409
# >55, 11/13, D_loss=0.613, G_loss=2.784
# >55, 12/13, D_loss=0.625, G_loss=2.797
# >55, 13/13, D_loss=0.475, G_loss=2.496
# >Epoch: 55 Porosity match: 18% Std: 0.20 real: 51% fake: 84%
# >56, 1/13, D_loss=0.600, G_loss=2.635
# >56, 2/13, D_loss=0.668, G_loss=2.208
# >56, 3/13, D_loss=0.635, G_loss=2.210
# >56, 4/13, D_loss=0.569, G_loss=2.058
# >56, 5/13, D_loss=0.526, G_loss=2.240
# >56, 6/13, D_loss=0.501, G_loss=2.394
# >56, 7/13, D_loss=0.491, G_loss=2.523
# >56, 8/13, D_loss=0.657, G_loss=2.289
# >56, 9/13, D_loss=0.492, G_loss=2.335
# >56, 10/13, D_loss=0.432, G_loss=2.472
# >56, 11/13, D_loss=0.458, G_loss=2.598
# >56, 12/13, D_loss=0.613, G_loss=2.376
# >56, 13/13, D_loss=0.528, G_loss=2.261
# >57, 1/13, D_loss=0.437, G_loss=2.589
# >57, 2/13, D_loss=0.422, G_loss=2.331
# >57, 3/13, D_loss=0.442, G_loss=2.487
# >57, 4/13, D_loss=0.420, G_loss=2.832
# >57, 5/13, D_loss=0.561, G_loss=2.657
# >57, 6/13, D_loss=0.547, G_loss=2.557
# >57, 7/13, D_loss=0.485, G_loss=2.481
# >57, 8/13, D_loss=0.433, G_loss=2.644
# >57, 9/13, D_loss=0.618, G_loss=2.384
# >57, 10/13, D_loss=0.523, G_loss=2.712
# >57, 11/13, D_loss=0.605, G_loss=2.682
# >57, 12/13, D_loss=0.443, G_loss=2.517
# >57, 13/13, D_loss=0.476, G_loss=2.831
# >58, 1/13, D_loss=0.445, G_loss=2.506
# >58, 2/13, D_loss=0.460, G_loss=2.822
# >58, 3/13, D_loss=0.403, G_loss=2.562
# >58, 4/13, D_loss=0.477, G_loss=2.696
# >58, 5/13, D_loss=0.525, G_loss=2.603
# >58, 6/13, D_loss=0.526, G_loss=2.410
# >58, 7/13, D_loss=0.495, G_loss=2.615
# >58, 8/13, D_loss=0.467, G_loss=2.879
# >58, 9/13, D_loss=0.421, G_loss=3.139
# >58, 10/13, D_loss=0.522, G_loss=3.226
# >58, 11/13, D_loss=0.417, G_loss=2.924
# >58, 12/13, D_loss=0.490, G_loss=2.592
# >58, 13/13, D_loss=0.545, G_loss=2.703
# >59, 1/13, D_loss=0.476, G_loss=2.493
# >59, 2/13, D_loss=0.367, G_loss=2.783
# >59, 3/13, D_loss=0.428, G_loss=2.745
# >59, 4/13, D_loss=0.349, G_loss=2.671
# >59, 5/13, D_loss=0.447, G_loss=2.801
# >59, 6/13, D_loss=0.454, G_loss=2.980
# >59, 7/13, D_loss=0.517, G_loss=3.199
# >59, 8/13, D_loss=0.422, G_loss=3.029
# >59, 9/13, D_loss=0.516, G_loss=3.344
# >59, 10/13, D_loss=0.412, G_loss=3.434
# >59, 11/13, D_loss=0.514, G_loss=3.182
# >59, 12/13, D_loss=0.455, G_loss=3.129
# >59, 13/13, D_loss=0.371, G_loss=2.570
# >60, 1/13, D_loss=0.528, G_loss=3.238
# >60, 2/13, D_loss=0.580, G_loss=3.187
# >60, 3/13, D_loss=0.427, G_loss=3.447
# >60, 4/13, D_loss=0.508, G_loss=3.549
# >60, 5/13, D_loss=0.482, G_loss=3.349
# >60, 6/13, D_loss=0.325, G_loss=3.320
# >60, 7/13, D_loss=0.472, G_loss=3.339
# >60, 8/13, D_loss=0.510, G_loss=3.191
# >60, 9/13, D_loss=0.544, G_loss=3.179
# >60, 10/13, D_loss=0.519, G_loss=3.105
# >60, 11/13, D_loss=0.428, G_loss=3.258
# >60, 12/13, D_loss=0.564, G_loss=3.203
# >60, 13/13, D_loss=0.533, G_loss=3.601
# Failure Mode 2: swapping to D model of epoch 35
# >Epoch: 60 Porosity match: 19% Std: 0.15 real: 97% fake: 16%
# >61, 1/13, D_loss=0.668, G_loss=2.311
# >61, 2/13, D_loss=0.724, G_loss=2.788
# >61, 3/13, D_loss=0.566, G_loss=2.823
# >61, 4/13, D_loss=0.627, G_loss=3.016
# >61, 5/13, D_loss=0.635, G_loss=3.020
# >61, 6/13, D_loss=0.754, G_loss=2.668
# >61, 7/13, D_loss=0.852, G_loss=2.776
# >61, 8/13, D_loss=0.706, G_loss=2.816
# >61, 9/13, D_loss=0.690, G_loss=2.365
# >61, 10/13, D_loss=0.600, G_loss=2.762
# >61, 11/13, D_loss=0.702, G_loss=2.489
# >61, 12/13, D_loss=0.567, G_loss=2.758
# >61, 13/13, D_loss=0.668, G_loss=2.877
# >62, 1/13, D_loss=0.560, G_loss=2.982
# >62, 2/13, D_loss=0.540, G_loss=2.755
# >62, 3/13, D_loss=0.576, G_loss=2.761
# >62, 4/13, D_loss=0.592, G_loss=2.988
# >62, 5/13, D_loss=0.659, G_loss=2.815
# >62, 6/13, D_loss=0.588, G_loss=2.497
# >62, 7/13, D_loss=0.645, G_loss=2.552
# >62, 8/13, D_loss=0.582, G_loss=2.473
# >62, 9/13, D_loss=0.651, G_loss=2.678
# >62, 10/13, D_loss=0.617, G_loss=2.366
# >62, 11/13, D_loss=0.686, G_loss=2.249
# >62, 12/13, D_loss=0.564, G_loss=2.456
# >62, 13/13, D_loss=0.686, G_loss=2.540
# >63, 1/13, D_loss=0.577, G_loss=2.429
# >63, 2/13, D_loss=0.566, G_loss=2.622
# >63, 3/13, D_loss=0.567, G_loss=2.585
# >63, 4/13, D_loss=0.565, G_loss=2.385
# >63, 5/13, D_loss=0.620, G_loss=2.719
# >63, 6/13, D_loss=0.569, G_loss=2.512
# >63, 7/13, D_loss=0.631, G_loss=2.770
# >63, 8/13, D_loss=0.763, G_loss=2.581
# >63, 9/13, D_loss=0.515, G_loss=2.354
# >63, 10/13, D_loss=0.613, G_loss=2.136
# >63, 11/13, D_loss=0.634, G_loss=2.190
# >63, 12/13, D_loss=0.530, G_loss=2.447
# >63, 13/13, D_loss=0.553, G_loss=2.401
# >64, 1/13, D_loss=0.633, G_loss=2.221
# >64, 2/13, D_loss=0.586, G_loss=2.329
# >64, 3/13, D_loss=0.561, G_loss=2.451
# >64, 4/13, D_loss=0.497, G_loss=2.345
# >64, 5/13, D_loss=0.684, G_loss=2.376
# >64, 6/13, D_loss=0.529, G_loss=2.233
# >64, 7/13, D_loss=0.561, G_loss=2.353
# >64, 8/13, D_loss=0.627, G_loss=2.710
# >64, 9/13, D_loss=0.621, G_loss=2.177
# >64, 10/13, D_loss=0.567, G_loss=2.106
# >64, 11/13, D_loss=0.535, G_loss=2.428
# >64, 12/13, D_loss=0.526, G_loss=2.227
# >64, 13/13, D_loss=0.636, G_loss=2.122
# >65, 1/13, D_loss=0.530, G_loss=2.495
# >65, 2/13, D_loss=0.574, G_loss=2.415
# >65, 3/13, D_loss=0.528, G_loss=2.431
# >65, 4/13, D_loss=0.546, G_loss=2.473
# >65, 5/13, D_loss=0.592, G_loss=2.669
# >65, 6/13, D_loss=0.552, G_loss=2.313
# >65, 7/13, D_loss=0.546, G_loss=2.144
# >65, 8/13, D_loss=0.648, G_loss=2.462
# >65, 9/13, D_loss=0.580, G_loss=2.186
# >65, 10/13, D_loss=0.512, G_loss=2.526
# >65, 11/13, D_loss=0.600, G_loss=2.480
# >65, 12/13, D_loss=0.535, G_loss=2.215
# >65, 13/13, D_loss=0.484, G_loss=2.009
# Failure Mode 2: swapping to D model of epoch 25
# >Epoch: 65 Porosity match: 18% Std: 0.22 real: 90% fake: 35%
# >66, 1/13, D_loss=0.839, G_loss=1.710
# >66, 2/13, D_loss=0.708, G_loss=2.353
# >66, 3/13, D_loss=0.675, G_loss=2.613
# >66, 4/13, D_loss=0.735, G_loss=2.260
# >66, 5/13, D_loss=0.845, G_loss=2.647
# >66, 6/13, D_loss=0.834, G_loss=2.297
# >66, 7/13, D_loss=0.711, G_loss=2.134
# >66, 8/13, D_loss=0.821, G_loss=2.029
# >66, 9/13, D_loss=0.704, G_loss=1.966
# >66, 10/13, D_loss=0.699, G_loss=2.080
# >66, 11/13, D_loss=0.682, G_loss=2.139
# >66, 12/13, D_loss=0.647, G_loss=2.406
# >66, 13/13, D_loss=0.668, G_loss=2.463
# >67, 1/13, D_loss=0.689, G_loss=2.585
# >67, 2/13, D_loss=0.689, G_loss=2.730
# >67, 3/13, D_loss=0.667, G_loss=2.323
# >67, 4/13, D_loss=0.678, G_loss=2.476
# >67, 5/13, D_loss=0.656, G_loss=2.180
# >67, 6/13, D_loss=0.669, G_loss=2.011
# >67, 7/13, D_loss=0.564, G_loss=1.968
# >67, 8/13, D_loss=0.768, G_loss=2.170
# >67, 9/13, D_loss=0.666, G_loss=2.226
# >67, 10/13, D_loss=0.575, G_loss=2.366
# >67, 11/13, D_loss=0.701, G_loss=2.442
# >67, 12/13, D_loss=0.607, G_loss=2.461
# >67, 13/13, D_loss=0.665, G_loss=2.296
# >68, 1/13, D_loss=0.521, G_loss=2.114
# >68, 2/13, D_loss=0.593, G_loss=2.453
# >68, 3/13, D_loss=0.600, G_loss=2.434
# >68, 4/13, D_loss=0.599, G_loss=2.325
# >68, 5/13, D_loss=0.472, G_loss=2.197
# >68, 6/13, D_loss=0.503, G_loss=2.527
# >68, 7/13, D_loss=0.614, G_loss=2.454
# >68, 8/13, D_loss=0.795, G_loss=2.414
# >68, 9/13, D_loss=0.596, G_loss=2.405
# >68, 10/13, D_loss=0.595, G_loss=2.531
# >68, 11/13, D_loss=0.542, G_loss=2.437
# >68, 12/13, D_loss=0.486, G_loss=2.448
# >68, 13/13, D_loss=0.584, G_loss=2.485
# >69, 1/13, D_loss=0.529, G_loss=2.420
# >69, 2/13, D_loss=0.491, G_loss=2.408
# >69, 3/13, D_loss=0.543, G_loss=2.234
# >69, 4/13, D_loss=0.498, G_loss=2.261
# >69, 5/13, D_loss=0.576, G_loss=2.406
# >69, 6/13, D_loss=0.469, G_loss=2.791
# >69, 7/13, D_loss=0.469, G_loss=2.577
# >69, 8/13, D_loss=0.558, G_loss=2.294
# >69, 9/13, D_loss=0.527, G_loss=2.409
# >69, 10/13, D_loss=0.545, G_loss=2.850
# >69, 11/13, D_loss=0.509, G_loss=3.015
# >69, 12/13, D_loss=0.440, G_loss=2.890
# >69, 13/13, D_loss=0.516, G_loss=2.702
# >70, 1/13, D_loss=0.456, G_loss=3.064
# >70, 2/13, D_loss=0.620, G_loss=2.948
# >70, 3/13, D_loss=0.498, G_loss=2.531
# >70, 4/13, D_loss=0.406, G_loss=2.711
# >70, 5/13, D_loss=0.468, G_loss=2.801
# >70, 6/13, D_loss=0.508, G_loss=2.758
# >70, 7/13, D_loss=0.504, G_loss=2.945
# >70, 8/13, D_loss=0.451, G_loss=2.844
# >70, 9/13, D_loss=0.479, G_loss=2.940
# >70, 10/13, D_loss=0.584, G_loss=2.919
# >70, 11/13, D_loss=0.541, G_loss=2.765
# >70, 12/13, D_loss=0.528, G_loss=3.124
# >70, 13/13, D_loss=0.509, G_loss=2.935
# >Epoch: 70 Porosity match: 19% Std: 0.17 real: 91% fake: 85%
# >71, 1/13, D_loss=0.486, G_loss=2.950
# >71, 2/13, D_loss=0.513, G_loss=2.897
# >71, 3/13, D_loss=0.464, G_loss=2.777
# >71, 4/13, D_loss=0.514, G_loss=2.932
# >71, 5/13, D_loss=0.439, G_loss=2.766
# >71, 6/13, D_loss=0.554, G_loss=3.228
# >71, 7/13, D_loss=0.499, G_loss=3.442
# >71, 8/13, D_loss=0.515, G_loss=3.184
# >71, 9/13, D_loss=0.404, G_loss=3.679
# >71, 10/13, D_loss=0.608, G_loss=3.326
# >71, 11/13, D_loss=0.453, G_loss=3.447
# >71, 12/13, D_loss=0.567, G_loss=3.138
# >71, 13/13, D_loss=0.474, G_loss=2.802
# >72, 1/13, D_loss=0.422, G_loss=2.851
# >72, 2/13, D_loss=0.467, G_loss=2.696
# >72, 3/13, D_loss=0.533, G_loss=2.899
# >72, 4/13, D_loss=0.548, G_loss=3.182
# >72, 5/13, D_loss=0.452, G_loss=3.093
# >72, 6/13, D_loss=0.523, G_loss=3.522
# >72, 7/13, D_loss=0.628, G_loss=3.131
# >72, 8/13, D_loss=0.646, G_loss=3.155
# >72, 9/13, D_loss=0.494, G_loss=3.092
# >72, 10/13, D_loss=0.448, G_loss=3.178
# >72, 11/13, D_loss=0.564, G_loss=2.764
# >72, 12/13, D_loss=0.590, G_loss=3.398
# >72, 13/13, D_loss=0.494, G_loss=2.742
# Failure Mode 2: swapping to D model of epoch 70
# >73, 1/13, D_loss=0.624, G_loss=2.644
# >73, 2/13, D_loss=0.528, G_loss=2.826
# >73, 3/13, D_loss=0.466, G_loss=2.924
# >73, 4/13, D_loss=0.638, G_loss=3.078
# >73, 5/13, D_loss=0.499, G_loss=2.880
# >73, 6/13, D_loss=0.603, G_loss=2.897
# >73, 7/13, D_loss=0.484, G_loss=2.865
# >73, 8/13, D_loss=0.526, G_loss=2.673
# >73, 9/13, D_loss=0.564, G_loss=3.220
# >73, 10/13, D_loss=0.556, G_loss=3.334
# >73, 11/13, D_loss=0.672, G_loss=3.426
# >73, 12/13, D_loss=0.589, G_loss=2.777
# >73, 13/13, D_loss=0.501, G_loss=3.211
# Failure Mode 2: swapping to D model of epoch 40
# >74, 1/13, D_loss=0.940, G_loss=2.678
# >74, 2/13, D_loss=0.912, G_loss=2.783
# >74, 3/13, D_loss=0.856, G_loss=3.539
# >74, 4/13, D_loss=0.920, G_loss=3.154
# >74, 5/13, D_loss=0.774, G_loss=3.213
# >74, 6/13, D_loss=1.074, G_loss=3.198
# >74, 7/13, D_loss=0.860, G_loss=3.058
# >74, 8/13, D_loss=0.848, G_loss=2.793
# >74, 9/13, D_loss=0.821, G_loss=2.849
# >74, 10/13, D_loss=0.682, G_loss=3.158
# >74, 11/13, D_loss=0.677, G_loss=2.802
# >74, 12/13, D_loss=0.657, G_loss=3.287
# >74, 13/13, D_loss=0.646, G_loss=2.889
# >75, 1/13, D_loss=0.677, G_loss=3.142
# >75, 2/13, D_loss=0.673, G_loss=3.039
# >75, 3/13, D_loss=0.696, G_loss=3.121
# >75, 4/13, D_loss=0.735, G_loss=3.470
# >75, 5/13, D_loss=0.643, G_loss=3.110
# >75, 6/13, D_loss=0.736, G_loss=3.210
# >75, 7/13, D_loss=0.529, G_loss=3.475
# >75, 8/13, D_loss=0.479, G_loss=3.153
# >75, 9/13, D_loss=0.492, G_loss=3.377
# >75, 10/13, D_loss=0.553, G_loss=3.203
# >75, 11/13, D_loss=0.574, G_loss=3.196
# >75, 12/13, D_loss=0.554, G_loss=3.421
# >75, 13/13, D_loss=0.520, G_loss=3.305
# >Epoch: 75 Porosity match: 18% Std: 0.15 real: 84% fake: 90%
# >76, 1/13, D_loss=0.527, G_loss=3.145
# >76, 2/13, D_loss=0.518, G_loss=3.583
# >76, 3/13, D_loss=0.528, G_loss=3.277
# >76, 4/13, D_loss=0.562, G_loss=3.369
# >76, 5/13, D_loss=0.530, G_loss=3.656
# >76, 6/13, D_loss=0.549, G_loss=3.576
# >76, 7/13, D_loss=0.377, G_loss=3.691
# >76, 8/13, D_loss=0.558, G_loss=3.381
# >76, 9/13, D_loss=0.593, G_loss=3.523
# >76, 10/13, D_loss=0.480, G_loss=3.581
# >76, 11/13, D_loss=0.493, G_loss=3.185
# >76, 12/13, D_loss=0.522, G_loss=3.512
# >76, 13/13, D_loss=0.394, G_loss=3.417
# >77, 1/13, D_loss=0.472, G_loss=3.849
# >77, 2/13, D_loss=0.347, G_loss=3.659
# >77, 3/13, D_loss=0.483, G_loss=3.866
# >77, 4/13, D_loss=0.404, G_loss=3.715
# >77, 5/13, D_loss=0.350, G_loss=3.705
# >77, 6/13, D_loss=0.430, G_loss=3.807
# >77, 7/13, D_loss=0.471, G_loss=3.510
# >77, 8/13, D_loss=0.409, G_loss=3.368
# >77, 9/13, D_loss=0.355, G_loss=3.725
# >77, 10/13, D_loss=0.471, G_loss=4.164
# >77, 11/13, D_loss=0.392, G_loss=4.031
# >77, 12/13, D_loss=0.521, G_loss=3.831
# >77, 13/13, D_loss=0.461, G_loss=3.926
# >78, 1/13, D_loss=0.517, G_loss=3.372
# >78, 2/13, D_loss=0.423, G_loss=4.135
# >78, 3/13, D_loss=0.585, G_loss=3.565
# >78, 4/13, D_loss=0.586, G_loss=3.776
# >78, 5/13, D_loss=0.545, G_loss=3.782
# >78, 6/13, D_loss=0.537, G_loss=3.444
# >78, 7/13, D_loss=0.583, G_loss=4.169
# >78, 8/13, D_loss=0.555, G_loss=3.660
# >78, 9/13, D_loss=0.554, G_loss=4.056
# >78, 10/13, D_loss=0.547, G_loss=3.832
# >78, 11/13, D_loss=0.632, G_loss=3.454
# >78, 12/13, D_loss=0.574, G_loss=3.652
# >78, 13/13, D_loss=0.632, G_loss=4.175
# >79, 1/13, D_loss=0.687, G_loss=3.620
# >79, 2/13, D_loss=0.590, G_loss=3.623
# >79, 3/13, D_loss=0.697, G_loss=3.458
# >79, 4/13, D_loss=0.602, G_loss=3.110
# >79, 5/13, D_loss=0.777, G_loss=2.915
# >79, 6/13, D_loss=0.527, G_loss=3.530
# >79, 7/13, D_loss=0.595, G_loss=3.690
# >79, 8/13, D_loss=0.595, G_loss=3.948
# >79, 9/13, D_loss=0.671, G_loss=4.010
# >79, 10/13, D_loss=0.623, G_loss=3.091
# >79, 11/13, D_loss=0.693, G_loss=3.966
# >79, 12/13, D_loss=0.608, G_loss=3.302
# >79, 13/13, D_loss=0.540, G_loss=3.538
# >80, 1/13, D_loss=0.523, G_loss=3.328
# >80, 2/13, D_loss=0.737, G_loss=3.498
# >80, 3/13, D_loss=0.653, G_loss=3.080
# >80, 4/13, D_loss=0.685, G_loss=3.596
# >80, 5/13, D_loss=0.604, G_loss=2.995
# >80, 6/13, D_loss=0.542, G_loss=3.080
# >80, 7/13, D_loss=0.633, G_loss=3.173
# >80, 8/13, D_loss=0.623, G_loss=3.180
# >80, 9/13, D_loss=0.561, G_loss=3.136
# >80, 10/13, D_loss=0.488, G_loss=3.081
# >80, 11/13, D_loss=0.543, G_loss=3.108
# >80, 12/13, D_loss=0.641, G_loss=3.138
# >80, 13/13, D_loss=0.522, G_loss=2.904
# >Epoch: 80 Porosity match: 18% Std: 0.18 real: 92% fake: 72%
# >81, 1/13, D_loss=0.541, G_loss=2.720
# >81, 2/13, D_loss=0.594, G_loss=2.693
# >81, 3/13, D_loss=0.532, G_loss=2.875
# >81, 4/13, D_loss=0.445, G_loss=2.736
# >81, 5/13, D_loss=0.535, G_loss=2.836
# >81, 6/13, D_loss=0.515, G_loss=2.541
# >81, 7/13, D_loss=0.492, G_loss=2.694
# >81, 8/13, D_loss=0.543, G_loss=2.907
# >81, 9/13, D_loss=0.489, G_loss=2.743
# >81, 10/13, D_loss=0.577, G_loss=2.650
# >81, 11/13, D_loss=0.503, G_loss=2.742
# >81, 12/13, D_loss=0.524, G_loss=2.548
# >81, 13/13, D_loss=0.467, G_loss=2.717
# >82, 1/13, D_loss=0.551, G_loss=2.602
# >82, 2/13, D_loss=0.458, G_loss=2.187
# >82, 3/13, D_loss=0.561, G_loss=2.199
# >82, 4/13, D_loss=0.481, G_loss=2.207
# >82, 5/13, D_loss=0.531, G_loss=2.125
# >82, 6/13, D_loss=0.519, G_loss=2.138
# >82, 7/13, D_loss=0.465, G_loss=2.317
# >82, 8/13, D_loss=0.471, G_loss=2.332
# >82, 9/13, D_loss=0.501, G_loss=2.324
# >82, 10/13, D_loss=0.440, G_loss=2.191
# >82, 11/13, D_loss=0.434, G_loss=2.461
# >82, 12/13, D_loss=0.526, G_loss=2.414
# >82, 13/13, D_loss=0.538, G_loss=2.325
# Failure Mode 2: swapping to D model of epoch 40
# >83, 1/13, D_loss=0.681, G_loss=1.983
# >83, 2/13, D_loss=0.663, G_loss=2.284
# >83, 3/13, D_loss=0.612, G_loss=2.633
# >83, 4/13, D_loss=0.625, G_loss=3.196
# >83, 5/13, D_loss=0.491, G_loss=3.372
# >83, 6/13, D_loss=0.859, G_loss=2.474
# >83, 7/13, D_loss=0.591, G_loss=2.238
# >83, 8/13, D_loss=0.930, G_loss=1.697
# >83, 9/13, D_loss=0.626, G_loss=2.245
# >83, 10/13, D_loss=0.623, G_loss=2.588
# >83, 11/13, D_loss=0.466, G_loss=3.298
# >83, 12/13, D_loss=0.825, G_loss=2.765
# >83, 13/13, D_loss=0.618, G_loss=2.560
# >84, 1/13, D_loss=0.612, G_loss=2.224
# >84, 2/13, D_loss=0.676, G_loss=2.175
# >84, 3/13, D_loss=0.806, G_loss=2.337
# >84, 4/13, D_loss=0.613, G_loss=2.291
# >84, 5/13, D_loss=0.719, G_loss=2.525
# >84, 6/13, D_loss=0.724, G_loss=2.610
# >84, 7/13, D_loss=0.698, G_loss=2.811
# >84, 8/13, D_loss=0.719, G_loss=2.273
# >84, 9/13, D_loss=0.656, G_loss=2.564
# >84, 10/13, D_loss=0.673, G_loss=2.529
# >84, 11/13, D_loss=0.714, G_loss=2.269
# >84, 12/13, D_loss=0.681, G_loss=2.518
# >84, 13/13, D_loss=0.679, G_loss=2.319
# >85, 1/13, D_loss=0.761, G_loss=2.364
# >85, 2/13, D_loss=0.671, G_loss=2.517
# >85, 3/13, D_loss=0.649, G_loss=2.659
# >85, 4/13, D_loss=0.597, G_loss=2.677
# >85, 5/13, D_loss=0.718, G_loss=2.665
# >85, 6/13, D_loss=0.772, G_loss=3.194
# >85, 7/13, D_loss=0.683, G_loss=2.823
# >85, 8/13, D_loss=0.746, G_loss=2.967
# >85, 9/13, D_loss=0.703, G_loss=3.127
# >85, 10/13, D_loss=0.712, G_loss=2.931
# >85, 11/13, D_loss=0.778, G_loss=2.990
# >85, 12/13, D_loss=0.768, G_loss=3.069
# >85, 13/13, D_loss=0.769, G_loss=2.952
# >Epoch: 85 Porosity match: 17% Std: 0.19 real: 65% fake: 56%
# >86, 1/13, D_loss=0.694, G_loss=2.937
# >86, 2/13, D_loss=0.693, G_loss=2.839
# >86, 3/13, D_loss=0.844, G_loss=3.087
# >86, 4/13, D_loss=0.858, G_loss=2.767
# >86, 5/13, D_loss=0.780, G_loss=3.246
# >86, 6/13, D_loss=0.718, G_loss=2.955
# >86, 7/13, D_loss=0.607, G_loss=3.059
# >86, 8/13, D_loss=0.685, G_loss=3.736
# >86, 9/13, D_loss=0.811, G_loss=3.621
# >86, 10/13, D_loss=0.722, G_loss=3.303
# >86, 11/13, D_loss=0.745, G_loss=3.372
# >86, 12/13, D_loss=0.637, G_loss=3.269
# >86, 13/13, D_loss=0.616, G_loss=3.415
# >87, 1/13, D_loss=0.584, G_loss=3.765
# >87, 2/13, D_loss=0.657, G_loss=3.920
# >87, 3/13, D_loss=0.811, G_loss=3.896
# >87, 4/13, D_loss=0.673, G_loss=4.288
# >87, 5/13, D_loss=0.709, G_loss=4.057
# >87, 6/13, D_loss=0.729, G_loss=3.874
# >87, 7/13, D_loss=0.620, G_loss=4.050
# >87, 8/13, D_loss=0.590, G_loss=4.230
# >87, 9/13, D_loss=0.660, G_loss=4.244
# >87, 10/13, D_loss=0.506, G_loss=4.403
# >87, 11/13, D_loss=0.635, G_loss=4.260
# >87, 12/13, D_loss=0.629, G_loss=4.245
# >87, 13/13, D_loss=0.572, G_loss=4.243
# Failure Mode 2: swapping to D model of epoch 10
# >88, 1/13, D_loss=1.491, G_loss=3.857
# >88, 2/13, D_loss=1.464, G_loss=3.698
# >88, 3/13, D_loss=1.346, G_loss=3.972
# >88, 4/13, D_loss=0.872, G_loss=4.340
# >88, 5/13, D_loss=0.952, G_loss=4.870
# >88, 6/13, D_loss=1.012, G_loss=4.677
# >88, 7/13, D_loss=1.038, G_loss=4.431
# >88, 8/13, D_loss=0.974, G_loss=4.724
# >88, 9/13, D_loss=0.785, G_loss=4.397
# >88, 10/13, D_loss=0.905, G_loss=4.488
# >88, 11/13, D_loss=0.798, G_loss=4.477
# >88, 12/13, D_loss=0.669, G_loss=4.292
# >88, 13/13, D_loss=0.764, G_loss=4.300
# >89, 1/13, D_loss=0.763, G_loss=4.003
# >89, 2/13, D_loss=0.759, G_loss=4.280
# >89, 3/13, D_loss=0.743, G_loss=4.078
# >89, 4/13, D_loss=0.600, G_loss=4.308
# >89, 5/13, D_loss=0.574, G_loss=4.666
# >89, 6/13, D_loss=0.861, G_loss=4.338
# >89, 7/13, D_loss=0.604, G_loss=4.347
# >89, 8/13, D_loss=0.601, G_loss=4.414
# >89, 9/13, D_loss=0.618, G_loss=4.869
# >89, 10/13, D_loss=0.650, G_loss=4.606
# >89, 11/13, D_loss=0.569, G_loss=4.650
# >89, 12/13, D_loss=0.607, G_loss=4.241
# >89, 13/13, D_loss=0.574, G_loss=4.291
# >90, 1/13, D_loss=0.689, G_loss=4.089
# >90, 2/13, D_loss=0.681, G_loss=4.151
# >90, 3/13, D_loss=0.637, G_loss=4.005
# >90, 4/13, D_loss=0.620, G_loss=3.994
# >90, 5/13, D_loss=0.506, G_loss=4.049
# >90, 6/13, D_loss=0.670, G_loss=3.576
# >90, 7/13, D_loss=0.691, G_loss=3.709
# >90, 8/13, D_loss=0.600, G_loss=3.522
# >90, 9/13, D_loss=0.708, G_loss=3.765
# >90, 10/13, D_loss=0.582, G_loss=4.114
# >90, 11/13, D_loss=0.621, G_loss=3.604
# >90, 12/13, D_loss=0.640, G_loss=3.722
# >90, 13/13, D_loss=0.604, G_loss=3.983
# >Epoch: 90 Porosity match: 15% Std: 0.16 real: 71% fake: 74%
# >91, 1/13, D_loss=0.571, G_loss=3.737
# >91, 2/13, D_loss=0.594, G_loss=3.658
# >91, 3/13, D_loss=0.705, G_loss=3.098
# >91, 4/13, D_loss=0.584, G_loss=3.131
# >91, 5/13, D_loss=0.564, G_loss=3.121
# >91, 6/13, D_loss=0.639, G_loss=2.832
# >91, 7/13, D_loss=0.642, G_loss=3.023
# >91, 8/13, D_loss=0.654, G_loss=2.888
# >91, 9/13, D_loss=0.596, G_loss=2.800
# >91, 10/13, D_loss=0.549, G_loss=3.167
# >91, 11/13, D_loss=0.574, G_loss=2.956
# >91, 12/13, D_loss=0.571, G_loss=2.903
# >91, 13/13, D_loss=0.630, G_loss=2.891
# >92, 1/13, D_loss=0.658, G_loss=2.763
# >92, 2/13, D_loss=0.629, G_loss=2.511
# >92, 3/13, D_loss=0.631, G_loss=2.560
# >92, 4/13, D_loss=0.655, G_loss=2.413
# >92, 5/13, D_loss=0.845, G_loss=2.491
# >92, 6/13, D_loss=0.680, G_loss=2.375
# >92, 7/13, D_loss=0.752, G_loss=2.401
# >92, 8/13, D_loss=0.710, G_loss=2.493
# >92, 9/13, D_loss=0.662, G_loss=2.245
# >92, 10/13, D_loss=0.637, G_loss=2.411
# >92, 11/13, D_loss=0.663, G_loss=2.323
# >92, 12/13, D_loss=0.731, G_loss=2.142
# >92, 13/13, D_loss=0.674, G_loss=2.015
# >93, 1/13, D_loss=0.667, G_loss=1.987
# >93, 2/13, D_loss=0.632, G_loss=1.915
# >93, 3/13, D_loss=0.702, G_loss=1.898
# >93, 4/13, D_loss=0.678, G_loss=1.933
# >93, 5/13, D_loss=0.668, G_loss=1.835
# >93, 6/13, D_loss=0.664, G_loss=2.103
# >93, 7/13, D_loss=0.679, G_loss=1.835
# >93, 8/13, D_loss=0.812, G_loss=1.813
# >93, 9/13, D_loss=0.705, G_loss=1.968
# >93, 10/13, D_loss=0.651, G_loss=1.845
# >93, 11/13, D_loss=0.655, G_loss=1.789
# >93, 12/13, D_loss=0.677, G_loss=1.861
# >93, 13/13, D_loss=0.637, G_loss=1.938
# Failure Mode 2: swapping to D model of epoch 25
# >94, 1/13, D_loss=0.861, G_loss=1.779
# >94, 2/13, D_loss=1.067, G_loss=2.084
# >94, 3/13, D_loss=0.955, G_loss=2.128
# >94, 4/13, D_loss=0.881, G_loss=1.990
# >94, 5/13, D_loss=0.990, G_loss=2.019
# >94, 6/13, D_loss=0.997, G_loss=1.803
# >94, 7/13, D_loss=0.797, G_loss=2.046
# >94, 8/13, D_loss=0.762, G_loss=1.898
# >94, 9/13, D_loss=0.807, G_loss=1.961
# >94, 10/13, D_loss=0.923, G_loss=1.901
# >94, 11/13, D_loss=0.773, G_loss=1.890
# >94, 12/13, D_loss=0.711, G_loss=1.828
# >94, 13/13, D_loss=0.775, G_loss=2.001
# >95, 1/13, D_loss=0.677, G_loss=2.031
# >95, 2/13, D_loss=0.717, G_loss=1.744
# >95, 3/13, D_loss=0.832, G_loss=1.739
# >95, 4/13, D_loss=0.692, G_loss=1.871
# >95, 5/13, D_loss=0.719, G_loss=1.788
# >95, 6/13, D_loss=0.717, G_loss=1.918
# >95, 7/13, D_loss=0.751, G_loss=1.983
# >95, 8/13, D_loss=0.654, G_loss=1.920
# >95, 9/13, D_loss=0.717, G_loss=2.009
# >95, 10/13, D_loss=0.702, G_loss=1.944
# >95, 11/13, D_loss=0.676, G_loss=1.984
# >95, 12/13, D_loss=0.706, G_loss=1.971
# >95, 13/13, D_loss=0.712, G_loss=2.067
# >Epoch: 95 Porosity match: 20% Std: 0.17 real: 72% fake: 57%
# >96, 1/13, D_loss=0.638, G_loss=1.913
# >96, 2/13, D_loss=0.742, G_loss=2.002
# >96, 3/13, D_loss=0.646, G_loss=2.170
# >96, 4/13, D_loss=0.674, G_loss=2.271
# >96, 5/13, D_loss=0.663, G_loss=2.288
# >96, 6/13, D_loss=0.629, G_loss=2.198
# >96, 7/13, D_loss=0.711, G_loss=2.425
# >96, 8/13, D_loss=0.614, G_loss=2.212
# >96, 9/13, D_loss=0.629, G_loss=2.376
# >96, 10/13, D_loss=0.610, G_loss=2.278
# >96, 11/13, D_loss=0.599, G_loss=2.240
# >96, 12/13, D_loss=0.647, G_loss=2.543
# >96, 13/13, D_loss=0.627, G_loss=2.530
# >97, 1/13, D_loss=0.582, G_loss=2.423
# >97, 2/13, D_loss=0.572, G_loss=2.660
# >97, 3/13, D_loss=0.576, G_loss=2.199
# >97, 4/13, D_loss=0.620, G_loss=2.790
# >97, 5/13, D_loss=0.613, G_loss=2.333
# >97, 6/13, D_loss=0.685, G_loss=2.858
# >97, 7/13, D_loss=0.701, G_loss=2.771
# >97, 8/13, D_loss=0.568, G_loss=2.679
# >97, 9/13, D_loss=0.640, G_loss=2.716
# >97, 10/13, D_loss=0.630, G_loss=2.570
# >97, 11/13, D_loss=0.555, G_loss=2.717
# >97, 12/13, D_loss=0.683, G_loss=2.891
# >97, 13/13, D_loss=0.676, G_loss=2.849
# >98, 1/13, D_loss=0.628, G_loss=2.891
# >98, 2/13, D_loss=0.536, G_loss=3.076
# >98, 3/13, D_loss=0.568, G_loss=2.902
# >98, 4/13, D_loss=0.595, G_loss=3.121
# >98, 5/13, D_loss=0.546, G_loss=3.056
# >98, 6/13, D_loss=0.558, G_loss=3.035
# >98, 7/13, D_loss=0.646, G_loss=3.210
# >98, 8/13, D_loss=0.567, G_loss=3.116
# >98, 9/13, D_loss=0.520, G_loss=3.075
# >98, 10/13, D_loss=0.440, G_loss=3.122
# >98, 11/13, D_loss=0.609, G_loss=3.347
# >98, 12/13, D_loss=0.551, G_loss=3.354
# >98, 13/13, D_loss=0.585, G_loss=3.165
# >99, 1/13, D_loss=0.563, G_loss=3.539
# >99, 2/13, D_loss=0.531, G_loss=3.194
# >99, 3/13, D_loss=0.540, G_loss=3.124
# >99, 4/13, D_loss=0.518, G_loss=3.304
# >99, 5/13, D_loss=0.566, G_loss=3.410
# >99, 6/13, D_loss=0.485, G_loss=3.378
# >99, 7/13, D_loss=0.595, G_loss=3.090
# >99, 8/13, D_loss=0.439, G_loss=3.284
# >99, 9/13, D_loss=0.516, G_loss=3.229
# >99, 10/13, D_loss=0.567, G_loss=2.958
# >99, 11/13, D_loss=0.511, G_loss=3.498
# >99, 12/13, D_loss=0.511, G_loss=2.723
# >99, 13/13, D_loss=0.554, G_loss=3.427
# >100, 1/13, D_loss=0.469, G_loss=2.696
# >100, 2/13, D_loss=0.553, G_loss=3.236
# >100, 3/13, D_loss=0.566, G_loss=3.075
# >100, 4/13, D_loss=0.630, G_loss=3.273
# >100, 5/13, D_loss=0.550, G_loss=3.024
# >100, 6/13, D_loss=0.580, G_loss=3.133
# >100, 7/13, D_loss=0.463, G_loss=2.489
# >100, 8/13, D_loss=0.497, G_loss=2.806
# >100, 9/13, D_loss=0.612, G_loss=2.931
# >100, 10/13, D_loss=0.560, G_loss=2.994
# >100, 11/13, D_loss=0.609, G_loss=3.087
# >100, 12/13, D_loss=0.547, G_loss=2.677
# >100, 13/13, D_loss=0.583, G_loss=2.628
# Failure Mode 2: swapping to D model of epoch 35
# >Epoch: 100 Porosity match: 18% Std: 0.12 real: 97% fake: 3%
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_21820\2085500453.py in <module>
#      48
#      49 seed_geom_gif = np.random.randn(input_G).reshape(1, input_G)
# ---> 50 train_GAN(X,y,G,D,GAN,input_G,porosity,tol_porosity,batch_size,num_epochs,sampling_method,tmp_models_dir,geom_epoch_dirs,seed_geom_gif,tol_fail,alpha_por, alpha_val, save=save, vstack=vstack,plot=plot,verbose_loss=verbose_loss,verbose_acc=verbose_acc)
#
# ~\AppData\Local\Temp\ipykernel_21820\2768515964.py in train_GAN(X, y, G_model, D_model, GAN_model, input_G, porosity, tol_porosity, batch_size, num_epochs, sampling_method, tmp_models_dir, geom_epoch_dirs, seed_geom_gif, tol_fail, alpha_por, alpha_val, vstack, save, plot, verbose_loss, verbose_acc)
#     197         fig.tight_layout(pad=0.75)
#     198         fig.set_size_inches((10,8))
# --> 199         ax[0].plot(list(range(1,num_epochs+1,10)),accs_fake,label='Accuracy fake')
#     200         ax[0].set_xlabel('Epoch')
#     201         ax[0].plot(list(range(1,num_epochs+1,10)),accs_real,label='Accuracy real')
#
# c:\Users\lucas.barbosa\.conda\envs\deeplearn37\lib\site-packages\matplotlib\axes\_axes.py in plot(self, scalex, scaley, data, *args, **kwargs)
#    1741         """
#    1742         kwargs = cbook.normalize_kwargs(kwargs, mlines.Line2D)
# -> 1743         lines = [*self._get_lines(*args, data=data, **kwargs)]
#    1744         for line in lines:
#    1745             self.add_line(line)
#
# c:\Users\lucas.barbosa\.conda\envs\deeplearn37\lib\site-packages\matplotlib\axes\_base.py in __call__(self, data, *args, **kwargs)
#     271                 this += args[0],
#     272                 args = args[1:]
# --> 273             yield from self._plot_args(this, kwargs)
#     274
#     275     def get_next_color(self):
#
# c:\Users\lucas.barbosa\.conda\envs\deeplearn37\lib\site-packages\matplotlib\axes\_base.py in _plot_args(self, tup, kwargs)
#     397
#     398         if x.shape[0] != y.shape[0]:
# --> 399             raise ValueError(f"x and y must have same first dimension, but "
#     400                              f"have shapes {x.shape} and {y.shape}")
#     401         if x.ndim > 2 or y.ndim > 2:
#
# ValueError: x and y must have same first dimension, but have shapes (10,) and (20,)

# %% [markdown]
# # Evaluate `Generator`

# %% [markdown]
# ## Compile gif

# %%
score_filename, geom_epoch_dirs, gif_filename, tmp_models_dir, models_dir, arrays_dir = get_filenames(dimension, simulation, simmetry, score)

with imageio.get_writer(gif_filename, mode='I') as writer:
    geom_filenames = os.listdir(geom_epoch_dirs)
    for geom_filename in geom_filenames:
        image = imageio.imread(geom_epoch_dirs+geom_filename)
        foo = cv2.putText(
                    image,
                    str((geom_filenames.index(geom_filename)+1)*5),
                    (5, 25),
                    cv2.FONT_HERSHEY_SIMPLEX,
                    1,
                    (255, 0, 0),
                    2)
        for i in range(3):
            # image = imageio.imread(geom_epoch_dirs+geom_filename)
            writer.append_data(image)

# %% [markdown]
# ## Visualize geometries

# %%
def check_unit(unit, desired_porosity, tol):
  labels = measure.label(unit,connectivity=1)
  main_label = 0
  main_label_count = 0
  passed = True

  element = unit[int(unit.shape[0]/2):,:int(unit.shape[0]/2)]

  for label in range(1,len(np.unique(labels))):
      label_count = np.where(labels==label)[0].shape[0]
      if label_count > main_label_count:
        main_label = label
        main_label_count = label_count

  void_count = 0

  for label in range(1,len(np.unique(labels))):
    if label not in [0,main_label]:
      void_count += np.where(labels==label)[0].shape[0]
      unit[np.where(labels==label)] = 0.

  porosity = get_porosity(unit)

  if porosity > desired_porosity - tol and porosity < desired_porosity + tol:
    for label in range(1,len(np.unique(labels))):
      if label not in [0,main_label]:
        unit[np.where(labels==label)] = 0.

    if unit[0,:].sum() > 0 and unit[:,0].sum() > 0:
      # check if there is connectivity right-left
      connections_rl = 0
      for i in range(unit.shape[0]):
        if (unit[i,0] == 1 and unit[i,-1] == 1):
          connections_rl += 1

      # check if there is connectivity top-bottom
      connections_tb = 0
      for j in range(unit.shape[1]):
        if (unit[0,j] == 1 and unit[-1,j] == 1):
          connections_tb += 1

      if connections_rl == 0 or connections_tb == 0:
        passed = False
      
    else:
      passed = False
      
  else:
    passed = False

  if passed:
    passed = False
    for i in range(element.shape[0]):
      if [element[i,0],element[element.shape[0]-1,element.shape[1]-i-1]]==[1,1]:
        passed = True

  return passed, element

def check_singularity(element, simmetry):
  passeds = [True for i in range(4)]

  # check singularities inside element
  for i in range(element.shape[0]-1):
    for j in range(element.shape[1]-1):
      # print(element[i:i+2,j:j+2])
      diag1 = list(element[i:i+2,j:j+2].diagonal())
      diag2 = list(np.fliplr(element[i:i+2,j:j+2]).diagonal())
      if (diag1 == [1,1] and diag2 == [0,0]) or (diag1 == [0,0] and diag2 == [1,1]):
        passeds[0] = False    

  # check singularities in element boundary and singularities in unit boundary
  if simmetry[1:] == '4':
    for j in range(element.shape[1]-1):
      arr = np.array([[element[element.shape[0]-j-1,element.shape[1]-1],element[element.shape[0]-j-2,element.shape[1]-1]],[element[0,j],element[0,j+1]]])
      diag1 = list(arr.diagonal())
      diag2 = list(np.fliplr(arr).diagonal())
      if (diag1 == [1,1] and diag2 == [0,0]) or (diag1 == [0,0] and diag2 == [1,1]):
        passeds[1] = False
      
      arr = np.array([[element[element.shape[0]-1,j],element[element.shape[0]-1,j+1]],[element[j,0],element[j+1,0]]])
      diag1 = list(arr.diagonal())
      diag2 = list(np.fliplr(arr).diagonal())
      if (diag1 == [1,1] and diag2 == [0,0]) or (diag1 == [0,0] and diag2 == [1,1]):
        passeds[2] = False
      if [element[0,0],element[element.shape[0]-1,element.shape[1]-1]] == [1, 0] or [element[0,0],element[element.shape[0]-1,element.shape[1]-1]] == [0, 1]:
        passeds[3] = False

  return passeds


def save_models(epoch_G,epoch_D,save,tmp_models_dir,models_dir):
  # select model
  G_files = os.listdir(tmp_models_dir+'/G/')
  for i in range(len(G_files)):
    G_file = G_files[i]
    if int(G_file.split('_')[1]) == epoch_G:
      G = load_model(tmp_models_dir+'/G/'+G_file)
      break

  D_files = os.listdir(tmp_models_dir+'/D/')
  for i in range(len(D_files)):
    D_file = D_files[i]
    if int(D_file.split('_')[1]) == epoch_D:
      D = load_model(tmp_models_dir+'/D/'+D_file, custom_objects={'custom_por_loss':porosity_loss(),'custom_val_loss':validity_loss(),'InstanceNormalization':InstanceNormalization()})
      break

  if save: 
      models_filename = os.listdir(models_dir)
      models_filename = ['_'.join(x.split('_')[1:]) for x in models_filename]
      if G_file not in models_filename:
        idx_model = len(models_filename)+1
        G.save(models_dir+'%04d_'%(idx_model)+G_file)
      else:
        # find idx of existing model
        idx_model = models_filename.index(G_file)+1
  else:
    idx_model = None
  return G, D, idx_model


def generate_geometries(test_size, rounds, idx_model, top, tol, desired_porosity, save, plot):
  idx = len(os.listdir(arrays_dir))+1
  for r in range(rounds):
    X_test = generate_input_G(input_G,test_size,sampling_method)
    geometries = G.predict(X_test,verbose = 0)
    size = geometries.shape[1]

    prepor_size = geometries.shape[0]
    
    if plot:
      fig,ax = plt.subplots(1,2);
      fig.set_size_inches((10,5));
      
      ax[0].set_title('Porosity Histogram')
      ax[0].set_ylabel('Frequency')
      porosities = 1-np.sum(geometries.round().reshape((test_size,int(size*size))),axis=-1)/int(size*size)
      sns.histplot(porosities,ax=ax[0],bins=32,stat="density");
    
    _, geometries = porosity_match(geometries, desired_porosity, tol)
    elements = []
    preval_size = geometries.shape[0]

    for i in range(len(geometries)):
      geom = geometries[i].reshape((size,size)).round()
      unit = create_unit(geom,size,simmetry)
      passed_connectivity,element = check_unit(unit, desired_porosity, tol)
      passed_singularity = check_singularity(element, simmetry)
      if passed_connectivity and all(passed_singularity):
        elements.append(element)

    geometries = np.array(elements)
    postval_size = geometries.shape[0]

    # Get scores
    scores = D.predict([geometries],verbose = 0)[0].ravel()

    if plot:
      ax[1].set_title('Score Histogram')
      ax[1].set_ylabel('Frequency')
      sns.histplot(scores,ax=ax[1],bins=32,stat="density");
      print('Avg porosity: %.2f. Avg score: %.2f Validity match: %.2f'%(porosities.mean(),scores.mean(),postval_size/preval_size))
      plt.show()

    top_idxs = np.argsort(-scores)[:top]

    for top_idx in top_idxs:
      elem = geometries[top_idx]
      unit = create_unit(elem.reshape((size,size)),size,simmetry)
      arrange = create_arrange(unit,3,3)
      
      if plot:
        print("Score: %.2f Porosity: %.2f"%(scores[top_idx],get_porosity(elem)))
        fig,ax = plt.subplots(1,3);
        fig.set_size_inches((15,5))
        
        ax[0].imshow(elem,cmap='Greys');
        ax[0].axis('off')
        
        ax[1].imshow(unit,cmap="Greys")
        ax[1].axis('off')

        ax[2].imshow(arrange,cmap="Greys")
        ax[2].axis('off')
        plt.show()

      if save:
        filename = arrays_dir+"%05d_model_%04d_porosity_%.4f.txt" % (idx, idx_model, 1.0-elem.ravel().sum()/(size*size))
        elem = elem.ravel()
        elem_ = np.zeros(elem.shape[0]+1)
        elem_[0] = int(np.sqrt(elem.shape[0]))
        elem_[1:] = elem[:]
        elem = elem_
        np.savetxt(filename, elem, delimiter='/n', fmt='%s')
        idx += 1

epoch_G = 95
epoch_D = 50
tol = 0.02
score = 'isotropy'
input_G = 128
simmetry = 'p4m'
sampling_method = 'normal'
top = 5
rounds = 20
test_size = 10000
desired_porosity=0.55
save = True
plot = not save

G,D,idx_model = save_models(epoch_G,epoch_D,save,tmp_models_dir,models_dir)
score_filename, geom_epoch_dirs, gif_filename, tmp_models_dir, models_dir, arrays_dir = get_filenames(dimension, simulation, simmetry, score)
generate_geometries(test_size, rounds, idx_model, top, tol, desired_porosity, save, plot)
