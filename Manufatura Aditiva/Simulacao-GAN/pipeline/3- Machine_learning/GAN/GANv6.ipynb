# %% [markdown]
# # Imports

# %%
import os
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.preprocessing import MinMaxScaler
from skimage import measure
import imageio
import  cv2
# %matplotlib inline

import tensorflow as tf
from tensorflow.keras import backend as K
from tensorflow.keras.models import Model,load_model
from tensorflow.keras.layers import Dense, Flatten, Conv1D, Conv2D, Input, Conv2DTranspose, Concatenate, MaxPool1D, Dropout, Reshape, Lambda, InputLayer, LeakyReLU, BatchNormalization, GaussianNoise
from keras_contrib.layers.normalization.instancenormalization import InstanceNormalization
from tensorflow.keras.optimizers import Adam 
from tensorflow.keras.losses import MeanSquaredError, kullback_leibler_divergence
from tensorflow.keras.metrics import BinaryCrossentropy
from tensorflow.keras.initializers import RandomNormal
from tensorflow.keras.constraints import Constraint
import warnings
import logging
warnings.simplefilter("ignore")
logging.getLogger("tensorflow").setLevel(logging.ERROR)

tf.autograph.set_verbosity(0)
os.environ['AUTOGRAPH_VERBOSITY'] = '0'
os.environ['TF_CPP_MIN_LOG_LEVEL'] = '0'

# %% [markdown]
# ## Test GPU

# %%
physical_devices = tf.config.list_physical_devices('GPU') 
print("GPUs available:",len(physical_devices))
# Out:
# GPUs available: 1

# %% [markdown]
# # Data preparation

# %%
def get_filenames(dimension, simulation, simmetry, score):
    if os.getcwd().split('\\')[2] == 'lucas':
        score_filename = 'E:/Lucas GAN/Dados/4- Mechanical_scores/%s/%sD/%s/%s.csv' %(simulation,dimension,simmetry,score)
        geom_epoch_dirs = 'E:/Lucas GAN/Dados/7- Perfomance_data/%sD/geom_epoch/%s/%s/' %(dimension,simmetry,score)
        gif_filename = 'E:/Lucas GAN/Dados/7- Perfomance_data/%sD/geom_epoch/%s/%s.gif' %(dimension,simmetry,score)
        tmp_models_dir = 'C:/Users/lucas/OneDrive/Documentos/GitHub/INT/Manufatura Aditiva/Simulacao-GAN/Pipeline/3- Machine_learning/GAN/tmp_models/GAN/'
        models_dir = 'D:/Lucas GAN/Dados/5- Models/cGAN/%sD/%s/%s/'%(dimension,simmetry,score)
        arrays_dir = 'E:/Lucas GAN/Dados/1- Arranged_geometries/GAN/%s/%s/' % (simmetry,score)
    else:
        score_filename = 'D:/Lucas GAN/Dados/4- Mechanical_scores/%s/%sD/%s/%s.csv' %(simulation,dimension,simmetry,score)
        geom_epoch_dirs = 'D:/Lucas GAN/Dados/7- Perfomance_data/%sD/geom_epoch/%s/%s/' %(dimension,simmetry,score)
        gif_filename = 'D:/Lucas GAN/Dados/7- Perfomance_data/%sD/geom_epoch/%s/%s.gif' %(dimension,simmetry,score)
        tmp_models_dir = 'C:/Users/lucas.barbosa/Documents/GitHub/INT/Manufatura Aditiva/Simulacao-GAN/Pipeline/3- Machine_learning/GAN/tmp_models/GAN/'
        models_dir = 'D:/Lucas GAN/Dados/5- Models/GAN/%sD/%s/%s/'%(dimension,simmetry,score)
        arrays_dir = 'D:/Lucas GAN/Dados/1- Arranged_geometries/GAN/%s/%s/' % (simmetry,score)


    return score_filename, geom_epoch_dirs, gif_filename, tmp_models_dir, models_dir, arrays_dir

def load_data(score_filename, cutoff, bins, soft=False, balance=False, plot=False):  
    def find_closest(arr, val):
       idx = np.abs(arr - val).argmin()
       return arr[idx]
    data = np.loadtxt(score_filename,delimiter=',')
    X = data[:,1:-1]
    size = int(np.sqrt(X.shape[1]))
    X = X.reshape((X.shape[0],size,size,1))

    y = data[:,-1]
    y = y.reshape((y.shape[0],1))
    y = y[np.argsort(y[:,0])]
    total_size = y.shape[0]

    if plot:
        sns.histplot(y, legend=True, bins=bins, color='b')
    
    cutoff = find_closest(bins,cutoff)
    idxs_good = np.where(y>cutoff)[0]
    y = y[idxs_good]
    X = X[idxs_good]
    min_bin = idxs_good.shape[0]

    if balance:
        bins_good = bins[np.where(bins>=cutoff)]
        for i in range(len(bins_good)-1):
            l,u = bins_good[i:i+2]
            idx_bin = np.where((y>=l) & (y<u))[0]
            y_bin = y[idx_bin]
            min_bin = min(min_bin,y_bin.shape[0])

        X_balanced = np.zeros((min_bin*(bins_good.shape[0]-1),X.shape[1],X.shape[2],X.shape[3]))
        y_balanced = np.zeros((min_bin*(bins_good.shape[0]-1),1))
        y_ = np.ones((min_bin*(bins_good.shape[0]-1),1))

        for i in range(len(bins_good)-1):
            l,u = bins_good[i:i+2]
            idx_bin = np.where((y>=l) & (y<u))[0]
            X_bin = X[idx_bin]
            y_bin = y[idx_bin]

            idx_bin = np.random.choice(y_bin.shape[0],min_bin)
            X_bin = X_bin[idx_bin]
            y_bin = y_bin[idx_bin]

            X_balanced[min_bin*i:min_bin*(i+1)] = X_bin
            y_balanced[min_bin*i:min_bin*(i+1)] = y_bin

        X = X_balanced
        y = y_

        if plot:
            sns.histplot(y_balanced, legend=True, bins=bins, color='r')

    if soft:
        y = np.random.choice(np.linspace(0.7,1.2,6)).round(1)*np.ones(y.shape)
    
    plt.legend(['raw','Balanced'])
    
    print(f"%.2f %% of data used."%(100*len(y)/total_size))
    
    return X, y, size

dimension = 2
simulation = '-r'
simulation = {'-m':'MATLAB','-r':'RTGA'}[simulation]
simmetry = 'p4m'
score = 'isotropy'
score_filename,_,_,_,_,_ = get_filenames(dimension, simulation, simmetry, score)

cutoff = 0.6
bins= np.linspace(0,1,41).round(3)
soft = False
plot = True
balance = True

X, y, size = load_data(score_filename, cutoff, bins, soft=soft, balance=balance, plot=plot)
# Out:
# Good = 17.70 %

# %% [markdown]
# # Models definition

# %% [markdown]
# ## Generator

# %%
def setup_G(input_G,output_G,size):
    size = int(size/2)
    in_G = Input(shape=(input_G,),name="G-Latent-Input")

    # foundation for 8x8 image
    n_nodes = input_G * size * size
    out_G = Dense(n_nodes,activation=LeakyReLU(alpha=0.2),name="G-FoundationLayer")(in_G)
    out_G = Reshape((size, size, 128),name="G-ReshapeLayer")(out_G)
    # upsample to 16x16
    out_G = Conv2DTranspose(128, (4,4), strides=(2,2), padding='same',activation=LeakyReLU(alpha=0.2),name="G-HiddenLayer1")(out_G)
    out_G = Conv2D(1, (size,size), activation='sigmoid', padding='same',name="G-Geometry-Output")(out_G)

    # model = Model(name='Generator',inputs=in_G,outputs=[out_G,out_porosity,out_validity])
    model = Model(name='Generator',inputs=in_G,outputs=[out_G])
    return model
G_test = setup_G(128,256,16)
G_test.summary()
tf.keras.utils.plot_model(G_test)
# Out:
# Model: "Generator"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  G-Latent-Input (InputLayer)  [(None, 128)]            0
#
#  G-FoundationLayer (Dense)   (None, 8192)              1056768
#
#  G-ReshapeLayer (Reshape)    (None, 8, 8, 128)         0
#
#  G-HiddenLayer1 (Conv2DTrans  (None, 16, 16, 128)      262272
#  pose)
#
#  G-Geometry-Output (Conv2D)  (None, 16, 16, 1)         8193
#
# =================================================================
# Total params: 1,327,233
# Trainable params: 1,327,233
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# ## Discriminator

# %%
def wasserstein_loss():
    def custom_loss(y_true, y_pred):
	    return K.mean(y_true * y_pred)
    return custom_loss

def porosity_loss():
    def custom_por_loss(y_true,y_pred):
        # size = y_pred.shape[1]*y_pred.shape[2]
        y_pred = K.round(y_pred)
        por_true = K.sum(K.sum(K.sum(y_true,axis=1),axis=1),axis=1)
        por_pred = K.sum(K.sum(K.sum(y_pred,axis=1),axis=1),axis=1)
        mse = tf.cast((por_true-por_pred)**2,tf.float32)
        return mse
        
    return custom_por_loss

def validity_loss():
    def custom_val_loss(y_true, y_pred):
        # @tf.function
        def connectivity_losss(element):
            size = element.shape[0]
            element = element.numpy().reshape((size,size))
            labels = measure.label(element,connectivity=1)
            return len(np.unique(labels))/(np.prod(element.shape)/2)

        def simmetry_loss_p4m(element):
            n,m,_ = element.shape
            score = 0
            idxs_row, idxs_col, _ = np.where(element == 1)
            idxs = list(zip(idxs_row,idxs_col))
            for i,j in idxs:
                if i+j<m and (n-j-1,m-i-1) in idxs:
                # if j >= i and (j,i) in idxs:
                    score += 1
            score /= ((n * m // 2) + n//2)
            return score

        y_pred = K.round(y_pred)
        con_loss = tf.map_fn(fn=connectivity_losss, elems=y_pred)
        if simmetry[1:] == '4m':
            sim_loss = tf.map_fn(fn=simmetry_loss_p4m, elems=y_pred)
            con_loss += sim_loss
        return con_loss

    return custom_val_loss
    
def setup_D(input_D,loss,lr,alpha_por,alpha_val,normalize=False):
    #define model
    in_D = Input(shape=input_D,name="D-Geometry-Input")

    out_D = GaussianNoise(0.1,name="D-NoiseLayer1")(in_D)
    out_D = Conv2D(64, (3,3), strides=(2, 2), padding='same',name="D-HiddenLayer1")(out_D)
    if normalize:
        out_D = InstanceNormalization(name="D-InstanceNormalization-Layer1")(out_D)
    out_D = LeakyReLU(alpha=0.2,name="D-Activation-Layer1")(out_D)

    out_D = GaussianNoise(0.1,name="D-NoiseLayer2")(out_D)
    out_D = Dropout(0.4,name="D-DropoutLayer1")(out_D)
    out_D = Conv2D(64, (3,3), strides=(2, 2), padding='same',name="D-HiddenLayer2")(out_D)
    if normalize:
        out_D = InstanceNormalization(name="D-InstanceNormalization-Layer2")(out_D)
    out_D = LeakyReLU(alpha=0.2,name="D-Activation-Layer2")(out_D)

    out_D = GaussianNoise(0.1,name="D-NoiseLayer3")(out_D)
    out_D = Dropout(0.4,name="D-DropoutLayer2")(out_D)
    out_D = Flatten(name="D-FlattenLayer")(out_D)
    out_D = Dense(1, activation='sigmoid',name="D-Classification-Output")(out_D)

    # porosity branch
    out_porosity = Lambda(lambda x: x,name='D-Porosity-Output')(in_D)

    # validity branch
    out_validity = Lambda(lambda x: x,name='D-Validity-Output')(in_D)

    opt = Adam(learning_rate=lr, beta_1=0.5)
    
    model = Model(
                name='Discriminator', \
                # inputs=[in_D,in_porosity,in_validity], \
                inputs=[in_D], \
                outputs=[out_D,out_porosity,out_validity])

    loss_func = {'bce':'binary_crossentropy','wl':wasserstein_loss,'kld':kullback_leibler_divergence}[loss]
    model.compile(
                loss=[loss_func,porosity_loss(),validity_loss()], \
                loss_weights=[1.0,0.0,0.0], \
                optimizer='adam', \
                metrics=['accuracy'], \
                run_eagerly=True)
    return model

D_test = setup_D((16,16,1),'bce',1e-4,0.01,0.01,True)
D_test.summary()
tf.keras.utils.plot_model(D_test)
# Out:
# Model: "Discriminator"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  D-Geometry-Input (InputLayer)  [(None, 16, 16, 1)]  0           []
#
#  D-NoiseLayer1 (GaussianNoise)  (None, 16, 16, 1)    0           ['D-Geometry-Input[0][0]']
#
#  D-HiddenLayer1 (Conv2D)        (None, 8, 8, 64)     640         ['D-NoiseLayer1[0][0]']
#
#  D-InstanceNormalization-Layer1  (None, 8, 8, 64)    2           ['D-HiddenLayer1[0][0]']
#   (InstanceNormalization)
#
#  D-Activation-Layer1 (LeakyReLU  (None, 8, 8, 64)    0           ['D-InstanceNormalization-Layer1[
#  )                                                               0][0]']
#
#  D-NoiseLayer2 (GaussianNoise)  (None, 8, 8, 64)     0           ['D-Activation-Layer1[0][0]']
#
#  D-DropoutLayer1 (Dropout)      (None, 8, 8, 64)     0           ['D-NoiseLayer2[0][0]']
#
#  D-HiddenLayer2 (Conv2D)        (None, 4, 4, 64)     36928       ['D-DropoutLayer1[0][0]']
#
#  D-InstanceNormalization-Layer2  (None, 4, 4, 64)    2           ['D-HiddenLayer2[0][0]']
#   (InstanceNormalization)
#
#  D-Activation-Layer2 (LeakyReLU  (None, 4, 4, 64)    0           ['D-InstanceNormalization-Layer2[
#  )                                                               0][0]']
#
#  D-NoiseLayer3 (GaussianNoise)  (None, 4, 4, 64)     0           ['D-Activation-Layer2[0][0]']
#
#  D-DropoutLayer2 (Dropout)      (None, 4, 4, 64)     0           ['D-NoiseLayer3[0][0]']
#
#  D-FlattenLayer (Flatten)       (None, 1024)         0           ['D-DropoutLayer2[0][0]']
#
#  D-Classification-Output (Dense  (None, 1)           1025        ['D-FlattenLayer[0][0]']
#  )
#
#  D-Porosity-Output (Lambda)     (None, 16, 16, 1)    0           ['D-Geometry-Input[0][0]']
#
#  D-Validity-Output (Lambda)     (None, 16, 16, 1)    0           ['D-Geometry-Input[0][0]']
#
# ==================================================================================================
# Total params: 38,597
# Trainable params: 38,597
# Non-trainable params: 0
# __________________________________________________________________________________________________

# %% [markdown]
# ## Setup GAN

# %%
def setup_GAN(G_model,D_model,loss,alpha_por,alpha_val,lr,size):
    D_model.trainable = False
    in_G = G_model.input
    out_GAN = D_model(G_model(in_G))
    
    opt = Adam(learning_rate=lr, beta_1=0.5)
    
    model = Model(name='GAN',inputs=in_G,outputs=out_GAN)
    loss_func = {'bce':'binary_crossentropy','wl':wasserstein_loss,'kld':kullback_leibler_divergence}[loss]
    model.compile(
                loss=[loss_func,porosity_loss(),validity_loss()], \
                loss_weights=[1.0,alpha_por,alpha_val], \
                optimizer='adam', \
                metrics=['accuracy'], \
                run_eagerly=True)
    return model

setup_GAN(setup_G(128,256,16),setup_D((16,16,1),'bce',1e-4,0.01,0.01),'bce',0.01,0.01,1e-4,16).summary()
# Out:
# Model: "GAN"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  G-Latent-Input (InputLayer)  [(None, 128)]            0
#
#  Generator (Functional)      (None, 16, 16, 1)         1327233
#
#  Discriminator (Functional)  [(None, 1),               38593
#                               (None, 16, 16, 1),
#                               (None, 16, 16, 1)]
#
# =================================================================
# Total params: 1,365,826
# Trainable params: 1,327,233
# Non-trainable params: 38,593
# _________________________________________________________________

# %% [markdown]
# # Aux functions

# %% [markdown]
# ## For geometry manipulation

# %%
def create_unit(element,size,simmetry):
  if simmetry[1:2] == '4':
    unit_size = 2*size
    # fold_size = np.random.choice(4,1)[0]
    unit = np.ones((2*size,2*size))*(-1)
    h,w = element.shape
    for i in range(h):
      for j in range(w):
        el = element[i,j]
        
        j_ = [j,w-1-i,2*h-1-j,i+w]
        i_ = [i+w,j,w-1-i,2*h-1-j]
        # (1,7)->(7,14)->(14,8)->(8,1)
        for (k,l) in list(zip(i_,j_)):
          unit[k,l]  = el
    return unit

def create_arrange(unit,rows,cols):
  size = unit.shape[0]
  arrange = np.zeros((rows*size,cols*size))
  for i in range(unit.shape[0]):
    for j in range(unit.shape[1]):
      for row in range(rows):
        for col in range(cols):
          arrange[j+row*size,i+col*size] = unit[j,i]
  
  return arrange

def get_porosity(geom):
    voids = np.where(geom == 0.0)[0].shape[0]

    return voids/(geom.shape[0]*geom.shape[1])

# %% [markdown]
# ## For GAN

# %%
def generate_fake_samples(G_model, input_G, n_samples, method):
    # generate points in latent space
    X_input = generate_input_G(input_G, n_samples,method)
    # predict outputs
    X = G_model.predict(X_input,verbose = 0)
    # create 'fake' class labels (0)
    y = np.zeros((n_samples, 1))
    return X,y

def generate_input_G(input_G, n_samples, method):

    if method == 'normal':
        # generate points in the latent space
        X_input = np.random.randn(input_G * n_samples)
        # reshape into a batch of inputs for the network
        X_input = X_input.reshape(n_samples, input_G)
    if method == 'uniform':
        X_input = np.random.uniform(n_samples,input_G)
    if method == 'spherical':
        X_input = np.random.randn(input_G * n_samples)
        # reshape into a batch of inputs for the network
        X_input = X_input.reshape(n_samples, input_G)
        X_input /= np.linalg.norm(X_input, axis=0)/3.0
    return X_input

def generate_real_samples(dataset, y, n_samples):
    # choose random instances
    idx = np.random.randint(0, dataset.shape[0], n_samples)
    # retrieve selected images
    X = dataset[idx]
    # generate 'real' class labels (1)
    y = y[idx]
    return X, y

def summarize_performance(epoch,porosity,G_model, D_model, dataset, y, input_G, sampling_method, n_samples=100):
    # prepare real samples
    X_real, y_real = generate_real_samples(dataset, y, n_samples)
    # evaluate discriminator on real examples
    _,_,_,_,acc_real,_,_ = D_model.evaluate(x=[X_real], y=[y_real,porosity*np.ones(X_real.shape),np.zeros(X_real.shape)], verbose=0)
    # prepare fake examples
    X_fake, y_fake = generate_fake_samples(G_model, input_G, n_samples, sampling_method)
    # evaluate discriminator on fake examples
    _,_,_,_,acc_fake,_,_ = D_model.evaluate(x=[X_fake], y=[y_fake,porosity*np.ones(X_fake.shape),np.zeros(X_fake.shape)], verbose=0)
    # summarize discriminator performance
    return  acc_real,acc_fake

# Filter per porosity
def porosity_match(geoms,porosity,tol):
    geoms_ = []
    passed = 0
    for i in range(geoms.shape[0]):
        g =geoms[i,:,:,0]
        size = g.shape[0]
        g = g.reshape((size*size,))
        p = 1 - np.sum(g)/(size*size)
        if p >= porosity-tol and p <= porosity+tol:
            geoms_.append(g.reshape((size,size)))
            passed += 1
    return passed/len(geoms),np.array(geoms_).reshape((passed,size,size,1))


def geometry_variance(geoms):
    n = len(geoms)
    score = 0
    for i in range(n-1):
        for j in range(i+1,n):
            score += np.sum(np.abs(geoms[i] - geoms[j]))
    return score/(n*(n-1)*np.prod(geoms[0].shape))

# %% [markdown]
# # Training GAN

# %%
def train_GAN(X, y, G_model, D_model, GAN_model, input_G, porosity, tol_porosity, batch_size, num_epochs, sampling_method, tmp_models_dir, geom_epoch_dirs, seed_geom_gif, tol_fail, alpha_por, alpha_val, vstack=True, swap=True, save=True, plot=False, verbose_loss=False, verbose_acc=False):
    def train_D(X,y,half_batch):
        if vstack:
            X_real,y_real = generate_real_samples(X,y,half_batch)
            X_fake,y_fake = generate_fake_samples(G_model,input_G,half_batch,sampling_method)            

            X, y = np.vstack((X_real, X_fake)), np.vstack((y_real, y_fake))
            
            if verbose_loss:
                D_loss = D_model.train_on_batch(x=[X], y=[y,porosity*np.ones(X.shape),0*np.ones(X.shape)],return_dict=True)
                D_loss = D_loss['loss']
            else:
                D_loss = D_model.train_on_batch(x=[X], y=[y,porosity*np.ones(X.shape),0*np.ones(X.shape)])
                D_loss = D_loss[0]

        else:
            X_real,y_real = generate_real_samples(X,y,half_batch)
            X_fake,y_fake = generate_fake_samples(G_model,input_G,half_batch,sampling_method)            

            if verbose_loss:
                D_loss_real = D_model.train_on_batch(x=[X_real], y=[y_real,porosity*np.ones(X_real.shape),0*np.ones(X_real.shape)],return_dict=True)
                D_loss_real = D_loss_real['loss']
                D_loss_fake = D_model.train_on_batch(x=[X_fake], y=[y_fake,porosity*np.ones(X_fake.shape),0*np.ones(X_fake.shape)],return_dict=True)
                D_loss_fake = D_loss_fake['loss']
            else:
                D_loss_real = D_model.train_on_batch(x=[X_real], y=[y_real,porosity*np.ones(X_real.shape),0*np.ones(X_real.shape)])
                D_loss_real = D_loss_real[0]
                D_loss_fake = D_model.train_on_batch(x=[X_fake], y=[y_fake,porosity*np.ones(X_fake.shape),0*np.ones(X_fake.shape)])
                D_loss_fake = D_loss_fake[0]

            D_loss = (D_loss_real+D_loss_fake)/2
            

        return D_loss

    def swap_weights(tmp_models_dir, epoch):
        D_files = os.listdir(tmp_models_dir+'/D/')
        idx_epoch = epoch//5 - 1
        idxs_swap = idx_epoch - 3
        D_file = np.random.choice(D_files[idxs_swap:idx_epoch],1)[0]
        D_model_swap = load_model(tmp_models_dir+'/D/'+D_file, custom_objects={'custom_por_loss':porosity_loss(),'custom_val_loss':validity_loss(),'InstanceNormalization':InstanceNormalization()})
        return (D_files.index(D_file)+1)*5, D_model_swap.get_weights()

    def train_G(X_shape,alpha_por,alpha_val):
        X_GAN = generate_input_G(input_G, batch_size, sampling_method)
        y_GAN = np.ones((batch_size, 1))

        if verbose_loss:
            G_loss_list = GAN_model.train_on_batch(x=X_GAN, y=[y_GAN,porosity*np.ones(X_shape),0*np.ones(X_shape)],return_dict=True)
            idxs = list(G_loss_list.keys())
        else:
            G_loss_list = GAN_model.train_on_batch(x=X_GAN, y=[y_GAN,porosity*np.ones(X_shape),0*np.ones(X_shape)])
            idxs = [0,1,2,3]

        G_total_loss = G_loss_list[idxs[0]]
        G_loss = G_loss_list[idxs[1]]
        G_por_loss = alpha_por*G_loss_list[idxs[2]]
        G_val_loss = alpha_val*G_loss_list[idxs[3]]

        return G_total_loss,G_loss,G_por_loss,G_val_loss

    def clean_tmp_models(tmp_models_dir):
        for file in os.listdir(tmp_models_dir+'G/'):
            os.remove(tmp_models_dir+'G/'+file)

        for file in os.listdir(tmp_models_dir+'D/'):
            os.remove(tmp_models_dir+'D/'+file)

        for geom_file in os.listdir(geom_epoch_dirs):
            os.remove(geom_epoch_dirs+geom_file)

    # remove previous tmp models files
    if save:
        clean_tmp_models(tmp_models_dir)
    
    weights_shape = [x.shape for x in D_model.get_weights()]
    batch_per_epoch = int(X.shape[0] /batch_size)
    half_batch = int(batch_size/2)
    
    G_losses = []
    G_por_losses = []
    G_val_losses = []
    D_losses = []

    accs_real = []
    accs_fake = []
    pors_match = []
    variances = []
    
    fig,ax = plt.subplots(1,3);
    fig.set_size_inches((24,8))

    epoch_count = 1
    while epoch_count <= num_epochs:
        G_losses_epoch = []
        G_por_losses_epoch = []
        G_val_losses_epoch = []
        D_losses_epoch = []
        batch_count = 0
        while batch_count < batch_per_epoch:
            # train D
            D_loss = train_D(X,y,half_batch)

            # check failure mode
            D_losses_epoch.append(D_loss)

            # train G
            G_total_loss,G_loss,G_por_loss,G_val_loss = train_G((batch_size,X.shape[1],X.shape[2],X.shape[3]),alpha_por,alpha_val)
            G_losses_epoch.append(G_loss)
            G_por_losses_epoch.append(G_por_loss)
            G_val_losses_epoch.append(G_val_loss)
            print(G_por_loss,G_val_loss)
            
            if verbose_loss: 
                print('>%d, %d/%d, D_loss=%.3f, G_loss=%.3f' % (epoch_count, batch_count+1, batch_per_epoch,  D_loss, G_total_loss))
            
            batch_count += 1
        
        epoch_count +=1 
            
        G_losses.append(np.array(G_losses_epoch).mean())
        G_por_losses.append(np.array(G_por_losses_epoch).mean())
        G_val_losses.append(np.array(G_val_losses_epoch).mean())
        D_losses.append(np.array(D_losses_epoch).mean())

        # check failure modes
        if (D_losses[-1] <= tol_fail or np.std(D_losses[-5:])) <= tol_fail and epoch_count > 20:
            epoch, weights = swap_weights(tmp_models_dir, epoch_count)
            D_model.set_weights(weights)
            print('Failure Mode: swapping to D model of epoch %d'%epoch)
            
        if epoch_count % 5 == 0:
            # evaluate model
            acc_real,acc_fake = summarize_performance(epoch_count,porosity,G_model,D_model,X,y,input_G,sampling_method)
            accs_real.append(acc_real)
            accs_fake.append(acc_fake)

            X_test = generate_input_G(input_G,1000,sampling_method)
            geoms = G_model.predict(X_test, verbose=0)
            geoms = np.array(geoms)
            por_match,_ = porosity_match(geoms, porosity, tol_porosity)
            pors_match.append(por_match)

            geometry_var = geometry_variance(geoms)
            variances.append(geometry_var)

            # save model
            if save:
                G_model.save(tmp_models_dir+'/G/epoch_%03d_por_%.2f_var_%.2f.h5'%(epoch_count, por_match, geometry_var))
                D_model.save(tmp_models_dir+'/D/epoch_%03d_real_%.2f_fake_%.2f.h5'%(epoch_count, acc_real, acc_fake))
                
            if verbose_acc:
                os.system('cls')
                print('>Epoch: %i Porosity match: %.0f%% Var: %.2f real: %.0f%% fake: %.0f%%' % (epoch_count,  por_match*100, geometry_var, acc_real*100, acc_fake*100))

            # save geometry
            geom_gif_filename = geom_epoch_dirs + 'epoch_%03d.png'%(epoch_count)
            elem_gif = G_model.predict(seed_geom_gif, verbose=0)
            size = elem_gif.shape[1]
            elem_gif = elem_gif.reshape((size,size))
            ax[0].imshow(elem_gif,cmap='Greys');
            ax[0].axis('off')

            unit_gif = create_unit(elem_gif,size,'p4') 
            ax[1].imshow(unit_gif,cmap='Greys');
            ax[1].axis('off')

            arrange_gif = create_arrange(unit_gif,3,3)
            ax[2].imshow(arrange_gif,cmap='Greys');
            ax[2].axis('off')
            plt.savefig(geom_gif_filename, bbox_inches='tight')
    
    G_losses = np.array(G_losses)
    G_por_losses = np.array(G_por_losses)
    G_val_losses = np.array(G_val_losses)
    D_losses = np.array(D_losses)

    if plot:
        plt.figure(figsize=((10,8)))
        plt.plot(list(range(1,num_epochs+1)),D_losses,label='D Loss')
        plt.title('Loss')
        plt.ylabel('Loss')
        plt.xlabel('Epoch')
        plt.plot(list(range(1,num_epochs+1)),G_losses,label='G Loss')
        plt.plot(list(range(1,num_epochs+1)),G_por_losses,label='Porosity loss')
        plt.plot(list(range(1,num_epochs+1)),G_val_losses,label='Validity loss')
        plt.legend()
        plt.show()

        fig, ax = plt.subplots(3)
        fig.tight_layout(pad=0.75)
        fig.set_size_inches((10,8))
        ax[0].plot(list(range(1,num_epochs+1,5)),accs_fake,label='Accuracy fake')
        ax[0].set_xlabel('Epoch')
        ax[0].plot(list(range(1,num_epochs+1,5)),accs_real,label='Accuracy real')
        ax[0].legend()

        ax[1].plot(list(range(1,num_epochs+1,5)),pors_match)
        ax[1].set_title('Porosity match')
        ax[1].set_xlabel('Epoch')
        
        ax[2].plot(list(range(1,num_epochs+1,5)),variances)
        ax[2].set_title('Geometries variance')
        ax[2].set_xlabel('Epoch')
        ax[1].legend()
        plt.show()

# %%
# data origin parameters
dimension = 2
simulation = '-r'
simulation = {'-m':'MATLAB','-r':'RTGA'}[simulation]
simmetry = 'p4m'
score = 'isotropy'

# data processing parameters
score_filename, geom_epoch_dirs, gif_filename, tmp_models_dir, models_dir, arrays_dir = get_filenames(dimension, simulation, simmetry, score)
cutoff = 0.8
bins= np.linspace(0,1,41).round(3)
soft = False
plot = True
balance = True
X, y, size = load_data(score_filename, cutoff, bins, soft=soft, balance=balance, plot = plot)

# GAN dimensions
input_G = 128
output_G = input_D = X.shape[1:]
output_D = 1

# training parameters
num_epochs = 100
batch_size = 64
sampling_method = 'normal'
loss = 'bce' 
lr = 1e-4 
alpha_por = 1e-3 #2e-4
alpha_val = 1e-1
vstack=False
swap=True

# style loss parameters
porosity = 0.55
tol_porosity = 0.02
tol_fail = 1e-2

# setup models
G = setup_G(input_G,output_G,size)
normalize=True
D = setup_D(input_D,loss,lr,alpha_por,alpha_val,normalize)
GAN = setup_GAN(G,D,loss,alpha_por,alpha_val,lr,size)

# metrics paramaters
plot=True
save=True
verbose_loss=True
verbose_acc=True

seed_geom_gif = np.random.randn(input_G).reshape(1, input_G)
train_GAN(X, y, G, D, GAN, input_G, porosity, 
    tol_porosity, batch_size, num_epochs, sampling_method, 
    tmp_models_dir, geom_epoch_dirs, seed_geom_gif, 
    tol_fail, alpha_por, alpha_val, 
    vstack=vstack, swap=swap, 
    save=save, plot=plot, verbose_loss=verbose_loss,verbose_acc=verbose_acc)
# Out:
# Good = 8.85 %
# 0.8094503784179687 0.05757554173469544
# >1, 1/13, D_loss=1.506, G_loss=1.231
# 0.26554058837890626 0.14473087787628175
# >1, 2/13, D_loss=1.025, G_loss=1.195
# 0.16761233520507812 0.15344884395599367
# >1, 3/13, D_loss=0.688, G_loss=1.631
# 0.16384046936035157 0.15372242927551272
# >1, 4/13, D_loss=0.704, G_loss=1.987
# 0.16384046936035157 0.15372242927551272
# >1, 5/13, D_loss=0.654, G_loss=2.296
# 0.16384046936035157 0.15372242927551272
# >1, 6/13, D_loss=0.731, G_loss=2.457
# 0.16384046936035157 0.15372242927551272
# >1, 7/13, D_loss=0.494, G_loss=2.745
# 0.16384046936035157 0.15372242927551272
# >1, 8/13, D_loss=0.482, G_loss=2.787
# 0.16384046936035157 0.15372242927551272
# >1, 9/13, D_loss=0.407, G_loss=2.873
# 0.16384046936035157 0.15372242927551272
# >1, 10/13, D_loss=0.254, G_loss=2.875
# 0.16384046936035157 0.15372242927551272
# >1, 11/13, D_loss=0.179, G_loss=3.062
# 0.16384046936035157 0.15372242927551272
# >1, 12/13, D_loss=0.142, G_loss=3.305
# 0.16384046936035157 0.15372242927551272
# >1, 13/13, D_loss=0.122, G_loss=3.460
# 0.16384046936035157 0.15372242927551272
# >2, 1/13, D_loss=0.075, G_loss=3.663
# 0.16384046936035157 0.15372242927551272
# >2, 2/13, D_loss=0.058, G_loss=3.942
# 0.16384046936035157 0.15372242927551272
# >2, 3/13, D_loss=0.022, G_loss=4.218
# 0.16384046936035157 0.15372242927551272
# >2, 4/13, D_loss=0.020, G_loss=4.548
# 0.16384046936035157 0.15372242927551272
# >2, 5/13, D_loss=0.012, G_loss=5.030
# 0.16384046936035157 0.15372242927551272
# >2, 6/13, D_loss=0.011, G_loss=5.290
# 0.16384046936035157 0.15372242927551272
# >2, 7/13, D_loss=0.007, G_loss=5.554
# 0.16384046936035157 0.15372242927551272
# >2, 8/13, D_loss=0.005, G_loss=5.779
# 0.16384046936035157 0.15372242927551272
# >2, 9/13, D_loss=0.004, G_loss=5.860
# 0.16384046936035157 0.15372242927551272
# >2, 10/13, D_loss=0.004, G_loss=6.082
# 0.16384046936035157 0.15372242927551272
# >2, 11/13, D_loss=0.004, G_loss=6.474
# 0.16384046936035157 0.15372242927551272
# >2, 12/13, D_loss=0.003, G_loss=6.546
# 0.16345608520507812 0.1537102222442627
# >2, 13/13, D_loss=0.002, G_loss=6.580
# 0.16345608520507812 0.1537102222442627
# >3, 1/13, D_loss=0.002, G_loss=6.728
# 0.16201234436035156 0.1536369800567627
# >3, 2/13, D_loss=0.002, G_loss=7.140
# 0.15778421020507813 0.1535027027130127
# >3, 3/13, D_loss=0.002, G_loss=6.963
# 0.1411623077392578 0.1530022144317627
# >3, 4/13, D_loss=0.002, G_loss=6.852
# 0.1337060546875 0.1525261402130127
# >3, 5/13, D_loss=0.001, G_loss=7.152
# 0.10926225280761719 0.1507194995880127
# >3, 6/13, D_loss=0.002, G_loss=6.918
# 0.07998094177246094 0.1480583667755127
# >3, 7/13, D_loss=0.002, G_loss=7.092
# 0.0373776969909668 0.14242876768112184
# >3, 8/13, D_loss=0.001, G_loss=6.552
# 0.02069617462158203 0.1305556297302246
# >3, 9/13, D_loss=0.002, G_loss=6.359
# 0.35759558105468753 0.10322337150573731
# >3, 10/13, D_loss=0.006, G_loss=6.025
# 1.8629353027343751 0.06536722183227539
# >3, 11/13, D_loss=0.015, G_loss=6.496
# 2.60982568359375 0.05447064638137818
# >3, 12/13, D_loss=0.030, G_loss=6.981
# 2.4806726074218752 0.053656363487243654
# >3, 13/13, D_loss=0.041, G_loss=7.168
# 2.1134228515625 0.05098158717155457
# >4, 1/13, D_loss=0.008, G_loss=7.492
# 0.55981103515625 0.03624052405357361
# >4, 2/13, D_loss=0.024, G_loss=5.592
# 0.06223041915893555 0.03029139041900635
# >4, 3/13, D_loss=0.115, G_loss=4.105
# 0.038927616119384764 0.030888098478317264
# >4, 4/13, D_loss=0.019, G_loss=4.673
# 0.07773713684082031 0.03224236071109772
# >4, 5/13, D_loss=0.046, G_loss=6.278
# 0.08388714599609375 0.033132755756378175
# >4, 6/13, D_loss=0.016, G_loss=6.766
# 0.11220912170410156 0.03286923170089722
# >4, 7/13, D_loss=0.056, G_loss=7.993
# 0.11632160949707032 0.03379265069961548
# >4, 8/13, D_loss=0.055, G_loss=8.058
# 0.11718099212646485 0.03374741673469544
# >4, 9/13, D_loss=0.154, G_loss=8.610
# 0.10804034423828125 0.03396211564540863
# >4, 10/13, D_loss=0.127, G_loss=8.092
# 0.09624345397949219 0.03393913507461548
# >4, 11/13, D_loss=0.149, G_loss=8.006
# 0.10234033966064453 0.03390467166900635
# >4, 12/13, D_loss=0.162, G_loss=8.326
# 0.09941532897949219 0.03404900133609772
# >4, 13/13, D_loss=0.173, G_loss=8.088
# >Epoch: 5 Porosity match: 0% Var: 0.10 real: 100% fake: 98%
# 0.09273092651367187 0.034428137540817264
# >5, 1/13, D_loss=0.107, G_loss=7.864
# 0.10724346923828125 0.03401022553443909
# >5, 2/13, D_loss=0.066, G_loss=8.200
# 0.09855282592773437 0.034320425987243657
# >5, 3/13, D_loss=0.057, G_loss=7.954
# 0.08956529235839844 0.034695973992347716
# >5, 4/13, D_loss=0.126, G_loss=8.023
# 0.08512777709960938 0.034484148025512695
# >5, 5/13, D_loss=0.060, G_loss=7.168
# 0.08181528472900391 0.03473905920982361
# >5, 6/13, D_loss=0.069, G_loss=7.402
# 0.09216217041015626 0.03459544479846954
# >5, 7/13, D_loss=0.050, G_loss=7.867
# 0.06716831970214844 0.0352294921875
# >5, 8/13, D_loss=0.189, G_loss=7.065
# 0.06328710174560546 0.03530704379081726
# >5, 9/13, D_loss=0.107, G_loss=6.992
# 0.03786202239990234 0.03590518832206726
# >5, 10/13, D_loss=0.148, G_loss=6.275
# 0.06672460937500001 0.03499755859375
# >5, 11/13, D_loss=0.176, G_loss=6.360
# 0.06748394775390625 0.03558134138584137
# >5, 12/13, D_loss=0.184, G_loss=6.415
# 0.04465570068359375 0.036566519737243654
# >5, 13/13, D_loss=0.058, G_loss=5.760
# 0.04689009475708008 0.036226880550384526
# >6, 1/13, D_loss=0.077, G_loss=5.636
# 0.04237442016601563 0.03654426336288452
# >6, 2/13, D_loss=0.152, G_loss=4.823
# 0.05177439498901367 0.03695786595344543
# >6, 3/13, D_loss=0.102, G_loss=4.824
# 0.06855552673339844 0.03815559148788453
# >6, 4/13, D_loss=0.165, G_loss=4.605
# 0.09572410583496094 0.04003475308418274
# >6, 5/13, D_loss=0.157, G_loss=3.471
# 0.21591458129882812 0.04306856095790863
# >6, 6/13, D_loss=0.180, G_loss=4.019
# 0.45922366333007814 0.047396311163902284
# >6, 7/13, D_loss=0.135, G_loss=4.244
# 1.26627001953125 0.05638068914413452
# >6, 8/13, D_loss=0.220, G_loss=4.542
# 1.558697998046875 0.059754133224487305
# >6, 9/13, D_loss=0.177, G_loss=5.288
# 1.6138105468750001 0.06210004091262818
# >6, 10/13, D_loss=0.174, G_loss=6.033
# 1.4944387207031251 0.06043055057525635
# >6, 11/13, D_loss=0.107, G_loss=5.851
# 1.6119573974609376 0.06581743955612183
# >6, 12/13, D_loss=0.103, G_loss=5.961
# 1.0465670166015626 0.06943789720535279
# >6, 13/13, D_loss=0.072, G_loss=4.503
# 0.82209521484375 0.07556942701339722
# >7, 1/13, D_loss=0.086, G_loss=4.568
# 0.44201434326171873 0.0736809253692627
# >7, 2/13, D_loss=0.056, G_loss=4.091
# 0.21276455688476564 0.08509951829910278
# >7, 3/13, D_loss=0.051, G_loss=4.735
# 0.14601475524902344 0.09689654111862184
# >7, 4/13, D_loss=0.139, G_loss=4.184
# 0.06437124633789063 0.1051262378692627
# >7, 5/13, D_loss=0.062, G_loss=4.240
# 0.12385598754882812 0.1241993546485901
# >7, 6/13, D_loss=0.175, G_loss=5.003
# 0.19550296020507812 0.12549833059310914
# >7, 7/13, D_loss=0.106, G_loss=5.705
# 0.28792495727539064 0.12493034601211549
# >7, 8/13, D_loss=0.160, G_loss=5.647
# 0.3980063171386719 0.1267082691192627
# >7, 9/13, D_loss=0.052, G_loss=5.543
# 0.621603271484375 0.12198702096939087
# >7, 10/13, D_loss=0.082, G_loss=5.226
# 0.6518501586914063 0.12853069305419923
# >7, 11/13, D_loss=0.219, G_loss=5.077
# 1.4276318359375 0.11647158861160278
# >7, 12/13, D_loss=0.270, G_loss=5.753
# 1.742909912109375 0.11154497861862184
# >7, 13/13, D_loss=0.177, G_loss=6.327
# 2.26478515625 0.10949994325637818
# >8, 1/13, D_loss=0.092, G_loss=7.987
# 3.210676025390625 0.10452163219451904
# >8, 2/13, D_loss=0.576, G_loss=8.289
# 3.888873291015625 0.10145623683929444
# >8, 3/13, D_loss=1.643, G_loss=8.135
# 4.11303271484375 0.09526008367538452
# >8, 4/13, D_loss=1.655, G_loss=7.595
# 3.7170322265625 0.1003769874572754
# >8, 5/13, D_loss=1.783, G_loss=7.765
# 5.67840185546875 0.08748348355293274
# >8, 6/13, D_loss=1.065, G_loss=8.999
# 4.02375439453125 0.09764045476913452
# >8, 7/13, D_loss=0.991, G_loss=8.012
# 4.7494921875000005 0.0941305696964264
# >8, 8/13, D_loss=0.571, G_loss=8.617
# 5.492189453125 0.08445470333099366
# >8, 9/13, D_loss=0.615, G_loss=8.943
# 5.742798828125 0.08717830777168274
# >8, 10/13, D_loss=0.356, G_loss=9.406
# 5.7560800781250006 0.0843433976173401
# >8, 11/13, D_loss=0.186, G_loss=9.659
# 5.3791611328125 0.08429601192474366
# >8, 12/13, D_loss=0.209, G_loss=9.382
# 6.587873046875 0.07738539576530457
# >8, 13/13, D_loss=0.113, G_loss=10.493
# 7.3111552734375005 0.07047765254974366
# >9, 1/13, D_loss=0.127, G_loss=10.846
# 4.9912480468750005 0.09097254276275635
# >9, 2/13, D_loss=0.092, G_loss=8.400
# 4.14726953125 0.09888485074043274
# >9, 3/13, D_loss=0.096, G_loss=7.678
# 5.7080888671875005 0.08359590768814087
# >9, 4/13, D_loss=0.063, G_loss=9.517
# 4.5000576171875 0.09118006229400635
# >9, 5/13, D_loss=0.102, G_loss=8.914
# 5.952736328125 0.08410357236862183
# >9, 6/13, D_loss=0.065, G_loss=10.517
# 5.7514453125000005 0.08074951171875
# >9, 7/13, D_loss=0.033, G_loss=10.900
# 6.54105859375 0.07696245908737183
# >9, 8/13, D_loss=0.052, G_loss=12.081
# 5.8246611328125 0.08244628906250001
# >9, 9/13, D_loss=0.043, G_loss=11.545
# 7.9176328125 0.06804988980293274
# >9, 10/13, D_loss=0.015, G_loss=13.506
# 7.3992490234375 0.07114401459693909
# >9, 11/13, D_loss=0.023, G_loss=13.077
# 5.894392578125 0.08205422163009644
# >9, 12/13, D_loss=0.018, G_loss=11.765
# 7.2336801757812506 0.07137235403060914
# >9, 13/13, D_loss=0.027, G_loss=12.904
# >Epoch: 10 Porosity match: 9% Var: 0.12 real: 100% fake: 100%
# 6.6823740234375 0.07789378762245179
# >10, 1/13, D_loss=0.012, G_loss=12.995
# 6.2539394531250005 0.07786003351211548
# >10, 2/13, D_loss=0.011, G_loss=12.783
# 6.1928828125 0.08252742886543274
# >10, 3/13, D_loss=0.012, G_loss=12.382
# 6.21058642578125 0.08050895929336549
# >10, 4/13, D_loss=0.012, G_loss=12.349
# 7.3050048828125 0.07472569942474365
# >10, 5/13, D_loss=0.012, G_loss=13.757
# 5.5295175781250006 0.08068704009056092
# >10, 6/13, D_loss=0.005, G_loss=11.448
# 6.8952236328125 0.07450597286224366
# >10, 7/13, D_loss=0.007, G_loss=13.058
# 6.52227734375 0.07371467351913452
# >10, 8/13, D_loss=0.005, G_loss=12.983
# 7.2402900390625 0.07143626213073731
# >10, 9/13, D_loss=0.008, G_loss=13.430
# 6.4003798828125005 0.07506390810012818
# >10, 10/13, D_loss=0.006, G_loss=12.615
# 6.0459765625 0.07839858531951904
# >10, 11/13, D_loss=0.013, G_loss=12.543
# 6.6870795898437505 0.07752901315689087
# >10, 12/13, D_loss=0.005, G_loss=13.382
# 7.55602734375 0.06927562355995179
# >10, 13/13, D_loss=0.009, G_loss=14.194
# 6.738001953125 0.07235394716262818
# >11, 1/13, D_loss=0.005, G_loss=13.569
# 7.902705078125 0.06592587232589722
# >11, 2/13, D_loss=0.004, G_loss=14.863
# 6.263876953125 0.07603329420089722
# >11, 3/13, D_loss=0.005, G_loss=13.014
# 7.98600244140625 0.06434397697448731
# >11, 4/13, D_loss=0.007, G_loss=14.634
# 6.48611767578125 0.07499784231185913
# >11, 5/13, D_loss=0.007, G_loss=13.119
# 6.1673300781250004 0.07647274136543275
# >11, 6/13, D_loss=0.003, G_loss=13.267
# 6.15001171875 0.0734971046447754
# >11, 7/13, D_loss=0.005, G_loss=13.167
# 6.234726562500001 0.07770278453826905
# >11, 8/13, D_loss=0.005, G_loss=13.396
# 6.7643642578125 0.07343246936798097
# >11, 9/13, D_loss=0.003, G_loss=13.702
# 7.8910678710937505 0.06424057483673096
# >11, 10/13, D_loss=0.006, G_loss=14.553
# 5.77064208984375 0.07835909128189088
# >11, 11/13, D_loss=0.003, G_loss=12.958
# 5.9024892578125 0.07621783018112183
# >11, 12/13, D_loss=0.004, G_loss=13.132
# 6.195830078125 0.07463594675064088
# >11, 13/13, D_loss=0.004, G_loss=13.227
# 5.405236328125 0.07772575616836548
# >12, 1/13, D_loss=0.008, G_loss=11.969
# 7.14371484375 0.05956528782844544
# >12, 2/13, D_loss=0.013, G_loss=13.951
# 6.1395673828125 0.0601311206817627
# >12, 3/13, D_loss=0.011, G_loss=11.922
# 4.06822021484375 0.06381189823150635
# >12, 4/13, D_loss=0.030, G_loss=8.998
# 5.2472949218750005 0.047221106290817265
# >12, 5/13, D_loss=0.194, G_loss=9.903
# 4.92988818359375 0.04597957730293274
# >12, 6/13, D_loss=0.237, G_loss=9.793
# 5.5693095703125 0.043795236945152284
# >12, 7/13, D_loss=0.157, G_loss=10.811
# 4.71032470703125 0.04520407319068909
# >12, 8/13, D_loss=0.378, G_loss=9.555
# 5.05330908203125 0.0450439453125
# >12, 9/13, D_loss=0.643, G_loss=8.773
# 5.139630859375 0.03944953680038452
# >12, 10/13, D_loss=0.457, G_loss=8.558
# 4.95445556640625 0.041744458675384524
# >12, 11/13, D_loss=0.650, G_loss=7.246
# 5.7986083984375005 0.04523063898086548
# >12, 12/13, D_loss=0.648, G_loss=8.152
# 5.00646142578125 0.04749971628189087
# >12, 13/13, D_loss=0.474, G_loss=8.872
# 4.23506494140625 0.0389476090669632
# >13, 1/13, D_loss=0.520, G_loss=7.598
# 4.9770029296875 0.04061710238456726
# >13, 2/13, D_loss=0.968, G_loss=7.728
# 5.4622744140625 0.04291848540306092
# >13, 3/13, D_loss=0.576, G_loss=7.485
# 5.7839736328125 0.04999928176403046
# >13, 4/13, D_loss=0.730, G_loss=7.962
# 5.41540234375 0.04916273951530457
# >13, 5/13, D_loss=0.622, G_loss=7.811
# 5.23859912109375 0.047223258018493655
# >13, 6/13, D_loss=0.423, G_loss=7.772
# 5.9697553710937505 0.05005744695663453
# >13, 7/13, D_loss=0.670, G_loss=9.023
# 4.269099609375 0.04282298386096955
# >13, 8/13, D_loss=0.467, G_loss=6.521
# 3.953205078125 0.052053654193878175
# >13, 9/13, D_loss=0.607, G_loss=6.191
# 4.337177734375 0.04480124115943909
# >13, 10/13, D_loss=0.695, G_loss=6.083
# 4.6174619140625 0.04914119839668274
# >13, 11/13, D_loss=0.507, G_loss=6.491
# 4.48551171875 0.04526079893112183
# >13, 12/13, D_loss=0.429, G_loss=6.184
# 3.5950310058593753 0.04524069726467133
# >13, 13/13, D_loss=0.553, G_loss=5.262
# 2.8990087890625 0.047101908922195436
# >14, 1/13, D_loss=0.410, G_loss=5.036
# 3.8770590820312503 0.04983843564987183
# >14, 2/13, D_loss=0.351, G_loss=6.070
# 3.551221435546875 0.05212618112564087
# >14, 3/13, D_loss=0.386, G_loss=5.778
# 3.0905615234375 0.05990708470344544
# >14, 4/13, D_loss=0.345, G_loss=5.286
# 3.94618115234375 0.05287798643112183
# >14, 5/13, D_loss=0.329, G_loss=6.255
# 2.3281152343750002 0.05634478330612183
# >14, 6/13, D_loss=0.304, G_loss=4.520
# 2.97087158203125 0.05775864720344544
# >14, 7/13, D_loss=0.379, G_loss=5.270
# 2.5071030273437502 0.056431668996810916
# >14, 8/13, D_loss=0.454, G_loss=4.691
# 3.296625244140625 0.0500236988067627
# >14, 9/13, D_loss=0.244, G_loss=5.721
# 2.473146728515625 0.059300321340560916
# >14, 10/13, D_loss=0.248, G_loss=4.804
# 3.104806396484375 0.05561667084693909
# >14, 11/13, D_loss=0.198, G_loss=6.038
# 3.17635302734375 0.05920769572257996
# >14, 12/13, D_loss=0.180, G_loss=6.331
# 3.05214404296875 0.05360251069068909
# >14, 13/13, D_loss=0.109, G_loss=6.754
# >Epoch: 15 Porosity match: 6% Var: 0.21 real: 99% fake: 100%
# 2.708090576171875 0.05908561944961548
# >15, 1/13, D_loss=0.119, G_loss=6.327
# 2.34136572265625 0.052183622121810914
# >15, 2/13, D_loss=0.095, G_loss=6.085
# 2.22802783203125 0.05507310032844544
# >15, 3/13, D_loss=0.121, G_loss=5.905
# 3.743081298828125 0.04958137273788452
# >15, 4/13, D_loss=0.104, G_loss=7.528
# 3.062427978515625 0.05331313610076904
# >15, 5/13, D_loss=0.124, G_loss=6.906
# 2.818333984375 0.05257712006568909
# >15, 6/13, D_loss=0.095, G_loss=5.906
# 2.4421494140625 0.05607981681823731
# >15, 7/13, D_loss=0.108, G_loss=6.141
# 2.940886962890625 0.055427104234695435
# >15, 8/13, D_loss=0.076, G_loss=6.841
# 2.369612060546875 0.052566349506378174
# >15, 9/13, D_loss=0.084, G_loss=6.505
# 3.16968701171875 0.04723331332206726
# >15, 10/13, D_loss=0.069, G_loss=6.835
# 3.17648046875 0.052228140830993655
# >15, 11/13, D_loss=0.110, G_loss=7.008
# 3.69254248046875 0.05424876213073731
# >15, 12/13, D_loss=0.100, G_loss=7.458
# 2.6751240234375 0.04966682195663452
# >15, 13/13, D_loss=0.080, G_loss=6.178
# 2.988880615234375 0.04800235331058503
# >16, 1/13, D_loss=0.084, G_loss=6.268
# 3.8598273925781252 0.04772877097129822
# >16, 2/13, D_loss=0.179, G_loss=7.103
# 2.820443115234375 0.042181754112243654
# >16, 3/13, D_loss=0.178, G_loss=5.901
# 4.3333701171875 0.05420209169387818
# >16, 4/13, D_loss=0.240, G_loss=7.534
# 4.256205078125 0.048110783100128174
# >16, 5/13, D_loss=0.162, G_loss=7.431
# 3.074905517578125 0.04455925226211548
# >16, 6/13, D_loss=0.226, G_loss=6.727
# 3.9284775390625 0.0427195817232132
# >16, 7/13, D_loss=0.280, G_loss=7.399
# 3.98265478515625 0.05524758696556092
# >16, 8/13, D_loss=0.237, G_loss=7.594

# %% [markdown]
# # Evaluate `Generator`

# %% [markdown]
# ## Compile gif

# %%
score_filename, geom_epoch_dirs, gif_filename, tmp_models_dir, models_dir, arrays_dir = get_filenames(dimension, simulation, simmetry, score)

with imageio.get_writer(gif_filename, mode='I') as writer:
    geom_filenames = os.listdir(geom_epoch_dirs)
    for geom_filename in geom_filenames:
        image = imageio.imread(geom_epoch_dirs+geom_filename)
        foo = cv2.putText(
                    image,
                    str((geom_filenames.index(geom_filename)+1)*5),
                    (5, 25),
                    cv2.FONT_HERSHEY_SIMPLEX,
                    1,
                    (255, 0, 0),
                    2)
        for i in range(3):
            # image = imageio.imread(geom_epoch_dirs+geom_filename)
            writer.append_data(image)

# %% [markdown]
# ## Visualize geometries

# %%
def check_unit(unit, desired_porosity, tol):
  labels = measure.label(unit,connectivity=1)
  main_label = 0
  main_label_count = 0
  passed = True

  element = unit[int(unit.shape[0]/2):,:int(unit.shape[0]/2)]

  for label in range(1,len(np.unique(labels))):
      label_count = np.where(labels==label)[0].shape[0]
      if label_count > main_label_count:
        main_label = label
        main_label_count = label_count

  void_count = 0

  for label in range(1,len(np.unique(labels))):
    if label not in [0,main_label]:
      void_count += np.where(labels==label)[0].shape[0]
      unit[np.where(labels==label)] = 0.

  porosity = get_porosity(unit)

  if porosity > desired_porosity - tol and porosity < desired_porosity + tol:
    for label in range(1,len(np.unique(labels))):
      if label not in [0,main_label]:
        unit[np.where(labels==label)] = 0.

    if unit[0,:].sum() > 0 and unit[:,0].sum() > 0:
      # check if there is connectivity right-left
      connections_rl = 0
      for i in range(unit.shape[0]):
        if (unit[i,0] == 1 and unit[i,-1] == 1):
          connections_rl += 1

      # check if there is connectivity top-bottom
      connections_tb = 0
      for j in range(unit.shape[1]):
        if (unit[0,j] == 1 and unit[-1,j] == 1):
          connections_tb += 1

      if connections_rl == 0 or connections_tb == 0:
        passed = False
      
    else:
      passed = False
      
  else:
    passed = False

  if passed:
    passed = False
    for i in range(element.shape[0]):
      if [element[i,0],element[element.shape[0]-1,element.shape[1]-i-1]]==[1,1]:
        passed = True

  return passed, element

def check_singularity(element, simmetry):
  passeds = [True for i in range(4)]

  # check singularities inside element
  for i in range(element.shape[0]-1):
    for j in range(element.shape[1]-1):
      # print(element[i:i+2,j:j+2])
      diag1 = list(element[i:i+2,j:j+2].diagonal())
      diag2 = list(np.fliplr(element[i:i+2,j:j+2]).diagonal())
      if (diag1 == [1,1] and diag2 == [0,0]) or (diag1 == [0,0] and diag2 == [1,1]):
        passeds[0] = False    

  # check singularities in element boundary and singularities in unit boundary
  if simmetry[1:] == '4':
    for j in range(element.shape[1]-1):
      arr = np.array([[element[element.shape[0]-j-1,element.shape[1]-1],element[element.shape[0]-j-2,element.shape[1]-1]],[element[0,j],element[0,j+1]]])
      diag1 = list(arr.diagonal())
      diag2 = list(np.fliplr(arr).diagonal())
      if (diag1 == [1,1] and diag2 == [0,0]) or (diag1 == [0,0] and diag2 == [1,1]):
        passeds[1] = False
      
      arr = np.array([[element[element.shape[0]-1,j],element[element.shape[0]-1,j+1]],[element[j,0],element[j+1,0]]])
      diag1 = list(arr.diagonal())
      diag2 = list(np.fliplr(arr).diagonal())
      if (diag1 == [1,1] and diag2 == [0,0]) or (diag1 == [0,0] and diag2 == [1,1]):
        passeds[2] = False
      if [element[0,0],element[element.shape[0]-1,element.shape[1]-1]] == [1, 0] or [element[0,0],element[element.shape[0]-1,element.shape[1]-1]] == [0, 1]:
        passeds[3] = False

  return passeds


def save_models(epoch_G,epoch_D,save,tmp_models_dir,models_dir):
  # select model
  G_files = os.listdir(tmp_models_dir+'/G/')
  for i in range(len(G_files)):
    G_file = G_files[i]
    if int(G_file.split('_')[1]) == epoch_G:
      G = load_model(tmp_models_dir+'/G/'+G_file)
      break

  D_files = os.listdir(tmp_models_dir+'/D/')
  for i in range(len(D_files)):
    D_file = D_files[i]
    if int(D_file.split('_')[1]) == epoch_D:
      D = load_model(tmp_models_dir+'/D/'+D_file, custom_objects={'custom_por_loss':porosity_loss(),'custom_val_loss':validity_loss(),'InstanceNormalization':InstanceNormalization()})
      break

  if save: 
      models_filename = os.listdir(models_dir)
      models_filename = ['_'.join(x.split('_')[1:]) for x in models_filename]
      if G_file not in models_filename:
        idx_model = len(models_filename)+1
        G.save(models_dir+'%04d_'%(idx_model)+G_file)
      else:
        # find idx of existing model
        idx_model = models_filename.index(G_file)+1
  else:
    idx_model = None
  return G, D, idx_model


def generate_geometries(test_size, rounds, idx_model, top, tol, desired_porosity, save, plot):
  idx = len(os.listdir(arrays_dir))+1
  for r in range(rounds):
    X_test = generate_input_G(input_G,test_size,sampling_method)
    geometries = G.predict(X_test,verbose = 0)
    size = geometries.shape[1]

    prepor_size = geometries.shape[0]
    
    if plot:
      fig,ax = plt.subplots(1,2);
      fig.set_size_inches((10,5));
      
      ax[0].set_title('Porosity Histogram')
      ax[0].set_ylabel('Frequency')
      porosities = 1-np.sum(geometries.round().reshape((test_size,int(size*size))),axis=-1)/int(size*size)
      sns.histplot(porosities,ax=ax[0],bins=32,stat="density");
    
    _, geometries = porosity_match(geometries, desired_porosity, tol)
    elements = []
    preval_size = geometries.shape[0]

    for i in range(len(geometries)):
      geom = geometries[i].reshape((size,size)).round()
      unit = create_unit(geom,size,simmetry)
      passed_connectivity,element = check_unit(unit, desired_porosity, tol)
      passed_singularity = check_singularity(element, simmetry)
      if passed_connectivity and all(passed_singularity):
        elements.append(element)

    geometries = np.array(elements)
    postval_size = geometries.shape[0]

    # Get scores
    scores = D.predict([geometries],verbose = 0)[0].ravel()

    if plot:
      ax[1].set_title('Score Histogram')
      ax[1].set_ylabel('Frequency')
      sns.histplot(scores,ax=ax[1],bins=32,stat="density");
      print('Avg porosity: %.2f. Avg score: %.2f Validity match: %.2f'%(porosities.mean(),scores.mean(),postval_size/preval_size))
      plt.show()

    top_idxs = np.argsort(-scores)[:top]

    for top_idx in top_idxs:
      elem = geometries[top_idx]
      unit = create_unit(elem.reshape((size,size)),size,simmetry)
      arrange = create_arrange(unit,3,3)
      
      if plot:
        print("Score: %.2f Porosity: %.2f"%(scores[top_idx],get_porosity(elem)))
        fig,ax = plt.subplots(1,3);
        fig.set_size_inches((15,5))
        
        ax[0].imshow(elem,cmap='Greys');
        ax[0].axis('off')
        
        ax[1].imshow(unit,cmap="Greys")
        ax[1].axis('off')

        ax[2].imshow(arrange,cmap="Greys")
        ax[2].axis('off')
        plt.show()

      if save:
        filename = arrays_dir+"%05d_model_%04d_porosity_%.4f.txt" % (idx, idx_model, 1.0-elem.ravel().sum()/(size*size))
        elem = elem.ravel()
        elem_ = np.zeros(elem.shape[0]+1)
        elem_[0] = int(np.sqrt(elem.shape[0]))
        elem_[1:] = elem[:]
        elem = elem_
        np.savetxt(filename, elem, delimiter='/n', fmt='%s')
        idx += 1

epoch_G = 60
epoch_D = 85
tol = 0.02
score = 'isotropy'
input_G = 128
simmetry = 'p4m'
sampling_method = 'normal'
top = 5
rounds = 20
test_size = 10000
desired_porosity=0.55
save = True
plot = not save

G,D,idx_model = save_models(epoch_G,epoch_D,save,tmp_models_dir,models_dir)
score_filename, geom_epoch_dirs, gif_filename, tmp_models_dir, models_dir, arrays_dir = get_filenames(dimension, simulation, simmetry, score)
generate_geometries(test_size, rounds, idx_model, top, tol, desired_porosity, save, plot)
