# %% [markdown]
# # Imports

# %%
import pandas as pd
import numpy as np
import os
import seaborn as sns
import matplotlib.pyplot as plt

# %% [markdown]
# # Extração de Dados

# %%
dados = pd.read_excel('Resultados OLABI.xlsx',sheet_name='Resultados individuais')
dados.columns = dados.iloc[0,:]
dados = dados.drop(['Width','Thickness'],axis=1)
dados = dados.drop([0,1])
dados = dados.drop(dados.columns[0],axis=1)
dados = dados.iloc[98:,:]
for i in range(6):
    dados = dados.drop(range(i*12+105,i*12+112))
    
dados = dados.drop(range(177,181))
dados['Direcao'] = dados['CP ID'].apply(lambda x: x[7:9])
dados['Plano'] = dados['Direcao'].apply(plano)
dados['Plano ID'] = dados['Plano'].apply(plano_id)
dados = dados.drop(['CP ID','Direcao'],axis=1)
dados
# Out:
# 0    Área S0 Modulus (Automatic Young's) Load at Fy ( 0.2 %) - LE  \
# 100  21.8066                        1378                    0.405
# 101  22.2238                        1383                    0.397
# 102  21.2423                        1362                    0.392
# 103  21.5404                        1412                    0.397
# 104  21.3542                        1351                    0.391
# 112  19.7911                        1459                    0.364
# 113  19.6486                        1432                    0.369
# 114  20.8265                        1362                    0.391
# 115  20.6451                        1373                    0.399
# 116  20.2261                        1358                    0.385
# 124  20.5448                        1428                    0.391
# 125  21.1696                        1330                    0.386
# 126  21.8557                        1422                    0.413
# 127  20.6601                        1381                    0.392
# 128  19.9947                        1394                    0.373
# 136  21.8941                        1437                    0.411
# 137  21.8658                        1388                    0.403
# 138  21.8615                        1403                    0.415
# 139  22.6065                        1359                    0.407
# 140  21.6241                        1335                    0.401
# 148  19.4042                        1586                    0.384
# 149  19.5165                        1571                    0.388
# 150  19.4314                        1546                    0.392
# 151   19.502                        1542                    0.386
# 152  19.6324                        1539                    0.412
# 160  18.5063                        1565                    0.376
# 161  18.5051                        1556                    0.388
# 162  18.5888                        1520                    0.386
# 163  18.2394                        1515                    0.368
# 164  18.5653                        1529                    0.375
# 172   20.691                        1520                    0.469
# 173    19.68                        1576                    0.431
# 174  19.9864                        1502                    0.439
# 175  19.9864                        1533                    0.406
# 176  21.2506                        1534                    0.459
#
# 0   Tensao em Fy ( 0.2 %) - LE Deformacao em  Fy ( 0.2 %) - LE Forca Max  \
# 100                    18.5724                           1.536     0.864
# 101                    17.8637                           1.521     0.864
# 102                    18.4538                           1.585     0.836
# 103                    18.4305                           1.515     0.855
# 104                    18.3102                           1.569     0.838
# 112                    18.3921                           1.448     0.808
# 113                      18.78                           1.529     0.785
# 114                    18.7742                           1.581      0.83
# 115                    19.3266                           1.613     0.834
# 116                    19.0348                           1.599     0.811
# 124                    19.0316                           1.547     0.827
# 125                    18.2337                           1.569     0.822
# 126                    18.8967                           1.568     0.866
# 127                    18.9738                           1.578     0.825
# 128                     18.655                           1.556     0.795
# 136                    18.7722                           1.505     0.889
# 137                    18.4306                           1.541     0.876
# 138                    18.9831                           1.629     0.884
# 139                    18.0037                            1.54     0.885
# 140                    18.5441                           1.618      0.87
# 148                    19.7895                           1.456      0.82
# 149                    19.8806                            1.49     0.825
# 150                    20.1735                            1.55     0.833
# 151                    19.7928                           1.485     0.812
# 152                    20.9858                           1.577     0.843
# 160                    20.3174                            1.49     0.788
# 161                    20.9672                            1.57     0.794
# 162                    20.7652                           1.557     0.804
# 163                    20.1761                           1.541     0.755
# 164                    20.1989                           1.561     0.786
# 172                    22.6669                           1.695     0.885
# 173                    21.9004                           1.594     0.854
# 174                    21.9649                            1.66      0.85
# 175                    20.3138                           1.531     0.857
# 176                    21.5994                           1.603     0.895
#
# 0   Tensao na Forca Max - LR Deformacao na Forca Max - LR  \
# 100                   39.621                       22.976
# 101                  38.8773                       23.239
# 102                  39.3555                       25.215
# 103                  39.6929                       23.809
# 104                  39.2429                        23.67
# 112                  40.8265                       26.312
# 113                   39.952                       23.331
# 114                  39.8531                       25.685
# 115                   40.397                       25.227
# 116                  40.0966                       26.405
# 124                  40.2536                       22.946
# 125                  38.8292                       24.461
# 126                  39.6236                        23.07
# 127                  39.9321                       23.731
# 128                  39.7606                       23.784
# 136                  40.6045                       26.897
# 137                  40.0625                       27.646
# 138                  40.4364                       25.884
# 139                  39.1481                       28.287
# 140                  40.2328                       27.556
# 148                  42.2588                       20.345
# 149                  42.2719                       21.677
# 150                  42.8687                       23.429
# 151                  41.6368                       18.787
# 152                  42.9393                       21.738
# 160                    42.58                       20.352
# 161                  42.9072                       21.235
# 162                  43.2519                       21.855
# 163                   41.394                       17.544
# 164                   42.337                       18.776
# 172                  42.7722                       22.656
# 173                  43.3943                       22.576
# 174                  42.5289                       22.909
# 175                  42.8792                       24.143
# 176                  42.1165                       21.604
#
# 0   Forca na Forca na Quebra - LQ Deformacao na Forca na Quebra - LQ    Plano  \
# 100                         0.733                             40.176  deitado
# 101                         0.675                             42.073  deitado
# 102                         0.766                             35.382  deitado
# 103                         0.738                             38.676  deitado
# 104                         0.763                             38.237  deitado
# 112                         0.739                             42.279  ao lado
# 113                         0.705                             44.631  ao lado
# 114                         0.717                             52.751  ao lado
# 115                         0.734                             43.128  ao lado
# 116                         0.729                             56.438  ao lado
# 124                         0.733                              38.68  deitado
# 125                         0.682                             45.461  deitado
# 126                         0.744                              37.17  deitado
# 127                         0.722                             38.398  deitado
# 128                         0.715                             36.951  deitado
# 136                         0.693                             52.864  ao lado
# 137                          0.71                             48.413  ao lado
# 138                         0.718                              46.05  ao lado
# 139                         0.734                             46.521  ao lado
# 140                         0.729                             45.756  ao lado
# 148                         0.814                             21.512    em pé
# 149                         0.786                             25.943    em pé
# 150                          0.82                             26.795    em pé
# 151                         0.803                             20.087    em pé
# 152                         0.812                             26.605    em pé
# 160                         0.784                             20.618    em pé
# 161                          0.78                             22.335    em pé
# 162                          0.79                             23.423    em pé
# 163                         0.752                             17.878    em pé
# 164                         0.776                             19.509    em pé
# 172                         0.791                             37.389       45
# 173                         0.706                              44.51       45
# 174                         0.761                              41.11       45
# 175                         0.729                              43.41       45
# 176                         0.823                             40.038       45
#
# 0    Plano ID
# 100         0
# 101         0
# 102         0
# 103         0
# 104         0
# 112         1
# 113         1
# 114         1
# 115         1
# 116         1
# 124         0
# 125         0
# 126         0
# 127         0
# 128         0
# 136         1
# 137         1
# 138         1
# 139         1
# 140         1
# 148         2
# 149         2
# 150         2
# 151         2
# 152         2
# 160         2
# 161         2
# 162         2
# 163         2
# 164         2
# 172         3
# 173         3
# 174         3
# 175         3
# 176         3

# %%
def plano(x):
    if x == 'XY' or x == 'YX':
        return 'deitado'
    elif x == 'XZ' or x == 'YZ':
        return 'ao lado'
    elif x == 'ZX' or x == 'ZY':
        return 'em pé'
    elif x == '45':
        return x
    
def plano_id(x):
    if x == 'deitado':
        return 0
    elif x == 'ao lado':
        return 1
    elif x == 'em pé':
        return 2
    elif x == '45':
        return 3

# %% [markdown]
# ## Exportar

# %%
dados.to_csv('Dados/Dados.csv',index=False)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-ad2ab4e95f8b> in <module>
# ----> 1 dados.to_csv('Dados/Dados.csv',index=False)
#
# NameError: name 'dados' is not defined
