# %%
import pandas as pd
import numpy as np
import seaborn as sns

# %%
df1 = pd.read_csv('Dados/Specimen_RawData_1.csv')
df1 = df1.drop(index = 0)
df1=df1.drop(['Strain 1'],axis=1)
df1.set_index('Time',inplace=True)
df1
# Out:
#          Extension        Load Tensile strain Tensile stress
# Time
# 0.00000    0.00000    -0.38219        0.00000       -0.00782
# 0.10000    0.00060     0.84913        0.00239        0.01736
# 0.20000    0.00383     2.00683        0.01531        0.04104
# 0.30000    0.00981     4.27740        0.03922        0.08747
# 0.40000    0.01525     8.44453        0.06099        0.17269
# ...            ...         ...            ...            ...
# 50.60000   2.10836  5566.80113        8.43343      113.84052
# 50.70000   2.11248  5573.14605        8.44993      113.97027
# 50.80000   2.11661  5579.16313        8.46643      114.09332
# 50.90000   2.12127  4077.00129        8.48509       83.37426
# 50.93800   2.12342     7.47733        8.49369        0.15291
#
# [511 rows x 4 columns]
