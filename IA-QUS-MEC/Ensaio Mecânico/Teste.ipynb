# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
data = pd.read_csv('Dados/Specimen_RawData_1.csv')
data = data.drop(index = 0)
data=data.drop(['Strain 1'],axis=1)

# %%
for col in data.columns:
    data[col] = data[col].apply(lambda x: float(x))
data
# Out:
#        Time  Extension        Load  Tensile strain  Tensile stress
# 1     0.000    0.00000    -0.38219         0.00000        -0.00782
# 2     0.100    0.00060     0.84913         0.00239         0.01736
# 3     0.200    0.00383     2.00683         0.01531         0.04104
# 4     0.300    0.00981     4.27740         0.03922         0.08747
# 5     0.400    0.01525     8.44453         0.06099         0.17269
# ..      ...        ...         ...             ...             ...
# 507  50.600    2.10836  5566.80113         8.43343       113.84052
# 508  50.700    2.11248  5573.14605         8.44993       113.97027
# 509  50.800    2.11661  5579.16313         8.46643       114.09332
# 510  50.900    2.12127  4077.00129         8.48509        83.37426
# 511  50.938    2.12342     7.47733         8.49369         0.15291
#
# [511 rows x 5 columns]

# %%
sns.jointplot("Time", "Extension", data=data, kind='reg',size = 10);
