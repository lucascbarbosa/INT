# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import os
# %matplotlib inline

# %%
path = 'C:/Users/lucas/Documents/GitHub/INT/Novo Ensaio US/Sinais/csv/'
listarq = os.listdir(path)
referencias = pd.DataFrame(columns = ['dt']+[str(i) for i in range(16000)])
amostras = pd.DataFrame(columns =  ['dt']+[str(i) for i in range(16000)])
listarq
# Out:
# ['osso23_p1_intacto_10MHz_rep1_med1.csv',
#  'osso23_p1_intacto_10MHz_rep1_med2.csv',
#  'osso23_p1_intacto_10MHz_rep1_med3.csv',
#  'osso23_p1_intacto_1MHz_rep1_med1.csv',
#  'osso23_p1_intacto_1MHz_rep1_med2.csv',
#  'osso23_p1_intacto_1MHz_rep1_med3.csv',
#  'osso23_p1_intacto_5MHz_rep1_med1.csv',
#  'osso23_p1_intacto_5MHz_rep1_med2.csv',
#  'osso23_p1_intacto_5MHz_rep1_med3.csv',
#  'osso25_p1_intacto_10MHz_rep1_med1.csv',
#  'osso25_p1_intacto_10MHz_rep1_med2.csv',
#  'osso25_p1_intacto_10MHz_rep1_med3.csv',
#  'osso25_p1_intacto_1MHz_rep1_med1.csv',
#  'osso25_p1_intacto_1MHz_rep1_med2.csv',
#  'osso25_p1_intacto_1MHz_rep1_med3.csv',
#  'osso25_p1_intacto_5MHz_rep1_med1.csv',
#  'osso25_p1_intacto_5MHz_rep1_med2.csv',
#  'osso25_p1_intacto_5MHz_rep1_med3.csv']

# %%
for i in range(len(listarq)):
    arq = listarq[i]
    df = pd.read_csv(path+arq,sep=';')
    dt_ref = float('.'.join(df['[0]'][1].split(',')))
    dt_am = float('.'.join(df['[1]'][1].split(',')))
    df['[0]'][3:16003] = df['[0]'][3:16003].apply(lambda x: '.'.join(x.split(','))).apply(lambda x: float(x))
    referencias.loc[i] = [dt_ref] + df['[0]'][3:16003].tolist()
    try:
        df['[1]'][3:16003] = df['[1]'][3:16003].apply(lambda x: '.'.join(x.split(','))).apply(lambda x: float(x))
        amostras.loc[i] = [dt_am] + df['[1]'][3:16003].tolist()
    except AttributeError:
        amostras.loc[i] = [dt_am] + df['[1]'][3:16003].tolist()
path2 = path[:len(path)-4]
referencias.to_csv(path2+'referencias.csv',index=False)
amostras.to_csv(path2+'amostras.csv',index=False)
# Out:
# c:\users\lucas\appdata\local\programs\python\python36\lib\site-packages\ipykernel_launcher.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# c:\users\lucas\appdata\local\programs\python\python36\lib\site-packages\ipykernel_launcher.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   if __name__ == '__main__':
